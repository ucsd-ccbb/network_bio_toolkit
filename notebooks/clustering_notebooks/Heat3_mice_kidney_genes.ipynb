# %% [markdown]
# # Space Flight Mice Kidney Gene Analysis
# ## Heat Propagation and Clustering Package
# ### Python 3 compatible version
#
# ----------------------
#
# Author: Mikayla Webster (13webstermj@gmail.com)
#
# Date: 19th May, 2018
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Define Analysis Preferences](#pref)
# 3. [Load Networks](#load)
# 4. [Localization](#local)
# 4. [Run Heat Propagation](#heat)
# 5. [Clustering](#cluster)
# 6. [Annotation](#annotation)
# 6. [Write to File](#write)

# %% [markdown]
# ## Background
# <a id='background'></a>

# %% [markdown]
# The Heat3 module provides tools to conduct an integrated network analysis of a set of differentially expressed genes (DEGs). The set of DEGs analyzed in this notebook come from an experiment performed by NASA called the [Rodent Research Project on the ISS](https://genelab-data.ndc.nasa.gov/genelab/accession/GLDS-48). The tissues sampled for this experiment were taken from the kidneys of mice who experienced space flight.
#
# The focus of this notebook is to show all available tools in the Heat Propogation and Clustering workflow (python 3 version), which includes an additional feature: annotation of clusters.

# %%
import sys
code_path = '../../network_bio_toolkit'
sys.path.append(code_path)

import importlib
import Heat3
importlib.reload(Heat3)

# uncomment if you have pip-installed 
#from network_bio_toolkit import create_graph
#from network_bio_toolkit import Heat3
#importlib.reload(Heat3)
# Out:
# <module 'Heat3' from '../../network_bio_toolkit\\Heat3.py'>

# %%
symbol = 'symbol'
entrez = 'entrez'

human = 'human'
mouse = 'mouse'

heat = Heat3.Heat(gene_type = symbol, species = mouse)

# %%
filename = '../../background_networks/10090.protein.links.v10.5.txt'
heat.load_STRING_links(filename, confidence_filter = 700)

print('\nNumber of interactions: ' + str(len(list(heat.DG_universe.edges()))))
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-8000...done.
# querying 8001-9000...done.
# querying 9001-10000...done.
# querying 10001-11000...done.
# querying 11001-12000...done.
# querying 12001-13000...done.
# querying 13001-13911...done.
# Finished.
# 70 input query terms found dup hits:
# 	[('ENSMUSP00000103671', 2), ('ENSMUSP00000087485', 2), ('ENSMUSP00000000574', 2), ('ENSMUSP000001267
# 410 input query terms found no hit:
# 	['ENSMUSP00000044573', 'ENSMUSP00000023462', 'ENSMUSP00000137380', 'ENSMUSP00000077813', 'ENSMUSP000
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
#
# Number of interactions: 368703

# %%
# for testing purposes only. Not necessary for analysis.
saved_DG_universe = heat.DG_universe
heat.DG_universe = saved_DG_universe

# %%
# load DEG file
DEG_filename = "../../DEG_databases/DE_SFvsGC_12_Kidney.csv"
heat.create_DEG_list(DEG_filename, p_value_filter = 0.02, sep = ',')

print('Number of DEG\'s: ' + str(len(heat.DEG_list)))
# Out:
# Number of DEG's: 7
# ../../network_bio_toolkit\create_graph.py:366: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   df = pd.DataFrame.from_csv(filename, sep = sep)

# %% [markdown]
# ## Localization
# <a id='local'></a>

# %%
numedges_list, numedges_rand, LCC_list, LCC_rand = heat.localization(num_reps = 250, 
                                                                     sample_frac = 0.8, 
                                                                     method = 'both', 
                                                                     plot = True)
# Out:
# C:\Users\m1web\Anaconda2\envs\ipykernel_py3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# test out plotting parameters with a smaller num_reps first.
numedges_list, numedges_rand, LCC_list, LCC_rand = heat.localization_full(num_reps = 200, 
                                                                          method = 'LCC', 
                                                                          label = 'focal genes',
                                                                          line_height = 1.2,
                                                                          legend_loc = 'upper left')
# Out:
# 0.0

# %% [markdown]
# ## Run Heat Propagation
# <a id='heat'></a>

# %%
heat.normalized_adj_matrix()

# %%
# for testing purposes only. Not necessary for analysis. 
saved_Wprime = heat.Wprime
heat.Wprime = saved_Wprime

# %%
heat.draw_heat_prop(num_nodes = 300,
#                  random_walk = False,
                  edge_width = 2,
                  edge_smooth_enabled = True,
                  edge_smooth_type = 'bezier',
                  node_size_multiplier = 5,
                  hover = False,
                  hover_connected_edges = False,
                  largest_connected_component = True,
                  physics_enabled = True,
                  node_font_size = 50,
                  graph_id = 1,
                  node_shadow_x = 6)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"id": "Col23a1", "border_width": 0, "degree": 41, "color": "rgba(256, 251, 0, 1.0)", "node_label": "", "node_size": 10, "node_shape": "dot", "title": "Col23a1<br/>heat = 0.00018", "x": 24.636314379280197, "y": 944.067457263077}, {"id": "Itgb2", "border_width": 0, "degree": 37, "color": "rgba(256, 178, 0, 1.0)", "node_label": "", "node_size": 10, "node_shape": "dot", "title": "Itgb2<br/>heat = 0.00114", "x": 131.49589433709053, "y": 690.411086132848}, {"id": "Crebbp", "border_width": 0, "degree": 67, "color": "rgba(256, 216, 0, 1.0)", "node_label": "", "node_size": 10, "node_shape": "dot", "title": "Crebbp<br/>heat = 0.00043", "x": 344.81340862238704, "y": 180.3857963484436}, {"id": "Cd44", "border_width": 0, "degree": 39, "color": "rgba(256, 213, 0, 1.0)", "node_label": "", "node_size": 10, "node_shape": "dot", "title": "Cd44<br/>heat = 0.00047", "x": 111.64504826781094, "y": 737.0525141812661}, {"id": "Actb", "border_width": 0, "degree": 44, "color": "rgba(256, 178, 0, 1.0)", "node_label": "", "node_size": 10, "node_shape": "dot", "title": "Actb<br/>heat = 0.00115", "x": 180.82756846698493, "y": 574.77627195064}, {"id": "Per3", "border_width": 0, "degree": 18, "color": "rgba(256, 101, 0, 1.0)", "node_label": "", "node_size": 10, "node_shape": "dot", "title": "Per3<br/>heat = 0.00803", "x": 280.5296412926723, "y": 336.9340696326738}, {"id": "Col18a1", "border_width": 0, "degree": 51, "color": "rgba(256, 220, 0, 1.0)", "node_label": "", "node_size": 10, "node_shape": "dot", "title": "Col18a1<br/>heat = 0.00039", "x": 56.504526593245885, "y": 860.1612153296188}, {"id": "Med10", "border_width": 0, "degree": 42, "color": "rgba(256, 232, 0, 1.0)", "node_label": "", "node_size": 10, "node_shape": "dot", "title": "Med10<br/>heat = 0.00028", "x": 388.2010348729871, "y": 65.97747928233481}, {"id": "Med14", "border_width": 0, "degree": 48, "color": "rgba(256, 223, 0, 1.0)", "node_label": "", "node_size": 10, "node_shape": "dot", "title": "Med14<br/>heat = 0.00037", "x": 378.74785656524807, "y": 88.13091317576706}, {"id": "Pik3r1", "border_width": 0, "degree": 29, "color": "rgba(256, 248, 0, 1.0)", "node_label": "", "node_size": 10, "node_shape": "dot", "title": "Pik3r1<br/>heat = 0.00019", "x": 192.67024682264176, "y": 541.8526088413225}, {"id": "Lamb3", "border_width": 0, "degree": 40, "color": "rgba(256, 173, 0, 1.0)", "node_label": "", "node_size": 10, "node_shape": "dot", "title": "Lamb3<br/>heat = 0.0013", "x": 95.77625727069731, "y": 775.3026161354974}, {"id": "Tnn", "border_width": 0, "degree": 24, "color": "rgba(256, 182, 0, 1.0)", "node_label": "", "node_size": 10, "node_shape": "dot", "title": "Tnn<br/>heat = 0.00102", "x": 106.56589197659696, "y": 751.0664750223076}, {"id": "Lamc2", "border_width": 0, "degree": 33, "color": "rgba(256, 178, 0, 1.0)", "node_label": "", "node_size": 10, "node_shape": "dot", "title": "Lamc2<br/>heat = 0.00114", "x": 107.51197369248656, "y": 747.3133716304296}, {"id": "F7", "border_width": 0, "degree": 10, "color": "rgba(256, 150, 0, 1.0)", "node_label": "", "node_size": 10, "node_shape": "dot", "title": "F7<br/>heat = 0.0023", "x": 241.1132539646113, "y": 426.0472606893103}, {"id": "Crtap", "border_width": 0, "degree": 41, "color": "rgba(256, 251, 0, 1.0)", "node_label": "", "node_size": 10, "node_shape": "dot", "title": "Crtap<br/>heat = 0.00018", "x": 17.918029508369205, "y": 960.1879083249523}, {"id": "Col8a1", "border_width": 0, "degree": 41, "color": "rgba(256, 252, 0, 1.0)", "node_label": "", "node_size": 10, "node_shape": "dot", "title": "Col8a1<br/>heat = 0.00017", "x": 25.176141638604875, "y": 942.7683912709738}, {"id": "Med29", "border_width": 0, "degree": 42, "color": "rgba(256, 233, 0, 1.0)", "node_label": "", "node_size": 10, "node_shape": "dot", "title": "Med29<br/>heat = 0.00028", "x": 41 ...

# %% [markdown]
# ## Clustering
# <a id='cluster'></a>

# %%
heat.draw_clustering(rad_positions = False,
                k = None,
                largest_connected_component = True,
                num_top_genes = 300,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                node_spacing = 700,
                node_size_multiplier = 10,
                physics_enabled = True,
                node_font_size = 50,
                graph_id = 2,
                edge_width = 2,
                edge_smooth_enabled = True,
                edge_smooth_type = 'bezier',
                hover = False,
                hover_connected_edges = False
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file2"];    frame.runVis([{"id": "Col23a1", "color": "#004033", "node_shape": "dot", "node_label": "", "node_full_label": "Col23a1", "title": "Col23a1<br/>cluster = 0", "x": 312.3195211621491, "y": 573.2064680680505, "border_width": 0, "degree": 3.0}, {"id": "Itgb2", "color": "#ff0044", "node_shape": "dot", "node_label": "", "node_full_label": "Itgb2", "title": "Itgb2<br/>cluster = 1", "x": 307.8706552357649, "y": 511.1513147213684, "border_width": 0, "degree": 3.0}, {"id": "Crebbp", "color": "#a300cc", "node_shape": "dot", "node_label": "", "node_full_label": "Crebbp", "title": "Crebbp<br/>cluster = 2", "x": 287.7820919119458, "y": 408.31453729698546, "border_width": 0, "degree": 3.0}, {"id": "Cd44", "color": "#ff0044", "node_shape": "dot", "node_label": "", "node_full_label": "Cd44", "title": "Cd44<br/>cluster = 1", "x": 306.95696479801217, "y": 519.6337360143289, "border_width": 0, "degree": 3.0}, {"id": "Actb", "color": "#ff0044", "node_shape": "dot", "node_label": "", "node_full_label": "Actb", "title": "Actb<br/>cluster = 1", "x": 296.35059844674146, "y": 489.48868473755454, "border_width": 0, "degree": 3.0}, {"id": "Per3", "color": "#3000b3", "node_shape": "dot", "node_label": "", "node_full_label": "Per3", "title": "Per3<br/>cluster = 3", "x": 178.35790181729374, "y": 525.9351263902873, "border_width": 0, "degree": 3.0}, {"id": "Col18a1", "color": "#004033", "node_shape": "dot", "node_label": "", "node_full_label": "Col18a1", "title": "Col18a1<br/>cluster = 0", "x": 310.04556705596497, "y": 551.6724754195506, "border_width": 0, "degree": 3.0}, {"id": "Med10", "color": "#a300cc", "node_shape": "dot", "node_label": "", "node_full_label": "Med10", "title": "Med10<br/>cluster = 2", "x": 285.0851011696099, "y": 405.12863211198294, "border_width": 0, "degree": 3.0}, {"id": "Med14", "color": "#a300cc", "node_shape": "dot", "node_label": "", "node_full_label": "Med14", "title": "Med14<br/>cluster = 2", "x": 294.54712173131253, "y": 401.4883963479018, "border_width": 0, "degree": 3.0}, {"id": "Pik3r1", "color": "#3000b3", "node_shape": "dot", "node_label": "", "node_full_label": "Pik3r1", "title": "Pik3r1<br/>cluster = 3", "x": 298.3436476683685, "y": 473.5480723522012, "border_width": 0, "degree": 3.0}, {"id": "Lamb3", "color": "#ff0044", "node_shape": "dot", "node_label": "", "node_full_label": "Lamb3", "title": "Lamb3<br/>cluster = 1", "x": 307.5585847273067, "y": 534.9484755606128, "border_width": 0, "degree": 3.0}, {"id": "Tnn", "color": "#ff0044", "node_shape": "dot", "node_label": "", "node_full_label": "Tnn", "title": "Tnn<br/>cluster = 1", "x": 310.8210496685032, "y": 527.8523717663927, "border_width": 0, "degree": 3.0}, {"id": "Lamc2", "color": "#ff0044", "node_shape": "dot", "node_label": "", "node_full_label": "Lamc2", "title": "Lamc2<br/>cluster = 1", "x": 309.9841782129199, "y": 527.9523633993293, "border_width": 0, "degree": 3.0}, {"id": "F7", "color": "#3000b3", "node_shape": "dot", "node_label": "", "node_full_label": "F7", "title": "F7<br/>cluster = 3", "x": 258.0913478042291, "y": 463.4946242937669, "border_width": 0, "degree": 3.0}, {"id": "Crtap", "color": "#004033", "node_shape": "dot", "node_label": "", "node_full_label": "Crtap", "title": "Crtap<br/>cluster = 0", "x": 312.40368210691895, "y": 574.5187955427314, "border_width": 0, "degree": 3.0}, {"id": "Col8a1", "color": "#004033", "node_shape": "dot", "node_label": "", "node_full_label": "Col8a1", "title": "Col8a1<br/>cluster = 0", "x": 312.1798177876566, "y": 571.3179891458543, "border_width": 0, "degree": 3.0}, {"id": "Med29", "color": "#a300cc", "node_shape": "dot", "node_label": "", "node_full_label": "Med29", "title": "Med29<br/>cluster = 2", "x": 291.3922153607864, "y": 402.2515918063483, "border_width": 0, "degree": 3.0}, {"id": "Vtn", "color": "#ff0044", "node_shape": "dot", "no ...

# %%
heat.draw_clustering(rad_positions = True,
                k = None,
                largest_connected_component = True,
                num_top_genes = 300,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                node_spacing = 700,
                node_size_multiplier = 10,
                node_font_size = 50,
                graph_id = 21,
                edge_width = 2,
                edge_smooth_enabled = True,
                edge_smooth_type = 'bezier',
                hover = False,
                r = 1.0,
                hover_connected_edges = False
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file21"];    frame.runVis([{"id": "Col23a1", "color": "#004033", "node_shape": "dot", "node_label": "", "node_full_label": "Col23a1", "title": "Col23a1<br/>cluster = 0", "x": 1213.4016059310745, "y": 5.364629623365764, "border_width": 0, "degree": 3.0}, {"id": "Itgb2", "color": "#ff0044", "node_shape": "dot", "node_label": "", "node_full_label": "Itgb2", "title": "Itgb2<br/>cluster = 1", "x": 664.5390974945608, "y": 743.506429523552, "border_width": 0, "degree": 3.0}, {"id": "Crebbp", "color": "#a300cc", "node_shape": "dot", "node_label": "", "node_full_label": "Crebbp", "title": "Crebbp<br/>cluster = 2", "x": -316.8089799668597, "y": 739.6182691915816, "border_width": 0, "degree": 3.0}, {"id": "Cd44", "color": "#ff0044", "node_shape": "dot", "node_label": "", "node_full_label": "Cd44", "title": "Cd44<br/>cluster = 1", "x": 669.4903245159569, "y": 738.2740428837029, "border_width": 0, "degree": 3.0}, {"id": "Actb", "color": "#ff0044", "node_shape": "dot", "node_label": "", "node_full_label": "Actb", "title": "Actb<br/>cluster = 1", "x": 610.920624746352, "y": 809.298246590553, "border_width": 0, "degree": 3.0}, {"id": "Per3", "color": "#3000b3", "node_shape": "dot", "node_label": "", "node_full_label": "Per3", "title": "Per3<br/>cluster = 3", "x": -248.87233882990242, "y": -177.5431834190388, "border_width": 0, "degree": 3.0}, {"id": "Col18a1", "color": "#004033", "node_shape": "dot", "node_label": "", "node_full_label": "Col18a1", "title": "Col18a1<br/>cluster = 0", "x": 1184.353417731416, "y": 37.94069623366932, "border_width": 0, "degree": 3.0}, {"id": "Med10", "color": "#a300cc", "node_shape": "dot", "node_label": "", "node_full_label": "Med10", "title": "Med10<br/>cluster = 2", "x": -352.6457725022986, "y": 793.4044810127414, "border_width": 0, "degree": 3.0}, {"id": "Med14", "color": "#a300cc", "node_shape": "dot", "node_label": "", "node_full_label": "Med14", "title": "Med14<br/>cluster = 2", "x": -373.4916054777487, "y": 821.8509900141229, "border_width": 0, "degree": 3.0}, {"id": "Pik3r1", "color": "#3000b3", "node_shape": "dot", "node_label": "", "node_full_label": "Pik3r1", "title": "Pik3r1<br/>cluster = 3", "x": -186.29469047958278, "y": -250.14776757823202, "border_width": 0, "degree": 3.0}, {"id": "Lamb3", "color": "#ff0044", "node_shape": "dot", "node_label": "", "node_full_label": "Lamb3", "title": "Lamb3<br/>cluster = 1", "x": 688.8584696980156, "y": 715.213464563176, "border_width": 0, "degree": 3.0}, {"id": "Tnn", "color": "#ff0044", "node_shape": "dot", "node_label": "", "node_full_label": "Tnn", "title": "Tnn<br/>cluster = 1", "x": 682.450578363034, "y": 722.5061102937213, "border_width": 0, "degree": 3.0}, {"id": "Lamc2", "color": "#ff0044", "node_shape": "dot", "node_label": "", "node_full_label": "Lamc2", "title": "Lamc2<br/>cluster = 1", "x": 679.8430556851803, "y": 724.7629476715307, "border_width": 0, "degree": 3.0}, {"id": "F7", "color": "#3000b3", "node_shape": "dot", "node_label": "", "node_full_label": "F7", "title": "F7<br/>cluster = 3", "x": -220.52331316904446, "y": -214.65181024851756, "border_width": 0, "degree": 3.0}, {"id": "Crtap", "color": "#004033", "node_shape": "dot", "node_label": "", "node_full_label": "Crtap", "title": "Crtap<br/>cluster = 0", "x": 1214.6411618372897, "y": 4.064957994185648, "border_width": 0, "degree": 3.0}, {"id": "Col8a1", "color": "#004033", "node_shape": "dot", "node_label": "", "node_full_label": "Col8a1", "title": "Col8a1<br/>cluster = 0", "x": 1212.0714772108845, "y": 6.776526713755763, "border_width": 0, "degree": 3.0}, {"id": "Med29", "color": "#a300cc", "node_shape": "dot", "node_label": "", "node_full_label": "Med29", "title": "Med29<br/>cluster = 2", "x": -356.70907300769437, "y": 795.3204337343527, "border_width": 0, "degree": 3.0}, {"id": "Vtn", "color": "#ff0044", "node_shape": "dot ...

# %%
heat.cluster_legend(cluster_size_cut_off = 5)

# %%
heat.draw_clustering(rad_positions = True,
                k = None,
                largest_connected_component = True,
                num_top_genes = 300,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                node_spacing = 700,
                node_size_multiplier = 10,
                node_font_size = 40,
                graph_id = 22,
                edge_width = 2,
                edge_smooth_enabled = True,
                edge_smooth_type = 'bezier',
                hover = False,
                r = 1.0,
                hover_connected_edges = False,
                color_lfc = True,
                vmin = -1,
                vmax = 1
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file22"];    frame.runVis([{"id": "Col23a1", "color": "rgba(256, 254, 254, 1.0)", "node_shape": "dot", "node_label": "", "node_full_label": "Col23a1", "title": "Col23a1<br/>cluster = 0", "x": 835.2359054977067, "y": 110.63069082750364, "border_width": 0, "degree": 3.0}, {"id": "Itgb2", "color": "rgba(256, 236, 236, 1.0)", "node_shape": "dot", "node_label": "", "node_full_label": "Itgb2", "title": "Itgb2<br/>cluster = 1", "x": 523.0076175716131, "y": 800.037569544539, "border_width": 0, "degree": 3.0}, {"id": "Crebbp", "color": "rgba(228, 228, 256, 1.0)", "node_shape": "dot", "node_label": "", "node_full_label": "Crebbp", "title": "Crebbp<br/>cluster = 2", "x": -411.1419942383539, "y": 725.2072114389388, "border_width": 0, "degree": 3.0}, {"id": "Cd44", "color": "rgba(256, 200, 200, 1.0)", "node_shape": "dot", "node_label": "", "node_full_label": "Cd44", "title": "Cd44<br/>cluster = 1", "x": 398.8786383578886, "y": 820.5661882459221, "border_width": 0, "degree": 3.0}, {"id": "Actb", "color": "rgba(256, 196, 196, 1.0)", "node_shape": "dot", "node_label": "", "node_full_label": "Actb", "title": "Actb<br/>cluster = 1", "x": 432.3286633834653, "y": 858.5077182851905, "border_width": 0, "degree": 3.0}, {"id": "Per3", "color": "rgba(0, 0, 256, 1.0)", "node_shape": "dot", "node_label": "", "node_full_label": "Per3", "title": "Per3<br/>cluster = 3", "x": -420.327139832777, "y": -115.85216084840795, "border_width": 0, "degree": 3.0}, {"id": "Col18a1", "color": "rgba(256, 200, 200, 1.0)", "node_shape": "dot", "node_label": "", "node_full_label": "Col18a1", "title": "Col18a1<br/>cluster = 0", "x": 862.704767369641, "y": 127.35681626374317, "border_width": 0, "degree": 3.0}, {"id": "Med10", "color": "rgba(254, 254, 256, 1.0)", "node_shape": "dot", "node_label": "", "node_full_label": "Med10", "title": "Med10<br/>cluster = 2", "x": -423.701906223118, "y": 755.8553835780273, "border_width": 0, "degree": 3.0}, {"id": "Med14", "color": "rgba(252, 252, 256, 1.0)", "node_shape": "dot", "node_label": "", "node_full_label": "Med14", "title": "Med14<br/>cluster = 2", "x": -422.7144182822874, "y": 753.9642789712655, "border_width": 0, "degree": 3.0}, {"id": "Pik3r1", "color": "rgba(218, 218, 256, 1.0)", "node_shape": "dot", "node_label": "", "node_full_label": "Pik3r1", "title": "Pik3r1<br/>cluster = 3", "x": -356.95545711697645, "y": -204.27050987053616, "border_width": 0, "degree": 3.0}, {"id": "Lamb3", "color": "rgba(256, 74, 74, 1.0)", "node_shape": "dot", "node_label": "", "node_full_label": "Lamb3", "title": "Lamb3<br/>cluster = 1", "x": 422.0390021922021, "y": 803.6716244025507, "border_width": 0, "degree": 3.0}, {"id": "Tnn", "color": "rgba(256, 184, 184, 1.0)", "node_shape": "dot", "node_label": "", "node_full_label": "Tnn", "title": "Tnn<br/>cluster = 1", "x": 458.5660086950931, "y": 797.8881514583953, "border_width": 0, "degree": 3.0}, {"id": "Lamc2", "color": "rgba(236, 236, 256, 1.0)", "node_shape": "dot", "node_label": "", "node_full_label": "Lamc2", "title": "Lamc2<br/>cluster = 1", "x": 248.60918800118563, "y": 841.3368677501118, "border_width": 0, "degree": 3.0}, {"id": "F7", "color": "rgba(256, 254, 254, 1.0)", "node_shape": "dot", "node_label": "", "node_full_label": "F7", "title": "F7<br/>cluster = 3", "x": -392.2622573498913, "y": -159.31117103459482, "border_width": 0, "degree": 3.0}, {"id": "Crtap", "color": "rgba(256, 228, 228, 1.0)", "node_shape": "dot", "node_label": "", "node_full_label": "Crtap", "title": "Crtap<br/>cluster = 0", "x": 837.0100716820161, "y": 110.63375128400496, "border_width": 0, "degree": 3.0}, {"id": "Col8a1", "color": "rgba(232, 232, 256, 1.0)", "node_shape": "dot", "node_label": "", "node_full_label": "Col8a1", "title": "Col8a1<br/>cluster = 0", "x": 828.948008065282, "y": 110.41181924309971, "border_width": 0, "degree": 3.0}, {"id":  ...

# %% [markdown]
# ## Annotation
# <a id='annotation'></a>

# %%
heat.draw_clustering_with_annotation(graph_id = 4,
                        num_nodes = 300,
                        annotation = True,
                        node_spacing = 700,
                        node_size_multiplier = 10,
                        physics_enabled = False,
                        node_font_size = 40,
                        color_lfc = True,
                        vmin = -1,
                        vmax = 1,
                        node_size = 7,
                        edge_smooth_enabled = True,
                        edge_smooth_type = 'bezier')
# Out:
# Annotating cluster 0 of 4...
# Annotating cluster 1 of 4...
# Annotating cluster 2 of 4...
# Annotating cluster 3 of 4...
# Annotating cluster 4 of 4...
# Done!
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file4"];    frame.runVis([{"id": "Col23a1", "color": "rgba(256, 254, 254, 1.0)", "node_shape": "dot", "node_label": "", "node_size": 7, "title": "Col23a1<br/>cluster = 0", "x": 539.2021213679395, "y": 165.9744771820165, "border_width": 0, "degree": 3.0}, {"id": "Itgb2", "color": "rgba(256, 236, 236, 1.0)", "node_shape": "dot", "node_label": "", "node_size": 7, "title": "Itgb2<br/>cluster = 1", "x": 309.2719633335237, "y": 537.8349887730084, "border_width": 0, "degree": 3.0}, {"id": "Crebbp", "color": "rgba(228, 228, 256, 1.0)", "node_shape": "dot", "node_label": "", "node_size": 7, "title": "Crebbp<br/>cluster = 2", "x": 297.67733743740814, "y": 252.54412420135742, "border_width": 0, "degree": 3.0}, {"id": "Cd44", "color": "rgba(256, 200, 200, 1.0)", "node_shape": "dot", "node_label": "", "node_size": 7, "title": "Cd44<br/>cluster = 1", "x": 362.9653731398823, "y": 495.7204197872206, "border_width": 0, "degree": 3.0}, {"id": "Actb", "color": "rgba(256, 196, 196, 1.0)", "node_shape": "dot", "node_label": "", "node_size": 7, "title": "Actb<br/>cluster = 1", "x": 434.64106462778955, "y": 476.7052335845011, "border_width": 0, "degree": 3.0}, {"id": "Per3", "color": "rgba(0, 0, 256, 1.0)", "node_shape": "dot", "node_label": "", "node_size": 7, "title": "Per3<br/>cluster = 3", "x": 204.26172462655148, "y": -127.09115935178781, "border_width": 0, "degree": 3.0}, {"id": "Col18a1", "color": "rgba(256, 200, 200, 1.0)", "node_shape": "dot", "node_label": "", "node_size": 7, "title": "Col18a1<br/>cluster = 0", "x": 573.7152638417167, "y": 164.36712571239735, "border_width": 0, "degree": 3.0}, {"id": "Med10", "color": "rgba(254, 254, 256, 1.0)", "node_shape": "dot", "node_label": "", "node_size": 7, "title": "Med10<br/>cluster = 2", "x": 371.0526504455275, "y": 223.35760408927825, "border_width": 0, "degree": 3.0}, {"id": "Med14", "color": "rgba(252, 252, 256, 1.0)", "node_shape": "dot", "node_label": "", "node_size": 7, "title": "Med14<br/>cluster = 2", "x": 402.5788523470457, "y": 210.6213696635333, "border_width": 0, "degree": 3.0}, {"id": "Pik3r1", "color": "rgba(218, 218, 256, 1.0)", "node_shape": "dot", "node_label": "", "node_size": 7, "title": "Pik3r1<br/>cluster = 3", "x": 55.8040301718209, "y": -59.888262988293626, "border_width": 0, "degree": 3.0}, {"id": "Lamb3", "color": "rgba(256, 74, 74, 1.0)", "node_shape": "dot", "node_label": "", "node_size": 7, "title": "Lamb3<br/>cluster = 1", "x": 335.8559567861235, "y": 506.07648093127534, "border_width": 0, "degree": 3.0}, {"id": "Tnn", "color": "rgba(256, 184, 184, 1.0)", "node_shape": "dot", "node_label": "", "node_size": 7, "title": "Tnn<br/>cluster = 1", "x": 331.2083490341502, "y": 511.04504114504533, "border_width": 0, "degree": 3.0}, {"id": "Lamc2", "color": "rgba(236, 236, 256, 1.0)", "node_shape": "dot", "node_label": "", "node_size": 7, "title": "Lamc2<br/>cluster = 1", "x": 336.4859149975202, "y": 510.1304705760925, "border_width": 0, "degree": 3.0}, {"id": "F7", "color": "rgba(256, 254, 254, 1.0)", "node_shape": "dot", "node_label": "", "node_size": 7, "title": "F7<br/>cluster = 3", "x": 130.7193086471527, "y": -91.41259361059271, "border_width": 0, "degree": 3.0}, {"id": "Crtap", "color": "rgba(256, 228, 228, 1.0)", "node_shape": "dot", "node_label": "", "node_size": 7, "title": "Crtap<br/>cluster = 0", "x": 532.1388070586073, "y": 165.62859241098303, "border_width": 0, "degree": 3.0}, {"id": "Col8a1", "color": "rgba(232, 232, 256, 1.0)", "node_shape": "dot", "node_label": "", "node_size": 7, "title": "Col8a1<br/>cluster = 0", "x": 542.7453658017963, "y": 166.10620615472365, "border_width": 0, "degree": 3.0}, {"id": "Med29", "color": "rgba(256, 208, 208, 1.0)", "node_shape": "dot", "node_label": "", "node_size": 7, "title": "Med29<br/>cluster = 2", "x": 369.2887657147992, "y": 224.05289006378166, "border ...

# %%
heat.draw_legend(vmin = -1, vmax = 1, label = 'log fold change')

# %% [markdown]
# ## Write to File
# <a id='write'></a>

# %%
#heat.write_cluster_table('cluster_table_3.csv')
