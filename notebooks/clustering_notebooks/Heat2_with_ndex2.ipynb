# %% [markdown]
# # Space Flight Mice Liver Gene Analysis
# ## Heat Propagation and Clustering Package
# ### Python 2 compatible version
#
# ----------------------
#
# Author: Mikayla Webster (13webstermj@gmail.com)
#
# Date: 2nd May, 2018
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Define Analysis Preferences](#pref)
# 3. [Load Networks](#load)
# 4. [Localization](#local)
# 4. [Run Heat Propagation](#heat)
# 5. [Clustering](#cluster)

# %% [markdown]
# ## Background
# <a id='background'></a>

# %% [markdown]
# The Heat2 module provides tools to conduct an integrated network analysis of a set of differentially expressed genes (DEGs). The set of DEGs analyzed in this notebook come from an experiment performed by NASA called the [Rodent Research Project on the ISS](https://genelab-data.ndc.nasa.gov/genelab/accession/GLDS-48). The tissues sampled for this experiment were taken from the livers of mice who experienced space flight.
#
# The focus of this notebook is to demonstrate how to load a background network from [NDEXbio](http://ndexbio.org/#/).

# %% [markdown]
# ## Import packages
# <a id='import'></a>

# %%
import sys
code_path = '../../network_bio_toolkit'
sys.path.append(code_path)

import Heat2
reload(Heat2)
# Out:
# <module 'Heat2' from '../../network_bio_toolkit\Heat2.pyc'>

# %% [markdown]
# ## Define Analysis Preferences
# <a id='pref'></a>

# %%
symbol = 'symbol'
entrez = 'entrez'

human = 'human'
mouse = 'mouse'

heat = Heat2.Heat(gene_type = symbol, species = mouse)

# %% [markdown]
# ## Load Networks
# <a id='load'></a>
#
# 1. Load DEG file
# 2. Load STRING background network

# %%
# load DEG file
DEG_filename = "../../DEG_databases/DE_CoeffspaceFlight - groundControl_glds48_20180312.csv"  
heat.create_DEG_list(DEG_filename, p_value_filter = 0.05, sep = ',')

print('Number of DEG\'s: ' + str(len(heat.DEG_list)))
# Out:
# Number of DEG's: 181
# ../../network_bio_toolkit\create_graph.py:366: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   df = pd.DataFrame.from_csv(filename, sep = sep)

# %%
# load our saved network from ndex rather than loading it ourselves
# equivalent to heat.load_STRING_links('../../background_networks/10090.protein.links.v10.5.txt', confidence_filter = 700)
heat.load_ndex_from_server(UUID = '76160faa-5d0f-11e8-a4bf-0ac135e8bacf', relabel_node_field = 'name')

print('\nNumber of interactions: ' + str(len(list(heat.DG_universe.edges()))))
# Out:
# Number of interactions: 369294

# %%
saved_DG_universe = heat.DG_universe
heat.DG_universe = saved_DG_universe

# %% [markdown]
# ## Localization ##
# <a id='local'></a>

# %%
numedges_list, numedges_rand, LCC_list, LCC_rand = heat.localization(num_reps = 250, 
                                                                     sample_frac = 0.8, 
                                                                     method = 'both', 
                                                                     plot = True)

# %%
# test out plotting parameters with a smaller num_reps first.
numedges_list, numedges_rand, LCC_list, LCC_rand = heat.localization_full(num_reps = 200, 
                                                                          method = 'LCC', 
                                                                          label = 'focal genes',
                                                                          line_height = 0.4,
                                                                          legend_loc = 'upper left')
# Out:
# 9.603429163007604e-14

# %% [markdown]
# ## Run Heat Propagation
# <a id='heat'></a>

# %%
Wprime = heat.normalized_adj_matrix() # optional. Saves time to do it once here.

# %%
saved_Wprime = heat.Wprime
heat.Wprime = saved_Wprime

# %%
heat.draw_heat_prop(num_nodes = 500,
                  random_walk = True,
                  edge_width = 2,
                  edge_smooth_enabled = True,
                  edge_smooth_type = 'bezier',
                  node_size_multiplier = 5,
                  hover = False,
                  hover_connected_edges = False,
                  largest_connected_component = True,
                  physics_enabled = True,
                  node_font_size = 40,
                  graph_id = 1,
                  node_shadow_x = 6)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"node_label": "Chic1", "node_shape": "triangle", "x": 592.3741295616504, "degree": 1, "node_size": 10, "color": "rgba(256, 28, 0, 1.0)", "title": "Chic1<br/>heat = 0.00431", "border_width": 2, "id": "Chic1", "y": 9.948757300259263}, {"node_label": "", "node_shape": "dot", "x": 497.3472803871415, "degree": 8, "node_size": 10, "color": "rgba(256, 238, 0, 1.0)", "title": "Sdsl<br/>heat = 0.00027", "border_width": 0, "id": "Sdsl", "y": 824.6450314614837}, {"node_label": "Cmpk2", "node_shape": "triangle", "x": 260.58639813616475, "degree": 29, "node_size": 10, "color": "rgba(256, 32, 0, 1.0)", "title": "Cmpk2<br/>heat = 0.00411", "border_width": 2, "id": "Cmpk2", "y": 503.02942618890245}, {"node_label": "", "node_shape": "dot", "x": 274.0031930393867, "degree": 13, "node_size": 10, "color": "rgba(256, 157, 0, 1.0)", "title": "Rbbp7<br/>heat = 0.00079", "border_width": 0, "id": "Rbbp7", "y": 417.1586815204627}, {"node_label": "", "node_shape": "dot", "x": 333.6975682808673, "degree": 15, "node_size": 10, "color": "rgba(256, 256, 0, 1.0)", "title": "Nampt<br/>heat = 0.00022", "border_width": 0, "id": "Nampt", "y": 636.8891265343814}, {"node_label": "", "node_shape": "dot", "x": 276.5058962110459, "degree": 16, "node_size": 10, "color": "rgba(256, 154, 0, 1.0)", "title": "Rbbp4<br/>heat = 0.00082", "border_width": 0, "id": "Rbbp4", "y": 439.34590971841635}, {"node_label": "Ccnf", "node_shape": "triangle", "x": 335.2162418168439, "degree": 27, "node_size": 10, "color": "rgba(256, 33, 0, 1.0)", "title": "Ccnf<br/>heat = 0.00403", "border_width": 2, "id": "Ccnf", "y": 414.702491346835}, {"node_label": "", "node_shape": "dot", "x": 854.0855902990662, "degree": 15, "node_size": 10, "color": "rgba(256, 240, 0, 1.0)", "title": "Hsd3b1<br/>heat = 0.00026", "border_width": 0, "id": "Hsd3b1", "y": 620.2811622083392}, {"node_label": "", "node_shape": "dot", "x": 765.9076670778652, "degree": 15, "node_size": 10, "color": "rgba(256, 195, 0, 1.0)", "title": "Cyp3a16<br/>heat = 0.00048", "border_width": 0, "id": "Cyp3a16", "y": 704.7744005301189}, {"node_label": "Klf1", "node_shape": "triangle", "x": 155.0077355428126, "degree": 2, "node_size": 10, "color": "rgba(256, 38, 0, 1.0)", "title": "Klf1<br/>heat = 0.00378", "border_width": 2, "id": "Klf1", "y": 302.54617835652033}, {"node_label": "", "node_shape": "dot", "x": 746.8948731174685, "degree": 2, "node_size": 10, "color": "rgba(256, 236, 0, 1.0)", "title": "Aqp11<br/>heat = 0.00028", "border_width": 0, "id": "Aqp11", "y": 942.8348338756026}, {"node_label": "", "node_shape": "dot", "x": 729.1213036578471, "degree": 2, "node_size": 10, "color": "rgba(256, 234, 0, 1.0)", "title": "Aqp12<br/>heat = 0.00029", "border_width": 0, "id": "Aqp12", "y": 944.1034834312669}, {"node_label": "", "node_shape": "dot", "x": 513.080569337599, "degree": 40, "node_size": 10, "color": "rgba(256, 211, 0, 1.0)", "title": "Bcl2<br/>heat = 0.00039", "border_width": 0, "id": "Bcl2", "y": 363.23651266408166}, {"node_label": "Avpr1a", "node_shape": "triangle", "x": 544.6853509749959, "degree": 3, "node_size": 10, "color": "rgba(256, 38, 0, 1.0)", "title": "Avpr1a<br/>heat = 0.00378", "border_width": 2, "id": "Avpr1a", "y": 193.1805427390403}, {"node_label": "", "node_shape": "dot", "x": 906.3444812193021, "degree": 5, "node_size": 10, "color": "rgba(256, 193, 0, 1.0)", "title": "Tecr<br/>heat = 0.00049", "border_width": 0, "id": "Tecr", "y": 780.3254309599286}, {"node_label": "", "node_shape": "dot", "x": 570.1325071702532, "degree": 18, "node_size": 10, "color": "rgba(256, 234, 0, 1.0)", "title": "Gys1<br/>heat = 0.00029", "border_width": 0, "id": "Gys1", "y": 498.85781918614026}, {"node_label": "", "node_shape": "dot", "x": 509.8596102473615, "degree": 54, "node_size": 10, "color": "rgba(256, 214, 0, 1.0)", "title": "Akt1<br/>he ...

# %% [markdown]
# ## Clustering
# <a id='cluster'></a>

# %% [markdown]
# Parameter information:
# - **G_DEG**: background network filtered by DEG list, output of load_STRING_to_digraph
# - **DG_universe**: full background network, output of create_graph.load_STRING_to_digraph
# - **seed_nodes**: list of DEG's, output of create_graph.create_DEG_list
# - **Wprime**: will calculate automatically of not specified, output of visualizations.normalized_adj_matrix
# - **num_top_genes**: number of genes to display in the output graph
# - **cluster_size_cut_off**: color clusters below this threshhold grey
# - **remove_stray_nodes**: remove custers below the cluster size cut off
# - **r**: increases spacing between clusters. recommended number between 0.5 and 4.0
# - **x_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **y_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **node_spacing**: recommended number between 500 and 2000
# - **node_size_multiplier**: as you scale node_spacing, scale this number. Recommended number between 5 and 25
# - **physics_enabled**: Nodes will bounce aroound when you click and drag them. Only set to True when number of nodes is 200 or less
# - **node_font_size**: as you scale node_spacing, scale this number. Recommended number between 20 and 50
# - **graph_id**: Allows rendering of multiple graphs in one notebook. Just make sure each graph has a unique id.

# %%
heat.draw_clustering(rad_positions = False,
                k = None,
                largest_connected_component = True,
                num_top_genes = 500,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                node_spacing = 700,
                node_size_multiplier = 10,
                physics_enabled = True,
                node_font_size = 40,
                graph_id = 2,
                edge_width = 2,
                edge_smooth_enabled = True,
                edge_smooth_type = 'bezier',
                hover = False,
                hover_connected_edges = False
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file2"];    frame.runVis([{"node_label": "Chic1", "node_shape": "triangle", "node_full_label": "Chic1", "degree": 3.0, "title": "Chic1<br/>cluster = 0", "color": "#004033", "x": 26.60313651505404, "border_width": 0, "id": "Chic1", "y": 445.04686730998577}, {"node_label": "", "node_shape": "dot", "node_full_label": "Sdsl", "degree": 3.0, "title": "Sdsl<br/>cluster = 1", "color": "#ff0044", "x": 644.3665367255278, "border_width": 0, "id": "Sdsl", "y": 337.366340748458}, {"node_label": "Cmpk2", "node_shape": "triangle", "node_full_label": "Cmpk2", "degree": 3.0, "title": "Cmpk2<br/>cluster = 2", "color": "#a300cc", "x": 395.10255474223305, "border_width": 0, "id": "Cmpk2", "y": 130.66942842118283}, {"node_label": "", "node_shape": "dot", "node_full_label": "Rbbp7", "degree": 3.0, "title": "Rbbp7<br/>cluster = 3", "color": "#3000b3", "x": 400.66255885902495, "border_width": 0, "id": "Rbbp7", "y": 175.9031787591844}, {"node_label": "", "node_shape": "dot", "node_full_label": "Nampt", "degree": 3.0, "title": "Nampt<br/>cluster = 2", "color": "#a300cc", "x": 468.4002027488008, "border_width": 0, "id": "Nampt", "y": 223.80456655110436}, {"node_label": "", "node_shape": "dot", "node_full_label": "Rbbp4", "degree": 3.0, "title": "Rbbp4<br/>cluster = 3", "color": "#3000b3", "x": 402.4696733335246, "border_width": 0, "id": "Rbbp4", "y": 171.84137658777246}, {"node_label": "Ccnf", "node_shape": "triangle", "node_full_label": "Ccnf", "degree": 3.0, "title": "Ccnf<br/>cluster = 4", "color": "#000c59", "x": 331.82243911377833, "border_width": 0, "id": "Ccnf", "y": 122.24620197324623}, {"node_label": "", "node_shape": "dot", "node_full_label": "Hsd3b1", "degree": 3.0, "title": "Hsd3b1<br/>cluster = 5", "color": "#00d9ca", "x": 410.1253638517163, "border_width": 0, "id": "Hsd3b1", "y": 570.4974137184182}, {"node_label": "Adssl1", "node_shape": "triangle", "node_full_label": "Adssl1", "degree": 3.0, "title": "Adssl1<br/>cluster = 2", "color": "#a300cc", "x": 521.4090324965437, "border_width": 0, "id": "Adssl1", "y": 205.8528172891706}, {"node_label": "Klf1", "node_shape": "triangle", "node_full_label": "Klf1", "degree": 3.0, "title": "Klf1<br/>cluster = 3", "color": "#3000b3", "x": 257.6701893378839, "border_width": 0, "id": "Klf1", "y": 417.29085057277666}, {"node_label": "", "node_shape": "dot", "node_full_label": "Aqp11", "degree": 3.0, "title": "Aqp11<br/>cluster = 6", "color": "#00f281", "x": 414.1960797021783, "border_width": 0, "id": "Aqp11", "y": 652.8495345598336}, {"node_label": "", "node_shape": "dot", "node_full_label": "Aqp12", "degree": 3.0, "title": "Aqp12<br/>cluster = 6", "color": "#00f281", "x": 370.8430472065708, "border_width": 0, "id": "Aqp12", "y": 666.7876384357078}, {"node_label": "", "node_shape": "dot", "node_full_label": "Bcl2", "degree": 3.0, "title": "Bcl2<br/>cluster = 7", "color": "#00660e", "x": 240.25480814571497, "border_width": 0, "id": "Bcl2", "y": 240.53082160962822}, {"node_label": "Avpr1a", "node_shape": "triangle", "node_full_label": "Avpr1a", "degree": 3.0, "title": "Avpr1a<br/>cluster = 7", "color": "#00660e", "x": 190.4108988541637, "border_width": 0, "id": "Avpr1a", "y": 373.04394598233625}, {"node_label": "", "node_shape": "dot", "node_full_label": "Tecr", "degree": 3.0, "title": "Tecr<br/>cluster = 8", "color": "#88ff00", "x": 565.1425210262444, "border_width": 0, "id": "Tecr", "y": 589.3628066552695}, {"node_label": "", "node_shape": "dot", "node_full_label": "Gys1", "degree": 3.0, "title": "Gys1<br/>cluster = 3", "color": "#3000b3", "x": 343.352043346482, "border_width": 0, "id": "Gys1", "y": 332.3687960323957}, {"node_label": "", "node_shape": "dot", "node_full_label": "Akt1", "degree": 3.0, "title": "Akt1<br/>cluster = 7", "color": "#00660e", "x": 252.178766785415, "border_width": 0, "id": "Akt1", "y": 256.7893365329084}, {"node_ ...

# %%
heat.draw_clustering(num_top_genes = 500,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                r = 1,
                node_spacing = 600,
                node_size_multiplier = 4,
                physics_enabled = False,
                node_font_size = 15,
                graph_id = 3,
                node_shadow_x = 6,
                color_lfc = True,
                largest_connected_component = True,
                vmin = -5,
                vmax = 5
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file3"];    frame.runVis([{"node_label": "Chic1", "node_shape": "triangle", "node_full_label": "Chic1", "degree": 3.0, "title": "Chic1<br/>cluster = 0", "color": "rgba(256, 218, 218, 1.0)", "x": 700.2108333876811, "border_width": 0, "id": "Chic1", "y": 551.2765791238871}, {"node_label": "", "node_shape": "dot", "node_full_label": "Sdsl", "degree": 3.0, "title": "Sdsl<br/>cluster = 1", "color": "rgba(256, 238, 238, 1.0)", "x": 666.1324129882371, "border_width": 0, "id": "Sdsl", "y": 383.76153154288926}, {"node_label": "Cmpk2", "node_shape": "triangle", "node_full_label": "Cmpk2", "degree": 3.0, "title": "Cmpk2<br/>cluster = 2", "color": "rgba(256, 174, 174, 1.0)", "x": 601.4705332349054, "border_width": 0, "id": "Cmpk2", "y": 837.2509047492752}, {"node_label": "", "node_shape": "dot", "node_full_label": "Rbbp7", "degree": 3.0, "title": "Rbbp7<br/>cluster = 3", "color": "rgba(246, 246, 256, 1.0)", "x": 581.6954317145835, "border_width": 0, "id": "Rbbp7", "y": 837.8907448249483}, {"node_label": "", "node_shape": "dot", "node_full_label": "Nampt", "degree": 3.0, "title": "Nampt<br/>cluster = 2", "color": "rgba(246, 246, 256, 1.0)", "x": 629.7009594023351, "border_width": 0, "id": "Nampt", "y": 754.9457488099865}, {"node_label": "", "node_shape": "dot", "node_full_label": "Rbbp4", "degree": 3.0, "title": "Rbbp4<br/>cluster = 3", "color": "rgba(252, 252, 256, 1.0)", "x": 561.3143412189597, "border_width": 0, "id": "Rbbp4", "y": 847.9299587116466}, {"node_label": "Ccnf", "node_shape": "triangle", "node_full_label": "Ccnf", "degree": 3.0, "title": "Ccnf<br/>cluster = 4", "color": "rgba(256, 202, 202, 1.0)", "x": 235.9196418678235, "border_width": 0, "id": "Ccnf", "y": 981.2153785393534}, {"node_label": "", "node_shape": "dot", "node_full_label": "Hsd3b1", "degree": 3.0, "title": "Hsd3b1<br/>cluster = 5", "color": "rgba(256, 254, 254, 1.0)", "x": -34.263251446507624, "border_width": 0, "id": "Hsd3b1", "y": 569.8309021002966}, {"node_label": "Adssl1", "node_shape": "triangle", "node_full_label": "Adssl1", "degree": 3.0, "title": "Adssl1<br/>cluster = 2", "color": "rgba(226, 226, 256, 1.0)", "x": 553.5726042626766, "border_width": 0, "id": "Adssl1", "y": 763.9658395879032}, {"node_label": "Klf1", "node_shape": "triangle", "node_full_label": "Klf1", "degree": 3.0, "title": "Klf1<br/>cluster = 3", "color": "rgba(206, 206, 256, 1.0)", "x": 716.2082105252379, "border_width": 0, "id": "Klf1", "y": 841.21133343112}, {"node_label": "", "node_shape": "dot", "node_full_label": "Aqp11", "degree": 3.0, "title": "Aqp11<br/>cluster = 6", "color": "rgba(252, 252, 256, 1.0)", "x": 12.976984371016709, "border_width": 0, "id": "Aqp11", "y": 420.00055440153676}, {"node_label": "", "node_shape": "dot", "node_full_label": "Aqp12", "degree": 3.0, "title": "Aqp12<br/>cluster = 6", "color": "rgba(256, 254, 254, 1.0)", "x": -30.292408135999672, "border_width": 0, "id": "Aqp12", "y": 392.5525150436052}, {"node_label": "", "node_shape": "dot", "node_full_label": "Bcl2", "degree": 3.0, "title": "Bcl2<br/>cluster = 7", "color": "rgba(256, 236, 236, 1.0)", "x": -208.76317267410556, "border_width": 0, "id": "Bcl2", "y": 518.5888987305391}, {"node_label": "Avpr1a", "node_shape": "triangle", "node_full_label": "Avpr1a", "degree": 3.0, "title": "Avpr1a<br/>cluster = 7", "color": "rgba(256, 218, 218, 1.0)", "x": -77.9992847257186, "border_width": 0, "id": "Avpr1a", "y": 465.70992817458614}, {"node_label": "", "node_shape": "dot", "node_full_label": "Tecr", "degree": 3.0, "title": "Tecr<br/>cluster = 8", "color": "rgba(254, 254, 256, 1.0)", "x": -530.5559578151591, "border_width": 0, "id": "Tecr", "y": 2.1141032874515853}, {"node_label": "", "node_shape": "dot", "node_full_label": "Gys1", "degree": 3.0, "title": "Gys1<br/>cluster = 3", "color": "rgba(256, 250, 250, 1.0)", "x": 551.3301444867412, "border_w ...
