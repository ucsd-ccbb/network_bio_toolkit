# %% [markdown]
# # Space Flight Mice Liver Gene Analysis
# ## Heat Propagation and Clustering Package
# ### Python 2 compatible version
#
# ----------------------
#
# Author: Mikayla Webster (13webstermj@gmail.com)
#
# Date: 2nd May, 2018
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Define Analysis Preferences](#pref)
# 3. [Load Networks](#load)
# 4. [Localization](#local)
# 4. [Run Heat Propagation](#heat)
# 5. [Clustering](#cluster)

# %% [markdown]
# ## Background
# <a id='background'></a>

# %% [markdown]
# The Heat2 module provides tools to conduct an integrated network analysis of a set of differentially expressed genes (DEGs). The set of DEGs analyzed in this notebook come from an experiment performed by NASA called the [Rodent Research Project on the ISS](https://genelab-data.ndc.nasa.gov/genelab/accession/GLDS-48). The tissues sampled for this experiment were taken from the livers of mice who experienced space flight.
#
# The focus of this notebook is to demonstrate how to load a background network from [NDEXbio](http://ndexbio.org/#/).

# %% [markdown]
# ## Import packages
# <a id='import'></a>

# %%
# uncomment if you have not pip-installed 

import sys
code_path = '../../network_bio_toolkit'
sys.path.append(code_path)

import Heat2
reload(Heat2)

import pandas as pd
import numpy as np

#from network_bio_toolkit import Heat2

# %% [markdown]
# ## Define Analysis Preferences
# <a id='pref'></a>

# %%
symbol_or_entrez='symbol'

species='mouse'


heat = Heat2.Heat(gene_type = symbol_or_entrez, species = species)

# %% [markdown]
# ## Load Networks
# <a id='load'></a>
#
# 1. Load DEG file
# 2. Load STRING background network

# %%
# load DEG file
DEG_filename = "../../DEG_files/DE_CoeffspaceFlight - groundControl_glds48_20180312.csv"  
heat.create_DEG_list(DEG_filename, p_value_filter = 0.05, sep = ',')

print('Number of DEG\'s: ' + str(len(heat.DEG_list)))
# Out:
# Number of DEG's: 181

# %%
# load our saved network from ndex rather than loading it ourselves
# equivalent to heat.load_STRING_links('../../background_networks/10090.protein.links.v10.5.txt', confidence_filter = 700)
heat.load_ndex_from_server(UUID = '76160faa-5d0f-11e8-a4bf-0ac135e8bacf', relabel_node_field = 'name')
# Out:
# Number of interactions: 369294

# %%
print('\nNumber of nodes: ' + str(len(list(heat.DG_universe.nodes()))))
print('\nNumber of interactions: ' + str(len(list(heat.DG_universe.edges()))))
# Out:
# Number of nodes: 13442
#
# Number of interactions: 369294

# %%
saved_DG_universe = heat.DG_universe
heat.DG_universe = saved_DG_universe

# %% [markdown]
# ## Localization ##
# <a id='local'></a>

# %%
numedges_list, numedges_rand, LCC_list, LCC_rand = heat.localization(num_reps = 250, 
                                                                     sample_frac = 0.8, 
                                                                     method = 'both', 
                                                                     plot = True)

# %%
# test out plotting parameters with a smaller num_reps first.
numedges_list, numedges_rand, LCC_list, LCC_rand = heat.localization_full(num_reps = 200, 
                                                                          method = 'LCC', 
                                                                          label = 'focal genes',
                                                                          line_height = 0.4,
                                                                          legend_loc = 'upper left')
# Out:
# 1.3322676295501878e-15

# %% [markdown]
# ## Run Heat Propagation
# <a id='heat'></a>

# %%
Wprime = heat.normalized_adj_matrix() # optional. Saves time to do it once here.

# %%
saved_Wprime = heat.Wprime
heat.Wprime = saved_Wprime

# %%
heat.draw_heat_prop(num_nodes = 300,
                  edge_width = 2,
                  edge_smooth_enabled = True,
                  edge_smooth_type = 'bezier',
                  node_size_multiplier = 5,
                  hover = False,
                  hover_connected_edges = False,
                  largest_connected_component = True,
                  physics_enabled = True,
                  node_font_size = 40,
                  graph_id = 1,
                  node_shadow_x = 6)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"node_label": "Dnmt3b", "node_shape": "triangle", "x": 429.4918696897904, "degree": 2, "node_size": 10, "color": "rgba(256, 44, 0, 1.0)", "title": "Dnmt3b<br/>heat = 0.00382", "border_width": 2, "id": "Dnmt3b", "y": 20.14955217064268}, {"node_label": "", "node_shape": "dot", "x": 61.932961848087835, "degree": 9, "node_size": 10, "color": "rgba(256, 171, 0, 1.0)", "title": "Cyp2b9<br/>heat = 0.00092", "border_width": 0, "id": "Cyp2b9", "y": 677.2182822565518}, {"node_label": "", "node_shape": "dot", "x": 490.7735514690422, "degree": 26, "node_size": 10, "color": "rgba(256, 218, 0, 1.0)", "title": "Cul1<br/>heat = 0.00054", "border_width": 0, "id": "Cul1", "y": 563.8556861205429}, {"node_label": "Cmpk2", "node_shape": "triangle", "x": 690.149256870176, "degree": 12, "node_size": 10, "color": "rgba(256, 37, 0, 1.0)", "title": "Cmpk2<br/>heat = 0.00411", "border_width": 2, "id": "Cmpk2", "y": 717.0156537216385}, {"node_label": "", "node_shape": "dot", "x": 414.61465454236435, "degree": 10, "node_size": 10, "color": "rgba(256, 185, 0, 1.0)", "title": "Rbbp7<br/>heat = 0.00079", "border_width": 0, "id": "Rbbp7", "y": 232.56891277520788}, {"node_label": "", "node_shape": "dot", "x": 431.75974140363246, "degree": 11, "node_size": 10, "color": "rgba(256, 182, 0, 1.0)", "title": "Rbbp4<br/>heat = 0.00082", "border_width": 0, "id": "Rbbp4", "y": 214.04724414569384}, {"node_label": "Ccnf", "node_shape": "triangle", "x": 506.4366639968957, "degree": 17, "node_size": 10, "color": "rgba(256, 39, 0, 1.0)", "title": "Ccnf<br/>heat = 0.00403", "border_width": 2, "id": "Ccnf", "y": 509.4211916595501}, {"node_label": "Pdgfc", "node_shape": "triangle", "x": 907.7871170070853, "degree": 2, "node_size": 10, "color": "rgba(256, 44, 0, 1.0)", "title": "Pdgfc<br/>heat = 0.0038", "border_width": 2, "id": "Pdgfc", "y": 208.31011559088137}, {"node_label": "Rnf144b", "node_shape": "triangle", "x": 449.05850823464783, "degree": 14, "node_size": 10, "color": "rgba(256, 41, 0, 1.0)", "title": "Rnf144b<br/>heat = 0.00392", "border_width": 2, "id": "Rnf144b", "y": 580.6298770849618}, {"node_label": "Tars", "node_shape": "triangle", "x": 475.21779971302266, "degree": 1, "node_size": 10, "color": "rgba(256, 44, 0, 1.0)", "title": "Tars<br/>heat = 0.0038", "border_width": 2, "id": "Tars", "y": 0.0}, {"node_label": "", "node_shape": "dot", "x": 340.5436992766421, "degree": 19, "node_size": 10, "color": "rgba(256, 179, 0, 1.0)", "title": "Acly<br/>heat = 0.00085", "border_width": 0, "id": "Acly", "y": 310.13952517467817}, {"node_label": "", "node_shape": "dot", "x": 249.8499914813582, "degree": 10, "node_size": 10, "color": "rgba(256, 166, 0, 1.0)", "title": "Nr1d2<br/>heat = 0.00097", "border_width": 0, "id": "Nr1d2", "y": 451.75715821860155}, {"node_label": "", "node_shape": "dot", "x": 211.2279880980061, "degree": 3, "node_size": 10, "color": "rgba(256, 186, 0, 1.0)", "title": "Asap1<br/>heat = 0.00078", "border_width": 0, "id": "Asap1", "y": 89.69375653089163}, {"node_label": "Asap2", "node_shape": "triangle", "x": 178.14581269189193, "degree": 3, "node_size": 10, "color": "rgba(256, 42, 0, 1.0)", "title": "Asap2<br/>heat = 0.0039", "border_width": 2, "id": "Asap2", "y": 116.14756648346328}, {"node_label": "", "node_shape": "dot", "x": 163.77575588804154, "degree": 3, "node_size": 10, "color": "rgba(256, 199, 0, 1.0)", "title": "Asap3<br/>heat = 0.00067", "border_width": 0, "id": "Asap3", "y": 132.22719537956613}, {"node_label": "", "node_shape": "dot", "x": 525.1264927226852, "degree": 15, "node_size": 10, "color": "rgba(256, 248, 0, 1.0)", "title": "Irf3<br/>heat = 0.00039", "border_width": 0, "id": "Irf3", "y": 655.1357638598955}, {"node_label": "", "node_shape": "dot", "x": 816.4860395906383, "degree": 9, "node_size": 10, "color": "rgba(256, 180, 0, 1.0)", "title": ...

# %% [markdown]
# ## Clustering
# <a id='cluster'></a>

# %% [markdown]
# Parameter information:
# - **G_DEG**: background network filtered by DEG list, output of load_STRING_to_digraph
# - **DG_universe**: full background network, output of create_graph.load_STRING_to_digraph
# - **seed_nodes**: list of DEG's, output of create_graph.create_DEG_list
# - **Wprime**: will calculate automatically of not specified, output of visualizations.normalized_adj_matrix
# - **num_top_genes**: number of genes to display in the output graph
# - **cluster_size_cut_off**: color clusters below this threshhold grey
# - **remove_stray_nodes**: remove custers below the cluster size cut off
# - **r**: increases spacing between clusters. recommended number between 0.5 and 4.0
# - **x_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **y_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **node_spacing**: recommended number between 500 and 2000
# - **node_size_multiplier**: as you scale node_spacing, scale this number. Recommended number between 5 and 25
# - **physics_enabled**: Nodes will bounce aroound when you click and drag them. Only set to True when number of nodes is 200 or less
# - **node_font_size**: as you scale node_spacing, scale this number. Recommended number between 20 and 50
# - **graph_id**: Allows rendering of multiple graphs in one notebook. Just make sure each graph has a unique id.

# %%
heat.draw_clustering(rad_positions = False,
                k = None,
                largest_connected_component = True,
                num_top_genes = 300,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                node_spacing = 700,
                node_size_multiplier = 10,
                physics_enabled = True,
                node_font_size = 40,
                graph_id = 2,
                edge_width = 2,
                edge_smooth_enabled = True,
                edge_smooth_type = 'bezier',
                hover = False,
                hover_connected_edges = False
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file2"];    frame.runVis([{"node_label": "Dnmt3b", "node_shape": "triangle", "node_full_label": "Dnmt3b", "degree": 3.0, "title": "Dnmt3b<br/>cluster = 0", "color": "#004033", "x": 612.634725875093, "border_width": 0, "id": "Dnmt3b", "y": 152.3599678652505}, {"node_label": "", "node_shape": "dot", "node_full_label": "Cyp2b9", "degree": 3.0, "title": "Cyp2b9<br/>cluster = 1", "color": "#ff0044", "x": 12.291543604691274, "border_width": 0, "id": "Cyp2b9", "y": 366.8001864566527}, {"node_label": "Cmpk2", "node_shape": "triangle", "node_full_label": "Cmpk2", "degree": 3.0, "title": "Cmpk2<br/>cluster = 3", "color": "#3000b3", "x": 197.39679858942725, "border_width": 0, "id": "Cmpk2", "y": 270.8187935992289}, {"node_label": "", "node_shape": "dot", "node_full_label": "Rbbp7", "degree": 3.0, "title": "Rbbp7<br/>cluster = 0", "color": "#004033", "x": 513.7286116565024, "border_width": 0, "id": "Rbbp7", "y": 253.13429551572003}, {"node_label": "", "node_shape": "dot", "node_full_label": "Rbbp4", "degree": 3.0, "title": "Rbbp4<br/>cluster = 0", "color": "#004033", "x": 527.607539985075, "border_width": 0, "id": "Rbbp4", "y": 249.71517580783254}, {"node_label": "Ccnf", "node_shape": "triangle", "node_full_label": "Ccnf", "degree": 3.0, "title": "Ccnf<br/>cluster = 2", "color": "#a300cc", "x": 364.49835530467686, "border_width": 0, "id": "Ccnf", "y": 334.51632735064294}, {"node_label": "Mcm10", "node_shape": "triangle", "node_full_label": "Mcm10", "degree": 3.0, "title": "Mcm10<br/>cluster = 0", "color": "#004033", "x": 607.8052443621505, "border_width": 0, "id": "Mcm10", "y": 228.69189013074342}, {"node_label": "Rnf144b", "node_shape": "triangle", "node_full_label": "Rnf144b", "degree": 3.0, "title": "Rnf144b<br/>cluster = 2", "color": "#a300cc", "x": 378.55261243006714, "border_width": 0, "id": "Rnf144b", "y": 276.7310074235628}, {"node_label": "Tars", "node_shape": "triangle", "node_full_label": "Tars", "degree": 3.0, "title": "Tars<br/>cluster = 5", "color": "#00d9ca", "x": 700.0, "border_width": 0, "id": "Tars", "y": 404.7723762507849}, {"node_label": "", "node_shape": "dot", "node_full_label": "Nr1d1", "degree": 3.0, "title": "Nr1d1<br/>cluster = 6", "color": "#00f281", "x": 505.10879961679717, "border_width": 0, "id": "Nr1d1", "y": 377.3006054359987}, {"node_label": "", "node_shape": "dot", "node_full_label": "Nr1d2", "degree": 3.0, "title": "Nr1d2<br/>cluster = 6", "color": "#00f281", "x": 516.0851867596042, "border_width": 0, "id": "Nr1d2", "y": 361.8472395792373}, {"node_label": "", "node_shape": "dot", "node_full_label": "Asap1", "degree": 3.0, "title": "Asap1<br/>cluster = 4", "color": "#000c59", "x": 0.0, "border_width": 0, "id": "Asap1", "y": 320.20686196615594}, {"node_label": "Asap2", "node_shape": "triangle", "node_full_label": "Asap2", "degree": 3.0, "title": "Asap2<br/>cluster = 4", "color": "#000c59", "x": 0.7596709375061776, "border_width": 0, "id": "Asap2", "y": 301.3174524966565}, {"node_label": "", "node_shape": "dot", "node_full_label": "Asap3", "degree": 3.0, "title": "Asap3<br/>cluster = 4", "color": "#000c59", "x": 4.838057274426413, "border_width": 0, "id": "Asap3", "y": 284.2340880684893}, {"node_label": "", "node_shape": "dot", "node_full_label": "Irf3", "degree": 3.0, "title": "Irf3<br/>cluster = 3", "color": "#3000b3", "x": 271.5206178792085, "border_width": 0, "id": "Irf3", "y": 253.66982376499175}, {"node_label": "", "node_shape": "dot", "node_full_label": "Plg", "degree": 3.0, "title": "Plg<br/>cluster = 4", "color": "#000c59", "x": 251.38047266887523, "border_width": 0, "id": "Plg", "y": 556.602299496426}, {"node_label": "", "node_shape": "dot", "node_full_label": "Irf1", "degree": 3.0, "title": "Irf1<br/>cluster = 3", "color": "#3000b3", "x": 144.4623234883326, "border_width": 0, "id": "Irf1", "y": 223.4711316647317}, {"node_label":  ...

# %%
heat.draw_clustering(num_top_genes = 300,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                r = 1,
                node_spacing = 600,
                node_size_multiplier = 4,
                physics_enabled = False,
                node_font_size = 15,
                graph_id = 3,
                node_shadow_x = 6,
                color_lfc = True,
                largest_connected_component = True,
                vmin = -5,
                vmax = 5
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file3"];    frame.runVis([{"node_label": "Dnmt3b", "node_shape": "triangle", "node_full_label": "Dnmt3b", "degree": 3.0, "title": "Dnmt3b<br/>cluster = 0", "color": "rgba(256, 182, 182, 1.0)", "x": 653.7157935174749, "border_width": 0, "id": "Dnmt3b", "y": 122.71084234948908}, {"node_label": "", "node_shape": "dot", "node_full_label": "Cyp2b9", "degree": 3.0, "title": "Cyp2b9<br/>cluster = 1", "color": "rgba(234, 234, 256, 1.0)", "x": 1084.862508435126, "border_width": 0, "id": "Cyp2b9", "y": 463.0083011991853}, {"node_label": "Cmpk2", "node_shape": "triangle", "node_full_label": "Cmpk2", "degree": 3.0, "title": "Cmpk2<br/>cluster = 3", "color": "rgba(256, 174, 174, 1.0)", "x": 271.1712417822765, "border_width": 0, "id": "Cmpk2", "y": 747.0200915130456}, {"node_label": "", "node_shape": "dot", "node_full_label": "Rbbp7", "degree": 3.0, "title": "Rbbp7<br/>cluster = 0", "color": "rgba(246, 246, 256, 1.0)", "x": 699.1395739792802, "border_width": 0, "id": "Rbbp7", "y": 200.3492368662593}, {"node_label": "", "node_shape": "dot", "node_full_label": "Rbbp4", "degree": 3.0, "title": "Rbbp4<br/>cluster = 0", "color": "rgba(252, 252, 256, 1.0)", "x": 686.7557114671444, "border_width": 0, "id": "Rbbp4", "y": 194.3192967940321}, {"node_label": "Ccnf", "node_shape": "triangle", "node_full_label": "Ccnf", "degree": 3.0, "title": "Ccnf<br/>cluster = 2", "color": "rgba(256, 202, 202, 1.0)", "x": 459.66657154680297, "border_width": 0, "id": "Ccnf", "y": 806.8876801676168}, {"node_label": "Mcm10", "node_shape": "triangle", "node_full_label": "Mcm10", "degree": 3.0, "title": "Mcm10<br/>cluster = 0", "color": "rgba(192, 192, 256, 1.0)", "x": 711.3102100136849, "border_width": 0, "id": "Mcm10", "y": 100.66129536101933}, {"node_label": "Rnf144b", "node_shape": "triangle", "node_full_label": "Rnf144b", "degree": 3.0, "title": "Rnf144b<br/>cluster = 2", "color": "rgba(256, 218, 218, 1.0)", "x": 447.18052082947213, "border_width": 0, "id": "Rnf144b", "y": 838.407024047463}, {"node_label": "Tars", "node_shape": "triangle", "node_full_label": "Tars", "degree": 3.0, "title": "Tars<br/>cluster = 5", "color": "rgba(256, 216, 216, 1.0)", "x": -221.3749679951141, "border_width": 0, "id": "Tars", "y": 900.0}, {"node_label": "", "node_shape": "dot", "node_full_label": "Nr1d1", "degree": 3.0, "title": "Nr1d1<br/>cluster = 6", "color": "rgba(170, 170, 256, 1.0)", "x": -566.9745706620166, "border_width": 0, "id": "Nr1d1", "y": 315.6087202588528}, {"node_label": "", "node_shape": "dot", "node_full_label": "Nr1d2", "degree": 3.0, "title": "Nr1d2<br/>cluster = 6", "color": "rgba(190, 190, 256, 1.0)", "x": -575.1095241971065, "border_width": 0, "id": "Nr1d2", "y": 348.40753133123087}, {"node_label": "", "node_shape": "dot", "node_full_label": "Asap1", "degree": 3.0, "title": "Asap1<br/>cluster = 4", "color": "rgba(256, 248, 248, 1.0)", "x": -252.06102481700455, "border_width": 0, "id": "Asap1", "y": 656.9666260568979}, {"node_label": "Asap2", "node_shape": "triangle", "node_full_label": "Asap2", "degree": 3.0, "title": "Asap2<br/>cluster = 4", "color": "rgba(256, 208, 208, 1.0)", "x": -257.6533879070153, "border_width": 0, "id": "Asap2", "y": 685.3905256791023}, {"node_label": "", "node_shape": "dot", "node_full_label": "Asap3", "degree": 3.0, "title": "Asap3<br/>cluster = 4", "color": "rgba(256, 254, 254, 1.0)", "x": -262.6572016338306, "border_width": 0, "id": "Asap3", "y": 700.2827685222948}, {"node_label": "", "node_shape": "dot", "node_full_label": "Irf3", "degree": 3.0, "title": "Irf3<br/>cluster = 3", "color": "rgba(248, 248, 256, 1.0)", "x": 227.0831690349169, "border_width": 0, "id": "Irf3", "y": 807.4096349412185}, {"node_label": "", "node_shape": "dot", "node_full_label": "Plg", "degree": 3.0, "title": "Plg<br/>cluster = 4", "color": "rgba(254, 254, 256, 1.0)", "x": -46.98408203648942, " ...

# %% [markdown]
# # Write the cluster results to a file

# %%
heat.write_cluster_table('cluster_results.csv')

# %% [markdown]
# # Gprofiler annotation of clusters

# %%
from gprofiler import GProfiler
gp = GProfiler("MyToolName/0.1")

# %%
partition = pd.Series(heat.node_to_cluster)
partition.value_counts()
# Out:
# 4     52
# 5     39
# 3     36
# 2     34
# 6     24
# 0     20
# 1     17
# 10    12
# 7     11
# 11     5
# 8      4
# 9      3
# dtype: int64

# %%
import os
if not os.path.isdir('gprofile_clusters_top300'):
    os.mkdir('gprofile_clusters_top300')

for focal_cluster in partition.value_counts().index.tolist():
    focal_genes = partition[partition==focal_cluster].index.tolist()

    gp_results = pd.DataFrame(gp.gprofile(focal_genes,custom_bg = partition.index.tolist(),correction_method=gp.THR_FDR))

    gp_results.columns = ["query.number", "significant", "p.value", "term.size",
                          "query.size", "overlap.size", "recall", "precision",
                          "term.id", "domain", "subgraph.number", "term.name",
                          "relative.depth", "intersection"]
    print(gp_results.head())
    
    writer = pd.ExcelWriter('gprofile_clusters_top300/cluster_'+str(focal_cluster)+'.xlsx')
    gp_results.to_excel(writer)
    writer.save()
# Out:
#    query.number  significant       p.value  term.size  query.size  \
# 0             1         True  1.140000e-08         51          48
# 1             1         True  1.140000e-08         34          48
# 2             1         True  1.870000e-08         25          48
# 3             1         True  1.870000e-08         17          48
# 4             1         True  1.960000e-08         19          48
#
#    overlap.size  recall  precision     term.id domain  subgraph.number  \
# 0            30   0.625      0.588  GO:0051128     BP                1
# 1            24   0.500      0.706  GO:0022610     BP                1
# 2            20   0.417      0.800  GO:0051130     BP                1
# 3            16   0.333      0.941  GO:0030036     BP                1
# 4            17   0.354      0.895  GO:0097435     BP                1
#
#                                            term.name  relative.depth  \
# 0      regulation of cellular component organization               1
# 1                                biological adhesion               1
# 2  positive regulation of cellular component orga...               1
# 3                    actin cytoskeleton organization               1
# 4                  supramolecular fiber organization               1
#
#                                         intersection
# 0  BCAR1,TNK2,NGEF,CDC42,ASAP3,MAPK1,SERPINE1,CXC...
# 1  BCAR1,CDC42,PKP1,HSP90AB1,SERPINE1,CXCL12,CD81...
# 2  CDC42,MAPK1,SERPINE1,CXCL12,MAPK14,C3,RAC2,RAC...
# 3  BCAR1,CDC42,ASAP3,CXCL12,RAC2,RAC1,EPHA1,ZYX,A...
# 4  BCAR1,CDC42,PKP1,ASAP3,HSP90AB1,CXCL12,RAC2,RA...
#    query.number  significant       p.value  term.size  query.size  \
# 0             1         True  2.980000e-13         54          31
# 1             1         True  8.320000e-09         76          31
# 2             1         True  1.030000e-08         13          37
# 3             1         True  3.750000e-07         11          37
# 4             1         True  4.200000e-07         76          37
#
#    overlap.size  recall  precision             term.id domain  \
# 0            28   0.903      0.519          KEGG:01100    keg
# 1            28   0.903      0.368  REAC:R-HSA-1430728    rea
# 2            13   0.351      1.000          GO:0006520     BP
# 3            11   0.297      1.000          GO:1901605     BP
# 4            29   0.784      0.382          GO:0044281     BP
#
#    subgraph.number                              term.name  relative.depth  \
# 0                1                     Metabolic pathways               1
# 1                1                             Metabolism               1
# 2                1  cellular amino acid metabolic process               1
# 3                1     alpha-amino acid metabolic process               1
# 4                1       small molecule metabolic process               1
#
#                                         intersection
# 0  CPS1,ALDH18A1,RDH11,ACACB,CAD,ACSBG1,SQLE,HMGC...
# 1  CPS1,ALDH18A1,RDH11,ACACB,CAD,ACSBG1,SQLE,HMGC...
# 2  CPS1,ALDH18A1,CAD,TARS,KYAT3,HDC,AZIN2,ALDH4A1...
# 3  CPS1,ALDH18A1,CAD,KYAT3,HDC,AZIN2,ALDH4A1,GMPS...
# 4  CPS1,ALDH18A1,RDH11,ACACB,CAD,ACSBG1,SQLE,HMGC...
#    query.number  significant       p.value  term.size  query.size  \
# 0             1         True  2.720000e-18         26          28
# 1             1         True  1.930000e-17         31          28
# 2             1         True  3.170000e-16         30          28
# 3             1         True  7.120000e-15         42          28
# 4             1         True  7.120000e-15         42          28
#
#    overlap.size  recall  precision     term.id domain  subgraph.number  \
# 0            22   0.786      0.846  GO:0051607     BP                1
# 1            23   0.821      0.742  GO:0009615     BP                1
# 2            22   0.786      0.733  GO:0098542     BP                1
# 3            24   0.857      0.571  GO:0051707     BP                1
# 4            24   0.857      0.571  GO:0043207     BP                1
#
#                               term.name  relative.depth  \
# 0             defense response to virus               1
# 1                     response to virus               1
# 2    defense response to other organism               1
# 3            response to other organism               1
# 4  response to external biotic stimulus               1
#
#                                         intersection
# 0  RNF125,DDX58,DHX58,OAS2,IFIH1,STAT1,IFIT3,IFIT...
# 1  RNF125,DDX58,DHX58,OAS2,IFIH1,STAT1,IFIT3,IFIT...
# 2  RNF125,DDX58,DHX58,OAS2,IFIH1,STAT1,IFIT3,IFIT...
# 3  RNF125,DDX58,DHX58,OAS2,IFIH1,STAT1,IFIT3,IFIT...
# 4  RNF125,DDX58,DHX58,OAS2,IFIH1,STAT1,IFIT3,IFIT...
#    query.number  significant       p.value  term.size  query.size  \
# 0             1         True  1.590000e-16         18          28
# 1             1         True  1.590000e-16         18          28
# 2             1         True  1.160000e-14         32          31
# 3             1         True  1.740000e-14         33          31
# 4             1         True  1.740000e-14         37          31
#
#    overlap.size  recall  precision            term.id domain  subgraph.number  \
# 0            18   0.643      1.000  REAC:R-HSA-983169    rea                1
# 1            18   0.643      1.000  REAC:R-HSA-983168    rea                1
# 2            23   0.742      0.719         GO:0016567     BP                1
# 3            23   0.742      0.697         GO:0032446     BP                1
# 4            24   0.774      0.649         GO:0070647     BP                1
#
#                                            term.name  relative.depth  \
# 0  Class I MHC mediated antigen processing & pres...               1
# 1  Antigen processing: Ubiquitination & Proteasom...               1
# 2                             protein ubiquitination               1
# 3  protein modification by small protein conjugation               1
# 4  protein modification by small protein conjugat...               1
#
#                                         intersection
# 0  FBXL3,NEDD4L,CUL1,NEDD4,FBXW11,ITCH,SMURF2,RNF...
# 1  FBXL3,NEDD4L,CUL1,NEDD4,FBXW11,ITCH,SMURF2,RNF...
# 2  FBXL3,NEDD4L,CUL1,NEDD4,FBXW11,ITCH,RNF24,RIPK...
# 3  FBXL3,NEDD4L,CUL1,NEDD4,FBXW11,ITCH,RNF24,RIPK...
# 4  FBXL3,NEDD4L,CUL1,NEDD4,FBXW11,ITCH,RNF24,RIPK...
#    query.number  significant       p.value  term.size  query.size  \
# 0             1         True  2.770000e-12         13          24
# 1             1         True  2.770000e-12         24          24
# 2             1         True  2.770000e-12         27          24
# 3             1         True  1.160000e-10         17          19
# 4             1         True  1.410000e-08         15          24
#
#    overlap.size  recall  precision     term.id domain  subgraph.number  \
# 0            13   0.542      1.000  GO:0032922     BP                1
# 1            17   0.708      0.708  GO:0007623     BP                1
# 2            18   0.750      0.667  GO:0048511     BP                1
# 3            13   0.684      0.765  KEGG:04710    keg                1
# 4            12   0.500      0.800  GO:0042752     BP                1
#
#                                  term.name  relative.depth  \
# 0  circadian regulation of gene expression               1
# 1                         circadian rhythm               1
# 2                         rhythmic process               1
# 3                         Circadian rhythm               1
# 4           regulation of circadian rhythm               1
#
#                                         intersection
# 0  CRY1,PER3,RORA,CRY2,BHLHE41,NR1D1,PER2,ARNTL,C...
# 1  CRY1,PER3,RORA,GSK3B,DBP,TIMELESS,CRY2,BHLHE41...
# 2  CRY1,PER3,RORA,GSK3B,DBP,TIMELESS,CRY2,BHLHE41...
# 3  CRY1,PER3,RORA,CRY2,BHLHE41,NR1D1,PER2,ARNTL,C...
# 4  CRY1,PER3,RORA,TIMELESS,CRY2,NR1D1,PER2,ARNTL,...
#    query.number  significant   p.value  term.size  query.size  overlap.size  \
# 0             1         True  0.000002         15          19            10
# 1             1         True  0.000002         15          19            10
# 2             1         True  0.000006         21          19            11
# 3             1         True  0.000029         19          19            10
# 4             1         True  0.000133         13          19             8
#
#    recall  precision     term.id domain  subgraph.number  \
# 0   0.526      0.667  GO:0044454     CC                1
# 1   0.526      0.667  GO:0000228     CC                1
# 2   0.579      0.524  GO:0005694     CC                1
# 3   0.526      0.526  GO:0044427     CC                1
# 4   0.421      0.615  GO:0000790     CC                1
#
#                  term.name  relative.depth  \
# 0  nuclear chromosome part               1
# 1       nuclear chromosome               1
# 2               chromosome               1
# 3         chromosomal part               1
# 4        nuclear chromatin               1
#
#                                         intersection
# 0  MCM10,CBX7,RBBP7,KLF1,PPARD,SMARCA4,PCNA,NCOR1...
# 1  MCM10,CBX7,RBBP7,KLF1,PPARD,SMARCA4,PCNA,NCOR1...
# 2  MCM10,CBX7,EP300,RBBP7,KLF1,PPARD,SMARCA4,PCNA...
# 3  MCM10,CBX7,RBBP7,KLF1,PPARD,SMARCA4,PCNA,NCOR1...
# 4     CBX7,RBBP7,KLF1,PPARD,SMARCA4,NCOR1,RBBP4,RXRA
#    query.number  significant   p.value  term.size  query.size  overlap.size  \
# 0             1         True  0.000528          8           9             5
# 1             1         True  0.001390         11           9             5
# 2             1         True  0.001390         11           9             5
# 3             1         True  0.002790          3           9             3
# 4             1         True  0.002790          3           9             3
#
#    recall  precision     term.id domain  subgraph.number  \
# 0   0.556      0.625  GO:0022804     MF                1
# 1   0.556      0.455  GO:0022857     MF                1
# 2   0.556      0.455  GO:0005215     MF                1
# 3   0.333      1.000  GO:0008509     MF                1
# 4   0.333      1.000  GO:0008514     MF                1
#
#                                           term.name  relative.depth  \
# 0         active transmembrane transporter activity               1
# 1                transmembrane transporter activity               1
# 2                              transporter activity               1
# 3          anion transmembrane transporter activity               1
# 4  organic anion transmembrane transporter activity               1
#
#                           intersection
# 0  ABCA2,ABCG2,SLC22A7,SLC22A8,SLC16A5
# 1  ABCA2,ABCG2,SLC22A7,SLC22A8,SLC16A5
# 2  ABCA2,ABCG2,SLC22A7,SLC22A8,SLC16A5
# 3              SLC22A7,SLC22A8,SLC16A5
# 4              SLC22A7,SLC22A8,SLC16A5
#    query.number  significant       p.value  term.size  query.size  \
# 0             1         True  1.850000e-08         11          11
# 1             1         True  1.530000e-07         17           9
# 2             1         True  4.880000e-07         32          12
# 3             1         True  1.520000e-06          6          12
# 4             1         True  2.710000e-06          5          11
#
#    overlap.size  recall  precision           term.id domain  subgraph.number  \
# 0             8   0.727      0.727        KEGG:00052    keg                1
# 1             8   0.889      0.471  REAC:R-HSA-71387    rea                1
# 2            11   0.917      0.344        GO:0005975     BP                1
# 3             6   0.500      1.000        GO:0006012     BP                1
# 4             5   0.455      1.000        KEGG:00520    keg                1
#
#                                      term.name  relative.depth  \
# 0                         Galactose metabolism               1
# 1                  Metabolism of carbohydrates               1
# 2               carbohydrate metabolic process               1
# 3                  galactose metabolic process               1
# 4  Amino sugar and nucleotide sugar metabolism               1
#
#                                         intersection
# 0    B4GALT1,GALK1,GALE,B4GALT2,GALM,LALBA,UGP2,GALT
# 1    B4GALT1,GALK1,GYS2,GALE,B4GALT2,LALBA,UGP2,GALT
# 2  B4GALT1,GALK1,GYS2,GALE,B4GALT2,GALM,GALK2,LAL...
# 3                 B4GALT1,GALK1,GALE,GALM,GALK2,GALT
# 4                          GALK1,UGDH,GALE,UGP2,GALT
#    query.number  significant       p.value  term.size  query.size  \
# 0             1         True  9.410000e-07          5           9
# 1             1         True  1.480000e-06          5           9
# 2             1         True  2.350000e-06         19           9
# 3             1         True  4.350000e-06          6           9
# 4             1         True  5.010000e-06         23           9
#
#    overlap.size  recall  precision           term.id domain  subgraph.number  \
# 0             5   0.556      1.000  REAC:R-HSA-70326    rea                1
# 1             5   0.556      1.000        KEGG:00051    keg                1
# 2             8   0.889      0.421        GO:0006732     BP                1
# 3             5   0.556      0.833        KEGG:00030    keg                1
# 4             8   0.889      0.348        GO:0051186     BP                1
#
#                          term.name  relative.depth  \
# 0               Glucose metabolism               1
# 1  Fructose and mannose metabolism               1
# 2       coenzyme metabolic process               1
# 3        Pentose phosphate pathway               1
# 4       cofactor metabolic process               1
#
#                                  intersection
# 0                    PFKP,FBP2,PFKL,PFKM,FBP1
# 1                    PFKP,FBP2,PFKL,PFKM,FBP1
# 2  PFKP,TECR,ACOT2,PFKL,PFKM,FBP1,ACOT4,ACOT1
# 3                    PFKP,FBP2,PFKL,PFKM,FBP1
# 4  PFKP,TECR,ACOT2,PFKL,PFKM,FBP1,ACOT4,ACOT1
#    query.number  significant       p.value  term.size  query.size  \
# 0             1         True  1.110000e-08          6           5
# 1             1         True  2.570000e-08          5           5
# 2             1         True  2.570000e-08          5           5
# 3             1         True  2.990000e-08          6           5
# 4             1         True  1.800000e-07          7           5
#
#    overlap.size  recall  precision             term.id domain  \
# 0             5     1.0      0.833          KEGG:04146    keg
# 1             5     1.0      1.000          GO:0031903     CC
# 2             5     1.0      1.000          GO:0005778     CC
# 3             5     1.0      0.833  REAC:R-HSA-1369062    rea
# 4             5     1.0      0.714          GO:0005777     CC
#
#    subgraph.number                              term.name  relative.depth  \
# 0                1                             Peroxisome               1
# 1                1                     microbody membrane               1
# 2                1                   peroxisomal membrane               1
# 3                1  ABC transporters in lipid homeostasis               1
# 4                1                             peroxisome               1
#
#                    intersection
# 0  PEX3,ABCD1,ABCD3,PEX19,ABCD2
# 1  PEX3,ABCD1,ABCD3,PEX19,ABCD2
# 2  PEX3,ABCD1,ABCD3,PEX19,ABCD2
# 3  PEX3,ABCD1,ABCD3,PEX19,ABCD2
# 4  PEX3,ABCD1,ABCD3,PEX19,ABCD2
#    query.number  significant   p.value  term.size  query.size  overlap.size  \
# 0             1         True  0.000137          8           4             4
# 1             1         True  0.000174          4           4             3
# 2             1         True  0.000700          3           3             3
# 3             1         True  0.000700          3           3             3
# 4             1         True  0.000700          3           3             3
#
#    recall  precision     term.id domain  subgraph.number  \
# 0    1.00       0.50  GO:0005811     CC                1
# 1    0.75       0.75  KEGG:04923    keg                1
# 2    1.00       1.00  HP:0006561     hp                1
# 3    1.00       1.00  HP:0001397     hp                1
# 4    1.00       1.00  HP:0031137     hp                1
#
#                                term.name  relative.depth  \
# 0                          lipid droplet               1
# 1  Regulation of lipolysis in adipocytes               1
# 2      Lipid accumulation in hepatocytes               1
# 3                      Hepatic steatosis               1
# 4                 Storage in hepatocytes               1
#
#               intersection
# 0  ABHD5,LIPE,PLIN2,PNPLA2
# 1        ABHD5,LIPE,PNPLA2
# 2        ABHD5,LIPE,PNPLA2
# 3        ABHD5,LIPE,PNPLA2
# 4        ABHD5,LIPE,PNPLA2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-23abb161135b> in <module>()
#      11                           "query.size", "overlap.size", "recall", "precision",
#      12                           "term.id", "domain", "subgraph.number", "term.name",
# ---> 13                           "relative.depth", "intersection"]
#      14     print(gp_results.head())
#      15
#
# /Users/brin/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __setattr__(self, name, value)
#    2981         try:
#    2982             object.__getattribute__(self, name)
# -> 2983             return object.__setattr__(self, name, value)
#    2984         except AttributeError:
#    2985             pass
#
# pandas/_libs/src/properties.pyx in pandas._libs.lib.AxisProperty.__set__ (pandas/_libs/lib.c:45103)()
#
# /Users/brin/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _set_axis(self, axis, labels)
#     469
#     470     def _set_axis(self, axis, labels):
# --> 471         self._data.set_axis(axis, labels)
#     472         self._clear_item_cache()
#     473
#
# /Users/brin/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in set_axis(self, axis, new_labels)
#    2834             raise ValueError('Length mismatch: Expected axis has %d elements, '
#    2835                              'new values have %d elements' %
# -> 2836                              (old_len, new_len))
#    2837
#    2838         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 14 elements
