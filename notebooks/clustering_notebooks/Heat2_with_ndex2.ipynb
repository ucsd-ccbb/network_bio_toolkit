# %% [markdown]
# # Space Flight Mice Liver Gene Analysis
# ## Heat Propagation and Clustering Package
# ### Python 2 compatible version
#
# ----------------------
#
# Author: Mikayla Webster (13webstermj@gmail.com)
#
# Date: 2nd May, 2018
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Define Analysis Preferences](#pref)
# 3. [Load Networks](#load)
# 4. [Localization](#local)
# 4. [Run Heat Propagation](#heat)
# 5. [Clustering](#cluster)

# %% [markdown]
# ## Background
# <a id='background'></a>

# %% [markdown]
# The Heat2 module provides tools to conduct an integrated network analysis of a set of differentially expressed genes (DEGs). The set of DEGs analyzed in this notebook come from an experiment performed by NASA called the [Rodent Research Project on the ISS](https://genelab-data.ndc.nasa.gov/genelab/accession/GLDS-48). The tissues sampled for this experiment were taken from the livers of mice who experienced space flight.
#
# The focus of this notebook is to demonstrate how to load a background network from [NDEXbio](http://ndexbio.org/#/).

# %% [markdown]
# ## Import packages
# <a id='import'></a>

# %%
# uncomment if you have not pip-installed 

#import sys
#code_path = '../../network_bio_toolkit'
#sys.path.append(code_path)

#import Heat2
#reload(Heat2)

from network_bio_toolkit import Heat2

# %% [markdown]
# ## Define Analysis Preferences
# <a id='pref'></a>

# %%
symbol = 'symbol'
entrez = 'entrez'

human = 'human'
mouse = 'mouse'

heat = Heat2.Heat(gene_type = symbol, species = mouse)

# %% [markdown]
# ## Load Networks
# <a id='load'></a>
#
# 1. Load DEG file
# 2. Load STRING background network

# %%
# load DEG file
DEG_filename = "../../DEG_databases/DE_CoeffspaceFlight - groundControl_glds48_20180312.csv"  
heat.create_DEG_list(DEG_filename, p_value_filter = 0.05, sep = ',')

print('Number of DEG\'s: ' + str(len(heat.DEG_list)))
# Out:
# Number of DEG's: 181
# C:\Users\m1web\Anaconda2\lib\site-packages\network_bio_toolkit\create_graph.py:366: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   df = pd.DataFrame.from_csv(filename, sep = sep)

# %%
# load our saved network from ndex rather than loading it ourselves
# equivalent to heat.load_STRING_links('../../background_networks/10090.protein.links.v10.5.txt', confidence_filter = 700)
heat.load_ndex_from_server(UUID = '76160faa-5d0f-11e8-a4bf-0ac135e8bacf', relabel_node_field = 'name')

print('\nNumber of interactions: ' + str(len(list(heat.DG_universe.edges()))))
# Out:
# Number of interactions: 369294

# %%
saved_DG_universe = heat.DG_universe
heat.DG_universe = saved_DG_universe

# %% [markdown]
# ## Localization ##
# <a id='local'></a>

# %%
numedges_list, numedges_rand, LCC_list, LCC_rand = heat.localization(num_reps = 250, 
                                                                     sample_frac = 0.8, 
                                                                     method = 'both', 
                                                                     plot = True)

# %%
# test out plotting parameters with a smaller num_reps first.
numedges_list, numedges_rand, LCC_list, LCC_rand = heat.localization_full(num_reps = 200, 
                                                                          method = 'LCC', 
                                                                          label = 'focal genes',
                                                                          line_height = 0.4,
                                                                          legend_loc = 'upper left')
# Out:
# 3.3306690738754696e-16

# %% [markdown]
# ## Run Heat Propagation
# <a id='heat'></a>

# %%
Wprime = heat.normalized_adj_matrix() # optional. Saves time to do it once here.

# %%
saved_Wprime = heat.Wprime
heat.Wprime = saved_Wprime

# %%
heat.draw_heat_prop(num_nodes = 500,
                  random_walk = True,
                  edge_width = 2,
                  edge_smooth_enabled = True,
                  edge_smooth_type = 'bezier',
                  node_size_multiplier = 5,
                  hover = False,
                  hover_connected_edges = False,
                  largest_connected_component = True,
                  physics_enabled = True,
                  node_font_size = 40,
                  graph_id = 1,
                  node_shadow_x = 6)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"node_label": "Chic1", "node_shape": "triangle", "x": 994.5547880295816, "degree": 1, "node_size": 10, "color": "rgba(256, 28, 0, 1.0)", "title": "Chic1<br/>heat = 0.00431", "border_width": 2, "id": "Chic1", "y": 556.7761284412434}, {"node_label": "", "node_shape": "dot", "x": 301.3197547257942, "degree": 8, "node_size": 10, "color": "rgba(256, 238, 0, 1.0)", "title": "Sdsl<br/>heat = 0.00027", "border_width": 0, "id": "Sdsl", "y": 806.4673641008281}, {"node_label": "Cmpk2", "node_shape": "triangle", "x": 618.2001061755507, "degree": 29, "node_size": 10, "color": "rgba(256, 32, 0, 1.0)", "title": "Cmpk2<br/>heat = 0.00411", "border_width": 2, "id": "Cmpk2", "y": 556.9790477142865}, {"node_label": "", "node_shape": "dot", "x": 649.551789344237, "degree": 13, "node_size": 10, "color": "rgba(256, 157, 0, 1.0)", "title": "Rbbp7<br/>heat = 0.00079", "border_width": 0, "id": "Rbbp7", "y": 669.886173252208}, {"node_label": "", "node_shape": "dot", "x": 503.0841650709407, "degree": 15, "node_size": 10, "color": "rgba(256, 256, 0, 1.0)", "title": "Nampt<br/>heat = 0.00022", "border_width": 0, "id": "Nampt", "y": 641.8081902783117}, {"node_label": "", "node_shape": "dot", "x": 636.715532817769, "degree": 16, "node_size": 10, "color": "rgba(256, 154, 0, 1.0)", "title": "Rbbp4<br/>heat = 0.00082", "border_width": 0, "id": "Rbbp4", "y": 662.3950316477683}, {"node_label": "Ccnf", "node_shape": "triangle", "x": 719.8434907857785, "degree": 27, "node_size": 10, "color": "rgba(256, 33, 0, 1.0)", "title": "Ccnf<br/>heat = 0.00403", "border_width": 2, "id": "Ccnf", "y": 543.2214340639822}, {"node_label": "", "node_shape": "dot", "x": 98.1822538011488, "degree": 15, "node_size": 10, "color": "rgba(256, 240, 0, 1.0)", "title": "Hsd3b1<br/>heat = 0.00026", "border_width": 0, "id": "Hsd3b1", "y": 554.1844541249333}, {"node_label": "", "node_shape": "dot", "x": 154.26202597689584, "degree": 15, "node_size": 10, "color": "rgba(256, 195, 0, 1.0)", "title": "Cyp3a16<br/>heat = 0.00048", "border_width": 0, "id": "Cyp3a16", "y": 423.46613617660097}, {"node_label": "Klf1", "node_shape": "triangle", "x": 791.2269870242674, "degree": 2, "node_size": 10, "color": "rgba(256, 38, 0, 1.0)", "title": "Klf1<br/>heat = 0.00378", "border_width": 2, "id": "Klf1", "y": 735.084790642781}, {"node_label": "", "node_shape": "dot", "x": 114.72688835911715, "degree": 2, "node_size": 10, "color": "rgba(256, 236, 0, 1.0)", "title": "Aqp11<br/>heat = 0.00028", "border_width": 0, "id": "Aqp11", "y": 158.24608006208587}, {"node_label": "", "node_shape": "dot", "x": 59.1651186893663, "degree": 2, "node_size": 10, "color": "rgba(256, 234, 0, 1.0)", "title": "Aqp12<br/>heat = 0.00029", "border_width": 0, "id": "Aqp12", "y": 236.76611695275105}, {"node_label": "", "node_shape": "dot", "x": 571.924190963897, "degree": 40, "node_size": 10, "color": "rgba(256, 211, 0, 1.0)", "title": "Bcl2<br/>heat = 0.00039", "border_width": 0, "id": "Bcl2", "y": 368.2847100318838}, {"node_label": "Avpr1a", "node_shape": "triangle", "x": 667.6018955683071, "degree": 3, "node_size": 10, "color": "rgba(256, 38, 0, 1.0)", "title": "Avpr1a<br/>heat = 0.00378", "border_width": 2, "id": "Avpr1a", "y": 239.39773616906302}, {"node_label": "", "node_shape": "dot", "x": 209.38832290265773, "degree": 5, "node_size": 10, "color": "rgba(256, 193, 0, 1.0)", "title": "Tecr<br/>heat = 0.00049", "border_width": 0, "id": "Tecr", "y": 905.272886841325}, {"node_label": "", "node_shape": "dot", "x": 527.7256554542063, "degree": 18, "node_size": 10, "color": "rgba(256, 234, 0, 1.0)", "title": "Gys1<br/>heat = 0.00029", "border_width": 0, "id": "Gys1", "y": 602.6918178560826}, {"node_label": "", "node_shape": "dot", "x": 590.8606437459148, "degree": 54, "node_size": 10, "color": "rgba(256, 214, 0, 1.0)", "title": "Akt1<br/>heat =  ...

# %% [markdown]
# ## Clustering
# <a id='cluster'></a>

# %% [markdown]
# Parameter information:
# - **G_DEG**: background network filtered by DEG list, output of load_STRING_to_digraph
# - **DG_universe**: full background network, output of create_graph.load_STRING_to_digraph
# - **seed_nodes**: list of DEG's, output of create_graph.create_DEG_list
# - **Wprime**: will calculate automatically of not specified, output of visualizations.normalized_adj_matrix
# - **num_top_genes**: number of genes to display in the output graph
# - **cluster_size_cut_off**: color clusters below this threshhold grey
# - **remove_stray_nodes**: remove custers below the cluster size cut off
# - **r**: increases spacing between clusters. recommended number between 0.5 and 4.0
# - **x_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **y_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **node_spacing**: recommended number between 500 and 2000
# - **node_size_multiplier**: as you scale node_spacing, scale this number. Recommended number between 5 and 25
# - **physics_enabled**: Nodes will bounce aroound when you click and drag them. Only set to True when number of nodes is 200 or less
# - **node_font_size**: as you scale node_spacing, scale this number. Recommended number between 20 and 50
# - **graph_id**: Allows rendering of multiple graphs in one notebook. Just make sure each graph has a unique id.

# %%
heat.draw_clustering(rad_positions = False,
                k = None,
                largest_connected_component = True,
                num_top_genes = 500,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                node_spacing = 700,
                node_size_multiplier = 10,
                physics_enabled = True,
                node_font_size = 40,
                graph_id = 2,
                edge_width = 2,
                edge_smooth_enabled = True,
                edge_smooth_type = 'bezier',
                hover = False,
                hover_connected_edges = False
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file2"];    frame.runVis([{"node_label": "Chic1", "node_shape": "triangle", "node_full_label": "Chic1", "degree": 3.0, "title": "Chic1<br/>cluster = 0", "color": "#004033", "x": 33.963705315580306, "border_width": 0, "id": "Chic1", "y": 517.8906981484432}, {"node_label": "", "node_shape": "dot", "node_full_label": "Sdsl", "degree": 3.0, "title": "Sdsl<br/>cluster = 1", "color": "#ff0044", "x": 516.6523978901805, "border_width": 0, "id": "Sdsl", "y": 506.98563408718087}, {"node_label": "Cmpk2", "node_shape": "triangle", "node_full_label": "Cmpk2", "degree": 3.0, "title": "Cmpk2<br/>cluster = 2", "color": "#a300cc", "x": 348.7024383042554, "border_width": 0, "id": "Cmpk2", "y": 343.59465851178373}, {"node_label": "", "node_shape": "dot", "node_full_label": "Rbbp7", "degree": 3.0, "title": "Rbbp7<br/>cluster = 3", "color": "#3000b3", "x": 368.67213516830736, "border_width": 0, "id": "Rbbp7", "y": 314.30297549097054}, {"node_label": "", "node_shape": "dot", "node_full_label": "Nampt", "degree": 3.0, "title": "Nampt<br/>cluster = 2", "color": "#a300cc", "x": 249.14221253627622, "border_width": 0, "id": "Nampt", "y": 398.7393967448925}, {"node_label": "", "node_shape": "dot", "node_full_label": "Rbbp4", "degree": 3.0, "title": "Rbbp4<br/>cluster = 3", "color": "#3000b3", "x": 362.3917732158391, "border_width": 0, "id": "Rbbp4", "y": 327.7653837306495}, {"node_label": "Ccnf", "node_shape": "triangle", "node_full_label": "Ccnf", "degree": 3.0, "title": "Ccnf<br/>cluster = 4", "color": "#000c59", "x": 372.7145172106386, "border_width": 0, "id": "Ccnf", "y": 241.23414316412592}, {"node_label": "", "node_shape": "dot", "node_full_label": "Hsd3b1", "degree": 3.0, "title": "Hsd3b1<br/>cluster = 5", "color": "#00d9ca", "x": 511.1471475729769, "border_width": 0, "id": "Hsd3b1", "y": 578.1760103804306}, {"node_label": "Adssl1", "node_shape": "triangle", "node_full_label": "Adssl1", "degree": 3.0, "title": "Adssl1<br/>cluster = 2", "color": "#a300cc", "x": 248.63660889923585, "border_width": 0, "id": "Adssl1", "y": 473.0519677401279}, {"node_label": "Klf1", "node_shape": "triangle", "node_full_label": "Klf1", "degree": 3.0, "title": "Klf1<br/>cluster = 3", "color": "#3000b3", "x": 77.9228879831577, "border_width": 0, "id": "Klf1", "y": 287.7768480795615}, {"node_label": "", "node_shape": "dot", "node_full_label": "Aqp11", "degree": 3.0, "title": "Aqp11<br/>cluster = 6", "color": "#00f281", "x": 657.3262646375089, "border_width": 0, "id": "Aqp11", "y": 519.0680129956994}, {"node_label": "", "node_shape": "dot", "node_full_label": "Aqp12", "degree": 3.0, "title": "Aqp12<br/>cluster = 6", "color": "#00f281", "x": 603.2834453831831, "border_width": 0, "id": "Aqp12", "y": 594.420291226355}, {"node_label": "", "node_shape": "dot", "node_full_label": "Bcl2", "degree": 3.0, "title": "Bcl2<br/>cluster = 7", "color": "#00660e", "x": 285.22391639037863, "border_width": 0, "id": "Bcl2", "y": 210.7452791060403}, {"node_label": "Avpr1a", "node_shape": "triangle", "node_full_label": "Avpr1a", "degree": 3.0, "title": "Avpr1a<br/>cluster = 7", "color": "#00660e", "x": 120.92236898075483, "border_width": 0, "id": "Avpr1a", "y": 183.72120477412855}, {"node_label": "", "node_shape": "dot", "node_full_label": "Tecr", "degree": 3.0, "title": "Tecr<br/>cluster = 8", "color": "#88ff00", "x": 116.13359035516987, "border_width": 0, "id": "Tecr", "y": 617.4267057932328}, {"node_label": "", "node_shape": "dot", "node_full_label": "Gys1", "degree": 3.0, "title": "Gys1<br/>cluster = 3", "color": "#3000b3", "x": 371.04567950759184, "border_width": 0, "id": "Gys1", "y": 321.86545999674814}, {"node_label": "", "node_shape": "dot", "node_full_label": "Akt1", "degree": 3.0, "title": "Akt1<br/>cluster = 7", "color": "#00660e", "x": 297.22334100644775, "border_width": 0, "id": "Akt1", "y": 225.20738293022075}, {" ...

# %%
heat.draw_clustering(num_top_genes = 500,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                r = 1,
                node_spacing = 600,
                node_size_multiplier = 4,
                physics_enabled = False,
                node_font_size = 15,
                graph_id = 3,
                node_shadow_x = 6,
                color_lfc = True,
                largest_connected_component = True,
                vmin = -5,
                vmax = 5
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file3"];    frame.runVis([{"node_label": "Chic1", "node_shape": "triangle", "node_full_label": "Chic1", "degree": 3.0, "title": "Chic1<br/>cluster = 0", "color": "rgba(256, 218, 218, 1.0)", "x": 1057.4363475016703, "border_width": 0, "id": "Chic1", "y": 39.851345377201625}, {"node_label": "", "node_shape": "dot", "node_full_label": "Sdsl", "degree": 3.0, "title": "Sdsl<br/>cluster = 1", "color": "rgba(256, 238, 238, 1.0)", "x": 775.9062551557635, "border_width": 0, "id": "Sdsl", "y": 737.711087581975}, {"node_label": "Cmpk2", "node_shape": "triangle", "node_full_label": "Cmpk2", "degree": 3.0, "title": "Cmpk2<br/>cluster = 2", "color": "rgba(256, 174, 174, 1.0)", "x": 719.3107792484722, "border_width": 0, "id": "Cmpk2", "y": 678.1410706808321}, {"node_label": "", "node_shape": "dot", "node_full_label": "Rbbp7", "degree": 3.0, "title": "Rbbp7<br/>cluster = 3", "color": "rgba(246, 246, 256, 1.0)", "x": 580.5040713283388, "border_width": 0, "id": "Rbbp7", "y": 906.0047407506732}, {"node_label": "", "node_shape": "dot", "node_full_label": "Nampt", "degree": 3.0, "title": "Nampt<br/>cluster = 2", "color": "rgba(246, 246, 256, 1.0)", "x": 648.8648488175222, "border_width": 0, "id": "Nampt", "y": 749.5389528987713}, {"node_label": "", "node_shape": "dot", "node_full_label": "Rbbp4", "degree": 3.0, "title": "Rbbp4<br/>cluster = 3", "color": "rgba(252, 252, 256, 1.0)", "x": 563.5713033734411, "border_width": 0, "id": "Rbbp4", "y": 896.9279835674051}, {"node_label": "Ccnf", "node_shape": "triangle", "node_full_label": "Ccnf", "degree": 3.0, "title": "Ccnf<br/>cluster = 4", "color": "rgba(256, 202, 202, 1.0)", "x": 347.4255230244697, "border_width": 0, "id": "Ccnf", "y": 895.5306137877257}, {"node_label": "", "node_shape": "dot", "node_full_label": "Hsd3b1", "degree": 3.0, "title": "Hsd3b1<br/>cluster = 5", "color": "rgba(256, 254, 254, 1.0)", "x": -99.03133703525603, "border_width": 0, "id": "Hsd3b1", "y": 1059.4569513924878}, {"node_label": "Adssl1", "node_shape": "triangle", "node_full_label": "Adssl1", "degree": 3.0, "title": "Adssl1<br/>cluster = 2", "color": "rgba(226, 226, 256, 1.0)", "x": 574.866240531737, "border_width": 0, "id": "Adssl1", "y": 701.6580048088193}, {"node_label": "Klf1", "node_shape": "triangle", "node_full_label": "Klf1", "degree": 3.0, "title": "Klf1<br/>cluster = 3", "color": "rgba(206, 206, 256, 1.0)", "x": 400.0444748520787, "border_width": 0, "id": "Klf1", "y": 719.3706472052384}, {"node_label": "", "node_shape": "dot", "node_full_label": "Aqp11", "degree": 3.0, "title": "Aqp11<br/>cluster = 6", "color": "rgba(252, 252, 256, 1.0)", "x": -184.5046950616885, "border_width": 0, "id": "Aqp11", "y": 358.2318538587739}, {"node_label": "", "node_shape": "dot", "node_full_label": "Aqp12", "degree": 3.0, "title": "Aqp12<br/>cluster = 6", "color": "rgba(256, 254, 254, 1.0)", "x": -186.02424775909054, "border_width": 0, "id": "Aqp12", "y": 352.83200969280927}, {"node_label": "", "node_shape": "dot", "node_full_label": "Bcl2", "degree": 3.0, "title": "Bcl2<br/>cluster = 7", "color": "rgba(256, 236, 236, 1.0)", "x": -248.02094306139998, "border_width": 0, "id": "Bcl2", "y": 335.71879355391}, {"node_label": "Avpr1a", "node_shape": "triangle", "node_full_label": "Avpr1a", "degree": 3.0, "title": "Avpr1a<br/>cluster = 7", "color": "rgba(256, 218, 218, 1.0)", "x": -340.4405880019305, "border_width": 0, "id": "Avpr1a", "y": 275.9174895541381}, {"node_label": "", "node_shape": "dot", "node_full_label": "Tecr", "degree": 3.0, "title": "Tecr<br/>cluster = 8", "color": "rgba(254, 254, 256, 1.0)", "x": -586.8885604402834, "border_width": 0, "id": "Tecr", "y": 171.32334103257188}, {"node_label": "", "node_shape": "dot", "node_full_label": "Gys1", "degree": 3.0, "title": "Gys1<br/>cluster = 3", "color": "rgba(256, 250, 250, 1.0)", "x": 518.8991857000891, "border_wi ...
