# %% [markdown]
# # Space Mice Genes
# ## Heat Propagation and Clustering Package
#
#
# ----------------------
#
# Author: Mikayla Webster (13webstermj@gmail.com)
#
# Date: 2nd May, 2018
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Define Analysis Preferences](#pref)
# 3. [Load Networks](#load)
# 4. [Run Heat Propagation](#heat)
# 5. [Clustering](#cluster)

# %% [markdown]
# ## Background
# <a id='background'></a>

# %% [markdown]
# ## Import packages
# <a id='import'></a>

# %%
import sys
code_path = '../../network_bio_toolkit'
sys.path.append(code_path)

import Heat2
reload(Heat2)
# Out:
# <module 'Heat2' from '../../network_bio_toolkit\Heat2.pyc'>

# %% [markdown]
# ## Define Analysis Preferences
# <a id='pref'></a>

# %%
symbol = 'symbol'
entrez = 'entrez'

human = 'human'
mouse = 'mouse'

heat = Heat2.Heat(gene_type = symbol, species = mouse)

# %% [markdown]
# ## Load Networks
# <a id='load'></a>
#
# 1. Load DEG file
# 2. Load STRING background network

# %%
# load DEG file
DEG_filename = "../../DEG_databases/DE_CoeffspaceFlight - groundControl_glds48_20180312.csv"  
heat.create_DEG_list(DEG_filename, p_value_filter = 0.05, sep = ',')

print('Number of DEG\'s: ' + str(len(heat.DEG_list)))
# Out:
# Number of DEG's: 181
# ../../network_bio_toolkit\create_graph.py:366: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   df = pd.DataFrame.from_csv(filename, sep = sep)

# %%
# load our saved network from ndex rather than loading it ourselves
# equivalent to heat.load_STRING_links('../../background_networks/10090.protein.links.v10.5.txt', confidence_filter = 700)
heat.load_ndex_from_server(UUID = '76160faa-5d0f-11e8-a4bf-0ac135e8bacf', relabel_node_field = 'name')

print('\nNumber of interactions: ' + str(len(list(heat.DG_universe.edges()))))
# Out:
# Number of interactions: 369294

# %%
saved_DG_universe = heat.DG_universe
heat.DG_universe = saved_DG_universe

# %% [markdown]
# ## Localization ##

# %%
numedges_list, numedges_rand, LCC_list, LCC_rand = heat.localization(num_reps = 250, 
                                                                     sample_frac = 0.8, 
                                                                     method = 'both', 
                                                                     plot = True)

# %%
# test out plotting parameters with a smaller num_reps first.
numedges_list, numedges_rand, LCC_list, LCC_rand = heat.localization_full(num_reps = 200, 
                                                                          method = 'LCC', 
                                                                          label = 'focal genes',
                                                                          line_height = 0.4,
                                                                          legend_loc = 'upper left')
# Out:
# 0.0

# %% [markdown]
# ## Run Heat Propagation
# <a id='heat'></a>

# %%
Wprime = heat.normalized_adj_matrix() # optional. Saves time to do it once here.

# %%
saved_Wprime = heat.Wprime
heat.Wprime = saved_Wprime

# %%
heat.draw_heat_prop(num_nodes = 500,
                  random_walk = True,
                  edge_width = 2,
                  edge_smooth_enabled = True,
                  edge_smooth_type = 'bezier',
                  node_size_multiplier = 5,
                  hover = False,
                  hover_connected_edges = False,
                  largest_connected_component = True,
                  physics_enabled = True,
                  node_font_size = 40,
                  graph_id = 1,
                  node_shadow_x = 6)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"node_label": "Chic1", "node_shape": "triangle", "x": 16.219783371142487, "degree": 1, "node_size": 10, "color": "rgba(256, 28, 0, 1.0)", "title": "Chic1<br/>heat = 0.00431", "border_width": 2, "id": "Chic1", "y": 655.7888304999474}, {"node_label": "", "node_shape": "dot", "x": 360.0507821505687, "degree": 8, "node_size": 10, "color": "rgba(256, 238, 0, 1.0)", "title": "Sdsl<br/>heat = 0.00027", "border_width": 0, "id": "Sdsl", "y": 179.64012984191436}, {"node_label": "Cmpk2", "node_shape": "triangle", "x": 598.4387957861451, "degree": 29, "node_size": 10, "color": "rgba(256, 32, 0, 1.0)", "title": "Cmpk2<br/>heat = 0.00411", "border_width": 2, "id": "Cmpk2", "y": 604.8315749314984}, {"node_label": "", "node_shape": "dot", "x": 270.01442620551245, "degree": 13, "node_size": 10, "color": "rgba(256, 157, 0, 1.0)", "title": "Rbbp7<br/>heat = 0.00079", "border_width": 0, "id": "Rbbp7", "y": 567.9960346598468}, {"node_label": "", "node_shape": "dot", "x": 540.9168635706295, "degree": 15, "node_size": 10, "color": "rgba(256, 256, 0, 1.0)", "title": "Nampt<br/>heat = 0.00022", "border_width": 0, "id": "Nampt", "y": 450.9527685880471}, {"node_label": "", "node_shape": "dot", "x": 288.7671735702125, "degree": 16, "node_size": 10, "color": "rgba(256, 154, 0, 1.0)", "title": "Rbbp4<br/>heat = 0.00082", "border_width": 0, "id": "Rbbp4", "y": 550.4746639238058}, {"node_label": "Ccnf", "node_shape": "triangle", "x": 385.1977900048128, "degree": 27, "node_size": 10, "color": "rgba(256, 33, 0, 1.0)", "title": "Ccnf<br/>heat = 0.00403", "border_width": 2, "id": "Ccnf", "y": 671.952621685451}, {"node_label": "", "node_shape": "dot", "x": 212.35657032970155, "degree": 15, "node_size": 10, "color": "rgba(256, 240, 0, 1.0)", "title": "Hsd3b1<br/>heat = 0.00026", "border_width": 0, "id": "Hsd3b1", "y": 194.96983990961274}, {"node_label": "", "node_shape": "dot", "x": 341.86217190092873, "degree": 15, "node_size": 10, "color": "rgba(256, 195, 0, 1.0)", "title": "Cyp3a16<br/>heat = 0.00048", "border_width": 0, "id": "Cyp3a16", "y": 178.74259951229695}, {"node_label": "Klf1", "node_shape": "triangle", "x": 166.64707564616114, "degree": 2, "node_size": 10, "color": "rgba(256, 38, 0, 1.0)", "title": "Klf1<br/>heat = 0.00378", "border_width": 2, "id": "Klf1", "y": 664.7262687750805}, {"node_label": "", "node_shape": "dot", "x": 990.8515955808731, "degree": 2, "node_size": 10, "color": "rgba(256, 236, 0, 1.0)", "title": "Aqp11<br/>heat = 0.00028", "border_width": 0, "id": "Aqp11", "y": 372.21928911151235}, {"node_label": "", "node_shape": "dot", "x": 952.469712369356, "degree": 2, "node_size": 10, "color": "rgba(256, 234, 0, 1.0)", "title": "Aqp12<br/>heat = 0.00029", "border_width": 0, "id": "Aqp12", "y": 279.05850304622317}, {"node_label": "", "node_shape": "dot", "x": 542.0000429477659, "degree": 40, "node_size": 10, "color": "rgba(256, 211, 0, 1.0)", "title": "Bcl2<br/>heat = 0.00039", "border_width": 0, "id": "Bcl2", "y": 628.7588979696875}, {"node_label": "Avpr1a", "node_shape": "triangle", "x": 409.384061869157, "degree": 3, "node_size": 10, "color": "rgba(256, 38, 0, 1.0)", "title": "Avpr1a<br/>heat = 0.00378", "border_width": 2, "id": "Avpr1a", "y": 542.4089212663307}, {"node_label": "", "node_shape": "dot", "x": 946.6263024384483, "degree": 5, "node_size": 10, "color": "rgba(256, 193, 0, 1.0)", "title": "Tecr<br/>heat = 0.00049", "border_width": 0, "id": "Tecr", "y": 538.1758058626858}, {"node_label": "", "node_shape": "dot", "x": 345.36566416706256, "degree": 18, "node_size": 10, "color": "rgba(256, 234, 0, 1.0)", "title": "Gys1<br/>heat = 0.00029", "border_width": 0, "id": "Gys1", "y": 491.35265174125567}, {"node_label": "", "node_shape": "dot", "x": 523.3232122883257, "degree": 54, "node_size": 10, "color": "rgba(256, 214, 0, 1.0)", "title": "Akt1<b ...

# %% [markdown]
# ## Clustering
# <a id='cluster'></a>

# %% [markdown]
# Parameter information:
# - **G_DEG**: background network filtered by DEG list, output of load_STRING_to_digraph
# - **DG_universe**: full background network, output of create_graph.load_STRING_to_digraph
# - **seed_nodes**: list of DEG's, output of create_graph.create_DEG_list
# - **Wprime**: will calculate automatically of not specified, output of visualizations.normalized_adj_matrix
# - **num_top_genes**: number of genes to display in the output graph
# - **cluster_size_cut_off**: color clusters below this threshhold grey
# - **remove_stray_nodes**: remove custers below the cluster size cut off
# - **r**: increases spacing between clusters. recommended number between 0.5 and 4.0
# - **x_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **y_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **node_spacing**: recommended number between 500 and 2000
# - **node_size_multiplier**: as you scale node_spacing, scale this number. Recommended number between 5 and 25
# - **physics_enabled**: Nodes will bounce aroound when you click and drag them. Only set to True when number of nodes is 200 or less
# - **node_font_size**: as you scale node_spacing, scale this number. Recommended number between 20 and 50
# - **graph_id**: Allows rendering of multiple graphs in one notebook. Just make sure each graph has a unique id.

# %%
heat.draw_clustering(rad_positions = False,
                k = None,
                largest_connected_component = True,
                num_top_genes = 500,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                node_spacing = 700,
                node_size_multiplier = 10,
                physics_enabled = True,
                node_font_size = 40,
                graph_id = 2,
                edge_width = 2,
                edge_smooth_enabled = True,
                edge_smooth_type = 'bezier',
                hover = False,
                hover_connected_edges = False
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file2"];    frame.runVis([{"node_label": "Chic1", "node_shape": "triangle", "degree": 3.0, "title": "Chic1<br/>cluster = 0", "color": "#004033", "y": 647.6390676498564, "x": 176.04789362685457, "border_width": 0, "id": "Chic1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Sdsl<br/>cluster = 1", "color": "#ff0044", "y": 455.53310041342473, "x": 80.65793904798154, "border_width": 0, "id": "Sdsl"}, {"node_label": "Cmpk2", "node_shape": "triangle", "degree": 3.0, "title": "Cmpk2<br/>cluster = 2", "color": "#a300cc", "y": 375.30966119812825, "x": 335.5993356973745, "border_width": 0, "id": "Cmpk2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Rbbp7<br/>cluster = 3", "color": "#3000b3", "y": 178.62116180162045, "x": 327.6404150887592, "border_width": 0, "id": "Rbbp7"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nampt<br/>cluster = 2", "color": "#a300cc", "y": 313.7159057818182, "x": 269.1799432189431, "border_width": 0, "id": "Nampt"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Rbbp4<br/>cluster = 3", "color": "#3000b3", "y": 190.62998508940439, "x": 321.0500360165085, "border_width": 0, "id": "Rbbp4"}, {"node_label": "Ccnf", "node_shape": "triangle", "degree": 3.0, "title": "Ccnf<br/>cluster = 4", "color": "#000c59", "y": 350.77704161615765, "x": 406.3029000544183, "border_width": 0, "id": "Ccnf"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hsd3b1<br/>cluster = 5", "color": "#00d9ca", "y": 379.6141873861336, "x": 132.56482077948104, "border_width": 0, "id": "Hsd3b1"}, {"node_label": "Adssl1", "node_shape": "triangle", "degree": 3.0, "title": "Adssl1<br/>cluster = 2", "color": "#a300cc", "y": 324.7264551908215, "x": 183.72703244282962, "border_width": 0, "id": "Adssl1"}, {"node_label": "Klf1", "node_shape": "triangle", "degree": 3.0, "title": "Klf1<br/>cluster = 3", "color": "#3000b3", "y": 61.448083889768235, "x": 362.6943089775599, "border_width": 0, "id": "Klf1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Aqp11<br/>cluster = 6", "color": "#00f281", "y": 320.92642221442975, "x": 6.609988025777305, "border_width": 0, "id": "Aqp11"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Aqp12<br/>cluster = 6", "color": "#00f281", "y": 234.1606671234409, "x": 21.365777391225254, "border_width": 0, "id": "Aqp12"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Bcl2<br/>cluster = 7", "color": "#00660e", "y": 253.9912523628561, "x": 451.522665026912, "border_width": 0, "id": "Bcl2"}, {"node_label": "Avpr1a", "node_shape": "triangle", "degree": 3.0, "title": "Avpr1a<br/>cluster = 7", "color": "#00660e", "y": 130.07730531484054, "x": 487.6466632823172, "border_width": 0, "id": "Avpr1a"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Tecr<br/>cluster = 8", "color": "#88ff00", "y": 697.7320418736275, "x": 298.1167502909771, "border_width": 0, "id": "Tecr"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Gys1<br/>cluster = 3", "color": "#3000b3", "y": 253.3801068719215, "x": 328.1831848913632, "border_width": 0, "id": "Gys1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Akt1<br/>cluster = 7", "color": "#00660e", "y": 278.57122695874733, "x": 448.30712376317007, "border_width": 0, "id": "Akt1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Med1<br/>cluster = 3", "color": "#3000b3", "y": 161.8312556440819, "x": 318.0601768315212, "border_width": 0, "id": "Med1"}, {"node_label": "Rrm2", "node_shape": "triangle", "degree": 3.0, "title": "Rrm2<br/>cluster = 2", "color": "#a300cc", "y": 281.9326468565707, "x": 299.8219379295853, "border_width": 0, "id": "Rrm2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nt5c1a<br/>cluster =  ...

# %%
heat.draw_clustering(num_top_genes = 500,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                r = 1,
                node_spacing = 600,
                node_size_multiplier = 4,
                physics_enabled = False,
                node_font_size = 15,
                graph_id = 3,
                node_shadow_x = 6,
                color_lfc = True,
                largest_connected_component = True,
                vmin = -5,
                vmax = 5
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file3"];    frame.runVis([{"node_label": "Chic1", "node_shape": "triangle", "degree": 3.0, "title": "Chic1<br/>cluster = 0", "color": "rgba(256, 218, 218, 1.0)", "y": 13.455306758765422, "x": 805.6958713264889, "border_width": 0, "id": "Chic1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Sdsl<br/>cluster = 1", "color": "rgba(256, 238, 238, 1.0)", "y": 774.1556850326829, "x": 767.0407991816295, "border_width": 0, "id": "Sdsl"}, {"node_label": "Cmpk2", "node_shape": "triangle", "degree": 3.0, "title": "Cmpk2<br/>cluster = 2", "color": "rgba(256, 174, 174, 1.0)", "y": 772.6201051518897, "x": 827.8723842924572, "border_width": 0, "id": "Cmpk2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Rbbp7<br/>cluster = 3", "color": "rgba(246, 246, 256, 1.0)", "y": 816.6014889688295, "x": 519.0886581323551, "border_width": 0, "id": "Rbbp7"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nampt<br/>cluster = 2", "color": "rgba(246, 246, 256, 1.0)", "y": 839.7277399710684, "x": 756.7457318218022, "border_width": 0, "id": "Nampt"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Rbbp4<br/>cluster = 3", "color": "rgba(252, 252, 256, 1.0)", "y": 836.2040327305515, "x": 531.5467305713736, "border_width": 0, "id": "Rbbp4"}, {"node_label": "Ccnf", "node_shape": "triangle", "degree": 3.0, "title": "Ccnf<br/>cluster = 4", "color": "rgba(256, 202, 202, 1.0)", "y": 851.5263801065391, "x": 346.90568940401624, "border_width": 0, "id": "Ccnf"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hsd3b1<br/>cluster = 5", "color": "rgba(256, 254, 254, 1.0)", "y": 908.4241442140242, "x": -246.3302712509402, "border_width": 0, "id": "Hsd3b1"}, {"node_label": "Adssl1", "node_shape": "triangle", "degree": 3.0, "title": "Adssl1<br/>cluster = 2", "color": "rgba(226, 226, 256, 1.0)", "y": 885.2030350123548, "x": 776.7273735612798, "border_width": 0, "id": "Adssl1"}, {"node_label": "Klf1", "node_shape": "triangle", "degree": 3.0, "title": "Klf1<br/>cluster = 3", "color": "rgba(206, 206, 256, 1.0)", "y": 906.198454240537, "x": 694.8034064943953, "border_width": 0, "id": "Klf1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Aqp11<br/>cluster = 6", "color": "rgba(252, 252, 256, 1.0)", "y": 569.5614471156234, "x": 106.78265154359978, "border_width": 0, "id": "Aqp11"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Aqp12<br/>cluster = 6", "color": "rgba(256, 254, 254, 1.0)", "y": 558.4490937575289, "x": 102.87604738926947, "border_width": 0, "id": "Aqp12"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Bcl2<br/>cluster = 7", "color": "rgba(256, 236, 236, 1.0)", "y": 330.25265486475695, "x": -286.253273161396, "border_width": 0, "id": "Bcl2"}, {"node_label": "Avpr1a", "node_shape": "triangle", "degree": 3.0, "title": "Avpr1a<br/>cluster = 7", "color": "rgba(256, 218, 218, 1.0)", "y": 360.42326452697193, "x": -375.7754540958953, "border_width": 0, "id": "Avpr1a"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Tecr<br/>cluster = 8", "color": "rgba(254, 254, 256, 1.0)", "y": 111.01513798091449, "x": -567.4676985499898, "border_width": 0, "id": "Tecr"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Gys1<br/>cluster = 3", "color": "rgba(256, 250, 250, 1.0)", "y": 853.329579253425, "x": 425.29913109893107, "border_width": 0, "id": "Gys1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Akt1<br/>cluster = 7", "color": "rgba(244, 244, 256, 1.0)", "y": 342.0971869734739, "x": -291.25462139478054, "border_width": 0, "id": "Akt1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Med1<br/>cluster = 3", "color": "rgba(248, 248, 256, 1.0)", "y": 844.8630302432368, "x": 568.2424888458565, "border_width": ...
