# %% [markdown]
# # Space Mice Genes
# ## Heat Propagation and Clustering Package
#
#
# ----------------------
#
# Author: Mikayla Webster (13webstermj@gmail.com)
#
# Date: 6th April, 2018
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Define Analysis Preferences](#pref)
# 3. [Load Networks](#load)
# 4. [Run Heat Propagation](#heat)
# 5. [Clustering](#cluster)

# %% [markdown]
# ## Background
# <a id='background'></a>

# %% [markdown]
# ## Import packages
# <a id='import'></a>

# %%
import sys
code_path = '../../network_bio_toolkit'
sys.path.append(code_path)
import Heat
reload(Heat)
import networkx as nx
import visJS2jupyter.visualizations as visualizations # pip install visJS2jupyter

# %% [markdown]
# ## Define Analysis Preferences
# <a id='pref'></a>

# %%
symbol = 'symbol'
entrez = 'entrez'

human = 'human'
mouse = 'mouse'

heat = Heat.Heat(gene_type = symbol, species = mouse)

# %% [markdown]
# ## Load Networks
# <a id='load'></a>
#
# 1. Load DEG file
# 2. Load STRING background network

# %%
# load DEG file
DEG_filename = "../../DEG_databases/DE_CoeffspaceFlight - groundControl_glds48_20180312.csv"  
heat.create_DEG_list(DEG_filename, p_value_filter = 0.1, sep = ',')

print "Number of DEG's: " + str(len(heat.DEG_list))
# Out:
# Number of DEG's: 394

# %%
# load background network
#filename = "../../background_networks/10090.protein.actions.v10.5.txt"
#heat.load_STRING_to_digraph(filename, confidence_filter = 400)

#print "\nNumber of interactions: " + str(len(list(heat.G_DEG.edges())))

# %% [markdown]
# ## Run Heat Propagation
# <a id='heat'></a>

# %%
# delete this later

#saved_G_DEG = heat.G_DEG
heat.G_DEG = saved_G_DEG

#saved_DG_universe = heat.DG_universe
heat.DG_universe = saved_DG_universe

# %%
Wprime = heat.normalized_adj_matrix() # optional. Only if you want to inspet Wprime

# %%
heat.draw_heat_prop(Wprime = Wprime, # you don't have to pass this argument. Will calculate automatically
                  num_nodes = 200,
                  edge_width = 2,
                  edge_smooth_enabled = True,
                  edge_smooth_type = 'bezier',
                  node_size_multiplier = 5,
                  hover = False,
                  hover_connected_edges = False,
                  largest_connected_component = True,
                  physics_enabled = True,
                  node_font_size = 40,
                  graph_id = 1,
                  node_shadow_x = 6)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"node_label": "Dnmt3b", "node_shape": "triangle", "x": 385.1255171762095, "degree": 2, "node_size": 10, "color": "rgba(256, 133, 0, 1.0)", "title": "Dnmt3b<br/>heat = 0.0034", "border_width": 2, "id": "Dnmt3b", "y": 580.6661576048706}, {"node_label": "Rbm4", "node_shape": "dot", "x": 20.638365852070656, "degree": 1, "node_size": 10, "color": "rgba(256, 217, 0, 1.0)", "title": "Rbm4<br/>heat = 0.00144", "border_width": 0, "id": "Rbm4", "y": 334.57485588367626}, {"node_label": "Rnf144b", "node_shape": "triangle", "x": 130.06749068485829, "degree": 1, "node_size": 10, "color": "rgba(256, 131, 0, 1.0)", "title": "Rnf144b<br/>heat = 0.00346", "border_width": 2, "id": "Rnf144b", "y": 783.646003316314}, {"node_label": "Nr1d1", "node_shape": "triangle", "x": 406.5606239419603, "degree": 3, "node_size": 10, "color": "rgba(256, 122, 0, 1.0)", "title": "Nr1d1<br/>heat = 0.0038", "border_width": 2, "id": "Nr1d1", "y": 229.49216402703846}, {"node_label": "Bcl6b", "node_shape": "triangle", "x": 213.36226290424182, "degree": 1, "node_size": 10, "color": "rgba(256, 134, 0, 1.0)", "title": "Bcl6b<br/>heat = 0.00336", "border_width": 2, "id": "Bcl6b", "y": 905.6483672168258}, {"node_label": "Cpt1a", "node_shape": "triangle", "x": 653.9652868258805, "degree": 1, "node_size": 10, "color": "rgba(256, 106, 0, 1.0)", "title": "Cpt1a<br/>heat = 0.00446", "border_width": 2, "id": "Cpt1a", "y": 492.77124167209405}, {"node_label": "Irf1", "node_shape": "dot", "x": 839.1585043083267, "degree": 2, "node_size": 10, "color": "rgba(256, 236, 0, 1.0)", "title": "Irf1<br/>heat = 0.00119", "border_width": 0, "id": "Irf1", "y": 853.0458983526057}, {"node_label": "Bid", "node_shape": "triangle", "x": 658.7259526616433, "degree": 5, "node_size": 10, "color": "rgba(256, 135, 0, 1.0)", "title": "Bid<br/>heat = 0.00333", "border_width": 2, "id": "Bid", "y": 792.8019121953008}, {"node_label": "Irf8", "node_shape": "dot", "x": 890.5612831077386, "degree": 1, "node_size": 10, "color": "rgba(256, 189, 0, 1.0)", "title": "Irf8<br/>heat = 0.00191", "border_width": 0, "id": "Irf8", "y": 746.2567245166988}, {"node_label": "Ppargc1a", "node_shape": "triangle", "x": 640.6653223198807, "degree": 8, "node_size": 10, "color": "rgba(256, 135, 0, 1.0)", "title": "Ppargc1a<br/>heat = 0.00332", "border_width": 2, "id": "Ppargc1a", "y": 363.81148665988536}, {"node_label": "Ppargc1b", "node_shape": "triangle", "x": 796.4920842781089, "degree": 1, "node_size": 10, "color": "rgba(256, 0, 0, 1.0)", "title": "Ppargc1b<br/>heat = 0.01317", "border_width": 2, "id": "Ppargc1b", "y": 104.97757333075027}, {"node_label": "Hbp1", "node_shape": "dot", "x": 390.24282804883563, "degree": 1, "node_size": 10, "color": "rgba(256, 183, 0, 1.0)", "title": "Hbp1<br/>heat = 0.00204", "border_width": 0, "id": "Hbp1", "y": 17.46066710317429}, {"node_label": "Creb3l3", "node_shape": "triangle", "x": 16.1945938807481, "degree": 2, "node_size": 10, "color": "rgba(256, 130, 0, 1.0)", "title": "Creb3l3<br/>heat = 0.00349", "border_width": 2, "id": "Creb3l3", "y": 446.8373740195602}, {"node_label": "Rpp14", "node_shape": "dot", "x": 807.6900554247991, "degree": 1, "node_size": 10, "color": "rgba(256, 176, 0, 1.0)", "title": "Rpp14<br/>heat = 0.00219", "border_width": 0, "id": "Rpp14", "y": 365.4677829609684}, {"node_label": "Avpr1a", "node_shape": "triangle", "x": 186.0123659910154, "degree": 2, "node_size": 10, "color": "rgba(256, 107, 0, 1.0)", "title": "Avpr1a<br/>heat = 0.00441", "border_width": 2, "id": "Avpr1a", "y": 888.1195308462446}, {"node_label": "Zbtb17", "node_shape": "dot", "x": 375.7311574146631, "degree": 1, "node_size": 10, "color": "rgba(256, 201, 0, 1.0)", "title": "Zbtb17<br/>heat = 0.00169", "border_width": 0, "id": "Zbtb17", "y": 64.36714900092242}, {"node_label": "Pcbp4", "node_shape": "triangle",  ...

# %% [markdown]
# ## Clustering
# <a id='cluster'></a>

# %% [markdown]
# Parameter information:
# - **G_DEG**: background network filtered by DEG list, output of load_STRING_to_digraph
# - **DG_universe**: full background network, output of create_graph.load_STRING_to_digraph
# - **seed_nodes**: list of DEG's, output of create_graph.create_DEG_list
# - **Wprime**: will calculate automatically of not specified, output of visualizations.normalized_adj_matrix
# - **num_top_genes**: number of genes to display in the output graph
# - **cluster_size_cut_off**: color clusters below this threshhold grey
# - **remove_stray_nodes**: remove custers below the cluster size cut off
# - **r**: increases spacing between clusters. recommended number between 0.5 and 4.0
# - **x_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **y_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **node_spacing**: recommended number between 500 and 2000
# - **node_size_multiplier**: as you scale node_spacing, scale this number. Recommended number between 5 and 25
# - **physics_enabled**: Nodes will bounce aroound when you click and drag them. Only set to True when number of nodes is 200 or less
# - **node_font_size**: as you scale node_spacing, scale this number. Recommended number between 20 and 50
# - **graph_id**: Allows rendering of multiple graphs in one notebook. Just make sure each graph has a unique id.

# %%
heat.draw_clustering(Wprime = Wprime,
                num_top_genes = 200,
                cluster_size_cut_off = 5,
                remove_stray_nodes = False,
                r = 2.0,
                x_offset = 10,
                y_offset = 78,
                node_spacing = 700,
                node_size_multiplier = 12,
                physics_enabled = False,
                node_font_size = 45,
                graph_id = 3,
                node_shadow_x = 6
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file3"];    frame.runVis([{"node_label": "Dnmt3b", "node_shape": "triangle", "degree": 3.0, "title": "Dnmt3b<br/>cluster = 0", "color": "#004033", "y": 489.866521860931, "x": 1672.43681701774, "border_width": 0, "id": "Dnmt3b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Igf1<br/>cluster = 1", "color": "#ff0044", "y": -953.285119658459, "x": 1519.904704617238, "border_width": 0, "id": "Igf1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Axin1<br/>cluster = 2", "color": "grey", "y": -959.6655765278155, "x": 847.3081343944303, "border_width": 0, "id": "Axin1"}, {"node_label": "Adora1", "node_shape": "triangle", "degree": 3.0, "title": "Adora1<br/>cluster = 3", "color": "grey", "y": 540.9213955088339, "x": -117.2610260922542, "border_width": 0, "id": "Adora1"}, {"node_label": "Cyp51", "node_shape": "triangle", "degree": 3.0, "title": "Cyp51<br/>cluster = 4", "color": "#a300cc", "y": 1901.3714356089604, "x": -1173.5114950893856, "border_width": 0, "id": "Cyp51"}, {"node_label": "Adamts7", "node_shape": "triangle", "degree": 3.0, "title": "Adamts7<br/>cluster = 1", "color": "#ff0044", "y": -790.0878397444242, "x": 1758.981503482631, "border_width": 0, "id": "Adamts7"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Foxa1<br/>cluster = 5", "color": "#3000b3", "y": 932.9883206219495, "x": -1233.9905460703574, "border_width": 0, "id": "Foxa1"}, {"node_label": "Ccnf", "node_shape": "triangle", "degree": 3.0, "title": "Ccnf<br/>cluster = 6", "color": "grey", "y": -989.4019088992153, "x": -679.2668295560527, "border_width": 0, "id": "Ccnf"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Foxa2<br/>cluster = 5", "color": "#3000b3", "y": 954.2204137736031, "x": -1260.757971445049, "border_width": 0, "id": "Foxa2"}, {"node_label": "Rnf144b", "node_shape": "triangle", "degree": 3.0, "title": "Rnf144b<br/>cluster = 1", "color": "#ff0044", "y": -797.2820248497161, "x": 1723.1928131117777, "border_width": 0, "id": "Rnf144b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Tnfrsf4<br/>cluster = 7", "color": "grey", "y": -1263.7058681147885, "x": 30.366621758765383, "border_width": 0, "id": "Tnfrsf4"}, {"node_label": "Nr1d1", "node_shape": "triangle", "degree": 3.0, "title": "Nr1d1<br/>cluster = 5", "color": "#3000b3", "y": 752.3520947458444, "x": -1313.7991869051998, "border_width": 0, "id": "Nr1d1"}, {"node_label": "Bcl6b", "node_shape": "triangle", "degree": 3.0, "title": "Bcl6b<br/>cluster = 0", "color": "#004033", "y": 598.0335981477667, "x": 1876.7660263030873, "border_width": 0, "id": "Bcl6b"}, {"node_label": "Mapkapk3", "node_shape": "triangle", "degree": 3.0, "title": "Mapkapk3<br/>cluster = 8", "color": "grey", "y": 194.83379512261664, "x": 1363.290916643352, "border_width": 0, "id": "Mapkapk3"}, {"node_label": "Adssl1", "node_shape": "triangle", "degree": 3.0, "title": "Adssl1<br/>cluster = 9", "color": "grey", "y": 1981.7671881061283, "x": 1549.0147462918899, "border_width": 0, "id": "Adssl1"}, {"node_label": "Asap2", "node_shape": "triangle", "degree": 3.0, "title": "Asap2<br/>cluster = 10", "color": "#000c59", "y": 1340.7825322323479, "x": 1876.8430395883777, "border_width": 0, "id": "Asap2"}, {"node_label": "Cpt1a", "node_shape": "triangle", "degree": 3.0, "title": "Cpt1a<br/>cluster = 5", "color": "#3000b3", "y": 927.6769568729591, "x": -1324.2635634228127, "border_width": 0, "id": "Cpt1a"}, {"node_label": "Spaca6", "node_shape": "triangle", "degree": 3.0, "title": "Spaca6<br/>cluster = 11", "color": "grey", "y": -474.8315743119721, "x": 1402.8901126920875, "border_width": 0, "id": "Spaca6"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Irf7<br/>cluster = 12", "color": "#00d9ca", "y": -1117.727697832683, "x": 593.0572416681551, "border_width": 0, "i ...
