# %% [markdown]
# # Space Mice Genes
# ## Heat Propagation and Clustering Package
#
#
# ----------------------
#
# Author: Mikayla Webster (13webstermj@gmail.com)
#
# Date: 6th April, 2018
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Define Analysis Preferences](#pref)
# 3. [Load Networks](#load)
# 4. [Run Heat Propagation](#heat)
# 5. [Clustering](#cluster)

# %% [markdown]
# ## Background
# <a id='background'></a>

# %% [markdown]
# ## Import packages
# <a id='import'></a>

# %%
import sys
code_path = '../../network_bio_toolkit'
sys.path.append(code_path)

import Heat
reload(Heat)

import pandas as pd

# %% [markdown]
# ## Define Analysis Preferences
# <a id='pref'></a>

# %%
symbol = 'symbol'
entrez = 'entrez'

human = 'human'
mouse = 'mouse'

heat = Heat.Heat(gene_type = symbol, species = mouse)

# %% [markdown]
# ## Load Networks
# <a id='load'></a>
#
# 1. Load STRING background network
# 2. Load DEG file

# %%
def load_STRING(datafile, conf_thresh = 700, species = 'human'):
    '''
    Helper function to parse and load STRING network
    
    '''
    
    string_df = pd.read_csv(datafile,sep=' ')
    string_df = string_df.loc[string_df['combined_score']>conf_thresh]
                              
    # create the network
    G_str = nx.Graph()
    G_str.add_weighted_edges_from(zip(string_df['protein1'],string_df['protein2'],string_df['combined_score']))
    
    # convert from ensembleID to gene symbol
    string_genes_temp = [n[n.find('.')+1:] for n in G_str.nodes()]

    mg_temp = mg.querymany(string_genes_temp,scopes='ensemblprotein',fields='symbol',species=species)
    ensembl_list = [x['query'] for x in mg_temp]
    symbol_list = [x['symbol'] if 'symbol' in x.keys() else 'None' for x in mg_temp]
    ensembl_to_symbol = dict(zip(ensembl_list,symbol_list))
    ensembl_to_symbol = pd.Series(ensembl_to_symbol)
    
    # relabel nodes with symbols
    G_str = nx.relabel_nodes(G_str,dict(zip(G_str.nodes(),string_genes_temp)))
    G_str = nx.relabel_nodes(G_str,dict(ensembl_to_symbol[ensembl_to_symbol!='None']))  # only keep the proteins that have associated genes
    
    return G_str

filename = "../../background_networks/10090.protein.actions.v10.5.txt"
heat.DG_universe = load_STRING(filename)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-cec2f2d8fb4d> in <module>()
#      28
#      29 filename = "../../background_networks/10090.protein.actions.v10.5.txt"
# ---> 30 heat.DG_universe = load_STRING(filename)
#
# <ipython-input-55-cec2f2d8fb4d> in load_STRING(datafile, conf_thresh, species)
#       6
#       7     string_df = pd.read_csv(datafile,sep=' ')
# ----> 8     string_df = string_df.loc[string_df['combined_score']>conf_thresh]
#       9
#      10     # create the network
#
# C:\Users\m1web\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# C:\Users\m1web\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# C:\Users\m1web\Anaconda2\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# C:\Users\m1web\Anaconda2\lib\site-packages\pandas\core\internals.pyc in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\Users\m1web\Anaconda2\lib\site-packages\pandas\core\indexes\base.pyc in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'combined_score'

# %%
print "\nNumber of interactions: " + str(len(list(heat.DG_universe.edges())))

# %%
# load DEG file
DEG_filename = "../../DEG_databases/DE_CoeffspaceFlight - groundControl_glds48_20180312.csv"  
heat.create_DEG_list(DEG_filename, p_value_filter = 0.02, sep = ',')

print "Number of DEG's: " + str(len(heat.DEG_list))
# Out:
# Number of DEG's: 45
#
# Number of interactions: 150042
# ../../network_bio_toolkit\create_graph.py:250: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   df = pd.DataFrame.from_csv(filename, sep=sep)

# %%
saved_DG_universe = heat.DG_universe
heat.DG_universe = saved_DG_universe

# %% [markdown]
# ## Run Heat Propagation
# <a id='heat'></a>

# %%
Wprime = heat.normalized_adj_matrix() # optional, but saves time to only do it once
# Out:
# Number of interactions: 150042

# %%
saved_Wprime = Wprime
Wprime = saved_Wprime

# %%
heat.draw_heat_prop(Wprime = Wprime, # you don't have to pass this argument. Will calculate automatically
                  num_nodes = 500,
#                  random_walk = False,
                  edge_width = 2,
                  edge_smooth_enabled = True,
                  edge_smooth_type = 'bezier',
                  node_size_multiplier = 5,
                  hover = False,
                  hover_connected_edges = False,
                  largest_connected_component = True,
                  physics_enabled = True,
                  node_font_size = 40,
                  graph_id = 1,
                  node_shadow_x = 6)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"node_label": "Ngf", "node_shape": "dot", "x": 337.2802440373469, "degree": 7, "node_size": 10, "color": "rgba(256, 180, 0, 1.0)", "title": "Ngf<br/>heat = 0.00016", "border_width": 0, "id": "Ngf", "y": 825.9348213734983}, {"node_label": "Lrba", "node_shape": "dot", "x": 385.0476410836502, "degree": 1, "node_size": 10, "color": "rgba(256, 49, 0, 1.0)", "title": "Lrba<br/>heat = 0.00604", "border_width": 0, "id": "Lrba", "y": 985.0588726226939}, {"node_label": "Adipor1", "node_shape": "dot", "x": 756.017512630054, "degree": 1, "node_size": 10, "color": "rgba(256, 242, 0, 1.0)", "title": "Adipor1<br/>heat = 3e-05", "border_width": 0, "id": "Adipor1", "y": 916.3482864239228}, {"node_label": "Nampt", "node_shape": "dot", "x": 691.5510093593457, "degree": 2, "node_size": 10, "color": "rgba(256, 252, 0, 1.0)", "title": "Nampt<br/>heat = 2e-05", "border_width": 0, "id": "Nampt", "y": 960.4681602847792}, {"node_label": "Olfr1507", "node_shape": "dot", "x": 288.33439128159864, "degree": 1, "node_size": 10, "color": "rgba(256, 239, 0, 1.0)", "title": "Olfr1507<br/>heat = 3e-05", "border_width": 0, "id": "Olfr1507", "y": 48.31310636278521}, {"node_label": "Olfr1112", "node_shape": "dot", "x": 521.5927428460454, "degree": 1, "node_size": 10, "color": "rgba(256, 238, 0, 1.0)", "title": "Olfr1112<br/>heat = 3e-05", "border_width": 0, "id": "Olfr1112", "y": 24.954864009308885}, {"node_label": "Olfr1263", "node_shape": "dot", "x": 678.9380832263505, "degree": 1, "node_size": 10, "color": "rgba(256, 239, 0, 1.0)", "title": "Olfr1263<br/>heat = 3e-05", "border_width": 0, "id": "Olfr1263", "y": 40.35892094888723}, {"node_label": "Nfkb1", "node_shape": "dot", "x": 464.7569258309972, "degree": 7, "node_size": 10, "color": "rgba(256, 126, 0, 1.0)", "title": "Nfkb1<br/>heat = 0.00071", "border_width": 0, "id": "Nfkb1", "y": 783.5705299775333}, {"node_label": "Bcl6b", "node_shape": "dot", "x": 16.324011286671023, "degree": 1, "node_size": 10, "color": "rgba(256, 205, 0, 1.0)", "title": "Bcl6b<br/>heat = 8e-05", "border_width": 0, "id": "Bcl6b", "y": 379.7693696533461}, {"node_label": "Csnk2a2", "node_shape": "dot", "x": 819.836025030258, "degree": 1, "node_size": 10, "color": "rgba(256, 226, 0, 1.0)", "title": "Csnk2a2<br/>heat = 4e-05", "border_width": 0, "id": "Csnk2a2", "y": 856.7841401835253}, {"node_label": "Olfr843", "node_shape": "dot", "x": 234.1652265686805, "degree": 1, "node_size": 10, "color": "rgba(256, 113, 0, 1.0)", "title": "Olfr843<br/>heat = 0.00103", "border_width": 0, "id": "Olfr843", "y": 170.23501124722821}, {"node_label": "Cenpt", "node_shape": "dot", "x": 908.2716457731365, "degree": 11, "node_size": 10, "color": "rgba(256, 226, 0, 1.0)", "title": "Cenpt<br/>heat = 4e-05", "border_width": 0, "id": "Cenpt", "y": 472.7403614514828}, {"node_label": "Ifnk", "node_shape": "dot", "x": 93.10671420166635, "degree": 4, "node_size": 10, "color": "rgba(256, 157, 0, 1.0)", "title": "Ifnk<br/>heat = 0.00031", "border_width": 0, "id": "Ifnk", "y": 512.5868605244293}, {"node_label": "Ppp1r3b", "node_shape": "triangle", "x": 949.6498301187744, "degree": 2, "node_size": 10, "color": "rgba(256, 0, 0, 1.0)", "title": "Ppp1r3b<br/>heat = 0.02412", "border_width": 2, "id": "Ppp1r3b", "y": 713.9508280502899}, {"node_label": "Sgk1", "node_shape": "dot", "x": 255.3669431158104, "degree": 6, "node_size": 10, "color": "rgba(256, 142, 0, 1.0)", "title": "Sgk1<br/>heat = 0.00046", "border_width": 0, "id": "Sgk1", "y": 733.2717156893373}, {"node_label": "Sumo1", "node_shape": "dot", "x": 771.0033447836746, "degree": 3, "node_size": 10, "color": "rgba(256, 126, 0, 1.0)", "title": "Sumo1<br/>heat = 0.00071", "border_width": 0, "id": "Sumo1", "y": 227.83246595435764}, {"node_label": "Sst", "node_shape": "dot", "x": 701.2300800363778, "degree": 2, "node_size": 10, " ...

# %% [markdown]
# ## Clustering
# <a id='cluster'></a>

# %% [markdown]
# Parameter information:
# - **G_DEG**: background network filtered by DEG list, output of load_STRING_to_digraph
# - **DG_universe**: full background network, output of create_graph.load_STRING_to_digraph
# - **seed_nodes**: list of DEG's, output of create_graph.create_DEG_list
# - **Wprime**: will calculate automatically of not specified, output of visualizations.normalized_adj_matrix
# - **num_top_genes**: number of genes to display in the output graph
# - **cluster_size_cut_off**: color clusters below this threshhold grey
# - **remove_stray_nodes**: remove custers below the cluster size cut off
# - **r**: increases spacing between clusters. recommended number between 0.5 and 4.0
# - **x_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **y_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **node_spacing**: recommended number between 500 and 2000
# - **node_size_multiplier**: as you scale node_spacing, scale this number. Recommended number between 5 and 25
# - **physics_enabled**: Nodes will bounce aroound when you click and drag them. Only set to True when number of nodes is 200 or less
# - **node_font_size**: as you scale node_spacing, scale this number. Recommended number between 20 and 50
# - **graph_id**: Allows rendering of multiple graphs in one notebook. Just make sure each graph has a unique id.

# %%
heat.draw_clustering(rad_positions = False,
                Wprime = Wprime,
                k = None,
                largest_connected_component = True,
                num_top_genes = 500,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                node_spacing = 700,
                node_size_multiplier = 5,
                physics_enabled = False,
                node_font_size = 16,
                graph_id = 2
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file2"];    frame.runVis([{"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Fdps<br/>cluster = 0", "color": "#004033", "y": 596.5554594993591, "x": 209.25992131233215, "border_width": 0, "id": "Fdps"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Rbm4<br/>cluster = 1", "color": "#ff0044", "y": 560.5235517024994, "x": 372.4382221698761, "border_width": 0, "id": "Rbm4"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Wrn<br/>cluster = 2", "color": "#a300cc", "y": 312.97484934329987, "x": 565.695732831955, "border_width": 0, "id": "Wrn"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Pmvk<br/>cluster = 0", "color": "#004033", "y": 544.0321862697601, "x": 177.74198949337006, "border_width": 0, "id": "Pmvk"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nampt<br/>cluster = 2", "color": "#a300cc", "y": 429.24238443374634, "x": 361.9021415710449, "border_width": 0, "id": "Nampt"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Arf6<br/>cluster = 3", "color": "#3000b3", "y": 396.0931360721588, "x": 405.2153408527374, "border_width": 0, "id": "Arf6"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Sp1<br/>cluster = 0", "color": "#004033", "y": 408.9551627635956, "x": 244.37913298606873, "border_width": 0, "id": "Sp1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Sp3<br/>cluster = 4", "color": "#000c59", "y": 418.78382563591003, "x": 181.8962275981903, "border_width": 0, "id": "Sp3"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Sp4<br/>cluster = 4", "color": "#000c59", "y": 381.4303755760193, "x": 4.034942202270031, "border_width": 0, "id": "Sp4"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hbp1<br/>cluster = 4", "color": "#000c59", "y": 395.72300910949707, "x": 77.14273482561111, "border_width": 0, "id": "Hbp1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Klf4<br/>cluster = 5", "color": "#00d9ca", "y": 313.2532060146332, "x": 248.59222173690796, "border_width": 0, "id": "Klf4"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Ngfr<br/>cluster = 5", "color": "#00d9ca", "y": 389.53161239624023, "x": 346.9461292028427, "border_width": 0, "id": "Ngfr"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Mitf<br/>cluster = 6", "color": "#00f281", "y": 301.233634352684, "x": 251.2107104063034, "border_width": 0, "id": "Mitf"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Bcl2<br/>cluster = 2", "color": "#a300cc", "y": 352.62468457221985, "x": 256.4126193523407, "border_width": 0, "id": "Bcl2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Cyp51<br/>cluster = 0", "color": "#004033", "y": 436.1331045627594, "x": 198.71808290481567, "border_width": 0, "id": "Cyp51"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Arap2<br/>cluster = 3", "color": "#3000b3", "y": 435.1387560367584, "x": 507.41565227508545, "border_width": 0, "id": "Arap2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Arap1<br/>cluster = 3", "color": "#3000b3", "y": 401.3640344142914, "x": 491.62477850914, "border_width": 0, "id": "Arap1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Faf1<br/>cluster = 7", "color": "#00660e", "y": 188.5438472032547, "x": 279.7791838645935, "border_width": 0, "id": "Faf1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Il12b<br/>cluster = 2", "color": "#a300cc", "y": 384.0178430080414, "x": 321.79122269153595, "border_width": 0, "id": "Il12b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Gys1<br/>cluster = 6", "color": "#00f281", "y": 211.4171802997589, "x": 307.82340466976166, "border_width": 0, "id": " ...

# %%
heat.draw_clustering(Wprime = Wprime,
                num_top_genes = 500,
                cluster_size_cut_off = 5,
#                remove_stray_nodes = True,
                r = 1.2,
#                x_offset = 2,
#                y_offset = 2,
                node_spacing = 700,
                node_size_multiplier = 12,
                physics_enabled = False,
                node_font_size = 45,
                graph_id = 3,
                node_shadow_x = 6
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file3"];    frame.runVis([{"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Fdps<br/>cluster = 0", "color": "#004033", "y": 54.239626973867416, "x": 1185.505187511444, "border_width": 0, "id": "Fdps"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Rbm4<br/>cluster = 1", "color": "#ff0044", "y": 701.5785574913025, "x": 1174.1890907287598, "border_width": 0, "id": "Rbm4"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Wrn<br/>cluster = 2", "color": "#a300cc", "y": 1293.9362406730652, "x": 533.018833398819, "border_width": 0, "id": "Wrn"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Pmvk<br/>cluster = 0", "color": "#004033", "y": 92.59873777627945, "x": 1182.4248433113098, "border_width": 0, "id": "Pmvk"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nampt<br/>cluster = 2", "color": "#a300cc", "y": 1056.6009521484375, "x": 390.6693637371063, "border_width": 0, "id": "Nampt"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Irs1<br/>cluster = 3", "color": "#3000b3", "y": 859.193229675293, "x": -322.65764772892, "border_width": 0, "id": "Irs1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Sp1<br/>cluster = 0", "color": "#004033", "y": 238.89037668704987, "x": 1171.1150884628296, "border_width": 0, "id": "Sp1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Sp3<br/>cluster = 4", "color": "#000c59", "y": 406.20514154434204, "x": -527.92609333992, "border_width": 0, "id": "Sp3"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Sp4<br/>cluster = 4", "color": "#000c59", "y": 530.0903618335724, "x": -578.7895739078522, "border_width": 0, "id": "Sp4"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hbp1<br/>cluster = 4", "color": "#000c59", "y": 479.40019965171814, "x": -473.1566905975342, "border_width": 0, "id": "Hbp1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Klf4<br/>cluster = 2", "color": "#a300cc", "y": 1182.2144746780396, "x": 364.2813265323639, "border_width": 0, "id": "Klf4"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Klf2<br/>cluster = 3", "color": "#3000b3", "y": 862.5023007392883, "x": -224.19684529304504, "border_width": 0, "id": "Klf2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Mitf<br/>cluster = 5", "color": "#00d9ca", "y": -251.29691064357758, "x": -317.0767664909363, "border_width": 0, "id": "Mitf"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Bcl2<br/>cluster = 2", "color": "#a300cc", "y": 1131.2655448913574, "x": 291.35423600673676, "border_width": 0, "id": "Bcl2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Prkag2<br/>cluster = 5", "color": "#00d9ca", "y": -398.0721950531006, "x": -294.7562247514725, "border_width": 0, "id": "Prkag2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Arap2<br/>cluster = 6", "color": "#00f281", "y": -460.98981499671936, "x": 103.22173833847046, "border_width": 0, "id": "Arap2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Arap1<br/>cluster = 6", "color": "#00f281", "y": -493.4615194797516, "x": 110.95523685216904, "border_width": 0, "id": "Arap1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Faf1<br/>cluster = 7", "color": "#00660e", "y": -216.14588499069214, "x": 750.5900263786316, "border_width": 0, "id": "Faf1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Il12b<br/>cluster = 2", "color": "#a300cc", "y": 1162.2014164924622, "x": 314.0876293182373, "border_width": 0, "id": "Il12b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Gys1<br/>cluster = 5", "color": "#00d9ca", "y": -426.86582803726196, "x": -353.0959904193878, "borde ...
