# %% [markdown]
# # Space Mice Genes
# ## Heat Propagation and Clustering Package
#
#
# ----------------------
#
# Author: Mikayla Webster (13webstermj@gmail.com)
#
# Date: 6th April, 2018
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Define Analysis Preferences](#pref)
# 3. [Load Networks](#load)
# 4. [Run Heat Propagation](#heat)
# 5. [Clustering](#cluster)

# %% [markdown]
# ## Background
# <a id='background'></a>

# %% [markdown]
# ## Import packages
# <a id='import'></a>

# %%
import sys
code_path = '../../network_bio_toolkit'
sys.path.append(code_path)
import Heat
reload(Heat)
import networkx as nx
import visJS2jupyter.visualizations as visualizations # pip install visJS2jupyter

# %% [markdown]
# ## Define Analysis Preferences
# <a id='pref'></a>

# %%
symbol = 'symbol'
entrez = 'entrez'

human = 'human'
mouse = 'mouse'

heat = Heat.Heat(gene_type = symbol, species = mouse)

# %% [markdown]
# ## Load Networks
# <a id='load'></a>
#
# 1. Load DEG file
# 2. Load STRING background network

# %%
# load DEG file
DEG_filename = "../../DEG_databases/DE_CoeffspaceFlight - groundControl_glds48_20180312.csv"  
heat.create_DEG_list(DEG_filename, p_value_filter = 0.02, sep = ',')

print "Number of DEG's: " + str(len(heat.DEG_list))
# Out:
# Number of DEG's: 45

# %%
# load background network
filename = "../../background_networks/10090.protein.actions.v10.5.txt"
heat.load_STRING_to_digraph(filename, confidence_filter = 400)

print "\nNumber of interactions: " + str(len(list(heat.G_DEG.edges())))
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-7303...done.
# Finished.
# 57 input query terms found dup hits:
# 	[(u'ENSMUSP00000042658', 2), (u'ENSMUSP00000126737', 2), (u'ENSMUSP00000051968', 3), (u'ENSMUSP00000
# 154 input query terms found no hit:
# 	[u'ENSMUSP00000036849', u'ENSMUSP00000097354', u'ENSMUSP00000097358', u'ENSMUSP00000137522', u'ENSMU
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
#
# Number of interactions: 442

# %% [markdown]
# ## Run Heat Propagation
# <a id='heat'></a>

# %%
# delete this later

saved_G_DEG = heat.G_DEG
heat.G_DEG = saved_G_DEG

saved_DG_universe = heat.DG_universe
heat.DG_universe = saved_DG_universe

# %%
Wprime = heat.normalized_adj_matrix() # optional. Only if you want to inspet Wprime

# %%
heat.draw_heat_prop(Wprime = Wprime, # you don't have to pass this argument. Will calculate automatically
                  num_nodes = 500,
                  edge_width = 2,
                  edge_smooth_enabled = True,
                  edge_smooth_type = 'bezier',
                  node_size_multiplier = 5,
                  hover = False,
                  hover_connected_edges = False,
                  largest_connected_component = True,
                  physics_enabled = True,
                  node_font_size = 40,
                  graph_id = 1,
                  node_shadow_x = 6)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"node_label": "Dnmt3b", "node_shape": "dot", "x": 717.3310163837665, "degree": 1, "node_size": 10, "color": "rgba(256, 256, 0, 1.0)", "title": "Dnmt3b<br/>heat = 0.00034", "border_width": 0, "id": "Dnmt3b", "y": 908.6019562226728}, {"node_label": "Igf1", "node_shape": "dot", "x": 914.9120962162712, "degree": 1, "node_size": 10, "color": "rgba(256, 256, 0, 1.0)", "title": "Igf1<br/>heat = 0.00034", "border_width": 0, "id": "Igf1", "y": 739.4711880223953}, {"node_label": "Gfi1b", "node_shape": "dot", "x": 622.6745219077685, "degree": 1, "node_size": 10, "color": "rgba(256, 256, 0, 1.0)", "title": "Gfi1b<br/>heat = 0.00034", "border_width": 0, "id": "Gfi1b", "y": 750.3851623342517}, {"node_label": "Wrn", "node_shape": "dot", "x": 61.764305050713844, "degree": 1, "node_size": 10, "color": "rgba(256, 208, 0, 1.0)", "title": "Wrn<br/>heat = 0.00078", "border_width": 0, "id": "Wrn", "y": 751.3362774649061}, {"node_label": "Nampt", "node_shape": "dot", "x": 51.76819870748004, "degree": 1, "node_size": 10, "color": "rgba(256, 211, 0, 1.0)", "title": "Nampt<br/>heat = 0.00074", "border_width": 0, "id": "Nampt", "y": 693.8518375866921}, {"node_label": "Thpo", "node_shape": "dot", "x": 27.45676466501386, "degree": 1, "node_size": 10, "color": "rgba(256, 256, 0, 1.0)", "title": "Thpo<br/>heat = 0.00034", "border_width": 0, "id": "Thpo", "y": 686.4678721829558}, {"node_label": "Rnf144b", "node_shape": "triangle", "x": 985.7418635056181, "degree": 1, "node_size": 10, "color": "rgba(256, 5, 0, 1.0)", "title": "Rnf144b<br/>heat = 0.02778", "border_width": 2, "id": "Rnf144b", "y": 583.1403092606407}, {"node_label": "Anapc1", "node_shape": "dot", "x": 965.279738063767, "degree": 1, "node_size": 10, "color": "rgba(256, 256, 0, 1.0)", "title": "Anapc1<br/>heat = 0.00034", "border_width": 0, "id": "Anapc1", "y": 644.0214126874081}, {"node_label": "Anapc2", "node_shape": "dot", "x": 599.1469421798072, "degree": 1, "node_size": 10, "color": "rgba(256, 256, 0, 1.0)", "title": "Anapc2<br/>heat = 0.00034", "border_width": 0, "id": "Anapc2", "y": 809.9380882072458}, {"node_label": "Anapc5", "node_shape": "dot", "x": 676.2768404394576, "degree": 1, "node_size": 10, "color": "rgba(256, 256, 0, 1.0)", "title": "Anapc5<br/>heat = 0.00034", "border_width": 0, "id": "Anapc5", "y": 687.1034174321194}, {"node_label": "Tfdp2", "node_shape": "dot", "x": 933.2812706877156, "degree": 1, "node_size": 10, "color": "rgba(256, 256, 0, 1.0)", "title": "Tfdp2<br/>heat = 0.00034", "border_width": 0, "id": "Tfdp2", "y": 599.7072009320304}, {"node_label": "Tfdp1", "node_shape": "dot", "x": 843.2841043333424, "degree": 1, "node_size": 10, "color": "rgba(256, 256, 0, 1.0)", "title": "Tfdp1<br/>heat = 0.00034", "border_width": 0, "id": "Tfdp1", "y": 333.239145404563}, {"node_label": "Irf3", "node_shape": "dot", "x": 483.51177923055934, "degree": 1, "node_size": 10, "color": "rgba(256, 230, 0, 1.0)", "title": "Irf3<br/>heat = 0.00053", "border_width": 0, "id": "Irf3", "y": 10.896008447265633}, {"node_label": "Sgk1", "node_shape": "dot", "x": 535.9803170713366, "degree": 2, "node_size": 10, "color": "rgba(256, 256, 0, 1.0)", "title": "Sgk1<br/>heat = 0.00034", "border_width": 0, "id": "Sgk1", "y": 858.9268328643136}, {"node_label": "Ifng", "node_shape": "dot", "x": 130.64827396774584, "degree": 1, "node_size": 10, "color": "rgba(256, 225, 0, 1.0)", "title": "Ifng<br/>heat = 0.00058", "border_width": 0, "id": "Ifng", "y": 841.5779596628263}, {"node_label": "Sp1", "node_shape": "dot", "x": 628.7532503179823, "degree": 2, "node_size": 10, "color": "rgba(256, 230, 0, 1.0)", "title": "Sp1<br/>heat = 0.00053", "border_width": 0, "id": "Sp1", "y": 905.7688505417973}, {"node_label": "Sp3", "node_shape": "dot", "x": 849.8669101851018, "degree": 1, "node_size": 10, "color": "rgba(256, 256, 0, 1.0 ...

# %% [markdown]
# ## Clustering
# <a id='cluster'></a>

# %% [markdown]
# Parameter information:
# - **G_DEG**: background network filtered by DEG list, output of load_STRING_to_digraph
# - **DG_universe**: full background network, output of create_graph.load_STRING_to_digraph
# - **seed_nodes**: list of DEG's, output of create_graph.create_DEG_list
# - **Wprime**: will calculate automatically of not specified, output of visualizations.normalized_adj_matrix
# - **num_top_genes**: number of genes to display in the output graph
# - **cluster_size_cut_off**: color clusters below this threshhold grey
# - **remove_stray_nodes**: remove custers below the cluster size cut off
# - **r**: increases spacing between clusters. recommended number between 0.5 and 4.0
# - **x_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **y_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **node_spacing**: recommended number between 500 and 2000
# - **node_size_multiplier**: as you scale node_spacing, scale this number. Recommended number between 5 and 25
# - **physics_enabled**: Nodes will bounce aroound when you click and drag them. Only set to True when number of nodes is 200 or less
# - **node_font_size**: as you scale node_spacing, scale this number. Recommended number between 20 and 50
# - **graph_id**: Allows rendering of multiple graphs in one notebook. Just make sure each graph has a unique id.

# %%
heat.draw_clustering(rad_positions = False,
                Wprime = Wprime,
                k = None,
                largest_connected_component = True,
                num_top_genes = 500,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                node_spacing = 700,
                node_size_multiplier = 5,
                physics_enabled = False,
                node_font_size = 16,
                graph_id = 2
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file2"];    frame.runVis([{"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Dnmt3b<br/>cluster = 0", "color": "#004033", "y": 544.4788390835137, "x": 208.91485156552085, "border_width": 0, "id": "Dnmt3b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Igf1<br/>cluster = 1", "color": "#ff0044", "y": 301.76252785408906, "x": 403.4782515742716, "border_width": 0, "id": "Igf1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Gfi1b<br/>cluster = 0", "color": "#004033", "y": 501.41942404350056, "x": 168.8536760887441, "border_width": 0, "id": "Gfi1b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Prkag1<br/>cluster = 3", "color": "#3000b3", "y": 331.95053858163334, "x": 261.63478443595767, "border_width": 0, "id": "Prkag1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Psen2<br/>cluster = 4", "color": "#000c59", "y": 187.93202592728463, "x": 127.46501866832185, "border_width": 0, "id": "Psen2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Psen1<br/>cluster = 4", "color": "#000c59", "y": 193.27216503704346, "x": 190.9585676196134, "border_width": 0, "id": "Psen1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Prkag2<br/>cluster = 3", "color": "#3000b3", "y": 321.29273298773535, "x": 226.4104264833036, "border_width": 0, "id": "Prkag2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nampt<br/>cluster = 2", "color": "#a300cc", "y": 194.03938616240006, "x": 352.5037870680846, "border_width": 0, "id": "Nampt"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Tnfaip3<br/>cluster = 3", "color": "#3000b3", "y": 344.1231696081148, "x": 151.09697163223305, "border_width": 0, "id": "Tnfaip3"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Thpo<br/>cluster = 1", "color": "#ff0044", "y": 306.6457018549159, "x": 550.2332376340606, "border_width": 0, "id": "Thpo"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Rbm4<br/>cluster = 2", "color": "#a300cc", "y": 0.6658297983812249, "x": 420.5189161575152, "border_width": 0, "id": "Rbm4"}, {"node_label": "Rnf144b", "node_shape": "triangle", "degree": 3.0, "title": "Rnf144b<br/>cluster = 5", "color": "#00d9ca", "y": 576.1762178152466, "x": 327.9937881220495, "border_width": 0, "id": "Rnf144b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Anapc1<br/>cluster = 6", "color": "#00f281", "y": 480.5627398259582, "x": 413.58329768373073, "border_width": 0, "id": "Anapc1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nr1d1<br/>cluster = 2", "color": "#a300cc", "y": 111.95554597585868, "x": 338.4931963196123, "border_width": 0, "id": "Nr1d1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nr1d2<br/>cluster = 2", "color": "#a300cc", "y": 59.67253694416289, "x": 222.6575043996344, "border_width": 0, "id": "Nr1d2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Anapc2<br/>cluster = 6", "color": "#00f281", "y": 475.07934410747856, "x": 373.1201019200587, "border_width": 0, "id": "Anapc2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Anapc5<br/>cluster = 6", "color": "#00f281", "y": 487.6925444433706, "x": 422.116306208063, "border_width": 0, "id": "Anapc5"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Tfdp2<br/>cluster = 0", "color": "#004033", "y": 427.1736683934774, "x": 468.3531596676119, "border_width": 0, "id": "Tfdp2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Anapc7<br/>cluster = 6", "color": "#00f281", "y": 481.9355463066082, "x": 438.45552603583764, "border_width": 0, "id": "Anapc7"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Irf3<br/>cluster = 4", "color": "#000c59", "y":  ...

# %%
heat.draw_clustering(Wprime = Wprime,
                num_top_genes = 500,
                cluster_size_cut_off = 5,
#                remove_stray_nodes = True,
                r = 1.2,
#                x_offset = 2,
#                y_offset = 2,
                node_spacing = 700,
                node_size_multiplier = 12,
                physics_enabled = False,
                node_font_size = 45,
                graph_id = 3,
                node_shadow_x = 6
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file3"];    frame.runVis([{"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Dnmt3b<br/>cluster = 0", "color": "#004033", "y": 74.32638132916671, "x": 1197.2723132648132, "border_width": 0, "id": "Dnmt3b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Rbm4<br/>cluster = 1", "color": "#ff0044", "y": 847.1128277162354, "x": 643.9241291349011, "border_width": 0, "id": "Rbm4"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Gfi1b<br/>cluster = 0", "color": "#004033", "y": 374.0164632152561, "x": 1391.9851249223564, "border_width": 0, "id": "Gfi1b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Cul1<br/>cluster = 0", "color": "#004033", "y": 315.87441111444343, "x": 1024.7388347256476, "border_width": 0, "id": "Cul1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Wrn<br/>cluster = 2", "color": "#a300cc", "y": 827.2385125302546, "x": 419.67618498482415, "border_width": 0, "id": "Wrn"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Psen2<br/>cluster = 3", "color": "#3000b3", "y": 1290.8778233755659, "x": -161.90558595747544, "border_width": 0, "id": "Psen2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Psen1<br/>cluster = 3", "color": "#3000b3", "y": 1221.3785185540935, "x": -205.49786712868132, "border_width": 0, "id": "Psen1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Prkag2<br/>cluster = 4", "color": "#000c59", "y": 604.7059265286633, "x": -358.6592879608419, "border_width": 0, "id": "Prkag2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nampt<br/>cluster = 2", "color": "#a300cc", "y": 1021.9964930641061, "x": 411.527124223152, "border_width": 0, "id": "Nampt"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Tnfaip3<br/>cluster = 4", "color": "#000c59", "y": 517.1362247623773, "x": -240.0467744520444, "border_width": 0, "id": "Tnfaip3"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Thpo<br/>cluster = 2", "color": "#a300cc", "y": 971.0360721370727, "x": 460.66233663337914, "border_width": 0, "id": "Thpo"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Igf1<br/>cluster = 2", "color": "#a300cc", "y": 1122.279408652101, "x": 486.43522645932853, "border_width": 0, "id": "Igf1"}, {"node_label": "Rnf144b", "node_shape": "triangle", "degree": 3.0, "title": "Rnf144b<br/>cluster = 1", "color": "#ff0044", "y": 737.5844736961229, "x": 756.5799569220846, "border_width": 0, "id": "Rnf144b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Crk<br/>cluster = 2", "color": "#a300cc", "y": 1032.2607990151414, "x": 567.1629523319186, "border_width": 0, "id": "Crk"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Anapc1<br/>cluster = 0", "color": "#004033", "y": 440.6424623029046, "x": 1128.2263540838742, "border_width": 0, "id": "Anapc1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nr1d1<br/>cluster = 1", "color": "#ff0044", "y": 696.8332928761145, "x": 852.0942336863443, "border_width": 0, "id": "Nr1d1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nr1d2<br/>cluster = 1", "color": "#ff0044", "y": 577.0720204895966, "x": 908.0604795265184, "border_width": 0, "id": "Nr1d2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Anapc2<br/>cluster = 0", "color": "#004033", "y": 412.85973528193495, "x": 1051.5852081794715, "border_width": 0, "id": "Anapc2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Anapc5<br/>cluster = 0", "color": "#004033", "y": 435.4340676863884, "x": 1093.611733564276, "border_width": 0, "id": "Anapc5"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Card6<br/>cluster = 4", "color": "#000c59", "y": 401.49310 ...
