# %% [markdown]
# # Space Mice Genes
# ## Heat Propagation and Clustering Package
#
#
# ----------------------
#
# Author: Mikayla Webster (13webstermj@gmail.com)
#
# Date: 6th April, 2018
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Define Analysis Preferences](#pref)
# 3. [Load Networks](#load)
# 4. [Run Heat Propagation](#heat)
# 5. [Clustering](#cluster)

# %% [markdown]
# ## Background
# <a id='background'></a>

# %% [markdown]
# ## Import packages
# <a id='import'></a>

# %%
import sys
code_path = '../../network_bio_toolkit'
sys.path.append(code_path)

import Heat
reload(Heat)

import pandas as pd

# %% [markdown]
# ## Define Analysis Preferences
# <a id='pref'></a>

# %%
symbol = 'symbol'
entrez = 'entrez'

human = 'human'
mouse = 'mouse'

heat = Heat.Heat(gene_type = symbol, species = mouse)

# %% [markdown]
# ## Load Networks
# <a id='load'></a>
#
# 1. Load DEG file
# 2. Load STRING background network

# %%
# load DEG file
DEG_filename = "../../DEG_databases/DE_CoeffspaceFlight - groundControl_glds48_20180312.csv"  
heat.create_DEG_list(DEG_filename, p_value_filter = 0.02, sep = ',')

print "Number of DEG's: " + str(len(heat.DEG_list))
# Out:
# Number of DEG's: 45
# ../../network_bio_toolkit\create_graph.py:251: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   df = pd.DataFrame.from_csv(filename, sep=sep)

# %%
# load background network
filename = "../../background_networks/10090.protein.actions.v10.5.txt"
heat.load_STRING_to_digraph(filename, confidence_filter = 400)

print "\nNumber of interactions: " + str(len(list(heat.G_DEG.edges())))
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-7303...done.
# Finished.
# 57 input query terms found dup hits:
# 	[(u'ENSMUSP00000042658', 2), (u'ENSMUSP00000126737', 2), (u'ENSMUSP00000051968', 3), (u'ENSMUSP00000
# 154 input query terms found no hit:
# 	[u'ENSMUSP00000036849', u'ENSMUSP00000097354', u'ENSMUSP00000097358', u'ENSMUSP00000137522', u'ENSMU
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
#
# Number of interactions: 442

# %% [markdown]
# ## Run Heat Propagation
# <a id='heat'></a>

# %%
Wprime = heat.normalized_adj_matrix() # optional. Only if you want to inspet Wprime

# %%
heat.draw_heat_prop(Wprime = Wprime, # you don't have to pass this argument. Will calculate automatically
                  num_nodes = 500,
#                  random_walk = False,
                  edge_width = 2,
                  edge_smooth_enabled = True,
                  edge_smooth_type = 'bezier',
                  node_size_multiplier = 5,
                  hover = False,
                  hover_connected_edges = False,
                  largest_connected_component = True,
                  physics_enabled = True,
                  node_font_size = 40,
                  graph_id = 1,
                  node_shadow_x = 6)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"node_label": "Dnmt3b", "node_shape": "dot", "x": 155.44936902860962, "degree": 1, "node_size": 10, "color": "rgba(256, 145, 0, 1.0)", "title": "Dnmt3b<br/>heat = 0.00029", "border_width": 0, "id": "Dnmt3b", "y": 453.13961227530035}, {"node_label": "Igf1", "node_shape": "dot", "x": 375.42602264585344, "degree": 1, "node_size": 10, "color": "rgba(256, 145, 0, 1.0)", "title": "Igf1<br/>heat = 0.00029", "border_width": 0, "id": "Igf1", "y": 65.62458165750711}, {"node_label": "Gfi1b", "node_shape": "dot", "x": 198.38361384416874, "degree": 1, "node_size": 10, "color": "rgba(256, 145, 0, 1.0)", "title": "Gfi1b<br/>heat = 0.00029", "border_width": 0, "id": "Gfi1b", "y": 77.17306271482896}, {"node_label": "Wrn", "node_shape": "dot", "x": 575.3299677800708, "degree": 1, "node_size": 10, "color": "rgba(256, 229, 0, 1.0)", "title": "Wrn<br/>heat = 1e-05", "border_width": 0, "id": "Wrn", "y": 988.5865816379363}, {"node_label": "Psen2", "node_shape": "dot", "x": 648.6334926232239, "degree": 1, "node_size": 10, "color": "rgba(256, 167, 0, 1.0)", "title": "Psen2<br/>heat = 0.00012", "border_width": 0, "id": "Psen2", "y": 972.9919475867031}, {"node_label": "Psen1", "node_shape": "dot", "x": 710.5908819599362, "degree": 1, "node_size": 10, "color": "rgba(256, 174, 0, 1.0)", "title": "Psen1<br/>heat = 9e-05", "border_width": 0, "id": "Psen1", "y": 945.3217043327569}, {"node_label": "Nampt", "node_shape": "dot", "x": 994.9336234231546, "degree": 1, "node_size": 10, "color": "rgba(256, 123, 0, 1.0)", "title": "Nampt<br/>heat = 0.00073", "border_width": 0, "id": "Nampt", "y": 503.3679406738942}, {"node_label": "Tnfaip3", "node_shape": "dot", "x": 779.7104019329977, "degree": 1, "node_size": 10, "color": "rgba(256, 123, 0, 1.0)", "title": "Tnfaip3<br/>heat = 0.00073", "border_width": 0, "id": "Tnfaip3", "y": 87.75127501466245}, {"node_label": "Thpo", "node_shape": "dot", "x": 431.7415595573153, "degree": 1, "node_size": 10, "color": "rgba(256, 145, 0, 1.0)", "title": "Thpo<br/>heat = 0.00029", "border_width": 0, "id": "Thpo", "y": 999.0317225650062}, {"node_label": "Rbm4", "node_shape": "dot", "x": 866.5755299052591, "degree": 1, "node_size": 10, "color": "rgba(256, 167, 0, 1.0)", "title": "Rbm4<br/>heat = 0.00012", "border_width": 0, "id": "Rbm4", "y": 819.0482654220581}, {"node_label": "Rnf144b", "node_shape": "triangle", "x": 269.52317138153944, "degree": 1, "node_size": 10, "color": "rgba(256, 34, 0, 1.0)", "title": "Rnf144b<br/>heat = 0.02778", "border_width": 2, "id": "Rnf144b", "y": 802.5262792235975}, {"node_label": "Anapc1", "node_shape": "dot", "x": 522.4983740186223, "degree": 1, "node_size": 10, "color": "rgba(256, 145, 0, 1.0)", "title": "Anapc1<br/>heat = 0.00029", "border_width": 0, "id": "Anapc1", "y": 62.440923944958215}, {"node_label": "Nr1d1", "node_shape": "dot", "x": 935.8695501830666, "degree": 1, "node_size": 10, "color": "rgba(256, 181, 0, 1.0)", "title": "Nr1d1<br/>heat = 7e-05", "border_width": 0, "id": "Nr1d1", "y": 696.3172374591876}, {"node_label": "Nr1d2", "node_shape": "dot", "x": 994.4819293089114, "degree": 1, "node_size": 10, "color": "rgba(256, 181, 0, 1.0)", "title": "Nr1d2<br/>heat = 7e-05", "border_width": 0, "id": "Nr1d2", "y": 469.1904794145241}, {"node_label": "Anapc2", "node_shape": "dot", "x": 523.2198160281313, "degree": 1, "node_size": 10, "color": "rgba(256, 145, 0, 1.0)", "title": "Anapc2<br/>heat = 0.00029", "border_width": 0, "id": "Anapc2", "y": 291.6326705702654}, {"node_label": "Anapc5", "node_shape": "dot", "x": 361.5542413184366, "degree": 1, "node_size": 10, "color": "rgba(256, 145, 0, 1.0)", "title": "Anapc5<br/>heat = 0.00029", "border_width": 0, "id": "Anapc5", "y": 26.029703955566216}, {"node_label": "Tfdp2", "node_shape": "dot", "x": 276.34315159137435, "degree": 1, "node_size": 10, "color": "rg ...

# %% [markdown]
# ## Clustering
# <a id='cluster'></a>

# %% [markdown]
# Parameter information:
# - **G_DEG**: background network filtered by DEG list, output of load_STRING_to_digraph
# - **DG_universe**: full background network, output of create_graph.load_STRING_to_digraph
# - **seed_nodes**: list of DEG's, output of create_graph.create_DEG_list
# - **Wprime**: will calculate automatically of not specified, output of visualizations.normalized_adj_matrix
# - **num_top_genes**: number of genes to display in the output graph
# - **cluster_size_cut_off**: color clusters below this threshhold grey
# - **remove_stray_nodes**: remove custers below the cluster size cut off
# - **r**: increases spacing between clusters. recommended number between 0.5 and 4.0
# - **x_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **y_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **node_spacing**: recommended number between 500 and 2000
# - **node_size_multiplier**: as you scale node_spacing, scale this number. Recommended number between 5 and 25
# - **physics_enabled**: Nodes will bounce aroound when you click and drag them. Only set to True when number of nodes is 200 or less
# - **node_font_size**: as you scale node_spacing, scale this number. Recommended number between 20 and 50
# - **graph_id**: Allows rendering of multiple graphs in one notebook. Just make sure each graph has a unique id.

# %%
heat.draw_clustering(rad_positions = False,
                Wprime = Wprime,
                k = None,
                largest_connected_component = True,
                num_top_genes = 500,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                node_spacing = 700,
                node_size_multiplier = 5,
                physics_enabled = False,
                node_font_size = 16,
                graph_id = 2
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file2"];    frame.runVis([{"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Dnmt3b<br/>cluster = 0", "color": "#004033", "y": 154.11145393040647, "x": 216.0367645684005, "border_width": 0, "id": "Dnmt3b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Dnmt3a<br/>cluster = 0", "color": "#004033", "y": 507.7566246659553, "x": 59.27525262288669, "border_width": 0, "id": "Dnmt3a"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Gfi1b<br/>cluster = 0", "color": "#004033", "y": 310.5922570448245, "x": 4.286102393691934, "border_width": 0, "id": "Gfi1b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Prkag1<br/>cluster = 1", "color": "#ff0044", "y": 264.0631422647529, "x": 278.5919547075913, "border_width": 0, "id": "Prkag1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Psen2<br/>cluster = 2", "color": "#a300cc", "y": 423.80817883067476, "x": 523.4597468358753, "border_width": 0, "id": "Psen2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Psen1<br/>cluster = 2", "color": "#a300cc", "y": 411.9257607887936, "x": 497.6968535952037, "border_width": 0, "id": "Psen1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Prkag2<br/>cluster = 1", "color": "#ff0044", "y": 236.4211454219841, "x": 270.5462488415674, "border_width": 0, "id": "Prkag2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nampt<br/>cluster = 3", "color": "#3000b3", "y": 238.6723433492742, "x": 366.55400033484466, "border_width": 0, "id": "Nampt"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Tnfaip3<br/>cluster = 1", "color": "#ff0044", "y": 229.68588547186366, "x": 433.62256805151543, "border_width": 0, "id": "Tnfaip3"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Thpo<br/>cluster = 4", "color": "#000c59", "y": 525.5574213707398, "x": 197.29931934484932, "border_width": 0, "id": "Thpo"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Rbm4<br/>cluster = 3", "color": "#3000b3", "y": 203.32331784754646, "x": 626.1904767489942, "border_width": 0, "id": "Rbm4"}, {"node_label": "Rnf144b", "node_shape": "triangle", "degree": 3.0, "title": "Rnf144b<br/>cluster = 3", "color": "#3000b3", "y": 539.0450923993014, "x": 490.4745923102348, "border_width": 0, "id": "Rnf144b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Anapc1<br/>cluster = 0", "color": "#004033", "y": 530.0419356346982, "x": 318.202608197366, "border_width": 0, "id": "Anapc1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nr1d1<br/>cluster = 3", "color": "#3000b3", "y": 189.22831919995585, "x": 400.63670874920035, "border_width": 0, "id": "Nr1d1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nr1d2<br/>cluster = 3", "color": "#3000b3", "y": 20.050197702203256, "x": 348.0547770123031, "border_width": 0, "id": "Nr1d2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Anapc2<br/>cluster = 0", "color": "#004033", "y": 497.8098896770812, "x": 365.4946098082482, "border_width": 0, "id": "Anapc2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Anapc5<br/>cluster = 0", "color": "#004033", "y": 515.5214817456996, "x": 340.0324161769486, "border_width": 0, "id": "Anapc5"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Tfdp2<br/>cluster = 5", "color": "#00d9ca", "y": 492.3044891137291, "x": 275.68436843472847, "border_width": 0, "id": "Tfdp2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Anapc7<br/>cluster = 0", "color": "#004033", "y": 526.5781512352637, "x": 305.01022400781824, "border_width": 0, "id": "Anapc7"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Irf3<br/>cluster = 2", "color": "#a300cc", "y":  ...

# %%
heat.draw_clustering(Wprime = Wprime,
                num_top_genes = 500,
                cluster_size_cut_off = 5,
#                remove_stray_nodes = True,
                r = 1.2,
#                x_offset = 2,
#                y_offset = 2,
                node_spacing = 700,
                node_size_multiplier = 12,
                physics_enabled = False,
                node_font_size = 45,
                graph_id = 3,
                node_shadow_x = 6
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file3"];    frame.runVis([{"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Dnmt3b<br/>cluster = 0", "color": "#004033", "y": 663.0535321844158, "x": 1137.1288531647174, "border_width": 0, "id": "Dnmt3b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Rbm4<br/>cluster = 1", "color": "#ff0044", "y": 845.2677335563103, "x": 644.2119535496531, "border_width": 0, "id": "Rbm4"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Gfi1b<br/>cluster = 0", "color": "#004033", "y": 669.4659683327361, "x": 1093.794292188834, "border_width": 0, "id": "Gfi1b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Cul1<br/>cluster = 1", "color": "#ff0044", "y": 970.2245800900137, "x": 857.993646551977, "border_width": 0, "id": "Cul1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Wrn<br/>cluster = 2", "color": "#a300cc", "y": 910.9365531648244, "x": 267.193039441436, "border_width": 0, "id": "Wrn"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Psen2<br/>cluster = 3", "color": "#3000b3", "y": 859.5460378616931, "x": -177.40293139244244, "border_width": 0, "id": "Psen2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Psen1<br/>cluster = 3", "color": "#3000b3", "y": 909.4937669976125, "x": -198.81909170865467, "border_width": 0, "id": "Psen1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Prkag2<br/>cluster = 4", "color": "#000c59", "y": 671.5864060200092, "x": -377.5895542867836, "border_width": 0, "id": "Prkag2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nampt<br/>cluster = 1", "color": "#ff0044", "y": 844.5387396749187, "x": 840.7607650289674, "border_width": 0, "id": "Nampt"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Tnfaip3<br/>cluster = 4", "color": "#000c59", "y": 619.0442618988276, "x": -252.313054770691, "border_width": 0, "id": "Tnfaip3"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Thpo<br/>cluster = 2", "color": "#a300cc", "y": 1042.9837610296433, "x": 415.50935934507305, "border_width": 0, "id": "Thpo"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Dnmt3a<br/>cluster = 0", "color": "#004033", "y": 598.77793308269, "x": 1309.4961365395877, "border_width": 0, "id": "Dnmt3a"}, {"node_label": "Rnf144b", "node_shape": "triangle", "degree": 3.0, "title": "Rnf144b<br/>cluster = 2", "color": "#a300cc", "y": 1304.7638616748072, "x": 252.38629527079752, "border_width": 0, "id": "Rnf144b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Crk<br/>cluster = 2", "color": "#a300cc", "y": 1060.003002794504, "x": 535.063481479435, "border_width": 0, "id": "Crk"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Anapc1<br/>cluster = 0", "color": "#004033", "y": 526.5911939123893, "x": 1190.4627148936559, "border_width": 0, "id": "Anapc1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nr1d1<br/>cluster = 1", "color": "#ff0044", "y": 924.2824665328038, "x": 776.145303011693, "border_width": 0, "id": "Nr1d1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nr1d2<br/>cluster = 1", "color": "#ff0044", "y": 990.984074299224, "x": 713.988825198101, "border_width": 0, "id": "Nr1d2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Anapc2<br/>cluster = 0", "color": "#004033", "y": 516.281362226415, "x": 1154.4251952327988, "border_width": 0, "id": "Anapc2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Anapc5<br/>cluster = 0", "color": "#004033", "y": 520.7503406189318, "x": 1205.4122093218211, "border_width": 0, "id": "Anapc5"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Card6<br/>cluster = 4", "color": "#000c59", "y": 543.5434453450226,  ...
