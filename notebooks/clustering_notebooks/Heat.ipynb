# %% [markdown]
# # Space Mice Genes
# ## Heat Propagation and Clustering Package
#
#
# ----------------------
#
# Author: Mikayla Webster (13webstermj@gmail.com)
#
# Date: 6th April, 2018
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Define Analysis Preferences](#pref)
# 3. [Load Networks](#load)
# 4. [Run Heat Propagation](#heat)
# 5. [Clustering](#cluster)

# %% [markdown]
# ## Background
# <a id='background'></a>

# %% [markdown]
# ## Import packages
# <a id='import'></a>

# %%
import sys
code_path = '../../network_bio_toolkit'
sys.path.append(code_path)

import importlib
import Heat
reload(Heat)

import create_graph
reload(create_graph)

import networkx as nx
import pandas as pd
import community
import heat_and_cluster
reload(heat_and_cluster)

import visJS2jupyter.visualizations as visualizations
reload(visualizations)

import visJS2jupyter.visJS_module as visJS_module
reload(visJS_module)

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Define Analysis Preferences
# <a id='pref'></a>

# %%
symbol = 'symbol'
entrez = 'entrez'

human = 'human'
mouse = 'mouse'

heat = Heat.Heat(gene_type = symbol, species = mouse)

# %% [markdown]
# ## Load Networks
# <a id='load'></a>
#
# 1. Load STRING background network
# 2. Load DEG file

# %%
#filename = '../../background_networks/10090.protein.links.v10.5.txt'
#heat.load_STRING_links(filename, confidence_filter = 700)

#print('\nNumber of interactions: ' + str(len(list(heat.DG_universe.edges()))))

# %%
# load DEG file
DEG_filename = '../../DEG_databases/DE_CoeffspaceFlight - groundControl_glds48_20180312.csv'  
heat.create_DEG_list(DEG_filename, p_value_filter = 0.02, sep = ',')

print('Number of DEG\'s: ' + str(len(heat.DEG_list)))
# Out:
# Number of DEG's: 45

# %%
#saved_DG_universe = heat.DG_universe
heat.DG_universe = saved_DG_universe

# %% [markdown]
# ## Run Heat Propagation
# <a id='heat'></a>

# %%
#heat.normalized_adj_matrix()

# %%
#saved_Wprime = heat.Wprime
heat.Wprime = saved_Wprime

# %%
heat.draw_heat_prop(num_nodes = 500,
#                  random_walk = False,
                  edge_width = 2,
                  edge_smooth_enabled = True,
                  edge_smooth_type = 'bezier',
                  node_size_multiplier = 5,
                  hover = False,
                  hover_connected_edges = False,
                  largest_connected_component = True,
                  physics_enabled = True,
                  node_font_size = 40,
                  graph_id = 1,
                  node_shadow_x = 6)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"node_label": "Chic1", "node_shape": "triangle", "x": 0.0, "degree": 1, "node_size": 10, "color": "rgba(256, 19, 0, 1.0)", "title": "Chic1<br/>heat = 0.01736", "border_width": 2, "id": "Chic1", "y": 0.0}, {"node_label": "", "node_shape": "dot", "x": 758.4967396448695, "degree": 6, "node_size": 10, "color": "rgba(256, 215, 0, 1.0)", "title": "Nampt<br/>heat = 0.00045", "border_width": 0, "id": "Nampt", "y": 720.7449428811004}, {"node_label": "", "node_shape": "dot", "x": 797.44981656628, "degree": 36, "node_size": 10, "color": "rgba(256, 248, 0, 1.0)", "title": "Hsd3b4<br/>heat = 0.00024", "border_width": 0, "id": "Hsd3b4", "y": 590.6572840017219}, {"node_label": "", "node_shape": "dot", "x": 797.3782985636367, "degree": 36, "node_size": 10, "color": "rgba(256, 251, 0, 1.0)", "title": "Hsd3b5<br/>heat = 0.00023", "border_width": 0, "id": "Hsd3b5", "y": 591.0365058763631}, {"node_label": "", "node_shape": "dot", "x": 797.2830185169611, "degree": 35, "node_size": 10, "color": "rgba(256, 251, 0, 1.0)", "title": "Hsd3b6<br/>heat = 0.00023", "border_width": 0, "id": "Hsd3b6", "y": 591.2949852036462}, {"node_label": "", "node_shape": "dot", "x": 792.674206701548, "degree": 45, "node_size": 10, "color": "rgba(256, 228, 0, 1.0)", "title": "Cyp2c23<br/>heat = 0.00035", "border_width": 0, "id": "Cyp2c23", "y": 600.1571026527713}, {"node_label": "", "node_shape": "dot", "x": 797.3775917017882, "degree": 37, "node_size": 10, "color": "rgba(256, 210, 0, 1.0)", "title": "Hsd3b1<br/>heat = 0.00049", "border_width": 0, "id": "Hsd3b1", "y": 590.8780073112353}, {"node_label": "", "node_shape": "dot", "x": 797.2967198954588, "degree": 35, "node_size": 10, "color": "rgba(256, 251, 0, 1.0)", "title": "Hsd3b2<br/>heat = 0.00023", "border_width": 0, "id": "Hsd3b2", "y": 591.2583518279843}, {"node_label": "", "node_shape": "dot", "x": 802.9645677943033, "degree": 12, "node_size": 10, "color": "rgba(256, 223, 0, 1.0)", "title": "Lrat<br/>heat = 0.00039", "border_width": 0, "id": "Lrat", "y": 596.9455191474684}, {"node_label": "", "node_shape": "dot", "x": 792.6258794677323, "degree": 45, "node_size": 10, "color": "rgba(256, 227, 0, 1.0)", "title": "Cyp2c29<br/>heat = 0.00035", "border_width": 0, "id": "Cyp2c29", "y": 600.2548261941088}, {"node_label": "", "node_shape": "dot", "x": 800.5728488253781, "degree": 27, "node_size": 10, "color": "rgba(256, 234, 0, 1.0)", "title": "Fdft1<br/>heat = 0.00031", "border_width": 0, "id": "Fdft1", "y": 587.6565388737838}, {"node_label": "", "node_shape": "dot", "x": 765.7263738573215, "degree": 16, "node_size": 10, "color": "rgba(256, 226, 0, 1.0)", "title": "Sp1<br/>heat = 0.00036", "border_width": 0, "id": "Sp1", "y": 659.9015576835467}, {"node_label": "", "node_shape": "dot", "x": 795.6229704986746, "degree": 16, "node_size": 10, "color": "rgba(256, 220, 0, 1.0)", "title": "Rdh5<br/>heat = 0.00041", "border_width": 0, "id": "Rdh5", "y": 613.8613842368615}, {"node_label": "", "node_shape": "dot", "x": 735.3598784540956, "degree": 8, "node_size": 10, "color": "rgba(256, 253, 0, 1.0)", "title": "Ngfr<br/>heat = 0.00022", "border_width": 0, "id": "Ngfr", "y": 722.567158438917}, {"node_label": "", "node_shape": "dot", "x": 799.9288965072615, "degree": 34, "node_size": 10, "color": "rgba(256, 223, 0, 1.0)", "title": "Sult2b1<br/>heat = 0.00039", "border_width": 0, "id": "Sult2b1", "y": 580.2696314456169}, {"node_label": "", "node_shape": "dot", "x": 746.4906613828637, "degree": 20, "node_size": 10, "color": "rgba(256, 239, 0, 1.0)", "title": "Flt1<br/>heat = 0.00028", "border_width": 0, "id": "Flt1", "y": 712.2365613561022}, {"node_label": "", "node_shape": "dot", "x": 996.3426907291343, "degree": 5, "node_size": 10, "color": "rgba(256, 165, 0, 1.0)", "title": "Aqp11<br/>heat = 0.00113", "border_width": 0, "id": "Aqp11", "y": ...

# %% [markdown]
# ## Clustering
# <a id='cluster'></a>

# %% [markdown]
# Parameter information:
# - **G_DEG**: background network filtered by DEG list, output of load_STRING_to_digraph
# - **DG_universe**: full background network, output of create_graph.load_STRING_to_digraph
# - **seed_nodes**: list of DEG's, output of create_graph.create_DEG_list
# - **Wprime**: will calculate automatically of not specified, output of visualizations.normalized_adj_matrix
# - **num_top_genes**: number of genes to display in the output graph
# - **cluster_size_cut_off**: color clusters below this threshhold grey
# - **remove_stray_nodes**: remove custers below the cluster size cut off
# - **r**: increases spacing between clusters. recommended number between 0.5 and 4.0
# - **x_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **y_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **node_spacing**: recommended number between 500 and 2000
# - **node_size_multiplier**: as you scale node_spacing, scale this number. Recommended number between 5 and 25
# - **physics_enabled**: Nodes will bounce aroound when you click and drag them. Only set to True when number of nodes is 200 or less
# - **node_font_size**: as you scale node_spacing, scale this number. Recommended number between 20 and 50
# - **graph_id**: Allows rendering of multiple graphs in one notebook. Just make sure each graph has a unique id.

# %%
heat.draw_clustering(rad_positions = False,
                k = None,
                largest_connected_component = True,
                num_top_genes = 500,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                node_spacing = 700,
                node_size_multiplier = 10,
                physics_enabled = True,
                node_font_size = 40,
                graph_id = 2,
                edge_width = 2,
                edge_smooth_enabled = True,
                edge_smooth_type = 'bezier',
                hover = False,
                color_lfc = True,
                vmin = -1,
                vmax = 1,
                hover_connected_edges = False
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file2"];    frame.runVis([{"node_label": "Chic1", "node_shape": "triangle", "degree": 3.0, "title": "Chic1<br/>cluster = 0", "color": "rgba(256, 74, 74, 1.0)", "y": 316.0554275360558, "x": 479.6193783706803, "border_width": 0, "id": "Chic1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nampt<br/>cluster = 1", "color": "rgba(256, 254, 254, 1.0)", "y": 329.301619630867, "x": 263.6489180052615, "border_width": 0, "id": "Nampt"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hsd3b4<br/>cluster = 2", "color": "rgba(256, 254, 254, 1.0)", "y": 232.73035899310912, "x": 363.5373819036512, "border_width": 0, "id": "Hsd3b4"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hsd3b5<br/>cluster = 2", "color": "rgba(256, 254, 254, 1.0)", "y": 233.01876038577933, "x": 363.2251060131643, "border_width": 0, "id": "Hsd3b5"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hsd3b6<br/>cluster = 2", "color": "rgba(256, 254, 254, 1.0)", "y": 233.27963703622052, "x": 362.9433125671452, "border_width": 0, "id": "Hsd3b6"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Cyp2c23<br/>cluster = 2", "color": "rgba(256, 254, 254, 1.0)", "y": 244.28481011146425, "x": 351.70767630861144, "border_width": 0, "id": "Cyp2c23"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hsd3b1<br/>cluster = 2", "color": "rgba(256, 254, 254, 1.0)", "y": 232.70620998186865, "x": 363.53055860824804, "border_width": 0, "id": "Hsd3b1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hsd3b2<br/>cluster = 2", "color": "rgba(256, 254, 254, 1.0)", "y": 233.24112423288003, "x": 362.98453524208105, "border_width": 0, "id": "Hsd3b2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Lrat<br/>cluster = 2", "color": "rgba(256, 254, 254, 1.0)", "y": 239.08502474258364, "x": 360.29608668924027, "border_width": 0, "id": "Lrat"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Cyp2c29<br/>cluster = 2", "color": "rgba(256, 254, 254, 1.0)", "y": 244.33555134098987, "x": 351.65111260310834, "border_width": 0, "id": "Cyp2c29"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Fdft1<br/>cluster = 2", "color": "rgba(256, 254, 254, 1.0)", "y": 224.61354119852638, "x": 373.6731581266541, "border_width": 0, "id": "Fdft1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Sp1<br/>cluster = 3", "color": "rgba(256, 254, 254, 1.0)", "y": 294.17514839154467, "x": 297.9015724021288, "border_width": 0, "id": "Sp1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Rdh5<br/>cluster = 2", "color": "rgba(256, 254, 254, 1.0)", "y": 256.98415852155426, "x": 340.1464632352022, "border_width": 0, "id": "Rdh5"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Ngfr<br/>cluster = 3", "color": "rgba(256, 254, 254, 1.0)", "y": 339.51345515966995, "x": 244.5821521638781, "border_width": 0, "id": "Ngfr"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Sult2b1<br/>cluster = 2", "color": "rgba(256, 254, 254, 1.0)", "y": 223.0418723616295, "x": 374.36261684926086, "border_width": 0, "id": "Sult2b1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Flt1<br/>cluster = 3", "color": "rgba(256, 254, 254, 1.0)", "y": 330.24243281410213, "x": 259.1978356158246, "border_width": 0, "id": "Flt1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Aqp11<br/>cluster = 4", "color": "rgba(256, 254, 254, 1.0)", "y": 26.04348031027184, "x": 667.463583781578, "border_width": 0, "id": "Aqp11"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Aqp12<br/>cluster = 4", "color": "rgba(256, 254, 254, 1.0)", "y": 20.36050772300148, "x": 675.2792108691795, "border_width": 0, "id": "Aqp12"}, {"node_ ...

# %%
heat.draw_clustering(rad_positions = False,
                k = None,
                largest_connected_component = True,
                num_top_genes = 500,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                node_spacing = 700,
                node_size_multiplier = 10,
                physics_enabled = True,
                node_font_size = 40,
                graph_id = 5,
                edge_width = 2,
                edge_smooth_enabled = True,
                edge_smooth_type = 'bezier',
                hover = False,
                color_lfc = True,
                hover_connected_edges = False
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file5"];    frame.runVis([{"node_label": "Chic1", "node_shape": "triangle", "degree": 3.0, "title": "Chic1<br/>cluster = 0", "color": "rgba(256, 158, 158, 1.0)", "y": 0.0, "x": 0.0, "border_width": 0, "id": "Chic1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nampt<br/>cluster = 1", "color": "rgba(256, 196, 196, 1.0)", "y": 171.8427502521181, "x": 367.7224347879521, "border_width": 0, "id": "Nampt"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hsd3b4<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 216.87395675899583, "x": 440.32188147656, "border_width": 0, "id": "Hsd3b4"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hsd3b5<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 216.70457454424377, "x": 439.90068025837576, "border_width": 0, "id": "Hsd3b5"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hsd3b6<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 216.68198436895923, "x": 439.7684157802782, "border_width": 0, "id": "Hsd3b6"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Cyp2c23<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 212.23515422139602, "x": 434.6598586779563, "border_width": 0, "id": "Cyp2c23"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hsd3b1<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 216.81853441028034, "x": 440.2020134991616, "border_width": 0, "id": "Hsd3b1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hsd3b2<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 216.69939141031873, "x": 439.80672247221537, "border_width": 0, "id": "Hsd3b2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Lrat<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 209.77355942129057, "x": 445.644227609491, "border_width": 0, "id": "Lrat"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Cyp2c29<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 212.51472140506752, "x": 435.1665505750345, "border_width": 0, "id": "Cyp2c29"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Fdft1<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 215.7117223950246, "x": 446.75951894201273, "border_width": 0, "id": "Fdft1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Sp1<br/>cluster = 3", "color": "rgba(256, 196, 196, 1.0)", "y": 191.72201765824525, "x": 389.8471787359065, "border_width": 0, "id": "Sp1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Rdh5<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 203.56317483232024, "x": 429.4928217392812, "border_width": 0, "id": "Rdh5"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Ngfr<br/>cluster = 3", "color": "rgba(256, 196, 196, 1.0)", "y": 168.61528712352978, "x": 346.63171098221596, "border_width": 0, "id": "Ngfr"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Sult2b1<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 219.22313670612857, "x": 447.0082966531514, "border_width": 0, "id": "Sult2b1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Flt1<br/>cluster = 3", "color": "rgba(256, 196, 196, 1.0)", "y": 172.19585927571669, "x": 360.7162582286202, "border_width": 0, "id": "Flt1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Aqp11<br/>cluster = 4", "color": "rgba(256, 196, 196, 1.0)", "y": 89.09514969197349, "x": 674.1796766784844, "border_width": 0, "id": "Aqp11"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Aqp12<br/>cluster = 4", "color": "rgba(256, 196, 196, 1.0)", "y": 87.70204337825069, "x": 678.7945816908197, "border_width": 0, "id": "Aqp12"}, {"node_label": "", "node_shape": "do ...

# %%
heat.draw_clustering(num_top_genes = 500,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                r = 1,
                node_spacing = 600,
                node_size_multiplier = 4,
                physics_enabled = False,
                node_font_size = 15,
                graph_id = 3,
                node_shadow_x = 6,
                color_lfc = True,
                largest_connected_component = True
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file3"];    frame.runVis([{"node_label": "Chic1", "node_shape": "triangle", "degree": 3.0, "title": "Chic1<br/>cluster = 0", "color": "rgba(256, 158, 158, 1.0)", "y": 0.0, "x": 1097.425190623932, "border_width": 0, "id": "Chic1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nampt<br/>cluster = 1", "color": "rgba(256, 196, 196, 1.0)", "y": 535.9682050898664, "x": 543.5085197688926, "border_width": 0, "id": "Nampt"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hsd3b4<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 787.9775883360713, "x": 260.63310354418047, "border_width": 0, "id": "Hsd3b4"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hsd3b5<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 788.041168987898, "x": 260.8230745691066, "border_width": 0, "id": "Hsd3b5"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hsd3b6<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 788.0797255267634, "x": 260.7843770591015, "border_width": 0, "id": "Hsd3b6"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Cyp2c23<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 791.7613162793652, "x": 265.1386136982033, "border_width": 0, "id": "Cyp2c23"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hsd3b1<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 787.9096729140526, "x": 259.8520696138895, "border_width": 0, "id": "Hsd3b1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hsd3b2<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 787.9626549014856, "x": 260.74671859726885, "border_width": 0, "id": "Hsd3b2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Lrat<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 804.9817197877878, "x": 267.6906455891389, "border_width": 0, "id": "Lrat"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Cyp2c29<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 790.7059277651872, "x": 265.18498552863446, "border_width": 0, "id": "Cyp2c29"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Fdft1<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 792.1829523192762, "x": 257.33793242442493, "border_width": 0, "id": "Fdft1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Sp1<br/>cluster = 3", "color": "rgba(256, 196, 196, 1.0)", "y": 756.654405374753, "x": -114.15174429007801, "border_width": 0, "id": "Sp1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Rdh5<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 795.4028779986177, "x": 266.20551066099245, "border_width": 0, "id": "Rdh5"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Ngfr<br/>cluster = 3", "color": "rgba(256, 196, 196, 1.0)", "y": 744.6281873272548, "x": -115.34459270367299, "border_width": 0, "id": "Ngfr"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Sult2b1<br/>cluster = 2", "color": "rgba(256, 196, 196, 1.0)", "y": 793.2811341646116, "x": 261.8166629347483, "border_width": 0, "id": "Sult2b1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Flt1<br/>cluster = 3", "color": "rgba(256, 196, 196, 1.0)", "y": 754.6106043654613, "x": -118.41264989187052, "border_width": 0, "id": "Flt1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Aqp11<br/>cluster = 4", "color": "rgba(256, 196, 196, 1.0)", "y": 952.671151375484, "x": -485.4101966249684, "border_width": 0, "id": "Aqp11"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Aqp12<br/>cluster = 4", "color": "rgba(256, 196, 196, 1.0)", "y": 902.7691174067959, "x": -474.9184691776179, "border_width": 0, "id": "Aqp12"}, {"node_label": "", "node_s ...
