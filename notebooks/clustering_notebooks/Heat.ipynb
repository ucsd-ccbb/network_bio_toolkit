# %% [markdown]
# # Space Mice Genes
# ## Heat Propagation and Clustering Package
#
#
# ----------------------
#
# Author: Mikayla Webster (13webstermj@gmail.com)
#
# Date: 6th April, 2018
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Define Analysis Preferences](#pref)
# 3. [Load Networks](#load)
# 4. [Run Heat Propagation](#heat)
# 5. [Clustering](#cluster)

# %% [markdown]
# ## Background
# <a id='background'></a>

# %% [markdown]
# ## Import packages
# <a id='import'></a>

# %%
import sys
code_path = '../../network_bio_toolkit'
sys.path.append(code_path)
import Heat
reload(Heat)
import networkx as nx
import visJS2jupyter.visualizations as visualizations # pip install visJS2jupyter

# %% [markdown]
# ## Define Analysis Preferences
# <a id='pref'></a>

# %%
symbol = 'symbol'
entrez = 'entrez'

human = 'human'
mouse = 'mouse'

heat = Heat.Heat(gene_type = symbol, species = mouse)

# %% [markdown]
# ## Load Networks
# <a id='load'></a>
#
# 1. Load DEG file
# 2. Load STRING background network

# %%
# load DEG file
DEG_filename = "../../DEG_databases/DE_CoeffspaceFlight - groundControl_glds48_20180312.csv"  
heat.create_DEG_list(DEG_filename, p_value_filter = 0.1, sep = ',')

print "Number of DEG's: " + str(len(heat.DEG_list))
# Out:
# Number of DEG's: 394

# %%
# load background network
filename = "../../background_networks/10090.protein.actions.v10.5.txt"
heat.load_STRING_to_digraph(filename, confidence_filter = 400)

print "\nNumber of interactions: " + str(len(list(heat.G_DEG.edges())))
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-7303...done.
# Finished.
# 57 input query terms found dup hits:
# 	[(u'ENSMUSP00000042658', 2), (u'ENSMUSP00000126737', 2), (u'ENSMUSP00000051968', 3), (u'ENSMUSP00000
# 154 input query terms found no hit:
# 	[u'ENSMUSP00000036849', u'ENSMUSP00000097354', u'ENSMUSP00000097358', u'ENSMUSP00000137522', u'ENSMU
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
#
# Number of interactions: 2564

# %% [markdown]
# ## Run Heat Propagation
# <a id='heat'></a>

# %%
# delete this later

saved_G_DEG = heat.G_DEG
heat.G_DEG = saved_G_DEG

saved_DG_universe = heat.DG_universe
heat.DG_universe = saved_DG_universe

# %%
Wprime = heat.normalized_adj_matrix() # optional. Only if you want to inspet Wprime

# %%
heat.draw_heat_prop(Wprime = Wprime, # you don't have to pass this argument. Will calculate automatically
                  num_nodes = 200,
                  edge_width = 2,
                  edge_smooth_enabled = True,
                  edge_smooth_type = 'bezier',
                  node_size_multiplier = 5,
                  hover = False,
                  hover_connected_edges = False,
                  largest_connected_component = True,
                  physics_enabled = True,
                  node_font_size = 40,
                  graph_id = 1,
                  node_shadow_x = 6)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"node_label": "Dnmt3b", "node_shape": "triangle", "x": 811.2082552578945, "degree": 2, "node_size": 10, "color": "rgba(256, 133, 0, 1.0)", "title": "Dnmt3b<br/>heat = 0.0034", "border_width": 2, "id": "Dnmt3b", "y": 660.5595381218744}, {"node_label": "Rbm4", "node_shape": "dot", "x": 125.8038560087856, "degree": 1, "node_size": 10, "color": "rgba(256, 217, 0, 1.0)", "title": "Rbm4<br/>heat = 0.00144", "border_width": 0, "id": "Rbm4", "y": 163.28544826733503}, {"node_label": "Rnf144b", "node_shape": "triangle", "x": 968.5863650732729, "degree": 1, "node_size": 10, "color": "rgba(256, 131, 0, 1.0)", "title": "Rnf144b<br/>heat = 0.00346", "border_width": 2, "id": "Rnf144b", "y": 463.93413115099924}, {"node_label": "Nr1d1", "node_shape": "triangle", "x": 310.1845665057693, "degree": 3, "node_size": 10, "color": "rgba(256, 122, 0, 1.0)", "title": "Nr1d1<br/>heat = 0.0038", "border_width": 2, "id": "Nr1d1", "y": 50.36084111772857}, {"node_label": "Bcl6b", "node_shape": "triangle", "x": 942.3871858357612, "degree": 1, "node_size": 10, "color": "rgba(256, 134, 0, 1.0)", "title": "Bcl6b<br/>heat = 0.00336", "border_width": 2, "id": "Bcl6b", "y": 275.6470699469024}, {"node_label": "Cpt1a", "node_shape": "triangle", "x": 89.13919162843037, "degree": 1, "node_size": 10, "color": "rgba(256, 106, 0, 1.0)", "title": "Cpt1a<br/>heat = 0.00446", "border_width": 2, "id": "Cpt1a", "y": 236.6210425067671}, {"node_label": "Irf1", "node_shape": "dot", "x": 97.78498681888982, "degree": 2, "node_size": 10, "color": "rgba(256, 236, 0, 1.0)", "title": "Irf1<br/>heat = 0.00119", "border_width": 0, "id": "Irf1", "y": 450.87740911576753}, {"node_label": "Bid", "node_shape": "triangle", "x": 501.4678329821133, "degree": 5, "node_size": 10, "color": "rgba(256, 135, 0, 1.0)", "title": "Bid<br/>heat = 0.00333", "border_width": 2, "id": "Bid", "y": 752.4472873291013}, {"node_label": "Irf8", "node_shape": "dot", "x": 131.20187147093063, "degree": 1, "node_size": 10, "color": "rgba(256, 189, 0, 1.0)", "title": "Irf8<br/>heat = 0.00191", "border_width": 0, "id": "Irf8", "y": 532.81370916978}, {"node_label": "Ppargc1a", "node_shape": "triangle", "x": 355.67006951561194, "degree": 8, "node_size": 10, "color": "rgba(256, 135, 0, 1.0)", "title": "Ppargc1a<br/>heat = 0.00332", "border_width": 2, "id": "Ppargc1a", "y": 204.0334222790362}, {"node_label": "Ppargc1b", "node_shape": "triangle", "x": 0.0, "degree": 1, "node_size": 10, "color": "rgba(256, 0, 0, 1.0)", "title": "Ppargc1b<br/>heat = 0.01317", "border_width": 2, "id": "Ppargc1b", "y": 504.44934414099527}, {"node_label": "Hbp1", "node_shape": "dot", "x": 726.2646497288887, "degree": 1, "node_size": 10, "color": "rgba(256, 183, 0, 1.0)", "title": "Hbp1<br/>heat = 0.00204", "border_width": 0, "id": "Hbp1", "y": 612.0075644055149}, {"node_label": "Creb3l3", "node_shape": "triangle", "x": 325.1163568962405, "degree": 2, "node_size": 10, "color": "rgba(256, 130, 0, 1.0)", "title": "Creb3l3<br/>heat = 0.00349", "border_width": 2, "id": "Creb3l3", "y": 531.4240345767345}, {"node_label": "Rpp14", "node_shape": "dot", "x": 106.23842986713287, "degree": 1, "node_size": 10, "color": "rgba(256, 176, 0, 1.0)", "title": "Rpp14<br/>heat = 0.00219", "border_width": 0, "id": "Rpp14", "y": 197.31846168455942}, {"node_label": "Avpr1a", "node_shape": "triangle", "x": 850.3610817324004, "degree": 2, "node_size": 10, "color": "rgba(256, 107, 0, 1.0)", "title": "Avpr1a<br/>heat = 0.00441", "border_width": 2, "id": "Avpr1a", "y": 855.7917139634623}, {"node_label": "Zbtb17", "node_shape": "dot", "x": 936.0804093688719, "degree": 1, "node_size": 10, "color": "rgba(256, 201, 0, 1.0)", "title": "Zbtb17<br/>heat = 0.00169", "border_width": 0, "id": "Zbtb17", "y": 506.89391860174703}, {"node_label": "Pcbp4", "node_shape": "triangle", "x": 940.90660 ...

# %% [markdown]
# ## Clustering
# <a id='cluster'></a>

# %% [markdown]
# Parameter information:
# - **G_DEG**: background network filtered by DEG list, output of load_STRING_to_digraph
# - **DG_universe**: full background network, output of create_graph.load_STRING_to_digraph
# - **seed_nodes**: list of DEG's, output of create_graph.create_DEG_list
# - **Wprime**: will calculate automatically of not specified, output of visualizations.normalized_adj_matrix
# - **num_top_genes**: number of genes to display in the output graph
# - **cluster_size_cut_off**: color clusters below this threshhold grey
# - **remove_stray_nodes**: remove custers below the cluster size cut off
# - **r**: increases spacing between clusters. recommended number between 0.5 and 4.0
# - **x_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **y_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **node_spacing**: recommended number between 500 and 2000
# - **node_size_multiplier**: as you scale node_spacing, scale this number. Recommended number between 5 and 25
# - **physics_enabled**: Nodes will bounce aroound when you click and drag them. Only set to True when number of nodes is 200 or less
# - **node_font_size**: as you scale node_spacing, scale this number. Recommended number between 20 and 50
# - **graph_id**: Allows rendering of multiple graphs in one notebook. Just make sure each graph has a unique id.

# %%
heat.draw_clustering(rad_positions = False,
                Wprime = Wprime,
                num_top_genes = 200,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                node_spacing = 700,
                node_size_multiplier = 12,
                physics_enabled = True,
                node_font_size = 45,
                graph_id = 2
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file2"];    frame.runVis([{"node_label": "Dnmt3b", "node_shape": "triangle", "degree": 3.0, "title": "Dnmt3b<br/>cluster = 0", "color": "#004033", "y": 163.29112491293478, "x": 324.68762441396825, "border_width": 0, "id": "Dnmt3b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Igf1<br/>cluster = 1", "color": "#ff0044", "y": 424.1303905127167, "x": 315.60546811751817, "border_width": 0, "id": "Igf1"}, {"node_label": "Cyp51", "node_shape": "triangle", "degree": 3.0, "title": "Cyp51<br/>cluster = 4", "color": "#a300cc", "y": 225.67515303834742, "x": 677.8901296497587, "border_width": 0, "id": "Cyp51"}, {"node_label": "Vmp1", "node_shape": "triangle", "degree": 3.0, "title": "Vmp1<br/>cluster = 12", "color": "#00d9ca", "y": 45.16872183115912, "x": 394.46968988375016, "border_width": 0, "id": "Vmp1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Foxa1<br/>cluster = 5", "color": "#3000b3", "y": 188.05253072229542, "x": 538.0320337808009, "border_width": 0, "id": "Foxa1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Foxa2<br/>cluster = 5", "color": "#3000b3", "y": 179.4163321066088, "x": 581.4802689978354, "border_width": 0, "id": "Foxa2"}, {"node_label": "Rnf144b", "node_shape": "triangle", "degree": 3.0, "title": "Rnf144b<br/>cluster = 1", "color": "#ff0044", "y": 298.5066482480228, "x": 74.45757397926238, "border_width": 0, "id": "Rnf144b"}, {"node_label": "Nr1d1", "node_shape": "triangle", "degree": 3.0, "title": "Nr1d1<br/>cluster = 5", "color": "#3000b3", "y": 382.9960109028985, "x": 699.9728122274188, "border_width": 0, "id": "Nr1d1"}, {"node_label": "Nr1d2", "node_shape": "triangle", "degree": 3.0, "title": "Nr1d2<br/>cluster = 1", "color": "#ff0044", "y": 550.9026497689977, "x": 591.2217652500129, "border_width": 0, "id": "Nr1d2"}, {"node_label": "Asap2", "node_shape": "triangle", "degree": 3.0, "title": "Asap2<br/>cluster = 10", "color": "#000c59", "y": 293.4306138851708, "x": 16.034015179178734, "border_width": 0, "id": "Asap2"}, {"node_label": "Cpt1a", "node_shape": "triangle", "degree": 3.0, "title": "Cpt1a<br/>cluster = 5", "color": "#3000b3", "y": 169.63328466294664, "x": 637.215865690325, "border_width": 0, "id": "Cpt1a"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Irf7<br/>cluster = 12", "color": "#00d9ca", "y": 283.408282686284, "x": 129.85802570779748, "border_width": 0, "id": "Irf7"}, {"node_label": "Sgk2", "node_shape": "triangle", "degree": 3.0, "title": "Sgk2<br/>cluster = 10", "color": "#000c59", "y": 637.0688128255987, "x": 166.9684775228193, "border_width": 0, "id": "Sgk2"}, {"node_label": "Zbp1", "node_shape": "triangle", "degree": 3.0, "title": "Zbp1<br/>cluster = 12", "color": "#00d9ca", "y": 588.135060532159, "x": 91.3842538794509, "border_width": 0, "id": "Zbp1"}, {"node_label": "Bid", "node_shape": "triangle", "degree": 3.0, "title": "Bid<br/>cluster = 10", "color": "#000c59", "y": 343.04231228974464, "x": 78.06879836468944, "border_width": 0, "id": "Bid"}, {"node_label": "Ppargc1a", "node_shape": "triangle", "degree": 3.0, "title": "Ppargc1a<br/>cluster = 5", "color": "#3000b3", "y": 281.85699049843214, "x": 548.9012654113125, "border_width": 0, "id": "Ppargc1a"}, {"node_label": "Ctsf", "node_shape": "triangle", "degree": 3.0, "title": "Ctsf<br/>cluster = 10", "color": "#000c59", "y": 324.6364805301134, "x": 1.4442859604642524, "border_width": 0, "id": "Ctsf"}, {"node_label": "Dhcr7", "node_shape": "triangle", "degree": 3.0, "title": "Dhcr7<br/>cluster = 4", "color": "#a300cc", "y": 242.600606489635, "x": 677.566507099514, "border_width": 0, "id": "Dhcr7"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nfyc<br/>cluster = 4", "color": "#a300cc", "y": 272.16349851097493, "x": 689.400968701833, "border_width": 0, "id": "Nfyc"}, {"node_la ...

# %%
heat.draw_clustering(Wprime = Wprime,
                num_top_genes = 200,
                cluster_size_cut_off = 5,
                remove_stray_nodes = False,
                r = 2.0,
                x_offset = 10,
                y_offset = 78,
                node_spacing = 700,
                node_size_multiplier = 12,
                physics_enabled = False,
                node_font_size = 45,
                graph_id = 3,
                node_shadow_x = 6
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file3"];    frame.runVis([{"node_label": "Dnmt3b", "node_shape": "triangle", "degree": 3.0, "title": "Dnmt3b<br/>cluster = 0", "color": "#004033", "y": 342.47457112400724, "x": 1641.387158351206, "border_width": 0, "id": "Dnmt3b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Igf1<br/>cluster = 1", "color": "#ff0044", "y": -894.165771275742, "x": 1434.0459347189683, "border_width": 0, "id": "Igf1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Axin1<br/>cluster = 2", "color": "grey", "y": -537.6738619793092, "x": 377.71225822728746, "border_width": 0, "id": "Axin1"}, {"node_label": "Adora1", "node_shape": "triangle", "degree": 3.0, "title": "Adora1<br/>cluster = 3", "color": "grey", "y": 1019.0862045114332, "x": 136.26684114250853, "border_width": 0, "id": "Adora1"}, {"node_label": "Cyp51", "node_shape": "triangle", "degree": 3.0, "title": "Cyp51<br/>cluster = 4", "color": "#a300cc", "y": 1430.8631632229817, "x": -738.5757727792394, "border_width": 0, "id": "Cyp51"}, {"node_label": "Adamts7", "node_shape": "triangle", "degree": 3.0, "title": "Adamts7<br/>cluster = 1", "color": "#ff0044", "y": -861.779142865555, "x": 1244.1619974039559, "border_width": 0, "id": "Adamts7"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Foxa1<br/>cluster = 5", "color": "#3000b3", "y": 738.4214624766014, "x": -1204.0283549414266, "border_width": 0, "id": "Foxa1"}, {"node_label": "Ccnf", "node_shape": "triangle", "degree": 3.0, "title": "Ccnf<br/>cluster = 6", "color": "grey", "y": -832.5068545715371, "x": -349.20089130778916, "border_width": 0, "id": "Ccnf"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Foxa2<br/>cluster = 5", "color": "#3000b3", "y": 730.7660409406209, "x": -1240.3637617600996, "border_width": 0, "id": "Foxa2"}, {"node_label": "Rnf144b", "node_shape": "triangle", "degree": 3.0, "title": "Rnf144b<br/>cluster = 1", "color": "#ff0044", "y": -1061.5529034282924, "x": 1651.1030243548294, "border_width": 0, "id": "Rnf144b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Tnfrsf4<br/>cluster = 7", "color": "grey", "y": -594.0835765734157, "x": 161.40596560235508, "border_width": 0, "id": "Tnfrsf4"}, {"node_label": "Nr1d1", "node_shape": "triangle", "degree": 3.0, "title": "Nr1d1<br/>cluster = 5", "color": "#3000b3", "y": 586.9434657428077, "x": -1208.276871772801, "border_width": 0, "id": "Nr1d1"}, {"node_label": "Bcl6b", "node_shape": "triangle", "degree": 3.0, "title": "Bcl6b<br/>cluster = 0", "color": "#004033", "y": 267.63317211350056, "x": 1920.4357605524, "border_width": 0, "id": "Bcl6b"}, {"node_label": "Mapkapk3", "node_shape": "triangle", "degree": 3.0, "title": "Mapkapk3<br/>cluster = 8", "color": "grey", "y": 673.4858712431453, "x": 1180.6824323465607, "border_width": 0, "id": "Mapkapk3"}, {"node_label": "Adssl1", "node_shape": "triangle", "degree": 3.0, "title": "Adssl1<br/>cluster = 9", "color": "grey", "y": 1295.9582787714733, "x": 1684.9147969091262, "border_width": 0, "id": "Adssl1"}, {"node_label": "Asap2", "node_shape": "triangle", "degree": 3.0, "title": "Asap2<br/>cluster = 10", "color": "#000c59", "y": 1363.1375093249403, "x": 1975.1590392856165, "border_width": 0, "id": "Asap2"}, {"node_label": "Cpt1a", "node_shape": "triangle", "degree": 3.0, "title": "Cpt1a<br/>cluster = 5", "color": "#3000b3", "y": 644.4137544025135, "x": -1169.7015285496327, "border_width": 0, "id": "Cpt1a"}, {"node_label": "Spaca6", "node_shape": "triangle", "degree": 3.0, "title": "Spaca6<br/>cluster = 11", "color": "grey", "y": -397.3551029493621, "x": 1478.916752063215, "border_width": 0, "id": "Spaca6"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Irf7<br/>cluster = 12", "color": "#00d9ca", "y": -814.8568181505631, "x": 333.917044099533, "border_width": 0,  ...
