# %% [markdown]
# # Space Mice Genes
# ## Heat Propagation and Clustering Package
#
#
# ----------------------
#
# Author: Mikayla Webster (13webstermj@gmail.com)
#
# Date: 2nd May, 2018
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Define Analysis Preferences](#pref)
# 3. [Load Networks](#load)
# 4. [Run Heat Propagation](#heat)
# 5. [Clustering](#cluster)

# %% [markdown]
# ## Background
# <a id='background'></a>

# %% [markdown]
# ## Import packages
# <a id='import'></a>

# %%
import sys
code_path = '../../network_bio_toolkit'
sys.path.append(code_path)

import Heat
reload(Heat)

import pandas as pd

# %% [markdown]
# ## Define Analysis Preferences
# <a id='pref'></a>

# %%
symbol = 'symbol'
entrez = 'entrez'

human = 'human'
mouse = 'mouse'

heat = Heat.Heat(gene_type = symbol, species = mouse)

# %% [markdown]
# ## Load Networks
# <a id='load'></a>
#
# 1. Load DEG file
# 2. Load STRING background network

# %%
# load DEG file
DEG_filename = "../../DEG_databases/DE_CoeffspaceFlight - groundControl_glds48_20180312.csv"  
heat.create_DEG_list(DEG_filename, p_value_filter = 0.05, sep = ',')

print "Number of DEG's: " + str(len(heat.DEG_list))
# Out:
# Number of DEG's: 181

# %%
# load background network from BIOGRID ndex2 network 
heat.load_ndex_from_server(UUID = '36f7d8fd-23dc-11e8-b939-0ac135e8bacf', relabel_node_field = 'name')

print "\nNumber of interactions: " + str(len(list(heat.G_DEG.edges())))
# Out:
# Number of interactions: 111

# %% [markdown]
# ## Run Heat Propagation
# <a id='heat'></a>

# %%
Wprime = heat.normalized_adj_matrix() # optional. Only if you want to inspet Wprime

# %%
heat.draw_heat_prop(Wprime = Wprime, # you don't have to pass this argument. Will calculate automatically
                  num_nodes = 500,
#                  random_walk = False,
                  edge_width = 2,
                  edge_smooth_enabled = True,
                  edge_smooth_type = 'bezier',
                  node_size_multiplier = 5,
                  hover = False,
                  hover_connected_edges = False,
                  largest_connected_component = False,
                  physics_enabled = True,
                  node_font_size = 20,
                  graph_id = 1,
                  node_shadow_x = 6)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"node_label": "SMARCC2", "node_shape": "dot", "x": 425.73894709507397, "degree": 1, "node_size": 10, "color": "rgba(256, 197, 0, 1.0)", "title": "SMARCC2<br/>heat = 0.00125", "border_width": 0, "id": "SMARCC2", "y": 0.0}, {"node_label": "BCL2L1", "node_shape": "dot", "x": 962.2778369378858, "degree": 1, "node_size": 10, "color": "rgba(256, 256, 0, 1.0)", "title": "BCL2L1<br/>heat = 0.0", "border_width": 0, "id": "BCL2L1", "y": 603.0983101770303}, {"node_label": "AGL", "node_shape": "dot", "x": 464.3859035393707, "degree": 1, "node_size": 10, "color": "rgba(256, 172, 0, 1.0)", "title": "AGL<br/>heat = 0.00198", "border_width": 0, "id": "AGL", "y": 926.5039155204651}, {"node_label": "DYNLL1", "node_shape": "dot", "x": 986.3959609811674, "degree": 1, "node_size": 10, "color": "rgba(256, 256, 0, 1.0)", "title": "DYNLL1<br/>heat = 0.0", "border_width": 0, "id": "DYNLL1", "y": 497.8652488250284}, {"node_label": "ERBB2IP", "node_shape": "dot", "x": 510.21822920727743, "degree": 1, "node_size": 10, "color": "rgba(256, 172, 0, 1.0)", "title": "ERBB2IP<br/>heat = 0.00198", "border_width": 0, "id": "ERBB2IP", "y": 973.3863615277338}, {"node_label": "LDLRAD3", "node_shape": "dot", "x": 71.32292205919826, "degree": 1, "node_size": 10, "color": "rgba(256, 232, 0, 1.0)", "title": "LDLRAD3<br/>heat = 0.00066", "border_width": 0, "id": "LDLRAD3", "y": 757.9028797255279}, {"node_label": "SLC25A19", "node_shape": "dot", "x": 893.0505974811579, "degree": 1, "node_size": 10, "color": "rgba(256, 256, 0, 1.0)", "title": "SLC25A19<br/>heat = 0.0", "border_width": 0, "id": "SLC25A19", "y": 180.68791457986865}, {"node_label": "Tars", "node_shape": "triangle", "x": 4.206321240118367, "degree": 1, "node_size": 10, "color": "rgba(256, 15, 0, 1.0)", "title": "Tars<br/>heat = 0.03571", "border_width": 2, "id": "Tars", "y": 501.37739001998773}, {"node_label": "USP26", "node_shape": "dot", "x": 208.412272629212, "degree": 1, "node_size": 10, "color": "rgba(256, 232, 0, 1.0)", "title": "USP26<br/>heat = 0.00066", "border_width": 0, "id": "USP26", "y": 83.46260303318381}, {"node_label": "PPP1R3D", "node_shape": "dot", "x": 452.01374977760594, "degree": 1, "node_size": 10, "color": "rgba(256, 172, 0, 1.0)", "title": "PPP1R3D<br/>heat = 0.00198", "border_width": 0, "id": "PPP1R3D", "y": 990.9806293318338}, {"node_label": "CHTF18", "node_shape": "dot", "x": 948.6641268927159, "degree": 1, "node_size": 10, "color": "rgba(256, 256, 0, 1.0)", "title": "CHTF18<br/>heat = 0.0", "border_width": 0, "id": "CHTF18", "y": 277.5016457123873}, {"node_label": "Ppp1r3b", "node_shape": "triangle", "x": 375.83235016960845, "degree": 9, "node_size": 10, "color": "rgba(256, 15, 0, 1.0)", "title": "Ppp1r3b<br/>heat = 0.03571", "border_width": 2, "id": "Ppp1r3b", "y": 948.1020132051138}, {"node_label": "CALM1", "node_shape": "dot", "x": 1000.0, "degree": 2, "node_size": 10, "color": "rgba(256, 108, 0, 1.0)", "title": "CALM1<br/>heat = 0.00649", "border_width": 0, "id": "CALM1", "y": 465.0426339324405}, {"node_label": "APBB1", "node_shape": "dot", "x": 44.186809827425165, "degree": 1, "node_size": 10, "color": "rgba(256, 232, 0, 1.0)", "title": "APBB1<br/>heat = 0.00066", "border_width": 0, "id": "APBB1", "y": 680.685363072733}, {"node_label": "Ppargc1b", "node_shape": "triangle", "x": 52.45130173968727, "degree": 1, "node_size": 10, "color": "rgba(256, 15, 0, 1.0)", "title": "Ppargc1b<br/>heat = 0.03571", "border_width": 2, "id": "Ppargc1b", "y": 261.59636775187005}, {"node_label": "PHC3", "node_shape": "dot", "x": 196.70281582786544, "degree": 1, "node_size": 10, "color": "rgba(256, 232, 0, 1.0)", "title": "PHC3<br/>heat = 0.00066", "border_width": 0, "id": "PHC3", "y": 225.12382945575075}, {"node_label": "PHC2", "node_shape": "dot", "x": 283.53762759365605, "degree": 1, "node_size": 10, " ...

# %% [markdown]
# ## Clustering
# <a id='cluster'></a>

# %% [markdown]
# Parameter information:
# - **G_DEG**: background network filtered by DEG list, output of load_STRING_to_digraph
# - **DG_universe**: full background network, output of create_graph.load_STRING_to_digraph
# - **seed_nodes**: list of DEG's, output of create_graph.create_DEG_list
# - **Wprime**: will calculate automatically of not specified, output of visualizations.normalized_adj_matrix
# - **num_top_genes**: number of genes to display in the output graph
# - **cluster_size_cut_off**: color clusters below this threshhold grey
# - **remove_stray_nodes**: remove custers below the cluster size cut off
# - **r**: increases spacing between clusters. recommended number between 0.5 and 4.0
# - **x_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **y_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **node_spacing**: recommended number between 500 and 2000
# - **node_size_multiplier**: as you scale node_spacing, scale this number. Recommended number between 5 and 25
# - **physics_enabled**: Nodes will bounce aroound when you click and drag them. Only set to True when number of nodes is 200 or less
# - **node_font_size**: as you scale node_spacing, scale this number. Recommended number between 20 and 50
# - **graph_id**: Allows rendering of multiple graphs in one notebook. Just make sure each graph has a unique id.

# %%
heat.draw_clustering(rad_positions = False,
                Wprime = Wprime,
                k = None,
                largest_connected_component = True,
                num_top_genes = 500,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                node_spacing = 700,
                node_size_multiplier = 5,
                physics_enabled = False,
                node_font_size = 16,
                graph_id = 2
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file2"];    frame.runVis([{"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "BCL2L1<br/>cluster = 0", "color": "#004033", "y": 323.4406709565935, "x": 143.1031299925051, "border_width": 0, "id": "BCL2L1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "SMARCC2<br/>cluster = 1", "color": "#ff0044", "y": 545.928915575208, "x": 248.15045096009663, "border_width": 0, "id": "SMARCC2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "SMARCC1<br/>cluster = 1", "color": "#ff0044", "y": 509.38466063754686, "x": 254.57880943658625, "border_width": 0, "id": "SMARCC1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "DYNLL1<br/>cluster = 0", "color": "#004033", "y": 340.36318227556046, "x": 177.36662069684758, "border_width": 0, "id": "DYNLL1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "ERBB2IP<br/>cluster = 0", "color": "#004033", "y": 156.14716416752262, "x": 96.44558514992457, "border_width": 0, "id": "ERBB2IP"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "BCL2L2<br/>cluster = 0", "color": "#004033", "y": 337.07306654570806, "x": 79.94484520583751, "border_width": 0, "id": "BCL2L2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "SLC25A19<br/>cluster = 2", "color": "#a300cc", "y": 318.69381764245554, "x": 693.3114775502603, "border_width": 0, "id": "SLC25A19"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "USP26<br/>cluster = 3", "color": "#3000b3", "y": 421.54308862061475, "x": 528.8460021174462, "border_width": 0, "id": "USP26"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "PPP1R3D<br/>cluster = 0", "color": "#004033", "y": 121.1092867984191, "x": 93.32762810476866, "border_width": 0, "id": "PPP1R3D"}, {"node_label": "Ppp1r3b", "node_shape": "triangle", "degree": 3.0, "title": "Ppp1r3b<br/>cluster = 0", "color": "#004033", "y": 137.50539431097823, "x": 123.86891598626248, "border_width": 0, "id": "Ppp1r3b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "CALM1<br/>cluster = 4", "color": "#000c59", "y": 226.96852664198417, "x": 350.36222054240807, "border_width": 0, "id": "CALM1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "APBB1<br/>cluster = 5", "color": "#00d9ca", "y": 484.519527226487, "x": 662.724962873149, "border_width": 0, "id": "APBB1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "PHC3<br/>cluster = 7", "color": "#00f281", "y": 588.9035915147563, "x": 430.9148045028097, "border_width": 0, "id": "PHC3"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "PHC2<br/>cluster = 7", "color": "#00f281", "y": 586.480264214911, "x": 459.3591967908668, "border_width": 0, "id": "PHC2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "IRAK1<br/>cluster = 4", "color": "#000c59", "y": 153.2526941243024, "x": 462.74993671915945, "border_width": 0, "id": "IRAK1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "CUL1<br/>cluster = 8", "color": "#00660e", "y": 279.24500845897836, "x": 271.28209097052155, "border_width": 0, "id": "CUL1"}, {"node_label": "Net1", "node_shape": "triangle", "degree": 3.0, "title": "Net1<br/>cluster = 5", "color": "#00d9ca", "y": 30.152959629293104, "x": 502.2509903281054, "border_width": 0, "id": "Net1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "SGMS2<br/>cluster = 1", "color": "#ff0044", "y": 677.9876602387263, "x": 249.1787890249935, "border_width": 0, "id": "SGMS2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "WNK3<br/>cluster = 5", "color": "#00d9ca", "y": 374.3866549053408, "x": 700.0, "border_width": 0, "id": "WNK3"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "SLC25A22<br/>cluster = 7", "color": "#00f281",  ...

# %%
heat.draw_clustering(Wprime = Wprime,
                num_top_genes = 500,
                cluster_size_cut_off = 5,
#                remove_stray_nodes = True,
                r = 1.2,
#                x_offset = 2,
#                y_offset = 2,
                node_spacing = 700,
                node_size_multiplier = 12,
                physics_enabled = False,
                node_font_size = 45,
                graph_id = 3,
                node_shadow_x = 6
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file3"];    frame.runVis([{"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "BCL2L1<br/>cluster = 0", "color": "#004033", "y": 141.04519851491781, "x": 1259.6549081769126, "border_width": 0, "id": "BCL2L1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "SMARCC2<br/>cluster = 1", "color": "#ff0044", "y": 1036.0532763824235, "x": 789.1625384373407, "border_width": 0, "id": "SMARCC2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "BCL2L2<br/>cluster = 0", "color": "#004033", "y": 100.37689311488543, "x": 1170.7808636378395, "border_width": 0, "id": "BCL2L2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "DYNLL1<br/>cluster = 0", "color": "#004033", "y": 220.85640596961267, "x": 1198.1428971487026, "border_width": 0, "id": "DYNLL1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "ERBB2IP<br/>cluster = 0", "color": "#004033", "y": 103.41995033613588, "x": 1323.106236194658, "border_width": 0, "id": "ERBB2IP"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "LDLRAD3<br/>cluster = 2", "color": "#a300cc", "y": 1537.575949616448, "x": 414.77192857872, "border_width": 0, "id": "LDLRAD3"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "SLC25A19<br/>cluster = 3", "color": "#3000b3", "y": 732.2805122699037, "x": 50.6167145327761, "border_width": 0, "id": "SLC25A19"}, {"node_label": "Tars", "node_shape": "triangle", "degree": 3.0, "title": "Tars<br/>cluster = 4", "color": "grey", "y": 308.1966382710863, "x": -836.9458530173916, "border_width": 0, "id": "Tars"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "USP26<br/>cluster = 5", "color": "#000c59", "y": -54.2563533758831, "x": -106.80565040999134, "border_width": 0, "id": "USP26"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "SDF4<br/>cluster = 6", "color": "#00d9ca", "y": -781.6086352781111, "x": 161.83201569635204, "border_width": 0, "id": "SDF4"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "CHTF18<br/>cluster = 3", "color": "#3000b3", "y": 655.9206886558103, "x": -52.23889266262616, "border_width": 0, "id": "CHTF18"}, {"node_label": "Ppp1r3b", "node_shape": "triangle", "degree": 3.0, "title": "Ppp1r3b<br/>cluster = 0", "color": "#004033", "y": 53.30217846554967, "x": 1125.5479310467645, "border_width": 0, "id": "Ppp1r3b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "CALM1<br/>cluster = 6", "color": "#00d9ca", "y": -585.2599928592622, "x": 297.11586029619286, "border_width": 0, "id": "CALM1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "APBB1<br/>cluster = 2", "color": "#a300cc", "y": 1540.0000000000002, "x": 331.2686859240325, "border_width": 0, "id": "APBB1"}, {"node_label": "Ppargc1b", "node_shape": "triangle", "degree": 3.0, "title": "Ppargc1b<br/>cluster = 0", "color": "#004033", "y": 253.7600002976564, "x": 855.4557837315881, "border_width": 0, "id": "Ppargc1b"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "MAGI1<br/>cluster = 2", "color": "#a300cc", "y": 1450.8488668814598, "x": 595.1282633423851, "border_width": 0, "id": "MAGI1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "PHC2<br/>cluster = 7", "color": "#00f281", "y": 34.89337463663079, "x": 896.9394309896124, "border_width": 0, "id": "PHC2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "IRAK1<br/>cluster = 6", "color": "#00d9ca", "y": -660.5519318615792, "x": 520.9911284188663, "border_width": 0, "id": "IRAK1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "CUL1<br/>cluster = 3", "color": "#3000b3", "y": 788.2371590649627, "x": -273.44121580345444, "border_width": 0, "id": "CUL1"}, {"node_label": "Net1", "node_shape": "triangle", "degree": 3.0, "title": "Net1 ...
