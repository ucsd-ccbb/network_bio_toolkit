# %% [markdown]
# # Space Mice Genes
# ## Heat Propagation and Clustering Package
#
#
# ----------------------
#
# Author: Mikayla Webster (13webstermj@gmail.com)
#
# Date: 2nd May, 2018
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Define Analysis Preferences](#pref)
# 3. [Load Networks](#load)
# 4. [Run Heat Propagation](#heat)
# 5. [Clustering](#cluster)

# %% [markdown]
# ## Background
# <a id='background'></a>

# %% [markdown]
# ## Import packages
# <a id='import'></a>

# %%
import sys
code_path = '../../network_bio_toolkit'
sys.path.append(code_path)

import Heat2
reload(Heat2)
# Out:
# <module 'Heat2' from '../../network_bio_toolkit\Heat2.pyc'>

# %% [markdown]
# ## Define Analysis Preferences
# <a id='pref'></a>

# %%
symbol = 'symbol'
entrez = 'entrez'

human = 'human'
mouse = 'mouse'

heat = Heat2.Heat(gene_type = symbol, species = mouse)

# %% [markdown]
# ## Load Networks
# <a id='load'></a>
#
# 1. Load DEG file
# 2. Load STRING background network

# %%
# load DEG file
DEG_filename = "../../DEG_databases/DE_CoeffspaceFlight - groundControl_glds48_20180312.csv"  
heat.create_DEG_list(DEG_filename, p_value_filter = 0.05, sep = ',')

print('Number of DEG\'s: ' + str(len(heat.DEG_list)))
# Out:
# Number of DEG's: 181
# ../../network_bio_toolkit\create_graph.py:274: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   df = pd.DataFrame.from_csv(filename, sep = sep)

# %%
# load our saved network from ndex rather than loading it ourselves
# equivalent to heat.load_STRING_links('../../background_networks/10090.protein.links.v10.5.txt', confidence_filter = 700)
heat.load_ndex_from_server(UUID = '76160faa-5d0f-11e8-a4bf-0ac135e8bacf', relabel_node_field = 'name')

print('\nNumber of interactions: ' + str(len(list(heat.DG_universe.edges()))))
# Out:
# Number of interactions: 369294

# %%
saved_DG_universe = heat.DG_universe
heat.DG_universe = saved_DG_universe

# %% [markdown]
# ## Run Heat Propagation
# <a id='heat'></a>

# %%
Wprime = heat.normalized_adj_matrix() # optional. Saves time to do it once here.

# %%
saved_Wprime = heat.Wprime
heat.Wprime = saved_Wprime

# %%
heat.draw_heat_prop(num_nodes = 500,
                  random_walk = True,
                  edge_width = 2,
                  edge_smooth_enabled = True,
                  edge_smooth_type = 'bezier',
                  node_size_multiplier = 5,
                  hover = False,
                  hover_connected_edges = False,
                  largest_connected_component = True,
                  physics_enabled = True,
                  node_font_size = 40,
                  graph_id = 1,
                  node_shadow_x = 6)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"node_label": "Chic1", "node_shape": "triangle", "x": 852.3680342655696, "degree": 1, "node_size": 10, "color": "rgba(256, 28, 0, 1.0)", "title": "Chic1<br/>heat = 0.00431", "border_width": 2, "id": "Chic1", "y": 836.0147999162623}, {"node_label": "", "node_shape": "dot", "x": 672.5896884141566, "degree": 8, "node_size": 10, "color": "rgba(256, 238, 0, 1.0)", "title": "Sdsl<br/>heat = 0.00027", "border_width": 0, "id": "Sdsl", "y": 175.15967288415683}, {"node_label": "Cmpk2", "node_shape": "triangle", "x": 552.1791460792407, "degree": 29, "node_size": 10, "color": "rgba(256, 32, 0, 1.0)", "title": "Cmpk2<br/>heat = 0.00411", "border_width": 2, "id": "Cmpk2", "y": 474.98392187736437}, {"node_label": "", "node_shape": "dot", "x": 299.72688547076234, "degree": 13, "node_size": 10, "color": "rgba(256, 157, 0, 1.0)", "title": "Rbbp7<br/>heat = 0.00079", "border_width": 0, "id": "Rbbp7", "y": 696.418069782084}, {"node_label": "", "node_shape": "dot", "x": 454.00403242360403, "degree": 15, "node_size": 10, "color": "rgba(256, 256, 0, 1.0)", "title": "Nampt<br/>heat = 0.00022", "border_width": 0, "id": "Nampt", "y": 422.40457429420337}, {"node_label": "", "node_shape": "dot", "x": 306.8825002141602, "degree": 16, "node_size": 10, "color": "rgba(256, 154, 0, 1.0)", "title": "Rbbp4<br/>heat = 0.00082", "border_width": 0, "id": "Rbbp4", "y": 664.7951040172941}, {"node_label": "Ccnf", "node_shape": "triangle", "x": 324.45151682772166, "degree": 27, "node_size": 10, "color": "rgba(256, 33, 0, 1.0)", "title": "Ccnf<br/>heat = 0.00403", "border_width": 2, "id": "Ccnf", "y": 553.6297257809974}, {"node_label": "", "node_shape": "dot", "x": 809.5536145082011, "degree": 15, "node_size": 10, "color": "rgba(256, 240, 0, 1.0)", "title": "Hsd3b1<br/>heat = 0.00026", "border_width": 0, "id": "Hsd3b1", "y": 300.35614657685034}, {"node_label": "", "node_shape": "dot", "x": 708.3823614256155, "degree": 15, "node_size": 10, "color": "rgba(256, 195, 0, 1.0)", "title": "Cyp3a16<br/>heat = 0.00048", "border_width": 0, "id": "Cyp3a16", "y": 236.21327763925464}, {"node_label": "Klf1", "node_shape": "triangle", "x": 248.8719421400338, "degree": 2, "node_size": 10, "color": "rgba(256, 38, 0, 1.0)", "title": "Klf1<br/>heat = 0.00378", "border_width": 2, "id": "Klf1", "y": 897.7032185712046}, {"node_label": "", "node_shape": "dot", "x": 766.1354369603256, "degree": 2, "node_size": 10, "color": "rgba(256, 236, 0, 1.0)", "title": "Aqp11<br/>heat = 0.00028", "border_width": 0, "id": "Aqp11", "y": 75.35652184713052}, {"node_label": "", "node_shape": "dot", "x": 829.4851533593061, "degree": 2, "node_size": 10, "color": "rgba(256, 234, 0, 1.0)", "title": "Aqp12<br/>heat = 0.00029", "border_width": 0, "id": "Aqp12", "y": 125.5962637011779}, {"node_label": "", "node_shape": "dot", "x": 463.2948730810596, "degree": 40, "node_size": 10, "color": "rgba(256, 211, 0, 1.0)", "title": "Bcl2<br/>heat = 0.00039", "border_width": 0, "id": "Bcl2", "y": 705.2783231689849}, {"node_label": "Avpr1a", "node_shape": "triangle", "x": 340.10105580811245, "degree": 3, "node_size": 10, "color": "rgba(256, 38, 0, 1.0)", "title": "Avpr1a<br/>heat = 0.00378", "border_width": 2, "id": "Avpr1a", "y": 862.2741450787621}, {"node_label": "", "node_shape": "dot", "x": 451.33738837145097, "degree": 5, "node_size": 10, "color": "rgba(256, 193, 0, 1.0)", "title": "Tecr<br/>heat = 0.00049", "border_width": 0, "id": "Tecr", "y": 1.8035019597776991}, {"node_label": "", "node_shape": "dot", "x": 460.0554550358663, "degree": 18, "node_size": 10, "color": "rgba(256, 234, 0, 1.0)", "title": "Gys1<br/>heat = 0.00029", "border_width": 0, "id": "Gys1", "y": 581.1846255126125}, {"node_label": "", "node_shape": "dot", "x": 442.039040044417, "degree": 54, "node_size": 10, "color": "rgba(256, 214, 0, 1.0)", "title": "Akt1<b ...

# %% [markdown]
# ## Clustering
# <a id='cluster'></a>

# %% [markdown]
# Parameter information:
# - **G_DEG**: background network filtered by DEG list, output of load_STRING_to_digraph
# - **DG_universe**: full background network, output of create_graph.load_STRING_to_digraph
# - **seed_nodes**: list of DEG's, output of create_graph.create_DEG_list
# - **Wprime**: will calculate automatically of not specified, output of visualizations.normalized_adj_matrix
# - **num_top_genes**: number of genes to display in the output graph
# - **cluster_size_cut_off**: color clusters below this threshhold grey
# - **remove_stray_nodes**: remove custers below the cluster size cut off
# - **r**: increases spacing between clusters. recommended number between 0.5 and 4.0
# - **x_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **y_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **node_spacing**: recommended number between 500 and 2000
# - **node_size_multiplier**: as you scale node_spacing, scale this number. Recommended number between 5 and 25
# - **physics_enabled**: Nodes will bounce aroound when you click and drag them. Only set to True when number of nodes is 200 or less
# - **node_font_size**: as you scale node_spacing, scale this number. Recommended number between 20 and 50
# - **graph_id**: Allows rendering of multiple graphs in one notebook. Just make sure each graph has a unique id.

# %%
heat.draw_clustering(rad_positions = False,
                k = None,
                largest_connected_component = True,
                num_top_genes = 500,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                node_spacing = 700,
                node_size_multiplier = 10,
                physics_enabled = True,
                node_font_size = 40,
                graph_id = 2,
                edge_width = 2,
                edge_smooth_enabled = True,
                edge_smooth_type = 'bezier',
                hover = False,
                hover_connected_edges = False
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file2"];    frame.runVis([{"node_label": "Chic1", "node_shape": "triangle", "degree": 3.0, "title": "Chic1<br/>cluster = 0", "color": "#004033", "y": 473.6094946739459, "x": 681.9467214986082, "border_width": 0, "id": "Chic1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Sdsl<br/>cluster = 1", "color": "#ff0044", "y": 375.4494798254893, "x": 95.09118155243372, "border_width": 0, "id": "Sdsl"}, {"node_label": "Cmpk2", "node_shape": "triangle", "degree": 3.0, "title": "Cmpk2<br/>cluster = 2", "color": "#a300cc", "y": 297.33150695385456, "x": 401.44981520271153, "border_width": 0, "id": "Cmpk2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Rbbp7<br/>cluster = 3", "color": "#3000b3", "y": 219.35143272525943, "x": 334.8096041652103, "border_width": 0, "id": "Rbbp7"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nampt<br/>cluster = 2", "color": "#a300cc", "y": 316.0550032037342, "x": 285.7997419170635, "border_width": 0, "id": "Nampt"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Rbbp4<br/>cluster = 3", "color": "#3000b3", "y": 225.60427694193754, "x": 328.4646528661129, "border_width": 0, "id": "Rbbp4"}, {"node_label": "Ccnf", "node_shape": "triangle", "degree": 3.0, "title": "Ccnf<br/>cluster = 4", "color": "#000c59", "y": 189.33339923605706, "x": 407.72687795362395, "border_width": 0, "id": "Ccnf"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hsd3b1<br/>cluster = 5", "color": "#00d9ca", "y": 565.9327330154432, "x": 182.25314709109156, "border_width": 0, "id": "Hsd3b1"}, {"node_label": "Adssl1", "node_shape": "triangle", "degree": 3.0, "title": "Adssl1<br/>cluster = 2", "color": "#a300cc", "y": 395.77884098334994, "x": 269.41441716436174, "border_width": 0, "id": "Adssl1"}, {"node_label": "Klf1", "node_shape": "triangle", "degree": 3.0, "title": "Klf1<br/>cluster = 3", "color": "#3000b3", "y": 250.88543772698387, "x": 616.0941872980934, "border_width": 0, "id": "Klf1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Aqp11<br/>cluster = 6", "color": "#00f281", "y": 596.7227960809843, "x": 103.68267329204367, "border_width": 0, "id": "Aqp11"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Aqp12<br/>cluster = 6", "color": "#00f281", "y": 561.5054697577004, "x": 78.22021020202625, "border_width": 0, "id": "Aqp12"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Bcl2<br/>cluster = 7", "color": "#00660e", "y": 320.0099264664207, "x": 476.9291807795459, "border_width": 0, "id": "Bcl2"}, {"node_label": "Avpr1a", "node_shape": "triangle", "degree": 3.0, "title": "Avpr1a<br/>cluster = 7", "color": "#00660e", "y": 450.4260181302251, "x": 485.91464860881183, "border_width": 0, "id": "Avpr1a"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Tecr<br/>cluster = 8", "color": "#88ff00", "y": 95.24279993360359, "x": 100.97695984022181, "border_width": 0, "id": "Tecr"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Gys1<br/>cluster = 3", "color": "#3000b3", "y": 384.3358754107607, "x": 387.2147067065461, "border_width": 0, "id": "Gys1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Akt1<br/>cluster = 7", "color": "#00660e", "y": 324.2101538000164, "x": 456.533439801235, "border_width": 0, "id": "Akt1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Med1<br/>cluster = 3", "color": "#3000b3", "y": 152.7432926240979, "x": 318.5990725963735, "border_width": 0, "id": "Med1"}, {"node_label": "Rrm2", "node_shape": "triangle", "degree": 3.0, "title": "Rrm2<br/>cluster = 2", "color": "#a300cc", "y": 299.6335973104465, "x": 349.789537546975, "border_width": 0, "id": "Rrm2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nt5c1a<br/>cluster = 2" ...

# %%
heat.draw_clustering(num_top_genes = 500,
                cluster_size_cut_off = 5,
                remove_stray_nodes = True,
                r = 1,
                node_spacing = 600,
                node_size_multiplier = 4,
                physics_enabled = False,
                node_font_size = 15,
                graph_id = 3,
                node_shadow_x = 6,
                color_lfc = True,
                largest_connected_component = True,
                vmin = -5,
                vmax = 5
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file3"];    frame.runVis([{"node_label": "Chic1", "node_shape": "triangle", "degree": 3.0, "title": "Chic1<br/>cluster = 0", "color": "rgba(256, 218, 218, 1.0)", "y": 600.0, "x": 866.1128783307337, "border_width": 0, "id": "Chic1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Sdsl<br/>cluster = 1", "color": "rgba(256, 238, 238, 1.0)", "y": 557.0759556656005, "x": 623.1180891800767, "border_width": 0, "id": "Sdsl"}, {"node_label": "Cmpk2", "node_shape": "triangle", "degree": 3.0, "title": "Cmpk2<br/>cluster = 2", "color": "rgba(256, 174, 174, 1.0)", "y": 865.8120440798137, "x": 748.8828690569023, "border_width": 0, "id": "Cmpk2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Rbbp7<br/>cluster = 3", "color": "rgba(246, 246, 256, 1.0)", "y": 776.4721781847632, "x": 475.63114912954416, "border_width": 0, "id": "Rbbp7"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Nampt<br/>cluster = 2", "color": "rgba(246, 246, 256, 1.0)", "y": 812.2167404898418, "x": 680.0798326146428, "border_width": 0, "id": "Nampt"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Rbbp4<br/>cluster = 3", "color": "rgba(252, 252, 256, 1.0)", "y": 797.5828365551727, "x": 472.84395917958966, "border_width": 0, "id": "Rbbp4"}, {"node_label": "Ccnf", "node_shape": "triangle", "degree": 3.0, "title": "Ccnf<br/>cluster = 4", "color": "rgba(256, 202, 202, 1.0)", "y": 859.1831330347962, "x": 324.75709318788756, "border_width": 0, "id": "Ccnf"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hsd3b1<br/>cluster = 5", "color": "rgba(256, 254, 254, 1.0)", "y": 721.8143018961837, "x": -240.7197896271463, "border_width": 0, "id": "Hsd3b1"}, {"node_label": "Adssl1", "node_shape": "triangle", "degree": 3.0, "title": "Adssl1<br/>cluster = 2", "color": "rgba(226, 226, 256, 1.0)", "y": 902.1376622386507, "x": 652.7452208846365, "border_width": 0, "id": "Adssl1"}, {"node_label": "Klf1", "node_shape": "triangle", "degree": 3.0, "title": "Klf1<br/>cluster = 3", "color": "rgba(206, 206, 256, 1.0)", "y": 666.5875548233597, "x": 498.66642935682876, "border_width": 0, "id": "Klf1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Aqp11<br/>cluster = 6", "color": "rgba(252, 252, 256, 1.0)", "y": 357.30156957216224, "x": -212.19740973130445, "border_width": 0, "id": "Aqp11"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Aqp12<br/>cluster = 6", "color": "rgba(256, 254, 254, 1.0)", "y": 352.67115137548393, "x": -201.76793801069815, "border_width": 0, "id": "Aqp12"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Bcl2<br/>cluster = 7", "color": "rgba(256, 236, 236, 1.0)", "y": 449.5256842838232, "x": -188.8920531186696, "border_width": 0, "id": "Bcl2"}, {"node_label": "Avpr1a", "node_shape": "triangle", "degree": 3.0, "title": "Avpr1a<br/>cluster = 7", "color": "rgba(256, 218, 218, 1.0)", "y": 351.3461263101213, "x": -90.28762831974153, "border_width": 0, "id": "Avpr1a"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Tecr<br/>cluster = 8", "color": "rgba(254, 254, 256, 1.0)", "y": 301.6328375455726, "x": -557.3296065273697, "border_width": 0, "id": "Tecr"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Gys1<br/>cluster = 3", "color": "rgba(256, 250, 250, 1.0)", "y": 794.0694601391484, "x": 464.9435312011437, "border_width": 0, "id": "Gys1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Akt1<br/>cluster = 7", "color": "rgba(244, 244, 256, 1.0)", "y": 418.0338177729905, "x": -196.96402212717675, "border_width": 0, "id": "Akt1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Med1<br/>cluster = 3", "color": "rgba(248, 248, 256, 1.0)", "y": 729.8995492215344, "x": 475.8546095511873, "border_width": 0, "id ...
