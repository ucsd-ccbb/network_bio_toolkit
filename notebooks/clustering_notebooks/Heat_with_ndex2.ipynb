# %% [markdown]
# # Space Mice Genes
# ## Heat Propagation and Clustering Package
#
#
# ----------------------
#
# Author: Mikayla Webster (13webstermj@gmail.com)
#
# Date: 2nd May, 2018
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Define Analysis Preferences](#pref)
# 3. [Load Networks](#load)
# 4. [Run Heat Propagation](#heat)
# 5. [Clustering](#cluster)

# %% [markdown]
# ## Background
# <a id='background'></a>

# %% [markdown]
# ## Import packages
# <a id='import'></a>

# %%
import sys
code_path = '../../network_bio_toolkit'
sys.path.append(code_path)

import Heat
reload(Heat)

import pandas as pd

# %% [markdown]
# ## Define Analysis Preferences
# <a id='pref'></a>

# %%
symbol = 'symbol'
entrez = 'entrez'

human = 'human'
mouse = 'mouse'

heat = Heat.Heat(gene_type = symbol, species = mouse)

# %% [markdown]
# ## Load Networks
# <a id='load'></a>
#
# 1. Load DEG file
# 2. Load STRING background network

# %%
# load DEG file
DEG_filename = "../../DEG_databases/DE_CoeffspaceFlight - groundControl_glds48_20180312.csv"  
heat.create_DEG_list(DEG_filename, p_value_filter = 0.05, sep = ',')

print('Number of DEG\'s: ' + str(len(heat.DEG_list)))
# Out:
# Number of DEG's: 181
# ../../network_bio_toolkit\create_graph.py:277: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   df = pd.DataFrame.from_csv(filename, sep=sep)

# %%
# load background network from BIOGRID ndex2 network 
heat.load_ndex_from_server(UUID = '52d57bf9-23dc-11e8-b939-0ac135e8bacf', relabel_node_field = 'name')

print('\nNumber of interactions: ' + str(len(list(heat.DG_universe.nodes()))))
# Out:
# Number of interactions: 12669

# %% [markdown]
# ## Run Heat Propagation
# <a id='heat'></a>

# %%
Wprime = heat.normalized_adj_matrix() # optional. Saves time to do it once here.

# %%
heat.draw_heat_prop(num_nodes = 500,
#                  random_walk = False,
                  edge_width = 2,
                  edge_smooth_enabled = True,
                  edge_smooth_type = 'bezier',
                  node_size_multiplier = 5,
                  hover = False,
                  hover_connected_edges = False,
                  largest_connected_component = False,
                  physics_enabled = True,
                  node_font_size = 20,
                  graph_id = 1,
                  node_shadow_x = 6)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"node_label": "", "node_shape": "dot", "x": 624.0726113319397, "degree": 4, "node_size": 10, "color": "rgba(256, 235, 0, 1.0)", "title": "SMARCC2<br/>heat = 0.00019", "border_width": 0, "id": "SMARCC2", "y": 729.1433811187744}, {"node_label": "", "node_shape": "dot", "x": 378.26767563819885, "degree": 1, "node_size": 10, "color": "rgba(256, 202, 0, 1.0)", "title": "AGL<br/>heat = 0.00041", "border_width": 0, "id": "AGL", "y": 818.3153867721558}, {"node_label": "", "node_shape": "dot", "x": 542.570173740387, "degree": 100, "node_size": 10, "color": "rgba(256, 0, 0, 1.0)", "title": "Fancd2<br/>heat = 0.04337", "border_width": 0, "id": "Fancd2", "y": 661.7745757102966}, {"node_label": "", "node_shape": "dot", "x": 396.27769589424133, "degree": 1, "node_size": 10, "color": "rgba(256, 197, 0, 1.0)", "title": "Xpc<br/>heat = 0.00045", "border_width": 0, "id": "Xpc", "y": 624.8259544372559}, {"node_label": "", "node_shape": "dot", "x": 539.3742918968201, "degree": 9, "node_size": 10, "color": "rgba(256, 249, 0, 1.0)", "title": "Lima1<br/>heat = 0.00014", "border_width": 0, "id": "Lima1", "y": 683.4036707878113}, {"node_label": "", "node_shape": "dot", "x": 393.71100068092346, "degree": 1, "node_size": 10, "color": "rgba(256, 197, 0, 1.0)", "title": "Xpa<br/>heat = 0.00045", "border_width": 0, "id": "Xpa", "y": 632.0159435272217}, {"node_label": "", "node_shape": "dot", "x": 550.0203967094421, "degree": 15, "node_size": 10, "color": "rgba(256, 132, 0, 1.0)", "title": "Invs<br/>heat = 0.00206", "border_width": 0, "id": "Invs", "y": 646.6743350028992}, {"node_label": "", "node_shape": "dot", "x": 617.3017024993896, "degree": 4, "node_size": 10, "color": "rgba(256, 235, 0, 1.0)", "title": "SMARCC1<br/>heat = 0.00019", "border_width": 0, "id": "SMARCC1", "y": 717.4796462059021}, {"node_label": "", "node_shape": "dot", "x": 434.6022307872772, "degree": 2, "node_size": 10, "color": "rgba(256, 251, 0, 1.0)", "title": "Peli1<br/>heat = 0.00013", "border_width": 0, "id": "Peli1", "y": 647.137701511383}, {"node_label": "", "node_shape": "dot", "x": 548.1361150741577, "degree": 30, "node_size": 10, "color": "rgba(256, 205, 0, 1.0)", "title": "Shank3<br/>heat = 0.00038", "border_width": 0, "id": "Shank3", "y": 664.7620797157288}, {"node_label": "", "node_shape": "dot", "x": 436.7126226425171, "degree": 2, "node_size": 10, "color": "rgba(256, 201, 0, 1.0)", "title": "SDF4<br/>heat = 0.00042", "border_width": 0, "id": "SDF4", "y": 755.8833956718445}, {"node_label": "", "node_shape": "dot", "x": 505.29754161834717, "degree": 1, "node_size": 10, "color": "rgba(256, 223, 0, 1.0)", "title": "Pdlim2<br/>heat = 0.00025", "border_width": 0, "id": "Pdlim2", "y": 773.3448147773743}, {"node_label": "", "node_shape": "dot", "x": 544.0115332603455, "degree": 10, "node_size": 10, "color": "rgba(256, 156, 0, 1.0)", "title": "Sp1<br/>heat = 0.00119", "border_width": 0, "id": "Sp1", "y": 716.881275177002}, {"node_label": "", "node_shape": "dot", "x": 525.862455368042, "degree": 15, "node_size": 10, "color": "rgba(256, 249, 0, 1.0)", "title": "Eef2<br/>heat = 0.00014", "border_width": 0, "id": "Eef2", "y": 681.2882423400879}, {"node_label": "Serpine1", "node_shape": "triangle", "x": 24.69056472182274, "degree": 1, "node_size": 10, "color": "rgba(256, 75, 0, 1.0)", "title": "Serpine1<br/>heat = 0.00758", "border_width": 2, "id": "Serpine1", "y": 588.4448885917664}, {"node_label": "", "node_shape": "dot", "x": 571.3143944740295, "degree": 4, "node_size": 10, "color": "rgba(256, 254, 0, 1.0)", "title": "Hes1<br/>heat = 0.00012", "border_width": 0, "id": "Hes1", "y": 743.5072660446167}, {"node_label": "", "node_shape": "dot", "x": 445.0678527355194, "degree": 9, "node_size": 10, "color": "rgba(256, 133, 0, 1.0)", "title": "Bcl6<br/>heat = 0.00199", "border_width": 0, "id": "B ...

# %% [markdown]
# ## Clustering
# <a id='cluster'></a>

# %% [markdown]
# Parameter information:
# - **G_DEG**: background network filtered by DEG list, output of load_STRING_to_digraph
# - **DG_universe**: full background network, output of create_graph.load_STRING_to_digraph
# - **seed_nodes**: list of DEG's, output of create_graph.create_DEG_list
# - **Wprime**: will calculate automatically of not specified, output of visualizations.normalized_adj_matrix
# - **num_top_genes**: number of genes to display in the output graph
# - **cluster_size_cut_off**: color clusters below this threshhold grey
# - **remove_stray_nodes**: remove custers below the cluster size cut off
# - **r**: increases spacing between clusters. recommended number between 0.5 and 4.0
# - **x_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **y_offset**: modify if some clusters are overlapping. Extra helpful when x_offset != y_offset
# - **node_spacing**: recommended number between 500 and 2000
# - **node_size_multiplier**: as you scale node_spacing, scale this number. Recommended number between 5 and 25
# - **physics_enabled**: Nodes will bounce aroound when you click and drag them. Only set to True when number of nodes is 200 or less
# - **node_font_size**: as you scale node_spacing, scale this number. Recommended number between 20 and 50
# - **graph_id**: Allows rendering of multiple graphs in one notebook. Just make sure each graph has a unique id.

# %%
heat.draw_clustering(rad_positions = False,
                largest_connected_component = False,
                num_top_genes = 500,
                cluster_size_cut_off = 5,
                remove_stray_nodes = False,
                node_spacing = 700,
                node_size_multiplier = 15,
                physics_enabled = True,
                node_font_size = 16,
                graph_id = 2
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file2"];    frame.runVis([{"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "SMARCC2<br/>cluster = 0", "color": "#004033", "y": 277.18120217323303, "x": 522.5118339061737, "border_width": 0, "id": "SMARCC2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "AGL<br/>cluster = 1", "color": "#ff0044", "y": 276.42446756362915, "x": 330.5745095014572, "border_width": 0, "id": "AGL"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Fancd2<br/>cluster = 2", "color": "#a300cc", "y": 199.32319521903992, "x": 466.554194688797, "border_width": 0, "id": "Fancd2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Xpc<br/>cluster = 3", "color": "#3000b3", "y": 266.42734706401825, "x": 382.98373222351074, "border_width": 0, "id": "Xpc"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Lima1<br/>cluster = 2", "color": "#a300cc", "y": 225.13699531555176, "x": 471.62315249443054, "border_width": 0, "id": "Lima1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Xpa<br/>cluster = 3", "color": "#3000b3", "y": 258.60319435596466, "x": 378.49005460739136, "border_width": 0, "id": "Xpa"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Invs<br/>cluster = 2", "color": "#a300cc", "y": 188.79157900810242, "x": 470.13217210769653, "border_width": 0, "id": "Invs"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "SMARCC1<br/>cluster = 0", "color": "#004033", "y": 264.64077830314636, "x": 526.1480569839478, "border_width": 0, "id": "SMARCC1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "DYNLL1<br/>cluster = 4", "color": "#000c59", "y": 212.79135644435883, "x": 466.8238937854767, "border_width": 0, "id": "DYNLL1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Shank3<br/>cluster = 4", "color": "#000c59", "y": 202.971351146698, "x": 484.2700958251953, "border_width": 0, "id": "Shank3"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "SDF4<br/>cluster = 1", "color": "#ff0044", "y": 255.52464425563812, "x": 392.3123836517334, "border_width": 0, "id": "SDF4"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Axin1<br/>cluster = 4", "color": "#000c59", "y": 192.15148985385895, "x": 482.85446763038635, "border_width": 0, "id": "Axin1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Sp1<br/>cluster = 5", "color": "#00d9ca", "y": 239.98947143554688, "x": 484.8826766014099, "border_width": 0, "id": "Sp1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Ewsr1<br/>cluster = 4", "color": "#000c59", "y": 222.45838344097137, "x": 488.7383222579956, "border_width": 0, "id": "Ewsr1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hes1<br/>cluster = 5", "color": "#00d9ca", "y": 283.07623863220215, "x": 471.4790403842926, "border_width": 0, "id": "Hes1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Bcl6<br/>cluster = 7", "color": "#00f281", "y": 189.17491137981415, "x": 532.9687654972076, "border_width": 0, "id": "Bcl6"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hes6<br/>cluster = 5", "color": "#00d9ca", "y": 309.318682551384, "x": 456.62935972213745, "border_width": 0, "id": "Hes6"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Bcl2<br/>cluster = 8", "color": "#00660e", "y": 221.10410928726196, "x": 505.95951080322266, "border_width": 0, "id": "Bcl2"}, {"node_label": "Rrm2", "node_shape": "triangle", "degree": 3.0, "title": "Rrm2<br/>cluster = 5", "color": "#00d9ca", "y": 246.01353704929352, "x": 532.342916727066, "border_width": 0, "id": "Rrm2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Rrm1<br/>cluster = 5", "color": "#00d9ca", "y": 231.1258465051651, "x": 500.31 ...

# %%
heat.draw_clustering(num_top_genes = 500,
                cluster_size_cut_off = 5,
                remove_stray_nodes = False,
                r = 1.0,
#                x_offset = 2,
#                y_offset = 2,
                node_spacing = 700,
                node_size_multiplier = 4,
                physics_enabled = False,
                node_font_size = 25,
                graph_id = 3,
                node_shadow_x = 6
               )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file3"];    frame.runVis([{"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "SMARCC2<br/>cluster = 0", "color": "#004033", "y": 397.4102973937988, "x": 1000.5452632904053, "border_width": 0, "id": "SMARCC2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "AGL<br/>cluster = 1", "color": "#ff0044", "y": 539.4251465797424, "x": 853.5618424415588, "border_width": 0, "id": "AGL"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Fancd2<br/>cluster = 2", "color": "#a300cc", "y": 937.4289989471436, "x": 758.6203336715698, "border_width": 0, "id": "Fancd2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Xpc<br/>cluster = 3", "color": "#3000b3", "y": 1109.6744298934937, "x": 676.8773078918457, "border_width": 0, "id": "Xpc"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Lima1<br/>cluster = 2", "color": "#a300cc", "y": 900.8856058120728, "x": 760.9212875366211, "border_width": 0, "id": "Lima1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Xpa<br/>cluster = 3", "color": "#3000b3", "y": 1103.7036657333374, "x": 677.9769241809845, "border_width": 0, "id": "Xpa"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Invs<br/>cluster = 2", "color": "#a300cc", "y": 932.9900622367859, "x": 746.8904256820679, "border_width": 0, "id": "Invs"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "SMARCC1<br/>cluster = 0", "color": "#004033", "y": 387.9374921321869, "x": 957.5855016708374, "border_width": 0, "id": "SMARCC1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "DYNLL1<br/>cluster = 4", "color": "#000c59", "y": 1118.092429637909, "x": 292.07575619220734, "border_width": 0, "id": "DYNLL1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Shank3<br/>cluster = 4", "color": "#000c59", "y": 1157.9717636108398, "x": 301.0232239961624, "border_width": 0, "id": "Shank3"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "SDF4<br/>cluster = 1", "color": "#ff0044", "y": 621.9738900661469, "x": 868.0692672729492, "border_width": 0, "id": "SDF4"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Axin1<br/>cluster = 4", "color": "#000c59", "y": 1173.291540145874, "x": 282.93339908123016, "border_width": 0, "id": "Axin1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Sp1<br/>cluster = 5", "color": "#00d9ca", "y": 1136.6828918457031, "x": 92.5438404083252, "border_width": 0, "id": "Sp1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Ewsr1<br/>cluster = 4", "color": "#000c59", "y": 1148.285710811615, "x": 331.2170058488846, "border_width": 0, "id": "Ewsr1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hes1<br/>cluster = 5", "color": "#00d9ca", "y": 1190.9993052482605, "x": 64.27637413144112, "border_width": 0, "id": "Hes1"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Bcl6<br/>cluster = 7", "color": "#00f281", "y": 912.2787237167358, "x": -299.06225204467773, "border_width": 0, "id": "Bcl6"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Hes6<br/>cluster = 5", "color": "#00d9ca", "y": 1190.3156280517578, "x": 28.195003420114517, "border_width": 0, "id": "Hes6"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Bcl2<br/>cluster = 8", "color": "#00660e", "y": 618.7847316265106, "x": -465.8639669418335, "border_width": 0, "id": "Bcl2"}, {"node_label": "Rrm2", "node_shape": "triangle", "degree": 3.0, "title": "Rrm2<br/>cluster = 5", "color": "#00d9ca", "y": 1182.326877117157, "x": 25.867492705583572, "border_width": 0, "id": "Rrm2"}, {"node_label": "", "node_shape": "dot", "degree": 3.0, "title": "Rrm1<br/>cluster = 5", "color": "#00d9ca", "y": 1168.37637424469, "x": 47.46782854199 ...
