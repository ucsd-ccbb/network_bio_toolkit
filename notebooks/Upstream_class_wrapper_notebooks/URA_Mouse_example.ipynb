# %% [markdown]
# # Upstream Regulator Analysis Package
# ## Mouse example
# ### Wrapper Class "Upstream" in Use
#
# ----------------------
#
# Author: Mikayla Webster (m1webste@ucsd.edu)
#
# Date: 9th February, 2018
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Load Networks](#load)
# 6. [P-value and Z-score Calculation](#pz)
# 8. [Display Our results](#display)

# %% [markdown]
# ## Background
# <a id='background'></a>
#
# The inspiration for these modules comes from Ingenuity System's [Ingenuity Upstream Regulator Analysis in IPA®](http://pages.ingenuity.com/rs/ingenuity/images/0812%20upstream_regulator_analysis_whitepaper.pdf).
#
# This notebook demonstrates how to use our ura package WITH the use of our "wrapper class" Upstream. This notebook creates an instance of class Upstream, and uses this instance to call all of our module's functions. This requires less module imports and simplifies work flow. This notebook emphasizes the flow of function calls, namely what order you should call functions in order for the workflow to process correctly. If you need further help on how to use a function or what that function's purpose is, see the comments associated with that function in the source code (create_graph.py or stat_analysis.py).

# %% [markdown]
# ## Import packages
# <a id='import'></a>

# %%
# import upstream regulator module
import sys
code_path = '../../ura'
sys.path.append(code_path)
import Upstream
reload(Upstream)
# Out:
# <module 'Upstream' from '../../ura\Upstream.pyc'>

# %%
# %matplotlib inline

# %%
# User preferences
symbol = 'symbol'
entrez = 'entrez'

human = 'human'
mouse = 'mouse'

ura = Upstream.Upstream(gene_type = symbol, species = mouse)

# %% [markdown]
# ## Load Networks
# <a id='load'></a>
#
# 1. List of all **Transcription Factors** (TF's) or regulators of interest to us
#     <br>
#     - Our sources are [slowkow](https://github.com/slowkow/tftargets) and [jaspar](http://jaspar.genereg.net/) TF databases
#     <br><br>
# 2. **Background Network**: [STRING human protein interactions network](https://string-db.org/cgi/download.pl?UserId=9BGA8WkVMRl6&sessionId=HWUK6Dum9xC6&species_text=Homo+sapiens)
#     - Filter our background network down to just the sub network of TF's and their targets
#     <br><br>
# 3. User-supplied list of **Differentially Expressed Genes** (DEG's)

# %%
# transcription factors
ura.easy_load_TF_list(slowkow_bool=True, jaspar_bool=True)
TF_list = ura.get('TF_list')
print "Number of TF's: " + str(len(TF_list))
# Out:
# Number of TF's: 3983

# %%
# background network
filename = "../../background_networks/10090.protein.actions.v10.5.txt"
confidence_filter = 400
ura.load_STRING_to_digraph(filename, confidence_filter)
DG_TF = ura.get('DG_TF')

print "\nNumber of interactions: " + str(len(list(DG_TF.edges())))
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-7303...done.
# Finished.
# 57 input query terms found dup hits:
# 	[(u'ENSMUSP00000042658', 2), (u'ENSMUSP00000126737', 2), (u'ENSMUSP00000051968', 3), (u'ENSMUSP00000
# 154 input query terms found no hit:
# 	[u'ENSMUSP00000036849', u'ENSMUSP00000097354', u'ENSMUSP00000097358', u'ENSMUSP00000137522', u'ENSMU
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
#
# Number of interactions: 21200

# %%
# differentially expressed genes
DEG_filename = '../../DEG_databases/DE_CoeffSaline_2w - Uninjured_Cooke_RNAseq_synovium_20171025.csv'
ura.create_DEG_list(DEG_filename, p_value_filter = 0.05, fold_change_filter = 1)

DEG_list = ura.get('DEG_list')
print "Number of DEG's: " + str(len(DEG_list))
# Out:
# Number of DEG's: 1528

# %% [markdown]
# ## P-values and Z-score Calculation
# <a id='pz'></a>
#
# 1. **P-values**: How relevant is a TF to its DEG targets? Are they connected by chance, or is their connection statistically significant?
#     <br>
#     1. -log(p-value) for each TF using [scipy.stats.hypergeom.logsf](https://docs.scipy.org/doc/scipy-0.19.1/reference/generated/scipy.stats.hypergeom.html).
#         1. high value = significant connection between this TF and its DEG targets
#         2. low value = TF is randomly associated with its DEG targets
#         3. zero = None of this TF's targets were DEG's
#         4. inf = original p-value was so small that its log is inf. Very high significance.
#         <br><br>
# 2. **Z-scores**: Goal is to predict the activation states of the TF's
#
#     - activation states: interaction type/regulation direction = predicted state
#         - activating/up  = activating
#         - activating/down = inhibiting
#         - inhibiting/up = inhibiting
#         - inhibiting/down = activating
#         <br><br>
#     - unbiased vs biased calculations:
#         - **unbiased calculation**: Assume a normal distribution of activating and inhibiting states
#         - **biased calculation**: For the case when you cannot assume a 50-50 split between up/down-regulated targets and activating/inhbiting interactions. Modify our formula to approximate a normal distribution.

# %%
# Enrichment of every TF with respect to its targets
ura.tf_target_enrichment_calc()

# Enrichment of TF's themselves
ura.tf_enrichment_calc()   
ura.get('tf_enrichment')
# Out:
# TF_ENRICHMENT   -1.661649e-11
# dtype: float64

# %%
ura.tf_zscore(bias_filter=0.25)

# %% [markdown]
# ## Display Our Results
# <a id='display'></a>
# - Display TF's with top z-scores
# - Display a histogram to see where specific genes rank among others according to z-score
# - Display subnetwork of a particular TF and its targets

# %%
top_values = ura.top_values(abs_value=True, top=10)
display(top_values)
# Out:
#          z-score  (adj) p-value  (log) fold change
# Bub3    3.899602       0.988472          -0.003605
# Xpo1    3.656552       0.048499           0.535212
# Cenpa   3.656552       0.075185           1.109307
# Kntc1   3.530090       0.225594           1.802828
# Nup37   3.530090       0.367464           0.345433
# Nup133  3.530090       0.867833          -0.055210
# Cenpt   3.530090       0.120306           0.678457
# Ranbp2  3.530090       0.311983           0.276706
# Ahctf1  3.530090       0.532534           0.258789
# Clip1   3.530090       0.030135          -0.719186

# %%
genes_to_rank = ['Hoxa4', 'Cebpb', 'Klf4', 'Tle3', 'Rbl2', 'Stat1', 'Bub3', 'Cenpa']
genes_to_rank = [x.title() for x in genes_to_rank]
ura.compare_genes(genes_to_rank)

# %%
ura.vis_tf_network('Klf4',
              directed_edges = False,
              color_non_DEGs=False,
              node_spacing = 1500,
              graph_id = 2,
              tf_size_amplifier = 0)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file2"];    frame.runVis([{"node_shape": "circle", "degree": 3.0, "title": "Il10", "color": "grey", "size_field": 4.496326598241282, "y": 1148.1530090413228, "x": 336.29034446464703, "border_width": 0, "id": "Il10"}, {"node_shape": "circle", "degree": 3.0, "title": "Plaur", "color": "grey", "size_field": 2.7802095404416023, "y": 293.1583674253022, "x": 1045.3593102688894, "border_width": 0, "id": "Plaur"}, {"node_shape": "circle", "degree": 3.0, "title": "Ctnnb1", "color": "grey", "size_field": 2.324284335815272, "y": 1131.6965470108676, "x": 725.5641729759687, "border_width": 0, "id": "Ctnnb1"}, {"node_shape": "circle", "degree": 3.0, "title": "Jup", "color": "grey", "size_field": 5.097892437482933, "y": 143.53639060224128, "x": 858.2049289740918, "border_width": 0, "id": "Jup"}, {"node_shape": "star", "degree": 3.0, "title": "Klf4", "color": "grey", "size_field": 11.438770068757355, "y": 762.5206958448647, "x": 447.862999278104, "border_width": 0, "id": "Klf4"}, {"node_shape": "circle", "degree": 3.0, "title": "Cdh1", "color": "grey", "size_field": 4.496326598241282, "y": 592.0068043812321, "x": 521.3289375431369, "border_width": 0, "id": "Cdh1"}, {"node_shape": "circle", "degree": 3.0, "title": "Stat3", "color": "grey", "size_field": 2.0321309523117717, "y": 954.7288706145384, "x": 529.0754176869269, "border_width": 0, "id": "Stat3"}, {"node_shape": "circle", "degree": 3.0, "title": "Trp53", "color": "grey", "size_field": 5.390162303466489, "y": 906.307582006002, "x": 639.5992038348044, "border_width": 0, "id": "Trp53"}, {"node_shape": "circle", "degree": 3.0, "title": "Cdkn1a", "color": "grey", "size_field": 4.6676737928100795, "y": 802.2714408193276, "x": 891.5910361184527, "border_width": 0, "id": "Cdkn1a"}, {"node_shape": "circle", "degree": 3.0, "title": "Slc2a4", "color": "rgba(0, 0, 256, 1.0)", "size_field": 11.438770068757355, "y": 1500.0, "x": 747.0491076391489, "border_width": 2, "id": "Slc2a4"}, {"node_shape": "circle", "degree": 3.0, "title": "Tcf7l1", "color": "grey", "size_field": 2.202195788588865, "y": 1362.7752114643868, "x": 536.7377114247414, "border_width": 0, "id": "Tcf7l1"}, {"node_shape": "circle", "degree": 3.0, "title": "Tcf7l2", "color": "grey", "size_field": 3.116953562855516, "y": 1171.3337967772356, "x": 1043.765871043103, "border_width": 0, "id": "Tcf7l2"}, {"node_shape": "circle", "degree": 3.0, "title": "Edn1", "color": "grey", "size_field": 2.6042680909836555, "y": 1325.4804162429828, "x": 912.5309253453618, "border_width": 0, "id": "Edn1"}, {"node_shape": "circle", "degree": 3.0, "title": "Hdc", "color": "grey", "size_field": 2.2996981321786176, "y": 29.411623650950748, "x": 444.9751114049016, "border_width": 0, "id": "Hdc"}, {"node_shape": "circle", "degree": 3.0, "title": "Mapk7", "color": "grey", "size_field": 4.336422777880523, "y": 525.5177664073228, "x": 1196.9204202291098, "border_width": 0, "id": "Mapk7"}, {"node_shape": "circle", "degree": 3.0, "title": "Tert", "color": "grey", "size_field": 4.496326598241282, "y": 984.0351202237802, "x": 1081.3511506516559, "border_width": 0, "id": "Tert"}, {"node_shape": "circle", "degree": 3.0, "title": "Crebbp", "color": "grey", "size_field": 5.908839903600919, "y": 1209.8389424870982, "x": 588.9302193378069, "border_width": 0, "id": "Crebbp"}, {"node_shape": "circle", "degree": 3.0, "title": "Tagln", "color": "rgba(198, 198, 256, 1.0)", "size_field": 6.3941999570854255, "y": 1002.057176367182, "x": 83.72359879622022, "border_width": 2, "id": "Tagln"}, {"node_shape": "circle", "degree": 3.0, "title": "Bmp6", "color": "grey", "size_field": 5.382784108344858, "y": 25.34033216273988, "x": 660.5850208484045, "border_width": 0, "id": "Bmp6"}, {"node_shape": "circle", "degree": 3.0, "title": "Bmp4", "color": "grey", "size_field": 3.0209141434076194, "y": 771.6162432281305, "x": 141.0 ...

# %%
# display subnetworks using visJS2jupyter
ura.vis_tf_network('Stat1',
              color_non_DEGs=False,
              directed_edges = True,
              node_spacing = 2000,
              graph_id = 1,
              tf_size_amplifier = 0)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"node_shape": "circle", "degree": 3.0, "title": "Cyp1b1", "color": "rgba(0, 0, 256, 1.0)", "size_field": 7.474510531017888, "y": 1605.8287571205021, "x": 474.44129054944693, "border_width": 2, "id": "Cyp1b1"}, {"node_shape": "circle", "degree": 3.0, "title": "Ptpn11", "color": "grey", "size_field": 2.7666455915793073, "y": 511.79967640339373, "x": 948.7342619764061, "border_width": 0, "id": "Ptpn11"}, {"node_shape": "circle", "degree": 3.0, "title": "Il17f", "color": "grey", "size_field": 3.905653086454519, "y": 898.4197919938966, "x": 905.1314502350508, "border_width": 0, "id": "Il17f"}, {"node_shape": "circle", "degree": 3.0, "title": "Thpo", "color": "grey", "size_field": 3.905653086454519, "y": 123.45411127984315, "x": 773.0904394372641, "border_width": 0, "id": "Thpo"}, {"node_shape": "circle", "degree": 3.0, "title": "Sp110", "color": "grey", "size_field": 2.1009348781558694, "y": 418.7836550910788, "x": 314.1673156987687, "border_width": 0, "id": "Sp110"}, {"node_shape": "circle", "degree": 3.0, "title": "Mapk14", "color": "grey", "size_field": 2.597527961043161, "y": 767.1167042183722, "x": 1455.979907691052, "border_width": 0, "id": "Mapk14"}, {"node_shape": "circle", "degree": 3.0, "title": "Irf1", "color": "grey", "size_field": 3.052537245331015, "y": 904.5364096612329, "x": 1471.6378289281552, "border_width": 0, "id": "Irf1"}, {"node_shape": "circle", "degree": 3.0, "title": "Ifng", "color": "grey", "size_field": 3.905653086454519, "y": 568.2708966545435, "x": 890.4708418820662, "border_width": 0, "id": "Ifng"}, {"node_shape": "circle", "degree": 3.0, "title": "Mpl", "color": "grey", "size_field": 3.905653086454519, "y": 281.0856956501256, "x": 258.9795618934374, "border_width": 0, "id": "Mpl"}, {"node_shape": "circle", "degree": 3.0, "title": "Irf8", "color": "grey", "size_field": 3.2156486264869226, "y": 32.49354342096028, "x": 758.9267521170054, "border_width": 0, "id": "Irf8"}, {"node_shape": "circle", "degree": 3.0, "title": "Fyn", "color": "grey", "size_field": 2.5994036020121065, "y": 700.1095593416977, "x": 890.2248760796311, "border_width": 0, "id": "Fyn"}, {"node_shape": "circle", "degree": 3.0, "title": "Sp7", "color": "grey", "size_field": 3.905653086454519, "y": 739.0386908797817, "x": 1713.499676475886, "border_width": 0, "id": "Sp7"}, {"node_shape": "circle", "degree": 3.0, "title": "Zfp36", "color": "grey", "size_field": 2.4368165140174938, "y": 592.9912259509894, "x": 345.2341450731191, "border_width": 0, "id": "Zfp36"}, {"node_shape": "circle", "degree": 3.0, "title": "Hes1", "color": "grey", "size_field": 5.0260827811161, "y": 541.897591880185, "x": 1820.8762746789328, "border_width": 0, "id": "Hes1"}, {"node_shape": "circle", "degree": 3.0, "title": "Lck", "color": "grey", "size_field": 3.3365227828909774, "y": 1515.109447186867, "x": 514.5681488647227, "border_width": 0, "id": "Lck"}, {"node_shape": "circle", "degree": 3.0, "title": "Bcl2", "color": "grey", "size_field": 2.8216085315491455, "y": 1068.066807185563, "x": 1231.4810503518888, "border_width": 0, "id": "Bcl2"}, {"node_shape": "circle", "degree": 3.0, "title": "Csf2rb", "color": "grey", "size_field": 4.596604368704286, "y": 1470.9977001168304, "x": 1133.849508633999, "border_width": 0, "id": "Csf2rb"}, {"node_shape": "circle", "degree": 3.0, "title": "Csf2ra", "color": "grey", "size_field": 2.166418038904068, "y": 173.9594172919083, "x": 1662.7467100713566, "border_width": 0, "id": "Csf2ra"}, {"node_shape": "circle", "degree": 3.0, "title": "Il27", "color": "grey", "size_field": 3.905653086454519, "y": 325.2207849824357, "x": 1014.7148658498318, "border_width": 0, "id": "Il27"}, {"node_shape": "circle", "degree": 3.0, "title": "Il12b", "color": "grey", "size_field": 3.905653086454519, "y": 8.470250348269701, "x": 1016.4095993819791, "border_ ...

# %%
# to write data to a csv file
csv_filename = 'analysis_mouse.txt'
ura.to_csv(csv_filename)
