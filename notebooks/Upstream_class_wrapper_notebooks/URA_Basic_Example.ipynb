# %% [markdown]
# # Upstream Regulator Analysis
# ## Basic Example
# ### Wrapper Class "Upstream" in Use
#
# ----------------------
#
# Author: Mikayla Webster (m1webste@ucsd.edu)
#
# Date: 8th November, 2017
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Create Graph](#graph)
#     1. [Transcription Factors](#tf)
#     2. [Background Network](#bn)
#     3. [Differentially Expressed Genes](#deg)
# 3. [Stat Analysis](#stat)
#     1. [P-value](#pvalue)
#     2. [Z-score](#zscore)
#     3. [Display Our Results](#display)
#         1. [Top Values](#top)
#         2. [Rank with z-score](#rank)
#         3. [Network Visualization using visJS2jupyter](#visJS)

# %% [markdown]
# ## Background
# <a id='background'></a>

# %% [markdown]
# The inspiration for these modules comes from Ingenuity System's [Ingenuity Upstream Regulator Analysis in IPA®](http://pages.ingenuity.com/rs/ingenuity/images/0812%20upstream_regulator_analysis_whitepaper.pdf).
#
# This notebook is meant to explain how to use the individual functions from our URA modules, with emphasis on different parameter options. If you need further help on how to use a function or what that function's purpose is, see the comments associated with that function in the source code (create_graph.py or stat_analysis.py).

# %% [markdown]
# ## Import packages
# <a id='import'></a>

# %%
# import upstream regulator module
import sys
code_path = '../../ura'
sys.path.append(code_path)
import Upstream
reload(Upstream)

# import matplotlib for color map
import matplotlib as plt

# %%
# %matplotlib inline

# %%
# User preferences
symbol = 'symbol'
entrez = 'entrez'

ura = Upstream.Upstream(symbol)

# %% [markdown]
# ## Create Graph ##
# <a id='graph'></a>

# %% [markdown]
# ### Transcription Factors
# <a id='tf'></a>
#
# Our create_graph module prepares 3 databases to use in our analysis: a transcription factor interaction network, a background network, and a differentially expressed genes database. Our transcription factor data comes from two sources: [slowkow](https://github.com/slowkow/tftargets) and [jaspar](http://jaspar.genereg.net/). Slowkow is a compilation of 6 smaller databases: TRED, ITFP, ENCODE, Neph2012, TRRUST, Marbach2016. Information about these specific databases, including links to their sources, is available through the slowkow github page. Some basic information on these databases is as follows:
# - Size of Jaspar Database: 2049
# - Size of Slowkow Database: 2705
# - Size of TRED: 133
# - Size of ITFP: 1974
# - Size of ENCODE: 157
# - Size of Neph2012: 536
# - Size of TRRUST: 748
# - Size of Marbach2016: 643
#
# Our trascription factor list contains 3983 unique entries.

# %%
ura.easy_load_TF_list(slowkow_bool=True,
                      slowkow_files=['../../TF_databases/slowkow_databases/TRED_TF.txt',
                      '../../TF_databases/slowkow_databases/ITFP_TF.txt',
                      '../../TF_databases/slowkow_databases/ENCODE_TF.txt',
                      '../../TF_databases/slowkow_databases/Neph2012_TF.txt',
                      '../../TF_databases/slowkow_databases/TRRUST_TF.txt',
                      '../../TF_databases/slowkow_databases/Marbach2016_TF.txt'],
                      jaspar_bool=True,
                      jaspar_file="../../TF_databases/jaspar_genereg_matrix.txt")
len(ura.get('TF_list'))
# Out:
# 3983

# %% [markdown]
# ### Background Network
# <a id='bn'></a>
#
# Our background network comes from the [STRING](https://string-db.org/) database. Our module uses our list of transcription factors (TF_list) to extract only relevant information from the STRING database. Namely, we remove all edges and nodes not conected to our TF's.
#
# This function may need a minute or so to process.

# %%
filename = "../../background_networks/9606.protein.actions.v10.5.txt"
confidence_filter = 400
ura.load_STRING_to_digraph(filename, confidence_filter)
DG_TF = ura.get('DG_TF')
DG_universe = ura.get('DG_universe')

print "\nNumber of interactions: " + str(len(list(DG_TF.edges())))
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-7374...done.
# Finished.
# 56 input query terms found dup hits:
# 	[(u'ENSP00000359550', 3), (u'ENSP00000447879', 2), (u'ENSP00000364076', 2), (u'ENSP00000348986', 2),
# 312 input query terms found no hit:
# 	[u'ENSP00000376684', u'ENSP00000289352', u'ENSP00000202788', u'ENSP00000373637', u'ENSP00000367802',
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
#
# Number of interactions: 28939

# %%
print 'Number of unique nodes without filtering: ' + str(len(list(set(DG_universe.nodes()))))
print 'Number of edges without filtering: ' + str(len(DG_universe.edges()))
print '-----------------------------------------------'
print 'Number of unique nodes with filtering: ' + str(len(list(set(DG_TF.nodes()))))
print 'Number of edges with filtering: ' + str(len(DG_TF.edges()))
# Out:
# Number of unique nodes without filtering: 7050
# Number of edges without filtering: 140382
# -----------------------------------------------
# Number of unique nodes with filtering: 4613
# Number of edges with filtering: 28939

# %% [markdown]
# ### Differentially Expressed Genes
# <a id='deg'></a>
#
# Our last database comes from a list of differentially exressed genes (DEG) found in an experiement. This should come in the form of a tab separated csv file with at least three columns: gene name, (adjusted) p-value, and (log) fold change. Our parser will look for common header names for each of these columns. However, if your file has unusual column headers for any of these three categories, please specify your column headers using the parameters "gene_column_header", "p_value_column_header", and "fold_change_column_header".
#
# **WARNING: Having spaces in your column headers can cause weird bugs.**
#
# Specify a networkx graph G in order to add the fold change (up-down) information from your csv file as a node attribute to this graph. NOTE: 1) the graph will not be modified in place, and 2) if G is not specified, 3 values will be returned rather than 2.

# %%
filename = '../../DEG_databases/differentially_expressed_genes.txt'

ura.create_DEG_list(filename,
                    p_value_filter = 0.05,
                    p_value_or_adj = 'adj',  # filtering by p-value ('p') or adjusted p-value ('adj')
                    fold_change_filter = None,  # specify a number to filter by absolute (log) fold change
                    gene_column_header = 'gene_symbol', # these are common names, but specifying for demonstration
                    p_value_column_header = 'adj_p_value',
                    fold_change_column_header = 'fold_change')

DEG_list = ura.get('DEG_list')
DG_TF = ura.get('DG_TF')
DEG_full_graph = ura.get('DEG_full_graph')
DEG_to_pvalue = ura.get('DEG_to_pvalue')
DEG_to_updown = ura.get('DEG_to_updown')

print "Number of DEG's: " + str(len(DEG_list))
print "Number of genes in our entire input file: " + str(len(DEG_full_graph.nodes()))
# Out:
# Number of DEG's: 8755
# Number of genes in our entire input file: 13297

# %%
DG_TF.nodes(data=True) # updown means fold change
# Out:
# [('HIF3A', {'updown': 0}),
#  ('RNF14', {'updown': 0.3508037846}),
#  (u'ELANE', {'updown': 0}),
#  ('KHSRP', {'updown': 0.9599754305}),
#  (u'NCBP1', {'updown': 0.9955238004000001}),
#  ('NCBP2', {'updown': 0.99833423890000006}),
#  ('RNF13', {'updown': 0}),
#  ('NELFB', {'updown': 0.99337302000000005}),
#  (u'HIST1H4J', {'updown': 0.99796412239999999}),
#  (u'HSPA9', {'updown': 0.84444869430000002}),
#  (u'HSPA8', {'updown': 0.94796409299999995}),
#  (u'NELFE', {'updown': 0}),
#  (u'B2M', {'updown': 0.99801843430000003}),
#  (u'CD226', {'updown': 0}),
#  (u'LIFR', {'updown': 0}),
#  (u'PDCD10', {'updown': 0.13305126619999999}),
#  ('PDCD11', {'updown': 0.99801437659999992}),
#  (u'AGT', {'updown': 0.99818587799999992}),
#  (u'ASS1', {'updown': 0.43299072960000001}),
#  (u'SQLE', {'updown': 0.99742004290000008}),
#  (u'ADIPOQ', {'updown': 0}),
#  (u'FHIT', {'updown': 0.99766488060000003}),
#  (u'CYP26B1', {'updown': 0.031157696000000002}),
#  ('SRY', {'updown': 0}),
#  (u'HSPA5', {'updown': 0.94674490010000001}),
#  (u'NID2', {'updown': 0}),
#  (u'CAMK1', {'updown': 0}),
#  ('NR0B2', {'updown': 0}),
#  ('NR0B1', {'updown': 0}),
#  (u'HSPA4', {'updown': 0}),
#  (u'PIK3CD', {'updown': 0}),
#  (u'CAMK4', {'updown': 0.083987409700000001}),
#  (u'PIK3CG', {'updown': 0}),
#  (u'CRBN', {'updown': 0.1009102585}),
#  (u'SPTLC2', {'updown': 0}),
#  ('DRAP1', {'updown': 0.99658972819999991}),
#  ('IRX5', {'updown': 0}),
#  ('IRX4', {'updown': 0}),
#  ('IRX6', {'updown': 0}),
#  (u'CCR9', {'updown': 0}),
#  ('IRX3', {'updown': 0}),
#  ('FOXQ1', {'updown': 0}),
#  ('DHX9', {'updown': 0.99832626290000004}),
#  (u'NELFA', {'updown': 0}),
#  ('TCOF1', {'updown': 0}),
#  (u'NUP98', {'updown': 0.99817139499999996}),
#  ('XPC', {'updown': 0.99822799409999996}),
#  ('SP1', {'updown': 0}),
#  ('SP2', {'updown': 0.99832071919999998}),
#  ('SP3', {'updown': 0.99774025519999998}),
#  (u'NUP93', {'updown': 0.99812470499999995}),
#  (u'MUC6', {'updown': 0}),
#  (u'PPP2R2C', {'updown': 0.066921332}),
#  ('PPP2R2B', {'updown': 0.00019809560000000001}),
#  (u'NUP50', {'updown': 0.080430958299999994}),
#  (u'TAS2R19', {'updown': 0}),
#  (u'NMS', {'updown': 0}),
#  (u'PRKCE', {'updown': 0.019267582299999999}),
#  (u'MYL12A', {'updown': 0}),
#  (u'ORM2', {'updown': 0}),
#  (u'HIPK2', {'updown': 0}),
#  (u'ELF4', {'updown': 0}),
#  (u'MAX', {'updown': 0}),
#  ('PARP14', {'updown': 0.99791827170000003}),
#  ('MAZ', {'updown': 0}),
#  (u'BAK1', {'updown': 0}),
#  (u'NRTN', {'updown': 0}),
#  (u'CSN2', {'updown': 0}),
#  ('MAF', {'updown': 0}),
#  (u'TRAF6', {'updown': 0.8370592376999999}),
#  ('CTBP1', {'updown': 0.99200095359999996}),
#  ('CTBP2', {'updown': 0}),
#  (u'CLDN7', {'updown': 0}),
#  (u'KCNJ9', {'updown': 0.99816979319999988}),
#  ('TSG101', {'updown': 0.9970897058}),
#  (u'ITGA9', {'updown': 0.93415424409999992}),
#  (u'UGCG', {'updown': 0.29593449799999999}),
#  (u'ATP2A1', {'updown': 0}),
#  (u'ATP2A2', {'updown': 0.0067718861}),
#  (u'ATP2A3', {'updown': 0}),
#  (u'ITGA1', {'updown': 0.99637524749999995}),
#  (u'ITGA2', {'updown': 0}),
#  (u'ITGA3', {'updown': 0.99832579720000003}),
#  (u'ITGA4', {'updown': 0}),
#  (u'ITGA5', {'updown': 0}),
#  (u'ITGA6', {'updown': 0}),
#  (u'ITGA7', {'updown': 0}),
#  (u'GTF3C5', {'updown': 0}),
#  (u'APOA5', {'updown': 0}),
#  ('PREB', {'updown': 0.99747473659999997}),
#  ('PHLDA1', {'updown': 0.9973778297}),
#  (u'APOA1', {'updown': 0}),
#  (u'APOA2', {'updown': 0}),
#  (u'PHLDA2', {'updown': 0.038411258199999999}),
#  ('XPO1', {'updown': 0.99724005680000005}),
#  (u'PPME1', {'updown': 0.55352825630000002}),
#  (u'XPO5', {'updown': 0.99308579900000005}),
#  (u'CSDE1', {'updown': 0.99819801080000004}),
#  (u'LILRB1', {'updown': 0}),
#  (u'TTR', {'updown': 0}),
#  (u'JAM3', {'updown': 0}),
#  (u'CSNK2A1', {'updown': 0.12435083500000001}),
#  (u'MDK', {'updown': 0.3287100537}),
#  (u'MTCP1', {'updown': 0}),
#  ('TTK', {'updown': 0}),
#  (u'HRH4', {'updown': 0}),
#  (u'GRAP2', {'updown': 0}),
#  (u'HRH2', {'updown': 0.9982293176}),
#  (u'HRH3', {'updown': 0}),
#  (u'RASEF', {'updown': 0}),
#  (u'KSR2', {'updown': 0.9982619184}),
#  (u'KCNIP4', {'updown': 0.029880542599999997}),
#  ('KCNIP3', {'updown': 0.9981592628}),
#  (u'CCNA1', {'updown': 0.86541341199999999}),
#  (u'PRSS50', {'updown': 0}),
#  (u'GRP', {'updown': 0}),
#  (u'LIN28B', {'updown': 0}),
#  ('LIN28A', {'updown': 0}),
#  (u'TFB2M', {'updown': 0.81349849540000008}),
#  (u'COL4A2', {'updown': 0.99749295370000002}),
#  (u'EPS15L1', {'updown': 0.81078741249999997}),
#  ('ANAPC1', {'updown': 0.0026609140999999999}),
#  ('ANAPC2', {'updown': 0.99833436279999999}),
#  ('ANAPC5', {'updown': 0.99795836920000003}),
#  (u'ANAPC4', {'updown': 0.99498368479999999}),
#  (u'ANAPC7', {'updown': 0.63553803009999998}),
#  ('ZEB2', {'updown': 0}),
#  (u'ITGAX', {'updown': 0}),
#  (u'RPS6KA1', {'updown': 0}),
#  (u'RPS6KA2', {'updown': 0}),
#  ('SNRPB2', {'updown': 0}),
#  (u'RPS6KA4', {'updown': 0.99805638209999992}),
#  (u'RPS6KA6', {'updown': 0}),
#  (u'BCL2A1', {'updown': 0}),
#  (u'PISD', {'updown': 0.98147127180000004}),
#  (u'TP53I13', {'updown': 0}),
#  (u'NOG', {'updown': 0.9950236737999999}),
#  ('PSMD10', {'updown': 0.1075874307}),
#  (u'TOP1', {'updown': 0}),
#  ('ATAD2', {'updown': 0.99598353829999997}),
#  (u'FRAT1', {'updown': 0}),
#  (u'FRAT2', {'updown': 0}),
#  (u'DLAT', {'updown': 0.000106665}),
#  ('GIT1', {'updown': 0}),
#  ('GIT2', {'updown': 0.1360269177}),
#  (u'SERBP1', {'updown': 0.99833121099999989}),
#  ('HLF', {'updown': 0.91367289239999994}),
#  (u'NOV', {'updown': 0.50101817810000004}),
#  ('MYO10', {'updown': 0}),
#  (u'ITGAD', {'updown': 0}),
#  (u'PIK3CB', {'updown': 0.77844153099999991}),
#  ('FOXC1', {'updown': 0}),
#  (u'GHRH', {'updown': 0}),
#  (u'CD40LG', {'updown': 0}),
#  ('SMAD9', {'updown': 0.99776436989999995}),
#  (u'NUP133', {'updown': 0.60060883909999996}),
#  (u'SESN3', {'updown': 0}),
#  (u'SMAD4', {'updown': 0}),
#  (u'SMAD5', {'updown': 0}),
#  (u'SMAD6', {'updown': 0}),
#  (u'SMAD7', {'updown': 0}),
#  (u'SMAD1', {'updown': 0.99493498739999997}),
#  (u'SMAD2', {'updown': 0}),
#  (u'SMAD3', {'updown': 0.99618182580000003}),
#  (u'POLG2', {'updown': 0.99670241939999993}),
#  (u'SC5D', {'updown': 0.1604219194}),
#  ('FOXM1', {'updown': 0}),
#  (u'NDUFAF2', {'updown': 0.99832666930000002}),
#  (u'IGF2R', {'updown': 0.99833337219999996}),
#  (u'CTH', {'updown': 0.97596321799999997}),
#  ('ARF3', {'updown': 0.096750597699999996}),
#  ('ARF1', {'updown': 0.4013190505}),
#  (u'ARF6', {'updown': 0.99814068450000004}),
#  ('ARF5', {'updown': 0.070634460999999996}),
#  (u'ARF4', {'updown': 0.83059825300000001}),
#  (u'CXCR2', {'updown': 0}),
#  (u'SERPIND1', {'updown': 0}),
#  (u'GRHL2', {'updown': 0}),
#  (u'ESPL1', {'updown': 0}),
#  (u'EIF4B', {'updown': 0.99552715859999996}),
#  ('ARTN', {'updown': 0}),
#  ('TCEA2', {'updown': 0.99815638950000007}),
#  ('TCEA3', {'updown': 0}),
#  ('TCEA1', {'updown': 0}),
#  (u'RGPD2', {'updown': 0}),
#  ('KDM2A', {'updown': 0}),
#  (u'RGPD1', {'updown': 0}),
#  (u'RGPD6', {'updown': 0.44740890799999999}),
#  (u'PRKAR1A', {'updown': 0.095661752400000008}),
#  (u'RGPD4', {'updown': 0}),
#  (u'RGPD5', {'updown': 0.99826695809999999}),
#  (u'SAR1A', {'updown': 0.9902988826000001}),
#  (u'RGPD8', {'updown': 0}),
#  (u'OLIG2', {'updown': 0}),
#  ('OLIG1', {'updown': 0}),
#  (u'BDKRB1', {'updown': 0}),
#  (u'LOR', {'updown': 0}),
#  (u'CD99', {'updown': 0}),
#  (u'SENP1', {'updown': 0.99818708909999998}),
#  (u'CD86', {'updown': 0}),
#  (u'SPP1', {'updown': 0}),
#  (u'CXXC5', {'updown': 0.99831087559999998}),
#  ('LGALS8', {'updown': 0.080270586599999999}),
#  (u'CDC45', {'updown': 0}),
#  (u'CDC40', {'updown': 0.98775924140000004}),
#  (u'CDC42', {'updown': 0.018640359199999998}),
#  (u'SPHK2', {'updown': 0.99334243329999994}),
#  ('IFIH1', {'updown': 0.99736524659999992}),
#  (u'DPT', {'updown': 0}),
#  (u'CBLB', {'updown': 0.99759885450000008}),
#  (u'CBLC', {'updown': 0}),
#  ('HMGB2', {'updown': 0.9862456584999999}),
#  ('HMGB1', {'updown': 0.99609950480000009}),
#  ('CPEB3', {'updown': 0.99768304200000002}),
#  ('CPEB2', {'updown': 0.99833440449999999}),
#  (u'PGLYRP3', {'updown': 0}),
#  (u'RAB2A', {'updown': 0.00059181940000000008}),
#  (u'CACNG6', {'updown': 0}),
#  (u'ACRV1', {'updown': 0.99833168230000002}),
#  ('CHAF1B', {'updown': 0.0020586714999999999}),
#  (u'AMHR2', {'updown': 0}),
#  ('BIN1', {'updown': 0}),
#  (u'DDAH2', {'updown': 0}),
#  (u'FRG2', {'updown': 0}),
#  (u'DPYD', {'updown': 0}),
#  ('EEA1', {'updown': 0.99743006629999997}),
#  (u'ADORA2B', {'updown': 0}),
#  ('UBTF', {'updown': 0}),
#  ('IFT88', {'updown': 0}),
#  (u'ACTA2', {'updown': 0.99821485349999994}),
#  ('CLIP3', {'updown': 0.0268555883}),
#  (u'CLIP1', {'updown': 0}),
#  (u'SLIT3', {'updown': 0.54771593220000003}),
#  (u'CDCA7', {'updown': 0}),
#  (u'SLIT1', {'updown': 0.77249725430000005}),
#  (u'FIP1L1', {'updown': 0.99824646799999994}),
#  (u'CDCA8', {'updown': 0}),
#  (u'GFAP', {'updown': 0}),
#  (u'PFKM', {'updown': 0.22257809940000001}),
#  (u'UTS2', {'updown': 0}),
#  (u'CNTF', {'updown': 0}),
#  (u'UCN2', {'updown': 0}),
#  (u'MND1', {'updown': 0}),
#  (u'PPP2R2A', {'updown': 0.99776842980000002}),
#  (u'CD46', {'updown': 0.99829313459999991}),
#  (u'CD40', {'updown': 0}),
#  ('RSF1', {'updown': 0}),
#  (u'SP5', {'updown': 0}),
#  (u'ATG4B', {'updown': 0}),
#  (u'FXN', {'updown': 0.98909766860000004}),
#  ('FGFR1OP', {'updown': 0.033579132000000005}),
#  (u'POLR3GL', {'updown': 0}),
#  ('PHOX2A', {'updown': 0}),
#  (u'SP7', {'updown': 0}),
#  (u'SMOX', {'updown': 0}),
#  ('REST', {'updown': 0}),
#  (u'TCL1B', {'updown': 0}),
#  (u'TCL1A', {'updown': 0}),
#  (u'SNW1', {'updown': 0.96862550560000005}),
#  ('TBL1X', {'updown': 0}),
#  (u'GPT2', {'updown': 0}),
#  (u'CALR', {'updown': 0.997550877}),
#  (u'CYB5A', {'updown': 0.99636417690000001}),
#  (u'ALOX15B', {'updown': 0}),
#  (u'RALA', {'updown': 0}),
#  (u'EWSR1', {'updown': 0.99830660650000003}),
#  ('WDR77', {'updown': 0.95958399129999994}),
#  (u'HLA-DMA', {'updown': 0}),
#  ('TRIM11', {'updown': 0}),
#  (u'EFNB2', {'updown': 0.98947426099999991}),
#  (u'AAAS', {'updown': 0.99740717739999996}),
#  (u'PCK1', {'updown': 0}),
#  (u'HAMP', {'updown': 0.99728583879999999}),
#  (u'AHCTF1', {'updown': 0.99802778799999992}),
#  (u'PPP2R3B', {'updown': 0}),
#  (u'PPP2R3C', {'updown': 0.9966372240000001}),
#  (u'TAS2R5', {'updown': 0}),
#  (u'PPP2R3A', {'updown': 0.99810534760000003}),
#  ('SPRED1', {'updown': 0}),
#  (u'SPRED2', {'updown': 0.99754932689999998}),
#  (u'NPAS2', {'updown': 0.99823783510000008}),
#  (u'BRK1', {'updown': 0.9540772206999999}),
#  ('RNF32', {'updown': 0}),
#  (u'TUBA4A', {'updown': 0.4526749611}),
#  (u'EFNB1', {'updown': 0}),
#  (u'CHI3L1', {'updown': 0}),
#  (u'STIM1', {'updown': 0.9696878189}),
#  (u'CD70', {'updown': 0}),
#  (u'ALX3', {'updown': 0}),
#  (u'PIWIL2', {'updown': 0}),
#  (u'MAPKAP1', {'updown': 0}),
#  (u'FBXO5', {'updown': 0}),
#  ('SIX4', {'updown': 0}),
#  (u'PRL', {'updown': 0}),
#  ('SIX6', {'updown': 0}),
#  (u'SIX1', {'updown': 0}),
#  ('SIX2', {'updown': 0}),
#  ('SIX3', {'updown': 0}),
#  (u'ESRP2', {'updown': 0}),
#  (u'ESRP1', {'updown': 0}),
#  (u'RELN', {'updown': 0.73497344459999991}),
#  ('HDAC8', {'updown': 0.99797361370000004}),
#  ('RELB', {'updown': 0.99832947709999997}),
#  (u'RELA', {'updown': 0}),
#  ('HDGF', {'updown': 0}),
#  (u'PRX', {'updown': 0}),
#  (u'HNRNPA2B1', {'updown': 0}),
#  (u'TYRP1', {'updown': 0}),
#  (u'RFFL', {'updown': 0}),
#  (u'LEFTY2', {'updown': 0}),
#  (u'LEFTY1', {'updown': 0.99751017330000002}),
#  ('ESX1', {'updown': 0}),
#  (u'KLK2', {'updown': 0}),
#  ('SHOX2', {'updown': 0}),
#  (u'ZFHX3', {'updown': 0}),
#  (u'THOC3', {'updown': 0.37717101229999994}),
#  (u'THOC2', {'updown': 0}),
#  (u'THOC1', {'updown': 0.99832975349999997}),
#  (u'AL591806.3', {'updown': 0}),
#  (u'THOC7', {'updown': 5.3960181848481801e-05}),
#  (u'THOC6', {'updown': 0}),
#  (u'THOC5', {'updown': 0.99755872540000001}),
#  (u'DBI', {'updown': 0}),
#  (u'DBH', {'updown': 0}),
#  (u'FABP7', {'updown': 0}),
#  ('RFX5', {'updown': 0.99821791489999989}),
#  (u'APP', {'updown': 0.11724267720000001}),
#  (u'NRXN3', {'updown': 0.0046067671999999995}),
#  ('RFX1', {'updown': 0}),
#  ('RFX2', {'updown': 0}),
#  ('RFX3', {'updown': 0.99321717349999994}),
#  (u'TCAP', {'updown': 0}),
#  (u'CDON', {'updown': 0.80586549819999997}),
#  ('ELK1', {'updown': 0}),
#  (u'CUBN', {'updown': 0}),
#  ('ELK4', {'updown': 0.9903678159999999}),
#  (u'DBP', {'updown': 0.99211940030000001}),
#  (u'MAVS', {'updown': 0}),
#  (u'PAK1', {'updown': 0.0010622400999999999}),
#  (u'STRADB', {'updown': 0}),
#  (u'STXBP4', {'updown': 0}),
#  (u'NUP88', {'updown': 0}),
#  (u'FOXP3', {'updown': 0}),
#  (u'COPS8', {'updown': 0.0216362173}),
#  ('FOXP1', {'updown': 0}),
#  (u'IL10RA', {'updown': 0.99810577200000006}),
#  (u'COPS2', {'updown': 0.71361065599999995}),
#  (u'COPS3', {'updown': 0.52790886799999992}),
#  (u'SMPD2', {'updown': 0}),
#  (u'COPS6', {'updown': 0.99789882769999994}),
#  (u'NUP85', {'updown': 0.9551047305}),
#  (u'COPS4', {'updown': 0.025125908500000002}),
#  (u'COPS5', {'updown': 0.3063448426}),
#  (u'KRT19', {'updown': 0}),
#  ('MED1', {'updown': 0}),
#  (u'MED6', {'updown': 0.57349320079999999}),
#  (u'MED7', {'updown': 0.98772894550000001}),
#  (u'MED4', {'updown': 0.22429646410000001}),
#  (u'CBX6', {'updown': 0.99806095360000002}),
#  (u'PINK1', {'updown': 0.99695303049999995}),
#  (u'MED8', {'updown': 0.984022222}),
#  (u'MED9', {'updown': 0.99611932959999994}),
#  (u'GAST', {'updown': 0}),
#  (u'WNT2B', {'updown': 0.99233054440000001}),
#  (u'MYCN', {'updown': 0.9942946077}),
#  (u'CBX4', {'updown': 0.69916848150000011}),
#  (u'AC006486.1', {'updown': 0}),
#  (u'ITIH4', {'updown': 0}),
#  (u'DMBT1', {'updown': 0}),
#  (u'PRKG1', {'updown': 0}),
#  ('MXD1', {'updown': 0.99833197659999995}),
#  (u'PANK1', {'updown': 0.67782950019999999}),
#  (u'PRKG2', {'updown': 0}),
#  (u'PLTP', {'updown': 0}),
#  (u'NLK', {'updown': 0.001267025}),
#  (u'AKR1C3', {'updown': 0}),
#  (u'FDFT1', {'updown': 0.99787278200000007}),
#  ('TNS4', {'updown': 0}),
#  (u'IGF2', {'updown': 0}),
#  ('TCF4', {'updown': 0}),
#  (u'TCF7', {'updown': 0}),
#  (u'IGF1', {'updown': 0}),
#  (u'GCG', {'updown': 0}),
#  (u'DLD', {'updown': 0.10458210130000001}),
#  ('ARID2', {'updown': 0}),
#  (u'GCK', {'updown': 0}),
#  (u'SPRR3', {'updown': 0}),
#  (u'PMEPA1', {'updown': 0}),
#  (u'IGFBP2', {'updown': 0.21422022460000001}),
#  ('IGFBP3', {'updown': 0}),
#  (u'IGFBP1', {'updown': 0}),
#  (u'HBE1', {'updown': 0}),
#  (u'IGFBP7', {'updown': 0.99802003739999989}),
#  ('IGFBP4', {'updown': 0.99810592540000009}),
#  (u'IGFBP5', {'updown': 0}),
#  (u'ZBTB17', {'updown': 0}),
#  (u'AFP', {'updown': 0}),
#  ('EIF5A2', {'updown': 0.046461187899999999}),
#  (u'GJA1', {'updown': 0}),
#  (u'APLNR', {'updown': 0}),
#  (u'NLRP3', {'updown': 0.9835519343000001}),
#  (u'DEPP1', {'updown': 0}),
#  (u'SST', {'updown': 2.3925498675786702e-05}),
#  (u'ATP5F1B', {'updown': 0}),
#  (u'MEF2C', {'updown': 0.99809943779999999}),
#  ('TRIM8', {'updown': 0}),
#  ('MEF2A', {'updown': 0.94224436329999994}),
#  (u'PFN3', {'updown': 0}),
#  (u'PFN4', {'updown': 0}),
#  (u'CREM', {'updown': 0}),
#  (u'BTC', {'updown': 0}),
#  (u'MEF2D', {'updown': 0.99833390510000009}),
#  (u'GAS1', {'updown': 0}),
#  ('TRIM3', {'updown': 0.99507943599999993}),
#  (u'KDM3A', {'updown': 0}),
#  (u'PROC', {'updown': 0}),
#  (u'DNAJB1', {'updown': 0}),
#  (u'BTK', {'updown': 0}),
#  ('SSB', {'updown': 0.99832869980000005}),
#  ('NUTF2', {'updown': 0.99661598790000006}),
#  (u'NSL1', {'updown': 0}),
#  (u'PDGFRA', {'updown': 0}),
#  (u'MFNG', {'updown': 0}),
#  (u'HIST1H4C', {'updown': 0}),
#  (u'RASGRP3', {'updown': 0}),
#  (u'TEX15', {'updown': 0}),
#  (u'EIF2B4', {'updown': 0}),
#  (u'EIF2B5', {'updown': 0.99750477339999999}),
#  (u'EIF2B2', {'updown': 0.99830145310000007}),
#  (u'EIF2B3', {'updown': 0.020669031399999999}),
#  (u'EIF2B1', {'updown': 0.00037454769999999994}),
#  (u'PRKAR2A', {'updown': 0}),
#  (u'CTNNA1', {'updown': 0.99833301669999996}),
#  (u'PRKAR2B', {'updown': 0.85675350579999998}),
#  (u'PPA1', {'updown': 0.99167117180000008}),
#  (u'S1PR4', {'updown': 0}),
#  (u'HIST1H4B', {'updown': 0}),
#  ('TRIM59', {'updown': 0}),
#  (u'FANCF', {'updown': 0.85215668379999998}),
#  (u'MECOM', {'updown': 0}),
#  (u'ITGA2B', {'updown': 0.99831351700000004}),
#  (u'TPM3', {'updown': 0.59160818780000002}),
#  (u'FANCE', {'updown': 0}),
#  (u'TRADD', {'updown': 0}),
#  (u'RPS6KB2', {'updown': 0}),
#  (u'THYN1', {'updown': 0.34548252659999995}),
#  (u'JCHAIN', {'updown': 0}),
#  (u'TNFRSF6B', {'updown': 0}),
#  ('FBXW7', {'updown': 0.99755454650000008}),
#  (u'TGFBR3', {'updown': 0}),
#  (u'TGFBR2', {'updown': 0}),
#  (u'TGFBR1', {'updown': 0.99699788919999999}),
#  (u'NTF3', {'updown': 0}),
#  (u'NUP107', {'updown': 0.99795949930000005}),
#  (u'TET1', {'updown': 0}),
#  (u'TET2', {'updown': 0}),
#  (u'UPP1', {'updown': 0.99550041959999991}),
#  ('ARID3B', {'updown': 0}),
#  (u'FOXL2', {'updown': 0}),
#  ('FOXL1', {'updown': 0}),
#  ('RPS4X', {'updown': 0}),
#  (u'RHPN1', {'updown': 0.99811233790000009}),
#  (u'GALR1', {'updown': 0}),
#  (u'FSD1L', {'updown': 0.99611959709999998}),
#  (u'API5', {'updown': 0.58794713470000004}),
#  (u'CYP24A1', {'updown': 0}),
#  ('YOD1', {'updown': 0.99824542080000001}),
#  (u'RAB14', {'updown': 0.19309164129999998}),
#  (u'MFN2', {'updown': 0.99333343590000001}),
#  (u'TCP1', {'updown': 0.99361811569999992}),
#  (u'PRG4', {'updown': 0}),
#  (u'HAS2', {'updown': 0}),
#  (u'BABAM2', {'updown': 0}),
#  (u'F2RL1', {'updown': 0}),
#  (u'TNFSF4', {'updown': 0}),
#  ('XAB2', {'updown': 0.9972350391}),
#  (u'MAD2L2', {'updown': 0}),
#  (u'VMP1', {'updown': 0.13467337500000001}),
#  (u'MAD2L1', {'updown': 0.00047801010000000005}),
#  (u'MYL9', {'updown': 0}),
#  (u'PRDX4', {'updown': 0.99810058230000009}),
#  (u'PRDX3', {'updown': 0.74455384670000002}),
#  (u'PRDX1', {'updown': 0}),
#  (u'NFYC', {'updown': 0.98701521519999991}),
#  (u'NFYB', {'updown': 0}),
#  (u'NFYA', {'updown': 0}),
#  ('BAZ2A', {'updown': 0}),
#  ('MYBL1', {'updown': 0}),
#  (u'SMOC2', {'updown': 0}),
#  ('SMARCA2', {'updown': 0.0046147771999999997}),
#  (u'MYBL2', {'updown': 0}),
#  ('SMARCA5', {'updown': 0.99735332639999996}),
#  (u'BLK', {'updown': 0}),
#  (u'AXIN2', {'updown': 0.99770688220000003}),
#  (u'AXIN1', {'updown': 0}),
#  ('CTCFL', {'updown': 0}),
#  (u'FYN', {'updown': 0}),
#  (u'RAB1A', {'updown': 0.19703555780000001}),
#  (u'ZAP70', {'updown': 0}),
#  (u'IDE', {'updown': 0.99814714000000004}),
#  (u'SULT2A1', {'updown': 0}),
#  (u'OSTN', {'updown': 0}),
#  (u'ST3GAL2', {'updown': 0.99752269269999994}),
#  (u'CSTA', {'updown': 0}),
#  (u'RAC2', {'updown': 0.99478865659999993}),
#  (u'RAC3', {'updown': 0.9403318369}),
#  (u'ST3GAL5', {'updown': 0.2485472011}),
#  (u'RAC1', {'updown': 0}),
#  (u'NINJ1', {'updown': 0}),
#  (u'FCGR2B', {'updown': 0}),
#  ('LNPEP', {'updown': 0.96352817299999993}),
#  (u'APOE', {'updown': 0}),
#  (u'SKIL', {'updown': 0}),
#  (u'CYTH1', {'updown': 0}),
#  (u'GCGR', {'updown': 0}),
#  (u'CYTH3', {'updown': 0.9979205820999999}),
#  (u'CYTH2', {'updown': 0.73813350749999995}),
#  ('PBX2', {'updown': 0.99713242760000009}),
#  (u'CYTH4', {'updown': 0.99833378150000007}),
#  (u'LILRB2', {'updown': 0}),
#  (u'LGMN', {'updown': 0.38076873979999998}),
#  (u'CYP7B1', {'updown': 0}),
#  ('AIRE', {'updown': 0}),
#  (u'SPAST', {'updown': 0.9982801562000001}),
#  (u'CALCR', {'updown': 0}),
#  (u'KATNB1', {'updown': 0.77352040609999995}),
#  (u'AGR2', {'updown': 0}),
#  ('PRDM4', {'updown': 0.99773203060000004}),
#  (u'SLC16A7', {'updown': 0}),
#  ('BACH2', {'updown': 0.99781397589999998}),
#  (u'PTCH2', {'updown': 0.99805879480000004}),
#  (u'CALCA', {'updown': 0}),
#  (u'NEUROG2', {'updown': 0}),
#  (u'PTCH1', {'updown': 0}),
#  (u'CMKLR1', {'updown': 0}),
#  (u'PAGR1', {'updown': 0}),
#  (u'LYVE1', {'updown': 0.99557219620000004}),
#  (u'CKM', {'updown': 0}),
#  (u'RAD9A', {'updown': 0.99635122819999988}),
#  (u'KMT5A', {'updown': 0}),
#  (u'CD34', {'updown': 0}),
#  (u'PECR', {'updown': 0.7522820615000001}),
#  (u'CD36', {'updown': 0}),
#  (u'POLR3F', {'updown': 0.34303287469999999}),
#  (u'POLR3G', {'updown': 0}),
#  (u'POLR3D', {'updown': 0.9959517578}),
#  (u'POLR3E', {'updown': 0}),
#  (u'POLR3B', {'updown': 0.087125057300000003}),
#  (u'POLR3C', {'updown': 0.075784587599999995}),
#  (u'POLR3A', {'updown': 0.0249297063}),
#  (u'B3GAT3', {'updown': 0.99689128739999999}),
#  (u'RGS18', {'updown': 0}),
#  (u'DAP', {'updown': 0}),
#  (u'POLR3K', {'updown': 0.034658463700000003}),
#  (u'POLR3H', {'updown': 0}),
#  (u'DCN', {'updown': 0}),
#  (u'UXT', {'updown': 0}),
#  (u'GPAM', {'updown': 0}),
#  (u'CALM2', {'updown': 0.2217373305}),
#  (u'CALM3', {'updown': 0.022548926899999999}),
#  (u'CALM1', {'updown': 0.88076637859999996}),
#  (u'CACNA1A', {'updown': 0.99825463180000007}),
#  (u'CACNA1B', {'updown': 0.50160294750000001}),
#  (u'DNMT1', {'updown': 0}),
#  (u'CACNA1D', {'updown': 0.99785891420000006}),
#  (u'CACNA1F', {'updown': 0}),
#  ('THRA', {'updown': 0}),
#  (u'CDX1', {'updown': 0}),
#  (u'TAF4B', {'updown': 0.1060893972}),
#  (u'PERP', {'updown': 0}),
#  (u'CYP51A1', {'updown': 0.91963386319999996}),
#  (u'GLO1', {'updown': 0.31390349350000002}),
#  (u'CACNA1S', {'updown': 0}),
#  (u'CUL1', {'updown': 0.89077058440000001}),
#  ('CUL3', {'updown': 0.99645262049999994}),
#  (u'FCAR', {'updown': 0}),
#  (u'CDX2', {'updown': 0}),
#  ('HOXD8', {'updown': 0}),
#  (u'TRIM29', {'updown': 0}),
#  ('TRIM24', {'updown': 0.99464374069999995}),
#  (u'CLCN2', {'updown': 0}),
#  (u'CREB5', {'updown': 0}),
#  (u'PRMT1', {'updown': 0.99833412749999995}),
#  (u'CLCN7', {'updown': 0}),
#  (u'PRMT7', {'updown': 0.87282026730000006}),
#  (u'CREB1', {'updown': 0.99764539780000006}),
#  (u'PRMT5', {'updown': 0.94462042900000009}),
#  (u'PER3', {'updown': 0.99696689090000001}),
#  (u'PER2', {'updown': 0.98879209620000008}),
#  (u'PER1', {'updown': 0}),
#  ('BRD4', {'updown': 0}),
#  ('BRD7', {'updown': 0}),
#  (u'BRD1', {'updown': 0.99832923370000004}),
#  (u'BRD2', {'updown': 0}),
#  ('CARHSP1', {'updown': 0}),
#  (u'KAT8', {'updown': 0}),
#  (u'DNAJA3', {'updown': 0.24466785829999999}),
#  (u'DNAJA1', {'updown': 0.99746474180000011}),
#  (u'ORMDL3', {'updown': 0}),
#  (u'FCER2', {'updown': 0}),
#  (u'PTPN13', {'updown': 0}),
#  (u'PTPN12', {'updown': 0}),
#  (u'KIF5B', {'updown': 0}),
#  (u'NPY1R', {'updown': 0.9974435438}),
#  (u'KAT5', {'updown': 0.99748895659999992}),
#  (u'MYCBP', {'updown': 0.99353289810000001}),
#  (u'KAT7', {'updown': 0.28386440329999996}),
#  (u'GALR3', {'updown': 0}),
#  (u'F2R', {'updown': 0}),
#  (u'IHH', {'updown': 0}),
#  (u'UTRN', {'updown': 0.99831941340000008}),
#  (u'LOC101930123', {'updown': 0}),
#  (u'RAD51C', {'updown': 0.074276899000000007}),
#  (u'CD3D', {'updown': 0}),
#  (u'CD3E', {'updown': 0}),
#  (u'CH25H', {'updown': 0.95193262849999993}),
#  (u'CSF2RB', {'updown': 0}),
#  ('AES', {'updown': 0.99826316519999991}),
#  (u'CSF2RA', {'updown': 0}),
#  ('DMD', {'updown': 0}),
#  (u'SEH1L', {'updown': 0.1788981288}),
#  (u'GNAO1', {'updown': 0.99660491559999997}),
#  (u'RRAS2', {'updown': 0}),
#  (u'GAB2', {'updown': 0}),
#  (u'KAT2B', {'updown': 0}),
#  (u'HIF1A', {'updown': 0.99724356719999996}),
#  (u'GAB1', {'updown': 0}),
#  (u'S100A11', {'updown': 0}),
#  (u'IFNGR1', {'updown': 0}),
#  (u'IFNGR2', {'updown': 0.99823976030000006}),
#  (u'CD200', {'updown': 0.0011286503999999998}),
#  (u'NDRG1', {'updown': 0}),
#  (u'ARHGAP6', {'updown': 0}),
#  (u'CMIP', {'updown': 0.51179290079999995}),
#  (u'ACADM', {'updown': 0.90773938109999996}),
#  (u'SRSF5', {'updown': 0.96931200000000006}),
#  (u'SRSF4', {'updown': 0}),
#  (u'SRSF7', {'updown': 0.94948696870000004}),
#  (u'PPM1D', {'updown': 0.99592437489999996}),
#  (u'SRSF1', {'updown': 0.99821611290000012}),
#  (u'HMOX1', {'updown': 0}),
#  (u'SRSF3', {'updown': 0.99831650029999996}),
#  (u'SRSF2', {'updown': 0.39262248100000002}),
#  ('EGR2', {'updown': 0}),
#  (u'C4BPA', {'updown': 0}),
#  (u'C4BPB', {'updown': 0}),
#  (u'EGR1', {'updown': 0.014227599399999999}),
#  (u'SRSF9', {'updown': 0.99750545180000005}),
#  (u'PPARGC1A', {'updown': 0.77348753810000004}),
#  ('EGR4', {'updown': 0.79555307279999998}),
#  (u'USP42', {'updown': 0}),
#  ('RAPH1', {'updown': 0.52676851769999999}),
#  (u'PRLH', {'updown': 0}),
#  (u'HOXA4', {'updown': 0}),
#  (u'RNF135', {'updown': 0}),
#  (u'CX3CL1', {'updown': 0.78434621170000007}),
#  ('HOXA3', {'updown': 0}),
#  ('MAFG', {'updown': 0}),
#  (u'CHEK2', {'updown': 0}),
#  (u'CHEK1', {'updown': 0}),
#  (u'PRKAB2', {'updown': 0.99833183889999999}),
#  (u'UMPS', {'updown': 0.99738058799999996}),
#  (u'PRKAB1', {'updown': 0.99823704299999994}),
#  (u'TSHZ3', {'updown': 0.98625564010000011}),
#  (u'CDK11A', {'updown': 0}),
#  (u'PAX5', {'updown': 0}),
#  ('PAX4', {'updown': 0}),
#  ('PAX7', {'updown': 0}),
#  (u'PAX6', {'updown': 0}),
#  ('PAX1', {'updown': 0}),
#  ('NCAPD2', {'updown': 0}),
#  (u'PAX3', {'updown': 0}),
#  ('PAX2', {'updown': 0}),
#  (u'PTPN2', {'updown': 0.99828420819999997}),
#  (u'PTPN1', {'updown': 0.99673299910000002}),
#  (u'NCAPD3', {'updown': 0.99824553829999996}),
#  ('PAX9', {'updown': 0}),
#  (u'PTPN6', {'updown': 0}),
#  (u'PROK1', {'updown': 0}),
#  (u'DDR2', {'updown': 0}),
#  (u'ATP5PF', {'updown': 0}),
#  (u'DDR1', {'updown': 0}),
#  (u'CYP2E1', {'updown': 0.89679966909999997}),
#  (u'EDN3', {'updown': 0}),
#  ('STUB1', {'updown': 0}),
#  (u'NNMT', {'updown': 0.99829661629999999}),
#  (u'EIF4EBP1', {'updown': 0}),
#  (u'NPBWR2', {'updown': 0}),
#  (u'EIF4EBP3', {'updown': 0}),
#  (u'EIF4EBP2', {'updown': 0}),
#  (u'BAG3', {'updown': 0}),
#  (u'HIST2H3A', {'updown': 0}),
#  (u'GRK2', {'updown': 0.98699306610000004}),
#  (u'SH2D1A', {'updown': 0}),
#  (u'CTDP1', {'updown': 0}),
#  (u'CNTFR', {'updown': 0}),
#  (u'ADAMTS13', {'updown': 0}),
#  (u'AMOTL2', {'updown': 0}),
#  ('RPS3', {'updown': 0}),
#  (u'ADAMTS16', {'updown': 0}),
#  (u'VDAC1', {'updown': 0.0079682142000000004}),
#  (u'CENPM', {'updown': 0}),
#  (u'CD79B', {'updown': 0}),
#  ('MEOX1', {'updown': 0}),
#  (u'MEOX2', {'updown': 0}),
#  (u'CD79A', {'updown': 0}),
#  (u'SLC34A1', {'updown': 0}),
#  (u'DEF6', {'updown': 0}),
#  (u'DHX58', {'updown': 0.99816142389999996}),
#  (u'ZEB1', {'updown': 0}),
#  (u'ZNF385A', {'updown': 0}),
#  (u'LCN2', {'updown': 0}),
#  ('HOXA13', {'updown': 0}),
#  (u'GPNMB', {'updown': 0}),
#  (u'HOXA11', {'updown': 0}),
#  (u'HOXA10', {'updown': 0}),
#  (u'PPBP', {'updown': 0}),
#  (u'RASGRF2', {'updown': 0.65650295209999998}),
#  (u'KRT12', {'updown': 0}),
#  (u'DSG2', {'updown': 0}),
#  (u'USP2', {'updown': 0.99820910340000002}),
#  (u'DSG4', {'updown': 0}),
#  (u'CAPN2', {'updown': 0}),
#  (u'HMGCS1', {'updown': 0.0035198}),
#  (u'HMGCS2', {'updown': 0}),
#  (u'PDHA1', {'updown': 0.27176983710000002}),
#  (u'SRF', {'updown': 0.99583087339999998}),
#  (u'PTP4A3', {'updown': 0.99758811400000003}),
#  (u'FBXO43', {'updown': 0}),
#  (u'MGLL', {'updown': 0}),
#  ('LGALS9', {'updown': 0}),
#  (u'RPS6KA3', {'updown': 0.98484614329999998}),
#  ('MZF1', {'updown': 0}),
#  ('LGALS3', {'updown': 0}),
#  (u'KCNH1', {'updown': 0}),
#  (u'LGALS1', {'updown': 0.99670490439999992}),
#  (u'CP', {'updown': 0.99830181790000005}),
#  (u'FSCN3', {'updown': 0}),
#  ('PIR', {'updown': 0}),
#  (u'FSCN1', {'updown': 0.99831501579999993}),
#  (u'LGALS4', {'updown': 0}),
#  (u'SFRP2', {'updown': 0}),
#  (u'KCNJ2', {'updown': 0}),
#  (u'EPHA1', {'updown': 0}),
#  (u'SFRP1', {'updown': 0}),
#  (u'MYL12B', {'updown': 0.68223002919999998}),
#  (u'AKIRIN1', {'updown': 0.99833080930000007}),
#  (u'NUP54', {'updown': 0.72020875279999996}),
#  (u'EIF2AK1', {'updown': 0.86896539019999997}),
#  (u'EIF2AK3', {'updown': 0.99485349459999994}),
#  ('EIF2AK2', {'updown': 0.99775108280000002}),
#  (u'EIF2AK4', {'updown': 0}),
#  (u'ADRB2', {'updown': 0}),
#  (u'CD247', {'updown': 0.99665491470000001}),
#  (u'COL1A2', {'updown': 0}),
#  (u'EREG', {'updown': 0}),
#  (u'COL1A1', {'updown': 0}),
#  (u'ELN', {'updown': 0}),
#  (u'ASAP1', {'updown': 0.78567863090000001}),
#  (u'ASAP2', {'updown': 0.99816187180000004}),
#  ('NMI', {'updown': 0.99804420769999991}),
#  (u'IDO1', {'updown': 0}),
#  (u'CAMK1G', {'updown': 0.22827154550000001}),
#  (u'PLAUR', {'updown': 0}),
#  (u'MMP14', {'updown': 0}),
#  (u'FCGR3A', {'updown': 0.995743814}),
#  (u'ECM1', {'updown': 0.26806564969999996}),
#  (u'FOXO3', {'updown': 0.99487968819999995}),
#  (u'FOXO1', {'updown': 0}),
#  (u'CD28', {'updown': 0}),
#  (u'ITGAV', {'updown': 0.99832392640000001}),
#  (u'FOXO4', {'updown': 0}),
#  (u'ALDH1A1', {'updown': 0.81677994230000006}),
#  (u'ALDH1A2', {'updown': 0}),
#  (u'HIST4H4', {'updown': 0}),
#  (u'UPK1B', {'updown': 0}),
#  (u'DEFB4A', {'updown': 0}),
#  (u'TAC1', {'updown': 0.00097469070000000008}),
#  (u'TNIK', {'updown': 0.99789934120000001}),
#  (u'TAC3', {'updown': 0.22223278600000002}),
#  (u'NCOA6', {'updown': 0.99450077870000009}),
#  (u'OPRL1', {'updown': 0.99041699750000001}),
#  (u'RGS4', {'updown': 0.0001708871}),
#  (u'RGS5', {'updown': 0.99601877980000009}),
#  ('RGS6', {'updown': 0.62845277129999999}),
#  (u'RGS1', {'updown': 0}),
#  (u'ATG5', {'updown': 0.87833197810000008}),
#  ('SOX5', {'updown': 0}),
#  (u'PLAG1', {'updown': 0}),
#  (u'C9orf24', {'updown': 0.99800590769999997}),
#  (u'EYA2', {'updown': 0}),
#  ('SMARCB1', {'updown': 0.99829121340000004}),
#  ('UTP20', {'updown': 0.99442675530000002}),
#  (u'ITGB6', {'updown': 0}),
#  (u'PIGR', {'updown': 0}),
#  (u'GOLGA2', {'updown': 0}),
#  (u'ILKAP', {'updown': 0}),
#  (u'HPN', {'updown': 0}),
#  (u'WRAP53', {'updown': 0}),
#  (u'EPCAM', {'updown': 0}),
#  (u'TAGLN', {'updown': 0.99805143530000007}),
#  ('OSTF1', {'updown': 0.91353930040000009}),
#  (u'PPP1CB', {'updown': 0.99280106310000005}),
#  (u'PPP1CC', {'updown': 0}),
#  (u'OLR1', {'updown': 0.9982973597}),
#  (u'PPP1CA', {'updown': 0.98959568860000002}),
#  (u'SRRM1', {'updown': 0.99694126849999998}),
#  (u'BBIP1', {'updown': 0.99824485760000004}),
#  (u'GABARAPL2', {'updown': 0.99650428019999993}),
#  (u'ITGAE', {'updown': 0.99542979340000004}),
#  (u'PDK2', {'updown': 0.9816131320999999}),
#  (u'PDK4', {'updown': 0}),
#  ('COL6A1', {'updown': 0}),
#  (u'PCLAF', {'updown': 0}),
#  (u'WBP1', {'updown': 0.99781168540000009}),
#  ('COL6A2', {'updown': 0}),
#  (u'DOK1', {'updown': 0}),
#  (u'HAVCR2', {'updown': 0}),
#  (u'ALPL', {'updown': 0.9983087826}),
#  (u'PTGS2', {'updown': 0}),
#  (u'PTGS1', {'updown': 0}),
#  (u'SH2B3', {'updown': 0.99719359629999993}),
#  (u'FXYD1', {'updown': 0}),
#  (u'PUF60', {'updown': 0.99783523129999996}),
#  ('MAFK', {'updown': 0}),
#  (u'SV2B', {'updown': 0.37586622560000005}),
#  (u'KIAA0141', {'updown': 0.97723206780000005}),
#  (u'FABP5', {'updown': 0.90604704569999994}),
#  ('MAFA', {'updown': 0}),
#  ('MAFB', {'updown': 0.91462374260000001}),
#  (u'PFKP', {'updown': 0}),
#  (u'PLIN2', {'updown': 0}),
#  (u'CDK2AP1', {'updown': 0}),
#  ('ZYX', {'updown': 0.99517350029999996}),
#  (u'PLIN1', {'updown': 0}),
#  (u'MED10', {'updown': 0.0425027272}),
#  ('TRERF1', {'updown': 0.99378734459999996}),
#  (u'MED11', {'updown': 0}),
#  (u'CCR3', {'updown': 0}),
#  (u'HIF1AN', {'updown': 0.99211845340000004}),
#  (u'RBPJ', {'updown': 0}),
#  (u'GHRL', {'updown': 0}),
#  ('EIF1AX', {'updown': 0.96257285519999991}),
#  (u'NTRK1', {'updown': 0}),
#  (u'NTRK2', {'updown': 0}),
#  (u'NTRK3', {'updown': 0}),
#  (u'HSP90AB1', {'updown': 0.044641891699999998}),
#  ('ARHGAP22', {'updown': 0}),
#  (u'MED13', {'updown': 0}),
#  (u'PTP4A1', {'updown': 0.0014600876000000001}),
#  (u'SAP18', {'updown': 0}),
#  (u'TAS2R46', {'updown': 0}),
#  (u'LIN37', {'updown': 0.99714246299999998}),
#  (u'BLNK', {'updown': 0}),
#  (u'CD8A', {'updown': 0.14974432839999999}),
#  (u'KCNMB1', {'updown': 0}),
#  (u'DDIT3', {'updown': 0.98503768400000002}),
#  (u'DDIT4', {'updown': 0}),
#  (u'MED16', {'updown': 0}),
#  (u'CCR4', {'updown': 0}),
#  (u'BMP6', {'updown': 0.99713603620000002}),
#  (u'HAX1', {'updown': 0.94269197780000002}),
#  (u'CCR10', {'updown': 0.99164859709999997}),
#  (u'IFI35', {'updown': 0}),
#  (u'CD27', {'updown': 0}),
#  (u'IFI30', {'updown': 0}),
#  (u'VAPB', {'updown': 0.99831861189999993}),
#  (u'RBP1', {'updown': 0.99831206560000008}),
#  (u'RBP2', {'updown': 0}),
#  (u'BMP4', {'updown': 0.99175364269999999}),
#  (u'VAPA', {'updown': 0.99310297219999999}),
#  (u'MYSM1', {'updown': 0.00445}),
#  ('CEBPZ', {'updown': 0}),
#  (u'MBTPS2', {'updown': 9.3596810531001599e-05}),
#  ('PA2G4', {'updown': 0.032663187699999999}),
#  (u'KRAS', {'updown': 0.016661298200000001}),
#  (u'BMP7', {'updown': 0}),
#  (u'SOCS4', {'updown': 0}),
#  (u'BMP5', {'updown': 0}),
#  (u'SOCS6', {'updown': 0.99405973180000007}),
#  (u'SOCS1', {'updown': 0}),
#  (u'BMP2', {'updown': 0}),
#  (u'SOCS3', {'updown': 0}),
#  (u'SOCS2', {'updown': 0.99766120400000002}),
#  (u'PPP2CA', {'updown': 0.0036965121000000004}),
#  (u'SGO2', {'updown': 0}),
#  (u'SGO1', {'updown': 0}),
#  (u'PPP2CB', {'updown': 0}),
#  ('WDR59', {'updown': 0}),
#  (u'ADAM9', {'updown': 0.19929085639999999}),
#  (u'TERF2', {'updown': 0.94971116799999999}),
#  (u'NR1I2', {'updown': 0}),
#  (u'FAT1', {'updown': 0}),
#  (u'TERF1', {'updown': 0.9983116178}),
#  (u'ULBP2', {'updown': 0}),
#  (u'DOK5', {'updown': 0.9983204979000001}),
#  ('GRB7', {'updown': 0}),
#  ('ARPC1B', {'updown': 0}),
#  (u'DLK1', {'updown': 0}),
#  (u'PSG4', {'updown': 0}),
#  (u'PSG5', {'updown': 0}),
#  (u'CCNH', {'updown': 0.94496686529999996}),
#  (u'EIF4G1', {'updown': 0}),
#  (u'CCNK', {'updown': 0.99721539530000003}),
#  ('HOXC9', {'updown': 0}),
#  ('HOXC8', {'updown': 0}),
#  (u'ACSL1', {'updown': 0}),
#  (u'RASSF1', {'updown': 0}),
#  (u'RPL7', {'updown': 0}),
#  (u'HP', {'updown': 0}),
#  (u'BCL2L2-PABPN1', {'updown': 0}),
#  (u'LRPPRC', {'updown': 0.00076543240000000005}),
#  (u'HOXC6', {'updown': 0}),
#  (u'GREM1', {'updown': 0.99830329979999999}),
#  (u'FEN1', {'updown': 0.68735286610000002}),
#  ('E2F8', {'updown': 0}),
#  (u'THAP11', {'updown': 0.99467923569999994}),
#  (u'RSAD2', {'updown': 0.98712078170000006}),
#  (u'NCKAP1', {'updown': 0.86976337659999992}),
#  ('NR1I3', {'updown': 0}),
#  (u'CHD3', {'updown': 0.99433077930000002}),
#  (u'SLC40A1', {'updown': 0.99824552900000008}),
#  (u'CHD4', {'updown': 0}),
#  (u'LRRK2', {'updown': 0.6464301737}),
#  (u'PTH', {'updown': 0}),
#  (u'WISP2', {'updown': 0}),
#  (u'SCD', {'updown': 0}),
#  (u'WISP1', {'updown': 0}),
#  ('MNT', {'updown': 0.98236621040000005}),
#  ('CCNF', {'updown': 0.99560770779999996}),
#  ('ESRRG', {'updown': 0.47063172119999996}),
#  (u'SUPT16H', {'updown': 0.95975383549999993}),
#  (u'GRB2', {'updown': 0.87257408609999998}),
#  ('TGFB1I1', {'updown': 0}),
#  (u'IL22RA1', {'updown': 0}),
#  ('PTS', {'updown': 0.41984865659999998}),
#  (u'TTC5', {'updown': 0.99804616989999995}),
#  (u'OXER1', {'updown': 0}),
#  (u'RAB3GAP2', {'updown': 0.68599652180000004}),
#  (u'IL4R', {'updown': 0}),
#  ('BHLHA15', {'updown': 0}),
#  (u'RAB3GAP1', {'updown': 0.22629240239999998}),
#  (u'CDC25C', {'updown': 0}),
#  (u'CDC25B', {'updown': 0}),
#  (u'CDC25A', {'updown': 0}),
#  ('CCNC', {'updown': 0.00036814949999999997}),
#  (u'LTB4R', {'updown': 0.99806009650000005}),
#  ('TTC8', {'updown': 0.85310692430000012}),
#  (u'ARPC5', {'updown': 0.99798152870000001}),
#  (u'ARPC4', {'updown': 0.99568431040000005}),
#  (u'POLR2E', {'updown': 0.94258547849999996}),
#  (u'POLR2D', {'updown': 0.54856781129999999}),
#  (u'POLR2G', {'updown': 0.99553612670000002}),
#  (u'POLR2F', {'updown': 0}),
#  ('ANKRD23', {'updown': 0}),
#  (u'ELOA2', {'updown': 0}),
#  (u'POLR2C', {'updown': 0.598786873}),
#  (u'POLR2B', {'updown': 0.78779769790000009}),
#  (u'ACO1', {'updown': 0.99786246719999994}),
#  (u'POLR2L', {'updown': 0.99722735959999997}),
#  (u'AKR7A2', {'updown': 0.99820542079999997}),
#  (u'ITPR1', {'updown': 0.0110083874}),
#  (u'POLR2I', {'updown': 0}),
#  (u'POLR2K', {'updown': 0.055269834599999998}),
#  (u'POLR2J', {'updown': 0}),
#  (u'INHA', {'updown': 0.99534739790000004}),
#  (u'IL1RN', {'updown': 0}),
#  ('PRDM14', {'updown': 0}),
#  (u'PRDM15', {'updown': 0.99742805489999997}),
#  (u'DEPTOR', {'updown': 0.99833398890000002}),
#  (u'ABCG5', {'updown': 0}),
#  (u'LRIG1', {'updown': 0}),
#  (u'PLSCR1', {'updown': 0.99820577970000002}),
#  (u'ABCG8', {'updown': 0}),
#  (u'MPO', {'updown': 0}),
#  ('HNF4G', {'updown': 0}),
#  (u'HNF4A', {'updown': 0}),
#  (u'CFTR', {'updown': 0}),
#  (u'GTF3A', {'updown': 0}),
#  (u'SLC25A3', {'updown': 0.0013876376000000001}),
#  (u'MTTP', {'updown': 0}),
#  (u'SNCA', {'updown': 0.17840172930000001}),
#  (u'AIFM2', {'updown': 0.99825919769999993}),
#  (u'AGO4', {'updown': 0.9982490852}),
#  (u'RNF125', {'updown': 0}),
#  (u'AIFM1', {'updown': 0.98905266219999999}),
#  (u'MPZ', {'updown': 0.99831862209999989}),
#  (u'IL17RA', {'updown': 0}),
#  (u'AGO2', {'updown': 0.99676700290000009}),
#  (u'KDM1A', {'updown': 0.36133209579999997}),
#  (u'SOST', {'updown': 0}),
#  (u'SSPN', {'updown': 0}),
#  (u'HTR5A', {'updown': 0.0017398330999999999}),
#  (u'ACAN', {'updown': 0}),
#  (u'SLK', {'updown': 0.99744849579999995}),
#  (u'HCFC1', {'updown': 0}),
#  (u'CKS1B', {'updown': 0}),
#  (u'MAPK14', {'updown': 0.9825553481}),
#  ('KRIT1', {'updown': 0.50019998529999998}),
#  (u'IL20RB', {'updown': 0}),
#  ...]

# %% [markdown]
# Our package also has a function to load your entire DEG file into a networkx graph, without filtering by p-value or fold change. This function will return a networkx graph representation of your entire specified csv file, a dictionary mapping genes to their (adj) p-values, and a dictionary mapping genes to their (log) fold change

# %% [markdown]
# ## Stat Analysis
# <a id='stat'></a>

# %% [markdown]
# Our stat_analysis package can help identify TF's that are statistically significant to our set of DEG's.

# %% [markdown]
# ### Enrichment
# <a id='pvalue'></a>

# %% [markdown]
# Given you have run the appropriate prerequisite functions, you can now start to anaylize your data! First, we check how enriched our set of TF's are. All of our p-value functions calculate the log of the p-value using [scipy.stats.hypergeom.logsf](https://docs.scipy.org/doc/scipy-0.19.1/reference/generated/scipy.stats.hypergeom.html).

# %%
# Enrichment of TF's themselves
ura.tf_enrichment_calc()   
ura.get('tf_enrichment')
# Out:
# TF_ENRICHMENT    8.308021e-12
# dtype: float64

# %% [markdown]
# Next we can check how enriched each TF's targets are.  These values help us determine which TF's are actually associated with our DEG's.
# - high value = significant connection between this TF and its DEG targets
# - low value = TF is randomly associated with its DEG targets
# - zero = None of this TF's targets were DEG's
# - inf = original p-value was so small that its log is inf. Very high significance.
#
# This function may need a minute or so.

# %%
# Enrichment of every TF with respect to its targets
ura.tf_target_enrichment_calc()
tf_target_pvalues = ura.get('tf_target_enrichment')

# %%
df = tf_target_pvalues.to_frame()
df = df.loc[df['tf-target enrichment'] != 0]
df = df.loc[df['tf-target enrichment'] != float('inf')] # removing zeros and inf's for the sake of visualization
display(df)
# Out:
#          tf-target enrichment
# AAAS             2.306869e+01
# ELL              2.058271e+01
# RAE1             2.034444e+01
# NUP50            2.016211e+01
# TPR              1.958330e+01
# RANBP2           1.771874e+01
# NUP37            1.696152e+01
# NFRKB            1.514671e+01
# NCBP2            1.475362e+01
# NUP133           1.437584e+01
# U2AF2            1.291924e+01
# U2AF1            1.291924e+01
# CPSF4            1.271997e+01
# WASL             1.256939e+01
# RNPS1            1.124994e+01
# ZC3H11A          1.124994e+01
# UPF3B            1.124994e+01
# EIF4A3           1.052509e+01
# THOC6            1.052509e+01
# GEMIN5           1.052509e+01
# DHX38            1.052509e+01
# THOC3            1.052509e+01
# POLDIP3          1.052509e+01
# CDC40            1.052509e+01
# SRSF1            1.041037e+01
# POLR2I           9.827322e+00
# NXF5             9.794074e+00
# NRF1             9.416798e+00
# DDX20            9.405881e+00
# MDC1             9.081920e+00
# ...                       ...
# EHMT1            4.158330e-03
# STAT3            4.079277e-03
# WWOX             4.070166e-03
# AHR              3.976594e-03
# STAT1            3.861742e-03
# KLF5             3.798874e-03
# FGF9             3.552079e-03
# RBPJ             3.151975e-03
# NKX2-1           2.693712e-03
# CBX6             2.538424e-03
# PHC3             2.538424e-03
# ASCL1            2.527401e-03
# SOX2             1.932616e-03
# MYD88            1.650517e-03
# CBX8             1.578214e-03
# NFKB1            1.559413e-03
# PPARG            1.264446e-03
# CTF1             1.181640e-03
# SNAI2            1.181640e-03
# LGALS3           1.103207e-03
# JUN              1.082202e-03
# IRF1             9.234695e-04
# FOXP3            8.069707e-04
# TBX21            3.061454e-04
# POU5F1           3.061454e-04
# STAT6            8.315991e-05
# CTGF             3.914727e-05
# TGFB1            4.201163e-06
# GATA3            8.931069e-08
# GPSM1            8.017656e-08
#
# [931 rows x 1 columns]

# %% [markdown]
# ### Z-score
# <a id='zscore'></a>

# %% [markdown]
# The goal of our z-score function is to predict the activation states of the TF's. We observe how a TF relates to each of its targets to make our prediction. We compare each targets' observed gene regulation (either up or down) and each TF-target interation (whether it is activating or inhibiting) to conclude whether a TF is activating or inhibiting. A positive value indicates activating while a negative value indicates inhibiting. A value of zero means that we did not have enough information about the target or TF-target interaction to make the prediction.
#
# Our z-score calculater has to calculation methods. Our method calculates how "biased" the background network is towards either activating or inhibiting interactions, then adjusts its calculations to that non-zero average. Our bias-filter parameter is a number between 0 and 1 that indicates the threshold at which the graph is considered "too biased", and therefore the bias z-score formula must be used.
#
# This function may need a minute or so.

# %%
ura.tf_zscore(bias_filter=1)
unbiased_zscores = ura.get('z_scores')
display(unbiased_zscores.to_frame())
# Out:
#           unbiased-calculated z-scores
# RANBP2                       12.609520
# NUP133                       12.609520
# NUP37                        12.288206
# XPO1                         10.049876
# PAFAH1B1                      9.433981
# CLIP1                         9.327379
# CENPA                         9.219544
# CKAP5                         9.165151
# NUP50                         9.165151
# CLASP1                        9.165151
# KNTC1                         9.110434
# AHCTF1                        9.110434
# CLASP2                        9.110434
# TPR                           9.055385
# RAE1                          9.055385
# MAD1L1                        8.954430
# AAAS                          8.944272
# ATM                           7.090547
# SHC1                          6.639528
# ELL                           6.164414
# BRCA1                         6.090777
# SOS1                          6.090777
# BUB3                          6.021972
# ABL1                          5.602794
# ESR1                          5.547002
# NCOA1                         5.385165
# ATF2                          5.357062
# CREBBP                        5.333494
# MDC1                          5.291503
# CDC20                         5.269652
# ...                                ...
# CDC6                         -2.683282
# OGT                          -2.713602
# CCNA2                        -2.722179
# PPP1R12A                     -2.828427
# CACNA2D2                     -2.897473
# BRAP                         -3.000000
# FBXO5                        -3.050851
# RBL2                         -3.050851
# CCNE1                        -3.202470
# TIA1                         -3.207135
# POLR2E                       -3.211586
# POLR2L                       -3.211586
# CCNB2                        -3.244428
# PER1                         -3.273268
# PPP2R2B                      -3.362691
# AKT3                         -3.517632
# POLR2G                       -3.655631
# AKT2                         -3.656552
# PER2                         -3.709704
# TIAL1                        -3.741657
# CACNA2D4                     -3.771711
# PPP2R2A                      -3.781177
# POLR2I                       -3.887710
# GTF2F2                       -3.889087
# PTTG1                        -4.146140
# RBL1                         -4.242641
# TBC1D1                       -4.472136
# FZR1                         -5.013774
# CCNE2                        -5.604485
# GPSM1                        -6.782330
#
# [1354 rows x 1 columns]

# %%
ura.tf_zscore(bias_filter=0)
biased_zscores = ura.get('z_scores')
display(biased_zscores.to_frame())
# Out:
# Graph has bias of 0.362797608763. Adjusting z-score calculation accordingly.
#           biased-calculated z-scores
# RANBP2                    101.315180
# NUP133                    101.315180
# NUP37                      96.217561
# XPO1                       64.357442
# PAFAH1B1                   56.711013
# CLIP1                      55.436608
# CENPA                      54.162203
# CLASP1                     53.525001
# NUP50                      53.525001
# CKAP5                      53.525001
# CLASP2                     52.887798
# AHCTF1                     52.887798
# KNTC1                      52.887798
# RAE1                       52.250596
# TPR                        52.250596
# MAD1L1                     52.073810
# AAAS                       50.976191
# ATM                        32.957739
# SHC1                       28.585715
# ELL                        24.213691
# BRCA1                      24.125298
# SOS1                       24.125298
# BUB3                       23.543453
# ABL1                       21.311310
# ESR1                       21.134524
# ATF2                       19.771727
# CREBBP                     19.418155
# NCOA1                      18.478869
# PPARGC1A                   18.213691
# MDC1                       17.841667
# ...                              ...
# PER1                      -22.618750
# IQGAP1                    -22.883928
# CCNB1                     -22.953868
# RBL1                      -24.530357
# PER2                      -24.618750
# NCBP2                     -24.688690
# GTF2F1                    -25.963095
# PTTG1                     -26.618750
# TBC1D1                    -27.255952
# CCNA2                     -31.149107
# POLR2L                    -31.697916
# POLR2E                    -31.697916
# TP53                      -32.029165
# CACNA2D4                  -32.246726
# POLR2G                    -32.972321
# GTF2F2                    -33.609523
# CCNB2                     -33.786309
# CACNA2D2                  -34.600297
# PPP2R2B                   -35.149107
# POLR2I                    -35.697916
# PTEN                      -36.139880
# PPP2R2A                   -36.423512
# CCNE1                     -36.600297
# FZR1                      -37.521131
# MYC                       -44.419641
# CCNE2                     -49.149107
# GPSM1                     -62.688690
# AKT1                      -63.852379
# AKT3                      -70.916963
# AKT2                      -77.182142
#
# [1354 rows x 1 columns]

# %% [markdown]
# ### Display Results
# <a id='display'></a>

# %% [markdown]
# Our stat_analysis module also inculdes methods to help you find the most statistically relevant TF's to your input DEG data set.
# - top_values: will display the highest activating, inhibiting, or overall values
# - rank_and_score_df: will display where an input set of genes rank among all others in terms of their z-score
# - vis_tf_network: will display an interactive network of a specified regulator and its downstream targets

# %% [markdown]
# **Top Values**
# <a id='top'></a>
#
# NOTE: Your DEG_to_pvalue and DEG_to_updown paramters should come from create_DEG_full_graph

# %%
top_act = ura.top_values(act = True, abs_value = False, top = 5)
top_inh = ura.top_values(act = False, abs_value = False, top = 5)
top_overall = ura.top_values(abs_value = True, top = 5)

print "\nTop five activating: "
display(top_act)
print "\nTop five inhibiting: "
display(top_inh)
print "\nTop five overall: "
display(top_overall)
# Out:
# Top five activating:
#              z-score  (adj) p-value  (log) fold change
# RANBP2    101.315180      -0.090858           0.975454
# NUP133    101.315180      -0.115508           0.600609
# NUP37      96.217561       0.006546           0.998296
# XPO1       64.357442       0.046577           0.997240
# PAFAH1B1   56.711013      -0.241807           0.008217
# Top five inhibiting:
#          z-score  (adj) p-value  (log) fold change
# AKT2  -77.182142       0.056609           0.978390
# AKT3  -70.916963      -0.136716           0.058052
# AKT1  -63.852379       0.099134           0.019114
# GPSM1 -62.688690       0.159024           0.010397
# CCNE2 -49.149107            NaN                NaN
# Top five overall:
#            z-score  (adj) p-value  (log) fold change
# NUP133  101.315180      -0.115508           0.600609
# RANBP2  101.315180      -0.090858           0.975454
# NUP37    96.217561       0.006546           0.998296
# AKT3    -70.916963      -0.136716           0.058052
# AKT2    -77.182142       0.056609           0.978390

# %% [markdown]
# **Rank with z-score**
# <a id='rank'></a>

# %% [markdown]
# Ranks range from 0 (best, aka strongest z-score) to whichever number is associated with a z-score of zero, in this case 47. If the remove_dups flag is set to True, any genes with the same z-score will have the same rank.

# %%
genes_to_rank = ['TAF1', 'RPL8', 'STAT1','TP53', 'ZEN2']
ura.compare_genes(genes_to_rank, anno_vert_dist=0.005)
# Out:
# RPL8 is not a valid transcription factor in our graph.
# ZEN2 is not a valid transcription factor in our graph.

# %% [markdown]
# **Network Visualization using visJS2jupyter**
# <a id='visJS'></a>
#
# If you do not already have the package visJS2jupyter, type "pip install visJS2jupyter" into your command prompt.
#
# **Node Color**:
# - yellow: regulator/TF
# - red: up-regulated tarets
# - blue: down-regulated targets
# - the stronger the gene's fold change (specified in DEG_filename), the stronger the shade of red or blue
# - white: no fold change information for this gene
#
# **Node Border**:
# - DEG's (secified by DEG_list) are outlined in black
#
# **Node Size**:
# - small: insiginificant/large adjusted p-value (taken from DEG_filename)
# - large: significant/small adjusted p-value
#
# **Edge Color**:
# - red: activating
# - blue: inhibiting
#
# **Tips**:
# - nodes look too clustered: increase node spacing to ~3000 or ~4000
# - nodes look to sparse: decrease node spacing to ~2000 or ~1000
# - directed_edges = False will center the TF
# - directed_edges = True will pull the TF off to the side
#
# **NOTE:** Unfortunately there is a bug with just this notebook, where any nodes that are not "circle" shaped may not appear in the graph visual. The TF is set to always be "star" shaped...

# %%
ura.vis_tf_network('STAT1',
                   directed_edges = False,
                   node_spacing = 3200,
                   color_non_DEGs = True,
                   color_map = plt.cm.bwr,
                   graph_id = 200,
                   tf_size_amplifier = 1000
                   )
# Out:
# ../../ura\stat_analysis.py:506: RuntimeWarning: invalid value encountered in log
#   nts = {n: (2+(-np.log(DEG_to_pvalue[n]))) for n in nodes if n in DEG_to_updown} # keep only those in graph G
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file200"];    frame.runVis([{"node_shape": "circle", "degree": 3.0, "title": "BCL2L1", "color": "rgba(4, 4, 256, 1.0)", "size_field": 4.24754988216634, "y": 405.6008446105305, "x": 675.935337277125, "border_width": 0, "id": "BCL2L1"}, {"node_shape": "circle", "degree": 3.0, "title": "HAMP", "color": "rgba(256, 0, 0, 1.0)", "size_field": NaN, "y": 439.19781858563726, "x": 792.428184212098, "border_width": 2, "id": "HAMP"}, {"node_shape": "circle", "degree": 3.0, "title": "TBX21", "color": "rgba(0, 0, 256, 1.0)", "size_field": NaN, "y": 1220.0047456159161, "x": 2061.7103266609315, "border_width": 0, "id": "TBX21"}, {"node_shape": "circle", "degree": 3.0, "title": "IL6ST", "color": "rgba(256, 6, 6, 1.0)", "size_field": 4.277491493492599, "y": 2628.1577150566154, "x": 2084.346269023788, "border_width": 0, "id": "IL6ST"}, {"node_shape": "circle", "degree": 3.0, "title": "IFNAR2", "color": "rgba(256, 0, 0, 1.0)", "size_field": 5.214921909404362, "y": 1522.9007380806868, "x": 1975.2292432703919, "border_width": 2, "id": "IFNAR2"}, {"node_shape": "circle", "degree": 3.0, "title": "EPO", "color": "rgba(0, 0, 256, 1.0)", "size_field": NaN, "y": 1214.120493771752, "x": 988.0091082963311, "border_width": 0, "id": "EPO"}, {"node_shape": "circle", "degree": 3.0, "title": "IL22", "color": "rgba(0, 0, 256, 1.0)", "size_field": NaN, "y": 3049.691895427782, "x": 666.4790930868465, "border_width": 0, "id": "IL22"}, {"node_shape": "circle", "degree": 3.0, "title": "IL27", "color": "rgba(0, 0, 256, 1.0)", "size_field": NaN, "y": 667.969537847347, "x": 1144.3508737180737, "border_width": 0, "id": "IL27"}, {"node_shape": "circle", "degree": 3.0, "title": "TYK2", "color": "rgba(8, 8, 256, 1.0)", "size_field": 3.6535665857039037, "y": 1053.9750198717688, "x": 1458.8974260880893, "border_width": 0, "id": "TYK2"}, {"node_shape": "circle", "degree": 3.0, "title": "EGF", "color": "rgba(0, 0, 256, 1.0)", "size_field": NaN, "y": 398.0986473733048, "x": 1152.4835414812098, "border_width": 0, "id": "EGF"}, {"node_shape": "circle", "degree": 3.0, "title": "IL12RB1", "color": "rgba(0, 0, 256, 1.0)", "size_field": NaN, "y": 896.9614271002342, "x": 1551.6458576953978, "border_width": 0, "id": "IL12RB1"}, {"node_shape": "circle", "degree": 3.0, "title": "ZNF148", "color": "rgba(256, 84, 84, 1.0)", "size_field": 3.8101929046713474, "y": 2260.8152403809518, "x": 2593.4044969857155, "border_width": 0, "id": "ZNF148"}, {"node_shape": "circle", "degree": 3.0, "title": "IL12RB2", "color": "rgba(0, 0, 256, 1.0)", "size_field": NaN, "y": 1117.1949278583857, "x": 1612.7532085924465, "border_width": 0, "id": "IL12RB2"}, {"node_shape": "circle", "degree": 3.0, "title": "FADD", "color": "rgba(256, 0, 0, 1.0)", "size_field": 5.205106180550429, "y": 2996.7806648306746, "x": 1484.481634699612, "border_width": 2, "id": "FADD"}, {"node_shape": "circle", "degree": 3.0, "title": "LYN", "color": "rgba(256, 0, 0, 1.0)", "size_field": 5.373315806539202, "y": 501.42575247917847, "x": 1315.9814302192315, "border_width": 2, "id": "LYN"}, {"node_shape": "circle", "degree": 3.0, "title": "IFNG", "color": "rgba(0, 0, 256, 1.0)", "size_field": NaN, "y": 1435.4023200595145, "x": 1214.8965966602743, "border_width": 0, "id": "IFNG"}, {"node_shape": "circle", "degree": 3.0, "title": "CAMK2G", "color": "rgba(256, 22, 22, 1.0)", "size_field": 4.635894704789523, "y": 1302.719594481221, "x": 785.4721425776175, "border_width": 0, "id": "CAMK2G"}, {"node_shape": "circle", "degree": 3.0, "title": "CAMK2A", "color": "rgba(256, 24, 24, 1.0)", "size_field": NaN, "y": 2020.16293085651, "x": 661.54317960803, "border_width": 2, "id": "CAMK2A"}, {"node_shape": "circle", "degree": 3.0, "title": "IFI30", "color": "rgba(256, 0, 0, 1.0)", "size_field": 4.2162752935524, "y": 2833.659755088801, "x": 585.1319855425578, "border_width": 0, "id": "IFI30 ...

# %%
ura.vis_tf_network('STAT5A',
                   directed_edges = True,
                   node_spacing = 3000,
                   color_non_DEGs = False,
                   color_map = plt.cm.bwr,
                   graph_id = 201,
                   tf_size_amplifier = 8
                   )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file201"];    frame.runVis([{"node_shape": "circle", "degree": 3.0, "title": "BCL2L1", "color": "grey", "size_field": 4.24754988216634, "y": 1305.4086471206328, "x": 2308.9569458390874, "border_width": 0, "id": "BCL2L1"}, {"node_shape": "circle", "degree": 3.0, "title": "SAC3D1", "color": "rgba(256, 0, 0, 1.0)", "size_field": 5.874660373207809, "y": 1128.0682118576185, "x": 583.3502244124827, "border_width": 2, "id": "SAC3D1"}, {"node_shape": "circle", "degree": 3.0, "title": "GHR", "color": "grey", "size_field": NaN, "y": 402.6005080653345, "x": 1075.137728002442, "border_width": 0, "id": "GHR"}, {"node_shape": "circle", "degree": 3.0, "title": "DPF3", "color": "grey", "size_field": 3.9610973209394835, "y": 2638.324175268777, "x": 1749.8099126831005, "border_width": 0, "id": "DPF3"}, {"node_shape": "circle", "degree": 3.0, "title": "ZFPM1", "color": "grey", "size_field": 4.246303085752858, "y": 1802.0523666544657, "x": 2273.3940094265313, "border_width": 0, "id": "ZFPM1"}, {"node_shape": "circle", "degree": 3.0, "title": "IL6ST", "color": "grey", "size_field": 4.277491493492599, "y": 708.2770824925766, "x": 1080.3190013549333, "border_width": 0, "id": "IL6ST"}, {"node_shape": "circle", "degree": 3.0, "title": "EPO", "color": "grey", "size_field": NaN, "y": 645.9936609471079, "x": 1504.4458213606629, "border_width": 0, "id": "EPO"}, {"node_shape": "circle", "degree": 3.0, "title": "IL22", "color": "grey", "size_field": NaN, "y": 89.86324934210052, "x": 2040.435960646007, "border_width": 0, "id": "IL22"}, {"node_shape": "circle", "degree": 3.0, "title": "IL27", "color": "grey", "size_field": NaN, "y": 1382.0503031532708, "x": 1933.8289367047016, "border_width": 0, "id": "IL27"}, {"node_shape": "circle", "degree": 3.0, "title": "TYK2", "color": "grey", "size_field": 3.6535665857039037, "y": 1331.084606746388, "x": 1586.0475303781118, "border_width": 0, "id": "TYK2"}, {"node_shape": "circle", "degree": 3.0, "title": "SLC30A2", "color": "grey", "size_field": NaN, "y": 2034.6743428030768, "x": 57.244793357792176, "border_width": 0, "id": "SLC30A2"}, {"node_shape": "circle", "degree": 3.0, "title": "IL12RB1", "color": "grey", "size_field": NaN, "y": 1431.2100898327471, "x": 1954.0200549147855, "border_width": 0, "id": "IL12RB1"}, {"node_shape": "circle", "degree": 3.0, "title": "PRL", "color": "grey", "size_field": NaN, "y": 532.8487455268653, "x": 1492.6408143731937, "border_width": 0, "id": "PRL"}, {"node_shape": "circle", "degree": 3.0, "title": "IL12RB2", "color": "grey", "size_field": NaN, "y": 946.917012157483, "x": 1550.452476571998, "border_width": 0, "id": "IL12RB2"}, {"node_shape": "circle", "degree": 3.0, "title": "CDH1", "color": "grey", "size_field": NaN, "y": 479.87954751303806, "x": 1730.3235737047835, "border_width": 0, "id": "CDH1"}, {"node_shape": "circle", "degree": 3.0, "title": "OSM", "color": "grey", "size_field": NaN, "y": 1790.0926302468313, "x": 0.0, "border_width": 0, "id": "OSM"}, {"node_shape": "circle", "degree": 3.0, "title": "LYN", "color": "rgba(256, 0, 0, 1.0)", "size_field": 5.373315806539202, "y": 855.9667299522397, "x": 2694.5724831356188, "border_width": 2, "id": "LYN"}, {"node_shape": "circle", "degree": 3.0, "title": "ERBB4", "color": "rgba(256, 52, 52, 1.0)", "size_field": NaN, "y": 297.44130497829457, "x": 1306.8413421590585, "border_width": 2, "id": "ERBB4"}, {"node_shape": "circle", "degree": 3.0, "title": "IFNG", "color": "grey", "size_field": NaN, "y": 651.8570456541429, "x": 1754.1475887169756, "border_width": 0, "id": "IFNG"}, {"node_shape": "circle", "degree": 3.0, "title": "FASLG", "color": "grey", "size_field": NaN, "y": 710.6156089534118, "x": 1450.6633151148883, "border_width": 0, "id": "FASLG"}, {"node_shape": "circle", "degree": 3.0, "title": "CXCL12", "color": "rgba(256, 2, 2, 1.0)", "size_field": NaN, "y": 917. ...

# %% [markdown]
# Last but not least, you have the option to write out all of the TF's, their targets, (adj) p-values, (log) fold change, and enrichment information to a tab-separated csv file.

# %%
ura.to_csv(out_filename = 'example_basic.txt')
