# %% [markdown]
# # Upstream Regulator Analysis Package
# ## Entrez Example
# ### Wrapper Class "Upstream" in Use
#
# ----------------------
#
# Author: Mikayla Webster (m1webste@ucsd.edu)
#
# Date: 26th February, 2018
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Load Networks](#load)
# 6. [P-value and Z-score Calculation](#pz)
# 8. [Display Our results](#display)

# %% [markdown]
# ## Background
# <a id='background'></a>
#
# The inspiration for these modules comes from Ingenuity System's [Ingenuity Upstream Regulator Analysis in IPA®](http://pages.ingenuity.com/rs/ingenuity/images/0812%20upstream_regulator_analysis_whitepaper.pdf).
#
# This notebook demonstrates how to use our ura package WITH the use of our "wrapper class" Upstream. This notebook creates an instance of class Upstream, and uses this instance to call all of our module's functions. This requires less module imports and simplifies work flow. This notebook emphasizes the flow of function calls, namely what order you should call functions in order for the workflow to process correctly. If you need further help on how to use a function or what that function's purpose is, see the comments associated with that function in the source code (create_graph.py or stat_analysis.py).

# %% [markdown]
# ## Import packages
# <a id='import'></a>

# %%
# import upstream regulator module
import sys
code_path = '../../ura'
sys.path.append(code_path)
import Upstream
reload(Upstream)
# Out:
# <module 'Upstream' from '../../ura\Upstream.pyc'>

# %%
# %matplotlib inline

# %%
# User preferences
symbol = 'symbol'
entrez = 'entrez'

human = 'human'
mouse = 'mouse'

ura = Upstream.Upstream(gene_type = entrez, species = human)

# %% [markdown]
# ## Load Networks
# <a id='load'></a>
#
# 1. List of all **Transcription Factors** (TF's) or regulators of interest to us
#     <br>
#     - Our sources are [slowkow](https://github.com/slowkow/tftargets) and [jaspar](http://jaspar.genereg.net/) TF databases
#     <br><br>
# 2. **Background Network**: [STRING human protein interactions network](https://string-db.org/cgi/download.pl?UserId=9BGA8WkVMRl6&sessionId=HWUK6Dum9xC6&species_text=Homo+sapiens)
#     - Filter our background network down to just the sub network of TF's and their targets
#     <br><br>
# 3. User-supplied list of **Differentially Expressed Genes** (DEG's)

# %%
# transcription factors
ura.easy_load_TF_list(slowkow_bool=True, jaspar_bool=True)
TF_list = ura.get('TF_list')
print "Number of TF's: " + str(len(TF_list))
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-4502...done.
# Finished.
# 505 input query terms found dup hits:
# 	[(u'EN1', 2), (u'IRX5', 2), (u'IRX4', 2), (u'IRX6', 2), (u'IRX2', 2), (u'GSC2', 2), (u'SP1', 2), (u'
# 1510 input query terms found no hit:
# 	[u'ASCC3L1', u'RNF12', u'WHSC1', u'IRF', u'FBXL11', u'DOBOX4', u'DOBOX5', u'ZFP161', u'C2ORF44', u'C
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# Number of TF's: 2503

# %%
# background network
#filename = "../../background_networks/10090.protein.actions.v10.5.txt"
filename = "../../background_networks/9606.protein.actions.v10.5.txt"
confidence_filter = 400
ura.load_STRING_to_digraph(filename, confidence_filter)
DG_TF = ura.get('DG_TF')

print "\nNumber of interactions: " + str(len(list(DG_TF.edges())))
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-7374...done.
# Finished.
# 56 input query terms found dup hits:
# 	[(u'ENSP00000359550', 3), (u'ENSP00000447879', 2), (u'ENSP00000364076', 2), (u'ENSP00000348986', 2),
# 312 input query terms found no hit:
# 	[u'ENSP00000376684', u'ENSP00000289352', u'ENSP00000202788', u'ENSP00000373637', u'ENSP00000367802',
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
#
# Number of interactions: 28832

# %%
# differentially expressed genes
# DEG_filename = 'DE_CoeffSaline_2w - Uninjured_Cooke_RNAseq_synovium_20171025.csv'
DEG_filename = "../../DEG_databases/DE_Coeff_OAvsNormal_OAvsNormal_20171215.csv" 
ura.create_DEG_list(DEG_filename, p_value_filter = 0.05, fold_change_filter = 1)

DEG_list = ura.get('DEG_list')
print "Number of DEG's: " + str(len(DEG_list))
# Out:
# Number of DEG's: 1407

# %% [markdown]
# ## P-values and Z-score Calculation
# <a id='pz'></a>
#
# 1. **P-values**: How relevant is a TF to its DEG targets? Are they connected by chance, or is their connection statistically significant?
#     <br>
#     1. -log(p-value) for each TF using [scipy.stats.hypergeom.logsf](https://docs.scipy.org/doc/scipy-0.19.1/reference/generated/scipy.stats.hypergeom.html).
#         1. high value = significant connection between this TF and its DEG targets
#         2. low value = TF is randomly associated with its DEG targets
#         3. zero = None of this TF's targets were DEG's
#         4. inf = original p-value was so small that its log is inf. Very high significance.
#         <br><br>
# 2. **Z-scores**: Goal is to predict the activation states of the TF's
#
#     - activation states: interaction type/regulation direction = predicted state
#         - activating/up  = activating
#         - activating/down = inhibiting
#         - inhibiting/up = inhibiting
#         - inhibiting/down = activating
#         <br><br>
#     - unbiased vs biased calculations:
#         - **unbiased calculation**: Assume a normal distribution of activating and inhibiting states
#         - **biased calculation**: For the case when you cannot assume a 50-50 split between up/down-regulated targets and activating/inhbiting interactions. Modify our formula to approximate a normal distribution.

# %%
# Enrichment of every TF with respect to its targets
ura.tf_target_enrichment_calc()

# Enrichment of TF's themselves
ura.tf_enrichment_calc()   
ura.get('tf_enrichment')
# Out:
# TF_ENRICHMENT    1.297993e-10
# dtype: float64

# %%
ura.tf_zscore(bias_filter=0.25)

# %% [markdown]
# ## Display Our Results
# <a id='display'></a>
# - Display TF's with top z-scores
# - Display a histogram to see where specific genes rank among others according to z-score
# - Display subnetwork of a particular TF and its targets

# %%
top_values = ura.top_values(act=True, abs_value=True, top=10)
display(top_values)
# Out:
#         z-score  (adj) p-value  (log) fold change
# 7514   2.840188       0.168758          -0.359554
# 5519   2.840188       0.611683          -0.177476
# 2305   2.500000       0.018920          -0.980677
# 5048   2.496151       0.503449          -0.184175
# 5728   2.449490       0.167299           0.283517
# 83439 -2.333333       0.290531           0.346579
# 4261  -2.333333            NaN                NaN
# 8856  -2.449490            NaN                NaN
# 6615  -2.496151       0.036286          -0.356284
# 26086 -2.496151       0.157689           0.729600

# %%
genes_to_rank = ['23332', '9184', '5934']
ura.compare_genes(genes_to_rank)

# %%
ura.vis_tf_network('9184',
              directed_edges = False,
              color_non_DEGs=True,
              node_spacing = 3000,
              graph_id = 5,
              tf_size_amplifier = 0)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file5"];    frame.runVis([{"node_shape": "circle", "degree": 3.0, "title": "91687", "color": "rgba(0, 0, 256, 1.0)", "size_field": 2.5118435458552946, "y": 786.2184489872025, "x": 130.17777638778847, "border_width": 0, "id": "91687"}, {"node_shape": "circle", "degree": 3.0, "title": "378708", "color": "rgba(0, 0, 256, 1.0)", "size_field": 4.275839909450419, "y": 359.64864740895825, "x": 332.4509999018884, "border_width": 0, "id": "378708"}, {"node_shape": "circle", "degree": 3.0, "title": "8881", "color": "rgba(22, 22, 256, 1.0)", "size_field": 2.1491361030699756, "y": 1242.4407132833235, "x": 1283.908161368789, "border_width": 0, "id": "8881"}, {"node_shape": "circle", "degree": 3.0, "title": "79902", "color": "rgba(0, 0, 256, 1.0)", "size_field": 2.92922234297816, "y": 335.6359117609664, "x": 213.0492470530685, "border_width": 0, "id": "79902"}, {"node_shape": "circle", "degree": 3.0, "title": "5501", "color": "rgba(256, 122, 122, 1.0)", "size_field": 4.534392280316201, "y": 538.2825450357229, "x": 209.37712937239934, "border_width": 0, "id": "5501"}, {"node_shape": "circle", "degree": 3.0, "title": "5515", "color": "rgba(0, 0, 256, 1.0)", "size_field": 3.4261662602482117, "y": 530.330078990711, "x": 316.2414778283453, "border_width": 0, "id": "5515"}, {"node_shape": "circle", "degree": 3.0, "title": "699", "color": "rgba(0, 0, 256, 1.0)", "size_field": 4.275839909450419, "y": 570.1440733970948, "x": 675.242074822324, "border_width": 0, "id": "699"}, {"node_shape": "circle", "degree": 3.0, "title": "79023", "color": "rgba(60, 60, 256, 1.0)", "size_field": 2.681196334416609, "y": 228.30960479182102, "x": 495.996110114737, "border_width": 0, "id": "79023"}, {"node_shape": "circle", "degree": 3.0, "title": "55055", "color": "rgba(0, 0, 256, 1.0)", "size_field": 6.991755288768988, "y": 616.748167958378, "x": 124.27197186357098, "border_width": 0, "id": "55055"}, {"node_shape": "circle", "degree": 3.0, "title": "5903", "color": "rgba(60, 60, 256, 1.0)", "size_field": 3.5729469815503245, "y": 271.87999283436204, "x": 162.74564190909254, "border_width": 0, "id": "5903"}, {"node_shape": "circle", "degree": 3.0, "title": "7514", "color": "rgba(0, 0, 256, 1.0)", "size_field": 3.7792903707960557, "y": 887.4094797710463, "x": 306.5628492875852, "border_width": 0, "id": "7514"}, {"node_shape": "circle", "degree": 3.0, "title": "5905", "color": "rgba(0, 0, 256, 1.0)", "size_field": 2.6017297326940474, "y": 421.25879811912046, "x": 457.63712286002016, "border_width": 0, "id": "5905"}, {"node_shape": "circle", "degree": 3.0, "title": "246184", "color": "rgba(0, 0, 256, 1.0)", "size_field": 2.0109667428136984, "y": 0.0, "x": 1591.2188222143575, "border_width": 0, "id": "246184"}, {"node_shape": "circle", "degree": 3.0, "title": "991", "color": "rgba(0, 0, 256, 1.0)", "size_field": 4.275839909450419, "y": 674.1337136724915, "x": 811.5724166929193, "border_width": 0, "id": "991"}, {"node_shape": "circle", "degree": 3.0, "title": "10726", "color": "rgba(0, 0, 256, 1.0)", "size_field": 2.68943783280298, "y": 466.33959900773857, "x": 590.3177676610853, "border_width": 0, "id": "10726"}, {"node_shape": "circle", "degree": 3.0, "title": "57122", "color": "rgba(256, 140, 140, 1.0)", "size_field": 3.6546879052344976, "y": 686.5864573441255, "x": 538.7558628370907, "border_width": 0, "id": "57122"}, {"node_shape": "circle", "degree": 3.0, "title": "998", "color": "rgba(0, 0, 256, 1.0)", "size_field": 7.0215285214991, "y": 58.81345782119352, "x": 334.63152856115227, "border_width": 0, "id": "998"}, {"node_shape": "circle", "degree": 3.0, "title": "5519", "color": "rgba(0, 0, 256, 1.0)", "size_field": 2.4915405338580507, "y": 391.4067028132203, "x": 256.53174396735056, "border_width": 0, "id": "5519"}, {"node_shape": "circle", "degree": 3.0, "title": "5518", "color": "rgba(78, 78, 256,  ...

# %%
# display subnetworks using visJS2jupyter
ura.vis_tf_network('5934',
              color_non_DEGs=True,
              directed_edges = True,
              node_spacing = 2000,
              graph_id = 6,
              tf_size_amplifier = 0)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file6"];    frame.runVis([{"node_shape": "circle", "degree": 3.0, "title": "4303", "color": "rgba(170, 170, 256, 1.0)", "size_field": 3.022624556556484, "y": 1307.4175651987105, "x": 185.1308820228714, "border_width": 0, "id": "4303"}, {"node_shape": "circle", "degree": 3.0, "title": "890", "color": "rgba(0, 0, 256, 1.0)", "size_field": 12.04549048919487, "y": 799.0590601427847, "x": 1713.3485080368712, "border_width": 2, "id": "890"}, {"node_shape": "circle", "degree": 3.0, "title": "5111", "color": "rgba(0, 0, 256, 1.0)", "size_field": 9.461030334746333, "y": 1155.702937354082, "x": 1354.3690615325108, "border_width": 2, "id": "5111"}, {"node_shape": "circle", "degree": 3.0, "title": "983", "color": "rgba(256, 122, 122, 1.0)", "size_field": 8.673138198332744, "y": 991.9296673593565, "x": 1857.0517329965428, "border_width": 2, "id": "983"}, {"node_shape": "circle", "degree": 3.0, "title": "1874", "color": "rgba(0, 0, 256, 1.0)", "size_field": 5.963655385565888, "y": 1414.0254721565034, "x": 1671.2955030233823, "border_width": 0, "id": "1874"}, {"node_shape": "circle", "degree": 3.0, "title": "1875", "color": "rgba(0, 0, 256, 1.0)", "size_field": 5.907233373100595, "y": 846.3765777228937, "x": 2000.0, "border_width": 0, "id": "1875"}, {"node_shape": "circle", "degree": 3.0, "title": "132660", "color": "rgba(0, 0, 256, 1.0)", "size_field": 2.7203831574052413, "y": 509.0483684391062, "x": 1338.1271788988022, "border_width": 0, "id": "132660"}, {"node_shape": "circle", "degree": 3.0, "title": "595", "color": "rgba(0, 0, 256, 1.0)", "size_field": 14.288267979151877, "y": 1055.2833518743178, "x": 1608.6663858876095, "border_width": 2, "id": "595"}, {"node_shape": "circle", "degree": 3.0, "title": "2309", "color": "rgba(256, 58, 58, 1.0)", "size_field": 10.13857549900668, "y": 1381.8003465979207, "x": 0.0, "border_width": 2, "id": "2309"}, {"node_shape": "circle", "degree": 3.0, "title": "993", "color": "rgba(0, 0, 256, 1.0)", "size_field": 5.907233373100595, "y": 930.533076727381, "x": 1737.284633238615, "border_width": 0, "id": "993"}, {"node_shape": "circle", "degree": 3.0, "title": "1719", "color": "rgba(0, 0, 256, 1.0)", "size_field": 5.907233373100595, "y": 1308.7538858125818, "x": 1127.323540458221, "border_width": 0, "id": "1719"}, {"node_shape": "circle", "degree": 3.0, "title": "7153", "color": "rgba(256, 64, 64, 1.0)", "size_field": 8.920813164092124, "y": 1390.1889939559044, "x": 1428.3361355729046, "border_width": 2, "id": "7153"}, {"node_shape": "circle", "degree": 3.0, "title": "1019", "color": "rgba(256, 0, 0, 1.0)", "size_field": 5.397161625291288, "y": 1018.7352374435823, "x": 1025.226779273509, "border_width": 0, "id": "1019"}, {"node_shape": "circle", "degree": 3.0, "title": "5928", "color": "rgba(92, 92, 256, 1.0)", "size_field": 2.2601737204031034, "y": 585.5137760409411, "x": 1493.708088269073, "border_width": 0, "id": "5928"}, {"node_shape": "circle", "degree": 3.0, "title": "8900", "color": "rgba(0, 0, 256, 1.0)", "size_field": 5.907233373100595, "y": 1110.8237229647882, "x": 1934.6990252042137, "border_width": 0, "id": "8900"}, {"node_shape": "circle", "degree": 3.0, "title": "995", "color": "rgba(0, 0, 256, 1.0)", "size_field": 5.907233373100595, "y": 1637.9640196021824, "x": 1345.017613126634, "border_width": 0, "id": "995"}, {"node_shape": "circle", "degree": 3.0, "title": "894", "color": "rgba(0, 0, 256, 1.0)", "size_field": 3.003093056477645, "y": 891.6256054093867, "x": 1146.6113686526853, "border_width": 0, "id": "894"}, {"node_shape": "circle", "degree": 3.0, "title": "990", "color": "rgba(0, 0, 256, 1.0)", "size_field": 2.6381562537916468, "y": 691.4866722672822, "x": 1811.0976202106435, "border_width": 0, "id": "990"}, {"node_shape": "circle", "degree": 3.0, "title": "896", "color": "rgba(84, 84, 256, 1.0)", "size_field": 2.930174 ...

# %%
# to write data to a csv file
csv_filename = 'analysis_entrez.txt'
ura.to_csv(csv_filename)
