# %% [markdown]
# # Mouse example
# ## Upstream Regulator Analysis
#
# ----------------------
#
# Author: Mikayla Webster (13webstermj@gmail.com)
#
# Date: 9th February, 2018
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Load Networks](#load)
# 6. [TF Enrichment and Activation State Prediction](#pz)
# 8. [Display Our results](#display)

# %% [markdown]
# ## Background
# <a id='background'></a>
#
# The inspiration for these modules comes from Ingenuity System's [Ingenuity Upstream Regulator Analysis in IPA®](http://pages.ingenuity.com/rs/ingenuity/images/0812%20upstream_regulator_analysis_whitepaper.pdf).
#
# This notebook is an example of how to run our package on mouse genes. Our easy_load_TF_list will automatically adjust to mouse gene symbols and entrez if mouse is specified as the species you would like to use upon instantiation of Upstream. Our load_STRING_to_digraph function requires an mouse gene input file, which can be found on the STRING-db website. It is your responsibility to ensure that the DEG file you load matches mouse naming convention (first letter capitalized, the rest lower case), or else you may encounter some errors.

# %% [markdown]
# ## Import packages
# <a id='import'></a>

# %%
# import upstream regulator module
import sys
code_path = '../../network_bio_toolkit'
sys.path.append(code_path)
import Upstream
reload(Upstream)
# Out:
# <module 'Upstream' from '../../network_bio_toolkit\Upstream.pyc'>

# %%
# User preferences
symbol = 'symbol'
entrez = 'entrez'

human = 'human'
mouse = 'mouse'

ura = Upstream.Upstream(gene_type = symbol, species = mouse)

# %% [markdown]
# ## Load Networks
# <a id='load'></a>
#
# 1. List of all **Transcription Factors** (TF's) or regulators of interest to us
#     <br>
#     - Our sources are [slowkow](https://github.com/slowkow/tftargets) and [jaspar](http://jaspar.genereg.net/) TF databases
#     <br><br>
# 2. **Background Network**: [STRING human protein interactions network](https://string-db.org/cgi/download.pl?UserId=9BGA8WkVMRl6&sessionId=HWUK6Dum9xC6&species_text=Homo+sapiens)
#     - Filter our background network down to just the sub network of TF's and their targets
#     <br><br>
# 3. User-supplied list of **Differentially Expressed Genes** (DEG's)

# %%
# transcription factors
ura.easy_load_TF_list('../../TF_databases/TF_database_URA.csv')
TF_list = ura.get('TF_list')
print "Number of TF's: " + str(len(TF_list))
# Out:
# Number of TF's: 3983
# ../../network_bio_toolkit\create_graph.py:46: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   df2 = pd.DataFrame.from_csv(csv_filename)

# %%
# background network
filename = "../../background_networks/10090.protein.actions.v10.5.txt"
confidence_filter = 400
ura.load_STRING_to_digraph(filename, confidence_filter)
DG_TF = ura.get('DG_TF')

print "\nNumber of interactions: " + str(len(list(DG_TF.edges())))
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-7303...done.
# Finished.
# 36 input query terms found dup hits:
# 	[(u'ENSMUSP00000010241', 2), (u'ENSMUSP00000010248', 2), (u'ENSMUSP00000095200', 2), (u'ENSMUSP00000
# 155 input query terms found no hit:
# 	[u'ENSMUSP00000036849', u'ENSMUSP00000097354', u'ENSMUSP00000097358', u'ENSMUSP00000137522', u'ENSMU
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
#
# Number of interactions: 24693

# %%
# differentially expressed genes
DEG_filename = '../../DEG_databases/DE_CoeffSaline_2w - Uninjured_Cooke_RNAseq_synovium_20171025.csv'
ura.create_DEG_list(DEG_filename, p_value_filter = 0.05, fold_change_filter = 1)

DEG_list = ura.get('DEG_list')
print "Number of DEG's: " + str(len(DEG_list))
# Out:
# ../../network_bio_toolkit\create_graph.py:366: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   df = pd.DataFrame.from_csv(filename, sep = sep)
# Number of DEG's: 1528

# %% [markdown]
# ## TF Enrichment and Activation State Prediction
# <a id='pz'></a>
#
# 1. **Enrichment**: How relevant is a TF to its DEG targets? Are they connected by chance, or is their connection statistically significant?
#     <br>
#     1. -log(p-value) for each TF using [scipy.stats.hypergeom.logsf](https://docs.scipy.org/doc/scipy-0.19.1/reference/generated/scipy.stats.hypergeom.html).
#         1. high value = significant connection between this TF and its DEG targets
#         2. low value = TF is randomly associated with its DEG targets
#         3. zero = None of this TF's targets were DEG's
#         4. inf = original p-value was so small that its log is inf. Very high significance.
#         <br><br>
# 2. **Activation State Prediction**: Goal is to predict the activation states of the TF's
#
#     - activation states: interaction type/regulation direction = predicted state
#         - activating/up  = activating
#         - activating/down = inhibiting
#         - inhibiting/up = inhibiting
#         - inhibiting/down = activating
#         <br><br>
#     - unbiased vs biased calculations:
#         - **unbiased calculation**: Assume a normal distribution of activating and inhibiting states
#         - **biased calculation**: For the case when you cannot assume a 50-50 split between up/down-regulated targets and activating/inhbiting interactions. Modify our formula to approximate a normal distribution.

# %%
# Enrichment of every TF with respect to its targets
ura.tf_target_enrichment_calc()

# Enrichment of TF's themselves
ura.tf_enrichment_calc()   
ura.get('tf_enrichment')
# Out:
# TF_ENRICHMENT   -1.661604e-11
# dtype: float64

# %%
ura.tf_zscore(bias_filter=0.25)

# %% [markdown]
# ## Display Our Results
# <a id='display'></a>
# - Display TF's with top z-scores
# - Display a histogram to see where specific genes rank among others according to z-score
# - Display subnetwork of a particular TF and its targets

# %%
top_values = ura.top_values(abs_value=True, top=10)
display(top_values)
# Out:
#            z-score  (adj) p-value  (log) fold change
# Bub3      3.899602       0.988472          -0.003605
# Xpo1      3.656552       0.048499           0.535212
# Cenpa     3.656552       0.075185           1.109307
# Ppp2r1b   3.655631       0.000097          -1.081904
# Ranbp2    3.530090       0.311983           0.276706
# Pafah1b1  3.530090       0.191472           0.282180
# Ahctf1    3.530090       0.532534           0.258789
# Clip1     3.530090       0.030135          -0.719186
# Cenpt     3.530090       0.120306           0.678457
# Kntc1     3.530090       0.225594           1.802828

# %%
genes_to_rank = ['Hoxa4', 'Cebpb', 'Klf4', 'Tle3', 'Rbl2', 'Stat1', 'Bub3', 'Cenpa']
ura.compare_genes(genes_to_rank)

# %%
ura.vis_tf_network('Klf4',
              directed_edges = False,
              color_non_DEGs=False,
              node_spacing = 1500,
              graph_id = 2,
              tf_size_amplifier = 0)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file2"];    frame.runVis([{"node_shape": "circle", "degree": 3.0, "title": "Il10", "color": "grey", "size_field": 4.496326598241282, "y": 1266.5525102006056, "x": 542.9765639028731, "border_width": 0, "id": "Il10"}, {"node_shape": "circle", "degree": 3.0, "title": "Plaur", "color": "grey", "size_field": 2.7802095404416023, "y": 185.4700557938243, "x": 1334.1062862647223, "border_width": 0, "id": "Plaur"}, {"node_shape": "circle", "degree": 3.0, "title": "Ctnnb1", "color": "grey", "size_field": 2.324284335815272, "y": 750.7878117380016, "x": 1156.3528053555258, "border_width": 0, "id": "Ctnnb1"}, {"node_shape": "circle", "degree": 3.0, "title": "Jup", "color": "grey", "size_field": 5.097892437482933, "y": 381.30503677588916, "x": 1330.3056578170776, "border_width": 0, "id": "Jup"}, {"node_shape": "star", "degree": 3.0, "title": "Klf4", "color": "grey", "size_field": 11.438770068757355, "y": 671.3824200819763, "x": 858.3217166763387, "border_width": 0, "id": "Klf4"}, {"node_shape": "circle", "degree": 3.0, "title": "Cdh1", "color": "grey", "size_field": 4.496326598241282, "y": 853.1773842004058, "x": 526.8405240318705, "border_width": 0, "id": "Cdh1"}, {"node_shape": "circle", "degree": 3.0, "title": "Stat3", "color": "grey", "size_field": 2.0321309523117717, "y": 1023.2359489908056, "x": 709.910741500382, "border_width": 0, "id": "Stat3"}, {"node_shape": "circle", "degree": 3.0, "title": "Trp53", "color": "grey", "size_field": 5.390162303466489, "y": 933.3872542529668, "x": 809.6625902444937, "border_width": 0, "id": "Trp53"}, {"node_shape": "circle", "degree": 3.0, "title": "Cdkn1a", "color": "grey", "size_field": 4.6676737928100795, "y": 1270.7959530198711, "x": 942.9932969432367, "border_width": 0, "id": "Cdkn1a"}, {"node_shape": "circle", "degree": 3.0, "title": "Slc2a4", "color": "rgba(0, 0, 256, 1.0)", "size_field": 11.438770068757355, "y": 1235.7183006779912, "x": 233.10339329329537, "border_width": 2, "id": "Slc2a4"}, {"node_shape": "circle", "degree": 3.0, "title": "Tcf7l1", "color": "grey", "size_field": 2.202195788588865, "y": 558.9685147563682, "x": 1495.3816263156298, "border_width": 0, "id": "Tcf7l1"}, {"node_shape": "circle", "degree": 3.0, "title": "Tcf7l2", "color": "grey", "size_field": 3.116953562855516, "y": 697.553159462454, "x": 1395.3368677160022, "border_width": 0, "id": "Tcf7l2"}, {"node_shape": "circle", "degree": 3.0, "title": "Edn1", "color": "grey", "size_field": 2.6042680909836555, "y": 975.0877959560399, "x": 1413.3967828639807, "border_width": 0, "id": "Edn1"}, {"node_shape": "circle", "degree": 3.0, "title": "Hdc", "color": "grey", "size_field": 2.2996981321786176, "y": 207.86185217861635, "x": 240.6021254473822, "border_width": 0, "id": "Hdc"}, {"node_shape": "circle", "degree": 3.0, "title": "Mapk7", "color": "grey", "size_field": 4.336422777880523, "y": 40.293331293817296, "x": 505.18907197489415, "border_width": 0, "id": "Mapk7"}, {"node_shape": "circle", "degree": 3.0, "title": "Tert", "color": "grey", "size_field": 4.496326598241282, "y": 1144.753261257097, "x": 1313.2677876221687, "border_width": 0, "id": "Tert"}, {"node_shape": "circle", "degree": 3.0, "title": "Crebbp", "color": "grey", "size_field": 5.908839903600919, "y": 1067.2014396258144, "x": 1026.8234022448528, "border_width": 0, "id": "Crebbp"}, {"node_shape": "circle", "degree": 3.0, "title": "Tagln", "color": "rgba(256, 132, 132, 1.0)", "size_field": 6.3941999570854255, "y": 1389.6043388290304, "x": 1307.4329427746309, "border_width": 2, "id": "Tagln"}, {"node_shape": "circle", "degree": 3.0, "title": "Bmp6", "color": "grey", "size_field": 5.382784108344858, "y": 1500.0, "x": 766.6517464130253, "border_width": 0, "id": "Bmp6"}, {"node_shape": "circle", "degree": 3.0, "title": "Bmp4", "color": "grey", "size_field": 3.0209141434076194, "y": 403.2418718983543, "x ...

# %%
# display subnetworks using visJS2jupyter
ura.vis_tf_network('Stat1',
              color_non_DEGs=False,
              directed_edges = True,
              node_spacing = 2000,
              graph_id = 1,
              tf_size_amplifier = 0)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"node_shape": "circle", "degree": 3.0, "title": "Cyp1b1", "color": "rgba(180, 180, 256, 1.0)", "size_field": 7.474510531017888, "y": 1077.0764243413257, "x": 374.80208414595893, "border_width": 2, "id": "Cyp1b1"}, {"node_shape": "circle", "degree": 3.0, "title": "Ptpn11", "color": "grey", "size_field": 2.7666455915793073, "y": 435.2588010271904, "x": 459.8226763713739, "border_width": 0, "id": "Ptpn11"}, {"node_shape": "circle", "degree": 3.0, "title": "Il17f", "color": "grey", "size_field": 3.9080449409710054, "y": 331.954930112223, "x": 485.6312874811086, "border_width": 0, "id": "Il17f"}, {"node_shape": "circle", "degree": 3.0, "title": "Thpo", "color": "grey", "size_field": 3.9080449409710054, "y": 719.1092230488678, "x": 341.8958532222314, "border_width": 0, "id": "Thpo"}, {"node_shape": "circle", "degree": 3.0, "title": "Sp110", "color": "grey", "size_field": 2.1009348781558694, "y": 78.3478600658801, "x": 1397.3315289038892, "border_width": 0, "id": "Sp110"}, {"node_shape": "circle", "degree": 3.0, "title": "Mapk14", "color": "grey", "size_field": 2.597527961043161, "y": 938.4026791605146, "x": 688.7575025467464, "border_width": 0, "id": "Mapk14"}, {"node_shape": "circle", "degree": 3.0, "title": "Irf1", "color": "grey", "size_field": 3.052537245331015, "y": 697.8009540407267, "x": 481.03060746421096, "border_width": 0, "id": "Irf1"}, {"node_shape": "circle", "degree": 3.0, "title": "Ifng", "color": "grey", "size_field": 3.9080449409710054, "y": 839.7487187581927, "x": 800.8285881567074, "border_width": 0, "id": "Ifng"}, {"node_shape": "circle", "degree": 3.0, "title": "Mpl", "color": "grey", "size_field": 3.9080449409710054, "y": 1306.2195699011045, "x": 809.2293465154308, "border_width": 0, "id": "Mpl"}, {"node_shape": "circle", "degree": 3.0, "title": "Irf8", "color": "grey", "size_field": 3.2156486264869226, "y": 143.10200808316557, "x": 1186.059546543597, "border_width": 0, "id": "Irf8"}, {"node_shape": "circle", "degree": 3.0, "title": "Fyn", "color": "grey", "size_field": 2.5994036020121065, "y": 998.9257814035449, "x": 1656.68989069, "border_width": 0, "id": "Fyn"}, {"node_shape": "circle", "degree": 3.0, "title": "Sp7", "color": "grey", "size_field": 3.9080449409710054, "y": 969.9929692957656, "x": 916.2645733428257, "border_width": 0, "id": "Sp7"}, {"node_shape": "circle", "degree": 3.0, "title": "Zfp36", "color": "grey", "size_field": 2.4368165140174938, "y": 1297.328969449595, "x": 1239.3475076657714, "border_width": 0, "id": "Zfp36"}, {"node_shape": "circle", "degree": 3.0, "title": "Hes1", "color": "grey", "size_field": 5.0260827811161, "y": 474.0622752109771, "x": 933.6837611232069, "border_width": 0, "id": "Hes1"}, {"node_shape": "circle", "degree": 3.0, "title": "Lck", "color": "grey", "size_field": 3.3365227828909774, "y": 1406.1160987183328, "x": 1061.8011955014215, "border_width": 0, "id": "Lck"}, {"node_shape": "circle", "degree": 3.0, "title": "Bcl2", "color": "grey", "size_field": 2.8216085315491455, "y": 512.4672208661786, "x": 628.7719187872235, "border_width": 0, "id": "Bcl2"}, {"node_shape": "circle", "degree": 3.0, "title": "Csf2rb", "color": "grey", "size_field": 4.596604368704286, "y": 1366.3532764164725, "x": 1531.1156018096244, "border_width": 0, "id": "Csf2rb"}, {"node_shape": "circle", "degree": 3.0, "title": "Csf2ra", "color": "grey", "size_field": 2.166418038904068, "y": 1372.0109303718234, "x": 1309.125403347919, "border_width": 0, "id": "Csf2ra"}, {"node_shape": "circle", "degree": 3.0, "title": "Il27", "color": "grey", "size_field": 3.9080449409710054, "y": 570.3050096819081, "x": 531.60721309945, "border_width": 0, "id": "Il27"}, {"node_shape": "circle", "degree": 3.0, "title": "Il12b", "color": "grey", "size_field": 3.9080449409710054, "y": 1309.3823373637692, "x": 1662.184175596268, "b ...

# %%
# to write data to a csv file
#csv_filename = 'analysis_mouse.txt'
#ura.to_csv(csv_filename)
