# %% [markdown]
# # Basic Example
# ## Upstream Regulator Analysis
#
#
# ----------------------
#
# Author: Mikayla Webster (13webstermj@gmail.com)
#
# Date: 8th November, 2017
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Load Graphs](#graph)
#     1. [Transcription Factors](#tf)
#     2. [Background Network](#bn)
#     3. [Differentially Expressed Genes](#deg)
# 3. [Data Analysis](#stat)
#     1. [Enrichment](#pvalue)
#     2. [TF Activation State Prediction](#zscore)
#     3. [Display Our Results](#display)
#         1. [Top Values](#top)
#         2. [Rank with z-score](#rank)
#         3. [Network Visualization using visJS2jupyter](#visJS)

# %% [markdown]
# ## Background
# <a id='background'></a>

# %% [markdown]
# The inspiration for these modules comes from Ingenuity System's [Ingenuity Upstream Regulator Analysis in IPA®](http://pages.ingenuity.com/rs/ingenuity/images/0812%20upstream_regulator_analysis_whitepaper.pdf).
#
# This notebook is meant to explain how to use the individual functions from our URA modules, with emphasis on different parameter options. If you need further help on how to use a function or what that function's purpose is, see the comments associated with that function in the source code (Upstream.py, create_graph.py, or stat_analysis.py).

# %% [markdown]
# ## Import packages
# <a id='import'></a>

# %%
# uncomment if you have not pip-installed network_bio_toolkit

#import sys
#code_path = '../../network_bio_toolkit'
#sys.path.append(code_path)
#import Upstream
#reload(Upstream)

from network_bio_toolkit import Upstream

# import matplotlib for color map
import matplotlib as plt

# %%
# User preferences
symbol = 'symbol'
entrez = 'entrez'

ura = Upstream.Upstream(symbol)

# %% [markdown]
# ## Load Graphs ##
# <a id='graph'></a>

# %% [markdown]
# ### Transcription Factors
# <a id='tf'></a>
#
# Our create_graph module prepares 3 databases to use in our analysis: a transcription factor interaction network, a background network, and a differentially expressed genes database. Our transcription factor data comes from two sources: [slowkow](https://github.com/slowkow/tftargets) and [jaspar](http://jaspar.genereg.net/). Slowkow is a compilation of 6 smaller databases: TRED, ITFP, ENCODE, Neph2012, TRRUST, Marbach2016. Information about these specific databases, including links to their sources, is available through the slowkow github page. Some basic information on these databases is as follows:
# - Size of Jaspar Database: 2049
# - Size of Slowkow Database: 2705
# - Size of TRED: 133
# - Size of ITFP: 1974
# - Size of ENCODE: 157
# - Size of Neph2012: 536
# - Size of TRRUST: 748
# - Size of Marbach2016: 643
#
# Our trascription factor list contains 3983 unique entries.

# %%
ura.easy_load_TF_list('../../TF_databases/TF_database_URA.csv', jaspar = False, TRED = True, ITFP = True, ENCODE = True, 
                          Neph2012 = True, TRRUST = True, Marbach2016 = True)
len(ura.get('TF_list'))
# Out:
# ../../network_bio_toolkit\create_graph.py:46: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   df2 = pd.DataFrame.from_csv(csv_filename)
# 2705

# %% [markdown]
# ### Background Network
# <a id='bn'></a>
#
# Our background network comes from the [STRING](https://string-db.org/) database. Our module uses our list of transcription factors (TF_list) to extract only relevant information from the STRING database. Namely, we remove all edges and nodes not conected to our TF's.
#
# This function may need a minute or so to process.

# %%
filename = "../../background_networks/9606.protein.actions.v10.5.txt"
confidence_filter = 400
ura.load_STRING_to_digraph(filename, confidence_filter)
DG_TF = ura.get('DG_TF')
DG_universe = ura.get('DG_universe')

print "\nNumber of interactions: " + str(len(list(DG_TF.edges())))
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-7374...done.
# Finished.
# 34 input query terms found dup hits:
# 	[(u'ENSP00000447879', 2), (u'ENSP00000364076', 2), (u'ENSP00000313571', 2), (u'ENSP00000368927', 2),
# 314 input query terms found no hit:
# 	[u'ENSP00000376684', u'ENSP00000289352', u'ENSP00000202788', u'ENSP00000373637', u'ENSP00000367802',
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
#
# Number of interactions: 28717

# %%
print 'Number of unique nodes without filtering: ' + str(len(list(set(DG_universe.nodes()))))
print 'Number of edges without filtering: ' + str(len(DG_universe.edges()))
print '-----------------------------------------------'
print 'Number of unique nodes with filtering: ' + str(len(list(set(DG_TF.nodes()))))
print 'Number of edges with filtering: ' + str(len(DG_TF.edges()))
# Out:
# Number of unique nodes without filtering: 7045
# Number of edges without filtering: 140306
# -----------------------------------------------
# Number of unique nodes with filtering: 4584
# Number of edges with filtering: 28717

# %% [markdown]
# ### Differentially Expressed Genes
# <a id='deg'></a>
#
# Our last database comes from a list of differentially exressed genes (DEG) found in an experiement. This should come in the form of a tab separated csv file with at least three columns: gene name, (adjusted) p-value, and (log) fold change. Our parser will look for common header names for each of these columns. However, if your file has unusual column headers for any of these three categories, please specify your column headers using the parameters "gene_column_header", "p_value_column_header", and "fold_change_column_header".
#
# **WARNING: Having spaces in your column headers can cause weird bugs.**
#
# Specify a networkx graph G in order to add the fold change (up-down) information from your csv file as a node attribute to this graph. NOTE: 1) the graph will not be modified in place, and 2) if G is not specified, 3 values will be returned rather than 2.

# %%
filename = '../../DEG_databases/differentially_expressed_genes.txt'

ura.create_DEG_list(filename,
                    p_value_filter = 0.05,
                    p_value_or_adj = 'adj',  # filtering by p-value ('p') or adjusted p-value ('adj')
                    fold_change_filter = None,  # specify a number to filter by absolute (log) fold change
                    gene_column_header = 'gene_symbol', # these are common names, but specifying for demonstration
                    p_value_column_header = 'adj_p_value',
                    fold_change_column_header = 'fold_change')

DEG_list = ura.get('DEG_list')
DG_TF = ura.get('DG_TF')
DEG_full_graph = ura.get('DEG_full_graph')
DEG_to_pvalue = ura.get('DEG_to_pvalue')
DEG_to_updown = ura.get('DEG_to_updown')

print "Number of DEG's: " + str(len(DEG_list))
print "Number of genes in our entire input file: " + str(len(DEG_full_graph.nodes()))
# Out:
# ../../network_bio_toolkit\create_graph.py:366: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   df = pd.DataFrame.from_csv(filename, sep = sep)
# Number of DEG's: 8755
# Number of genes in our entire input file: 13297

# %%
DG_TF.nodes(data=True) # updown means fold change
# Out:
# [('HIF3A', {'updown': 0}),
#  ('RNF14', {'updown': 0.3508037846}),
#  ('ELANE', {'updown': 0}),
#  ('KHSRP', {'updown': 0.9599754305}),
#  ('NCBP1', {'updown': 0.9955238004000001}),
#  ('NCBP2', {'updown': 0.9983342389000001}),
#  ('RNF13', {'updown': 0}),
#  ('NELFB', {'updown': 0.99337302}),
#  ('HIST1H4J', {'updown': 0.9979641224}),
#  ('HSPA9', {'updown': 0.8444486943}),
#  ('HSPA8', {'updown': 0.947964093}),
#  ('NELFE', {'updown': 0}),
#  ('B2M', {'updown': 0.9980184343}),
#  ('CD226', {'updown': 0}),
#  ('LIFR', {'updown': 0}),
#  ('PDCD10', {'updown': 0.1330512662}),
#  ('PDCD11', {'updown': 0.9980143765999999}),
#  ('AGT', {'updown': 0.9981858779999999}),
#  ('ASS1', {'updown': 0.4329907296}),
#  ('SQLE', {'updown': 0.9974200429000001}),
#  ('ADIPOQ', {'updown': 0}),
#  ('FHIT', {'updown': 0.9976648806}),
#  ('CYP26B1', {'updown': 0.031157696000000002}),
#  ('SRY', {'updown': 0}),
#  ('HSPA5', {'updown': 0.9467449001}),
#  ('NID2', {'updown': 0}),
#  ('CAMK1', {'updown': 0}),
#  ('NR0B2', {'updown': 0}),
#  ('NR0B1', {'updown': 0}),
#  ('HSPA4', {'updown': 0}),
#  ('PIK3CD', {'updown': 0}),
#  ('CAMK4', {'updown': 0.0839874097}),
#  ('PIK3CG', {'updown': 0}),
#  ('CRBN', {'updown': 0.1009102585}),
#  ('SPTLC2', {'updown': 0}),
#  ('DRAP1', {'updown': 0.9965897281999999}),
#  ('IRX5', {'updown': 0}),
#  ('IRX4', {'updown': 0}),
#  ('IRX6', {'updown': 0}),
#  ('CCR9', {'updown': 0}),
#  ('IRX3', {'updown': 0}),
#  ('FOXQ1', {'updown': 0}),
#  ('DHX9', {'updown': 0.9983262629}),
#  ('NELFA', {'updown': 0}),
#  ('TCOF1', {'updown': 0}),
#  ('NUP98', {'updown': 0.998171395}),
#  ('XPC', {'updown': 0.9982279941}),
#  ('SP1', {'updown': 0}),
#  ('SP2', {'updown': 0.9983207192}),
#  ('SP3', {'updown': 0.9977402552}),
#  ('NUP93', {'updown': 0.998124705}),
#  ('MUC6', {'updown': 0}),
#  ('PPP2R2C', {'updown': 0.066921332}),
#  ('PPP2R2B', {'updown': 0.0001980956}),
#  ('NUP50', {'updown': 0.0804309583}),
#  ('NMS', {'updown': 0}),
#  ('PRKCE', {'updown': 0.0192675823}),
#  ('MYL12A', {'updown': 0}),
#  ('ORM2', {'updown': 0}),
#  ('HIPK2', {'updown': 0}),
#  ('ELF4', {'updown': 0}),
#  ('MAX', {'updown': 0}),
#  ('PARP14', {'updown': 0.9979182717}),
#  ('MAZ', {'updown': 0}),
#  ('BAK1', {'updown': 0}),
#  ('NRTN', {'updown': 0}),
#  ('CSN2', {'updown': 0}),
#  ('MAF', {'updown': 0}),
#  ('TRAF6', {'updown': 0.8370592376999999}),
#  ('CTBP1', {'updown': 0.9920009536}),
#  ('CTBP2', {'updown': 0}),
#  ('CLDN7', {'updown': 0}),
#  ('KCNJ9', {'updown': 0.9981697931999999}),
#  ('TSG101', {'updown': 0.9970897058}),
#  ('ITGA9', {'updown': 0.9341542440999999}),
#  ('UGCG', {'updown': 0.295934498}),
#  ('ATP2A1', {'updown': 0}),
#  ('ATP2A2', {'updown': 0.0067718861}),
#  ('ATP2A3', {'updown': 0}),
#  ('ITGA1', {'updown': 0.9963752475}),
#  ('ITGA2', {'updown': 0}),
#  ('ITGA3', {'updown': 0.9983257972}),
#  ('ITGA4', {'updown': 0}),
#  ('ITGA5', {'updown': 0}),
#  ('ITGA6', {'updown': 0}),
#  ('ITGA7', {'updown': 0}),
#  ('GTF3C5', {'updown': 0}),
#  ('APOA5', {'updown': 0}),
#  ('PREB', {'updown': 0.9974747366}),
#  ('PHLDA1', {'updown': 0.9973778297}),
#  ('APOA1', {'updown': 0}),
#  ('APOA2', {'updown': 0}),
#  ('PHLDA2', {'updown': 0.0384112582}),
#  ('XPO1', {'updown': 0.9972400568}),
#  ('PPME1', {'updown': 0.5535282563}),
#  ('XPO5', {'updown': 0.993085799}),
#  ('CSDE1', {'updown': 0.9981980108}),
#  ('LILRB1', {'updown': 0}),
#  ('TTR', {'updown': 0}),
#  ('JAM3', {'updown': 0}),
#  ('CSNK2A1', {'updown': 0.124350835}),
#  ('MDK', {'updown': 0.3287100537}),
#  ('MTCP1', {'updown': 0}),
#  ('TTK', {'updown': 0}),
#  ('HRH4', {'updown': 0}),
#  ('GRAP2', {'updown': 0}),
#  ('HRH2', {'updown': 0.9982293176}),
#  ('HRH3', {'updown': 0}),
#  ('RASEF', {'updown': 0}),
#  ('KSR2', {'updown': 0.9982619184}),
#  ('KCNIP4', {'updown': 0.029880542599999997}),
#  ('KCNIP3', {'updown': 0.9981592628}),
#  ('CCNA1', {'updown': 0.865413412}),
#  ('ABCB1', {'updown': 0}),
#  ('PRSS50', {'updown': 0}),
#  ('GRP', {'updown': 0}),
#  ('LIN28B', {'updown': 0}),
#  ('LIN28A', {'updown': 0}),
#  ('TFB2M', {'updown': 0.8134984954000001}),
#  ('COL4A2', {'updown': 0.9974929537}),
#  ('EPS15L1', {'updown': 0.8107874125}),
#  ('ANAPC1', {'updown': 0.0026609141}),
#  ('ANAPC2', {'updown': 0.9983343628}),
#  ('ANAPC5', {'updown': 0.9979583692}),
#  ('ANAPC4', {'updown': 0.9949836848}),
#  ('ANAPC7', {'updown': 0.6355380301}),
#  ('ZEB2', {'updown': 0}),
#  ('ITGAX', {'updown': 0}),
#  ('RPS6KA1', {'updown': 0}),
#  ('RPS6KA2', {'updown': 0}),
#  ('SNRPB2', {'updown': 0}),
#  ('RPS6KA4', {'updown': 0.9980563820999999}),
#  ('RPS6KA6', {'updown': 0}),
#  ('BCL2A1', {'updown': 0}),
#  ('PISD', {'updown': 0.9814712718}),
#  ('TP53I13', {'updown': 0}),
#  ('NOG', {'updown': 0.9950236737999999}),
#  ('PSMD10', {'updown': 0.1075874307}),
#  ('ITGAV', {'updown': 0.9983239264}),
#  ('ATAD2', {'updown': 0.9959835383}),
#  ('FRAT1', {'updown': 0}),
#  ('FRAT2', {'updown': 0}),
#  ('DLAT', {'updown': 0.000106665}),
#  ('GIT1', {'updown': 0}),
#  ('GIT2', {'updown': 0.1360269177}),
#  ('SERBP1', {'updown': 0.9983312109999999}),
#  ('HLF', {'updown': 0.9136728923999999}),
#  ('NOV', {'updown': 0.5010181781}),
#  ('MYO10', {'updown': 0}),
#  ('ITGAD', {'updown': 0}),
#  ('PIK3CB', {'updown': 0.7784415309999999}),
#  ('FOXC1', {'updown': 0}),
#  ('ISL1', {'updown': 0}),
#  ('GHRH', {'updown': 0}),
#  ('CD40LG', {'updown': 0}),
#  ('SMAD9', {'updown': 0.9977643699}),
#  ('NUP133', {'updown': 0.6006088391}),
#  ('SESN3', {'updown': 0}),
#  ('SMAD4', {'updown': 0}),
#  ('SMAD5', {'updown': 0}),
#  ('SMAD6', {'updown': 0}),
#  ('SMAD7', {'updown': 0}),
#  ('SMAD1', {'updown': 0.9949349874}),
#  ('SMAD2', {'updown': 0}),
#  ('SMAD3', {'updown': 0.9961818258}),
#  ('SC5D', {'updown': 0.1604219194}),
#  ('FOXM1', {'updown': 0}),
#  ('NDUFAF2', {'updown': 0.9983266693}),
#  ('RAB10', {'updown': 0.9982672004}),
#  ('IGF2R', {'updown': 0.9983333722}),
#  ('CTH', {'updown': 0.975963218}),
#  ('ARF3', {'updown': 0.0967505977}),
#  ('ARF1', {'updown': 0.4013190505}),
#  ('ARF6', {'updown': 0.9981406845}),
#  ('ARF5', {'updown': 0.070634461}),
#  ('ARF4', {'updown': 0.830598253}),
#  ('CXCR2', {'updown': 0}),
#  ('SERPIND1', {'updown': 0}),
#  ('PRIM1', {'updown': 0.9735268449}),
#  ('EIF4B', {'updown': 0.9955271586}),
#  ('ARTN', {'updown': 0}),
#  ('TCEA2', {'updown': 0.9981563895000001}),
#  ('TCEA3', {'updown': 0}),
#  ('TCEA1', {'updown': 0}),
#  ('RGPD2', {'updown': 0}),
#  ('KDM2A', {'updown': 0}),
#  ('RGPD1', {'updown': 0}),
#  ('RGPD6', {'updown': 0.447408908}),
#  ('PRKAR1A', {'updown': 0.09566175240000001}),
#  ('RGPD4', {'updown': 0}),
#  ('RGPD5', {'updown': 0.9982669581}),
#  ('SAR1A', {'updown': 0.9902988826000001}),
#  ('RGPD8', {'updown': 0}),
#  ('OLIG2', {'updown': 0}),
#  ('OLIG1', {'updown': 0}),
#  ('BDKRB1', {'updown': 0}),
#  ('LOR', {'updown': 0}),
#  ('CD99', {'updown': 0}),
#  ('TRIM62', {'updown': 0}),
#  ('ADCY3', {'updown': 0.9981810989}),
#  ('SENP1', {'updown': 0.9981870891}),
#  ('CD86', {'updown': 0}),
#  ('SPP1', {'updown': 0}),
#  ('CXXC5', {'updown': 0.9983108756}),
#  ('LGALS8', {'updown': 0.0802705866}),
#  ('CDC45', {'updown': 0}),
#  ('CDC40', {'updown': 0.9877592414}),
#  ('CDC42', {'updown': 0.018640359199999998}),
#  ('SP8', {'updown': 0}),
#  ('IFIH1', {'updown': 0.9973652465999999}),
#  ('DPT', {'updown': 0}),
#  ('CBLB', {'updown': 0.9975988545000001}),
#  ('CBLC', {'updown': 0}),
#  ('HMGB2', {'updown': 0.9862456584999999}),
#  ('HMGB1', {'updown': 0.9960995048000001}),
#  ('CPEB3', {'updown': 0.997683042}),
#  ('CPEB2', {'updown': 0.9983344045}),
#  ('PGLYRP3', {'updown': 0}),
#  ('PGLYRP2', {'updown': 0}),
#  ('CACNG6', {'updown': 0}),
#  ('ACRV1', {'updown': 0.9983316823}),
#  ('CHAF1B', {'updown': 0.0020586715}),
#  ('AMHR2', {'updown': 0}),
#  ('BIN1', {'updown': 0}),
#  ('DDAH2', {'updown': 0}),
#  ('FRG2', {'updown': 0}),
#  ('EEA1', {'updown': 0.9974300663}),
#  ('ADORA2B', {'updown': 0}),
#  ('UBTF', {'updown': 0}),
#  ('IFT88', {'updown': 0}),
#  ('ACTA2', {'updown': 0.9982148534999999}),
#  ('CLIP3', {'updown': 0.0268555883}),
#  ('CLIP1', {'updown': 0}),
#  ('SLIT3', {'updown': 0.5477159322}),
#  ('CDCA7', {'updown': 0}),
#  ('SLIT1', {'updown': 0.7724972543}),
#  ('FIP1L1', {'updown': 0.9982464679999999}),
#  ('CDCA8', {'updown': 0}),
#  ('GFAP', {'updown': 0}),
#  ('UTS2', {'updown': 0}),
#  ('CNTF', {'updown': 0}),
#  ('UCN2', {'updown': 0}),
#  ('MND1', {'updown': 0}),
#  ('PPP2R2A', {'updown': 0.9977684298}),
#  ('CD46', {'updown': 0.9982931345999999}),
#  ('CD40', {'updown': 0}),
#  ('RSF1', {'updown': 0}),
#  ('SP5', {'updown': 0}),
#  ('ATG4B', {'updown': 0}),
#  ('FXN', {'updown': 0.9890976686}),
#  ('FGFR1OP', {'updown': 0.033579132000000005}),
#  ('POLR3GL', {'updown': 0}),
#  ('PHOX2A', {'updown': 0}),
#  ('SP7', {'updown': 0}),
#  ('PFKL', {'updown': 0}),
#  ('SMOX', {'updown': 0}),
#  ('REST', {'updown': 0}),
#  ('TCL1B', {'updown': 0}),
#  ('EIF4E3', {'updown': 0.4106209779}),
#  ('SNW1', {'updown': 0.9686255056}),
#  ('TBL1X', {'updown': 0}),
#  ('GPT2', {'updown': 0}),
#  ('CALR', {'updown': 0.997550877}),
#  ('CYB5A', {'updown': 0.9963641769}),
#  ('LOC107984923', {'updown': 0}),
#  ('RALA', {'updown': 0}),
#  ('EWSR1', {'updown': 0.9983066065}),
#  ('WDR77', {'updown': 0.9595839912999999}),
#  ('HLA-DMA', {'updown': 0}),
#  ('TRIM11', {'updown': 0}),
#  ('EFNB2', {'updown': 0.9894742609999999}),
#  ('AAAS', {'updown': 0.9974071774}),
#  ('PCK1', {'updown': 0}),
#  ('HAMP', {'updown': 0.9972858388}),
#  ('AHCTF1', {'updown': 0.9980277879999999}),
#  ('PPP2R3B', {'updown': 0}),
#  ('PPP2R3C', {'updown': 0.9966372240000001}),
#  ('TAS2R5', {'updown': 0}),
#  ('PPP2R3A', {'updown': 0.9981053476}),
#  ('IL12RB1', {'updown': 0}),
#  ('SPRED1', {'updown': 0}),
#  ('SPRED2', {'updown': 0.9975493269}),
#  ('PTHLH', {'updown': 0.2816572782}),
#  ('BRK1', {'updown': 0.9540772206999999}),
#  ('RNF32', {'updown': 0}),
#  ('EFNB1', {'updown': 0}),
#  ('CHI3L1', {'updown': 0}),
#  ('STIM1', {'updown': 0.9696878189}),
#  ('HDAC5', {'updown': 0.9933101051000001}),
#  ('ALX3', {'updown': 0}),
#  ('PIWIL2', {'updown': 0}),
#  ('MAPKAP1', {'updown': 0}),
#  ('FBXO5', {'updown': 0}),
#  ('SLC4A1', {'updown': 0}),
#  ('SIX4', {'updown': 0}),
#  ('PRL', {'updown': 0}),
#  ('SIX6', {'updown': 0}),
#  ('SIX1', {'updown': 0}),
#  ('SIX2', {'updown': 0}),
#  ('SIX3', {'updown': 0}),
#  ('ESRP2', {'updown': 0}),
#  ('ESRP1', {'updown': 0}),
#  ('RELN', {'updown': 0.7349734445999999}),
#  ('HDAC8', {'updown': 0.9979736137}),
#  ('RELB', {'updown': 0.9983294771}),
#  ('RELA', {'updown': 0}),
#  ('HDGF', {'updown': 0}),
#  ('PRX', {'updown': 0}),
#  ('HNRNPA2B1', {'updown': 0}),
#  ('TYRP1', {'updown': 0}),
#  ('DYNC1I1', {'updown': 0.0111532028}),
#  ('RFFL', {'updown': 0}),
#  ('LEFTY2', {'updown': 0}),
#  ('LEFTY1', {'updown': 0.9975101733}),
#  ('SMARCE1', {'updown': 0.9959937616}),
#  ('ESX1', {'updown': 0}),
#  ('KLK2', {'updown': 0}),
#  ('KLK3', {'updown': 0}),
#  ('ZFHX3', {'updown': 0}),
#  ('THOC3', {'updown': 0.37717101229999994}),
#  ('THOC2', {'updown': 0}),
#  ('THOC1', {'updown': 0.9983297535}),
#  ('AL591806.3', {'updown': 0}),
#  ('THOC7', {'updown': 5.39601818484818e-05}),
#  ('THOC6', {'updown': 0}),
#  ('THOC5', {'updown': 0.9975587254}),
#  ('DBI', {'updown': 0}),
#  ('DBH', {'updown': 0}),
#  ('RFX5', {'updown': 0.9982179148999999}),
#  ('APP', {'updown': 0.1172426772}),
#  ('NRXN3', {'updown': 0.0046067671999999995}),
#  ('RFX1', {'updown': 0}),
#  ('RFX2', {'updown': 0}),
#  ('RFX3', {'updown': 0.9932171734999999}),
#  ('TCAP', {'updown': 0}),
#  ('CDON', {'updown': 0.8058654982}),
#  ('ELK1', {'updown': 0}),
#  ('ELK4', {'updown': 0.9903678159999999}),
#  ('APC', {'updown': 0.9981121339}),
#  ('MAVS', {'updown': 0}),
#  ('PAK1', {'updown': 0.0010622401}),
#  ('STRADB', {'updown': 0}),
#  ('STXBP4', {'updown': 0}),
#  ('NUP88', {'updown': 0}),
#  ('FOXP3', {'updown': 0}),
#  ('COPS8', {'updown': 0.0216362173}),
#  ('FOXP1', {'updown': 0}),
#  ('IL10RA', {'updown': 0.9981057720000001}),
#  ('COPS2', {'updown': 0.713610656}),
#  ('COPS3', {'updown': 0.5279088679999999}),
#  ('SMPD2', {'updown': 0}),
#  ('COPS6', {'updown': 0.9978988276999999}),
#  ('NUP85', {'updown': 0.9551047305}),
#  ('COPS4', {'updown': 0.025125908500000002}),
#  ('COPS5', {'updown': 0.3063448426}),
#  ('KRT19', {'updown': 0}),
#  ('HES7', {'updown': 0}),
#  ('MED1', {'updown': 0}),
#  ('MED6', {'updown': 0.5734932008}),
#  ('MED7', {'updown': 0.9877289455}),
#  ('MED4', {'updown': 0.2242964641}),
#  ('MESP1', {'updown': 0.9974985848000001}),
#  ('PINK1', {'updown': 0.9969530305}),
#  ('MED8', {'updown': 0.984022222}),
#  ('MED9', {'updown': 0.9961193295999999}),
#  ('GAST', {'updown': 0}),
#  ('WNT2B', {'updown': 0.9923305444}),
#  ('MYCN', {'updown': 0.9942946077}),
#  ('CBX4', {'updown': 0.6991684815000001}),
#  ('CRY2', {'updown': 0.006186917199999999}),
#  ('AC006486.1', {'updown': 0}),
#  ('MIB1', {'updown': 0}),
#  ('ITIH4', {'updown': 0}),
#  ('DMBT1', {'updown': 0}),
#  ('PRKG1', {'updown': 0}),
#  ('MXD1', {'updown': 0.9983319766}),
#  ('PANK1', {'updown': 0.6778295002}),
#  ('PRKG2', {'updown': 0}),
#  ('PLTP', {'updown': 0}),
#  ('NLK', {'updown': 0.001267025}),
#  ('AKR1C3', {'updown': 0}),
#  ('FDFT1', {'updown': 0.9978727820000001}),
#  ('TNS4', {'updown': 0}),
#  ('IGF2', {'updown': 0}),
#  ('TCF4', {'updown': 0}),
#  ('TCF7', {'updown': 0}),
#  ('IGF1', {'updown': 0}),
#  ('TCF3', {'updown': 0}),
#  ('DLD', {'updown': 0.10458210130000001}),
#  ('ARID2', {'updown': 0}),
#  ('GCK', {'updown': 0}),
#  ('SPRR3', {'updown': 0}),
#  ('PMEPA1', {'updown': 0}),
#  ('IGFBP2', {'updown': 0.2142202246}),
#  ('IGFBP3', {'updown': 0}),
#  ('IGFBP1', {'updown': 0}),
#  ('HBE1', {'updown': 0}),
#  ('IGFBP7', {'updown': 0.9980200373999999}),
#  ('IGFBP4', {'updown': 0.9981059254000001}),
#  ('IGFBP5', {'updown': 0}),
#  ('NLRP1', {'updown': 0.8187841209000001}),
#  ('AFP', {'updown': 0}),
#  ('EIF5A2', {'updown': 0.0464611879}),
#  ('GJA1', {'updown': 0}),
#  ('APLNR', {'updown': 0}),
#  ('NLRP3', {'updown': 0.9835519343000001}),
#  ('DEPP1', {'updown': 0}),
#  ('CYP8B1', {'updown': 0}),
#  ('ATP5F1B', {'updown': 0}),
#  ('MEF2C', {'updown': 0.9980994378}),
#  ('TRIM8', {'updown': 0}),
#  ('MEF2A', {'updown': 0.9422443632999999}),
#  ('PFN3', {'updown': 0}),
#  ('PFN4', {'updown': 0}),
#  ('CREM', {'updown': 0}),
#  ('BTC', {'updown': 0}),
#  ('MEF2D', {'updown': 0.9983339051000001}),
#  ('GAS1', {'updown': 0}),
#  ('TRIM3', {'updown': 0.9950794359999999}),
#  ('KDM3A', {'updown': 0}),
#  ('PROC', {'updown': 0}),
#  ('DNAJB1', {'updown': 0}),
#  ('BTK', {'updown': 0}),
#  ('SSB', {'updown': 0.9983286998}),
#  ('NUTF2', {'updown': 0.9966159879}),
#  ('NSL1', {'updown': 0}),
#  ('PDGFRA', {'updown': 0}),
#  ('MFNG', {'updown': 0}),
#  ('HIST1H4C', {'updown': 0}),
#  ('LGR4', {'updown': 0.9982864279000001}),
#  ('TEX15', {'updown': 0}),
#  ('EIF2B4', {'updown': 0}),
#  ('EIF2B5', {'updown': 0.9975047734}),
#  ('EIF2B2', {'updown': 0.9983014531000001}),
#  ('EIF2B3', {'updown': 0.0206690314}),
#  ('EIF2B1', {'updown': 0.00037454769999999994}),
#  ('PRKAR2A', {'updown': 0}),
#  ('COL24A1', {'updown': 0.9923886476999999}),
#  ('PRKAR2B', {'updown': 0.8567535058}),
#  ('PPA1', {'updown': 0.9916711718000001}),
#  ('S1PR4', {'updown': 0}),
#  ('HIST1H4B', {'updown': 0}),
#  ('FANCF', {'updown': 0.8521566838}),
#  ('MECOM', {'updown': 0}),
#  ('ITGA2B', {'updown': 0.998313517}),
#  ('TPM3', {'updown': 0.5916081878}),
#  ('IFI16', {'updown': 0}),
#  ('TRADD', {'updown': 0}),
#  ('RPS6KB2', {'updown': 0}),
#  ('THYN1', {'updown': 0.34548252659999995}),
#  ('JCHAIN', {'updown': 0}),
#  ('TNFRSF6B', {'updown': 0}),
#  ('FBXW7', {'updown': 0.9975545465000001}),
#  ('TGFBR3', {'updown': 0}),
#  ('TGFBR2', {'updown': 0}),
#  ('TGFBR1', {'updown': 0.9969978892}),
#  ('NTF3', {'updown': 0}),
#  ('NUP107', {'updown': 0.9979594993}),
#  ('TET1', {'updown': 0}),
#  ('TET2', {'updown': 0}),
#  ('UPP1', {'updown': 0.9955004195999999}),
#  ('ARAP1', {'updown': 0}),
#  ('FOXL2', {'updown': 0}),
#  ('FOXL1', {'updown': 0}),
#  ('RPS4X', {'updown': 0}),
#  ('RHPN1', {'updown': 0.9981123379000001}),
#  ('FSD1L', {'updown': 0.9961195971}),
#  ('CXADR', {'updown': 0.9982862088}),
#  ('CYP24A1', {'updown': 0}),
#  ('AGTR2', {'updown': 0}),
#  ('YOD1', {'updown': 0.9982454208}),
#  ('RAB14', {'updown': 0.19309164129999998}),
#  ('MFN2', {'updown': 0.9933334359}),
#  ('TCP1', {'updown': 0.9936181156999999}),
#  ('PRG4', {'updown': 0}),
#  ('FANCI', {'updown': 0.6911805320000001}),
#  ('BABAM2', {'updown': 0}),
#  ('F2RL1', {'updown': 0}),
#  ('TNFSF4', {'updown': 0}),
#  ('XAB2', {'updown': 0.9972350391}),
#  ('MAD2L2', {'updown': 0}),
#  ('VMP1', {'updown': 0.134673375}),
#  ('MAD2L1', {'updown': 0.00047801010000000005}),
#  ('MYL9', {'updown': 0}),
#  ('PRDX4', {'updown': 0.9981005823000001}),
#  ('PRDX3', {'updown': 0.7445538467}),
#  ('PRDX1', {'updown': 0}),
#  ('NFYC', {'updown': 0.9870152151999999}),
#  ('NFYB', {'updown': 0}),
#  ('NFYA', {'updown': 0}),
#  ('BAZ2A', {'updown': 0}),
#  ('MYBL1', {'updown': 0}),
#  ('SMOC2', {'updown': 0}),
#  ('SMARCA2', {'updown': 0.0046147772}),
#  ('MYBL2', {'updown': 0}),
#  ('SMARCA5', {'updown': 0.9973533264}),
#  ('PPP1R17', {'updown': 0}),
#  ('AXIN2', {'updown': 0.9977068822}),
#  ('AXIN1', {'updown': 0}),
#  ('CTCFL', {'updown': 0}),
#  ('FYN', {'updown': 0}),
#  ('RAB1A', {'updown': 0.1970355578}),
#  ('ZAP70', {'updown': 0}),
#  ('IDE', {'updown': 0.99814714}),
#  ('SULT2A1', {'updown': 0}),
#  ('ST3GAL3', {'updown': 0.2925102999}),
#  ('ST3GAL2', {'updown': 0.9975226926999999}),
#  ('CSTA', {'updown': 0}),
#  ('RAC2', {'updown': 0.9947886565999999}),
#  ('RAC3', {'updown': 0.9403318369}),
#  ('ST3GAL5', {'updown': 0.2485472011}),
#  ('RAC1', {'updown': 0}),
#  ('NINJ1', {'updown': 0}),
#  ('FCGR2B', {'updown': 0}),
#  ('LNPEP', {'updown': 0.9635281729999999}),
#  ('APOE', {'updown': 0}),
#  ('SKIL', {'updown': 0}),
#  ('MED23', {'updown': 0.38586861310000004}),
#  ('GCGR', {'updown': 0}),
#  ('VASP', {'updown': 0}),
#  ('PBX2', {'updown': 0.9971324276000001}),
#  ('PBX3', {'updown': 0}),
#  ('LILRB2', {'updown': 0}),
#  ('LGMN', {'updown': 0.3807687398}),
#  ('CYP7B1', {'updown': 0}),
#  ('AIRE', {'updown': 0}),
#  ('SPAST', {'updown': 0.9982801562000001}),
#  ('CALCR', {'updown': 0}),
#  ('KATNB1', {'updown': 0.7735204061}),
#  ('AGR2', {'updown': 0}),
#  ('PRDM4', {'updown': 0.9977320306}),
#  ('SLC16A7', {'updown': 0}),
#  ('BACH2', {'updown': 0.9978139759}),
#  ('PTCH2', {'updown': 0.9980587948}),
#  ('CALCA', {'updown': 0}),
#  ('PTCH1', {'updown': 0}),
#  ('CMKLR1', {'updown': 0}),
#  ('PAGR1', {'updown': 0}),
#  ('LYVE1', {'updown': 0.9955721962}),
#  ('CKM', {'updown': 0}),
#  ('RAD9A', {'updown': 0.9963512281999999}),
#  ('KMT5A', {'updown': 0}),
#  ('CD34', {'updown': 0}),
#  ('PTGS1', {'updown': 0}),
#  ('CD36', {'updown': 0}),
#  ('POLR3F', {'updown': 0.3430328747}),
#  ('POLR3G', {'updown': 0}),
#  ('POLR3D', {'updown': 0.9959517578}),
#  ('POLR3E', {'updown': 0}),
#  ('POLR3B', {'updown': 0.0871250573}),
#  ('POLR3C', {'updown': 0.0757845876}),
#  ('POLR3A', {'updown': 0.0249297063}),
#  ('B3GAT3', {'updown': 0.9968912874}),
#  ('DAP', {'updown': 0}),
#  ('POLR3K', {'updown': 0.0346584637}),
#  ('POLR3H', {'updown': 0}),
#  ('DCN', {'updown': 0}),
#  ('UXT', {'updown': 0}),
#  ('GPAM', {'updown': 0}),
#  ('CALM2', {'updown': 0.2217373305}),
#  ('CALM3', {'updown': 0.0225489269}),
#  ('CACNA1A', {'updown': 0.9982546318000001}),
#  ('CACNA1B', {'updown': 0.5016029475}),
#  ('DNMT1', {'updown': 0}),
#  ('CACNA1D', {'updown': 0.9978589142000001}),
#  ('CACNA1F', {'updown': 0}),
#  ('THRA', {'updown': 0}),
#  ('CDX1', {'updown': 0}),
#  ('TAF4B', {'updown': 0.1060893972}),
#  ('PERP', {'updown': 0}),
#  ('CYP51A1', {'updown': 0.9196338632}),
#  ('GLO1', {'updown': 0.3139034935}),
#  ('CACNA1S', {'updown': 0}),
#  ('WTAP', {'updown': 0.9885000127}),
#  ('CUL1', {'updown': 0.8907705844}),
#  ('CUL3', {'updown': 0.9964526204999999}),
#  ('FCAR', {'updown': 0}),
#  ('PLK2', {'updown': 0.0010715554}),
#  ('HOXD8', {'updown': 0}),
#  ('TRIM29', {'updown': 0}),
#  ('TRIM24', {'updown': 0.9946437407}),
#  ('CLCN2', {'updown': 0}),
#  ('CREB5', {'updown': 0}),
#  ('PRMT1', {'updown': 0.9983341275}),
#  ('CLCN7', {'updown': 0}),
#  ('PRMT7', {'updown': 0.8728202673000001}),
#  ('CREB1', {'updown': 0.9976453978000001}),
#  ('PRMT5', {'updown': 0.9446204290000001}),
#  ('PER3', {'updown': 0.9969668909}),
#  ('BGLAP', {'updown': 0.9977856995000001}),
#  ('PER1', {'updown': 0}),
#  ('BRD4', {'updown': 0}),
#  ('BRD7', {'updown': 0}),
#  ('BRD1', {'updown': 0.9983292337}),
#  ('BRD2', {'updown': 0}),
#  ('CARHSP1', {'updown': 0}),
#  ('KAT8', {'updown': 0}),
#  ('DNAJA3', {'updown': 0.24466785829999999}),
#  ('DNAJA1', {'updown': 0.9974647418000001}),
#  ('ORMDL3', {'updown': 0}),
#  ('FCER2', {'updown': 0}),
#  ('PTPN13', {'updown': 0}),
#  ('PTPN12', {'updown': 0}),
#  ('KIF5B', {'updown': 0}),
#  ('NPY1R', {'updown': 0.9974435438}),
#  ('KAT5', {'updown': 0.9974889565999999}),
#  ('MASP2', {'updown': 0}),
#  ('KAT7', {'updown': 0.28386440329999996}),
#  ('GALR3', {'updown': 0}),
#  ('F2R', {'updown': 0}),
#  ('IHH', {'updown': 0}),
#  ('UTRN', {'updown': 0.9983194134000001}),
#  ('RAD51C', {'updown': 0.07427689900000001}),
#  ('CD3D', {'updown': 0}),
#  ('CD3E', {'updown': 0}),
#  ('CH25H', {'updown': 0.9519326284999999}),
#  ('CSF2RB', {'updown': 0}),
#  ('AES', {'updown': 0.9982631651999999}),
#  ('SLBP', {'updown': 0.4878188897}),
#  ('DMD', {'updown': 0}),
#  ('SEH1L', {'updown': 0.1788981288}),
#  ('GNAO1', {'updown': 0.9966049156}),
#  ('RRAS2', {'updown': 0}),
#  ('GAB2', {'updown': 0}),
#  ('GAPDH', {'updown': 0.9290688067}),
#  ('HIF1A', {'updown': 0.9972435672}),
#  ('GAB1', {'updown': 0}),
#  ('NKX2-2', {'updown': 0}),
#  ('HAX1', {'updown': 0.9426919778}),
#  ('IFNGR1', {'updown': 0}),
#  ('IFNGR2', {'updown': 0.9982397603000001}),
#  ('CD200', {'updown': 0.0011286503999999998}),
#  ('NDRG1', {'updown': 0}),
#  ('NDRG2', {'updown': 0}),
#  ('CMIP', {'updown': 0.5117929008}),
#  ('ACADM', {'updown': 0.9077393811}),
#  ('SRSF5', {'updown': 0.9693120000000001}),
#  ('SRSF4', {'updown': 0}),
#  ('SRSF7', {'updown': 0.9494869687}),
#  ('PPM1D', {'updown': 0.9959243749}),
#  ('SRSF1', {'updown': 0.9982161129000001}),
#  ('HMOX1', {'updown': 0}),
#  ('SRSF3', {'updown': 0.9983165003}),
#  ('SRSF2', {'updown': 0.392622481}),
#  ('EGR2', {'updown': 0}),
#  ('C4BPA', {'updown': 0}),
#  ('C4BPB', {'updown': 0}),
#  ('EGR1', {'updown': 0.014227599399999999}),
#  ('SRSF9', {'updown': 0.9975054518}),
#  ('PPARGC1A', {'updown': 0.7734875381}),
#  ('EGR4', {'updown': 0.7955530728}),
#  ('USP42', {'updown': 0}),
#  ('RAPH1', {'updown': 0.5267685177}),
#  ('PRLH', {'updown': 0}),
#  ('HOXA4', {'updown': 0}),
#  ('RNF135', {'updown': 0}),
#  ('CX3CL1', {'updown': 0.7843462117000001}),
#  ('HOXA3', {'updown': 0}),
#  ('MAFG', {'updown': 0}),
#  ('CHEK2', {'updown': 0}),
#  ('CHEK1', {'updown': 0}),
#  ('PRKAB2', {'updown': 0.9983318389}),
#  ('CDK6', {'updown': 0}),
#  ('PRKAB1', {'updown': 0.9982370429999999}),
#  ('TSHZ3', {'updown': 0.9862556401000001}),
#  ('CDK11A', {'updown': 0}),
#  ('PAX5', {'updown': 0}),
#  ('PAX4', {'updown': 0}),
#  ('PAX7', {'updown': 0}),
#  ('PAX6', {'updown': 0}),
#  ('PAX1', {'updown': 0}),
#  ('NCAPD2', {'updown': 0}),
#  ('PAX3', {'updown': 0}),
#  ('PAX2', {'updown': 0}),
#  ('PTPN2', {'updown': 0.9982842082}),
#  ('PTPN1', {'updown': 0.9967329991}),
#  ('PAXIP1', {'updown': 0}),
#  ('PAX9', {'updown': 0}),
#  ('PTPN6', {'updown': 0}),
#  ('PROK1', {'updown': 0}),
#  ('DDR2', {'updown': 0}),
#  ('ATP5PF', {'updown': 0}),
#  ('DDR1', {'updown': 0}),
#  ('CYP2E1', {'updown': 0.8967996691}),
#  ('EDN3', {'updown': 0}),
#  ('STUB1', {'updown': 0}),
#  ('NNMT', {'updown': 0.9982966163}),
#  ('EIF4EBP1', {'updown': 0}),
#  ('NPBWR2', {'updown': 0}),
#  ('EIF4EBP3', {'updown': 0}),
#  ('EIF4EBP2', {'updown': 0}),
#  ('BAG3', {'updown': 0}),
#  ('HIST2H3A', {'updown': 0}),
#  ('GRK2', {'updown': 0.9869930661}),
#  ('SH2D1A', {'updown': 0}),
#  ('CTDP1', {'updown': 0}),
#  ('CNTFR', {'updown': 0}),
#  ('ADAMTS13', {'updown': 0}),
#  ('AMOTL2', {'updown': 0}),
#  ('RPS3', {'updown': 0}),
#  ('ADAMTS16', {'updown': 0}),
#  ('VDAC1', {'updown': 0.0079682142}),
#  ('CENPM', {'updown': 0}),
#  ('CD79B', {'updown': 0}),
#  ('MEOX1', {'updown': 0}),
#  ('BCR', {'updown': 0}),
#  ('CD79A', {'updown': 0}),
#  ('ADORA1', {'updown': 0}),
#  ('SLC34A1', {'updown': 0}),
#  ('CRTC2', {'updown': 0}),
#  ('PGBD3', {'updown': 0}),
#  ('DHX58', {'updown': 0.9981614239}),
#  ('ZEB1', {'updown': 0}),
#  ('ZNF385A', {'updown': 0}),
#  ('LCN2', {'updown': 0}),
#  ('HOXA13', {'updown': 0}),
#  ('GPNMB', {'updown': 0}),
#  ('HOXA11', {'updown': 0}),
#  ('HOXA10', {'updown': 0}),
#  ('PPBP', {'updown': 0}),
#  ('RASGRF2', {'updown': 0.6565029521}),
#  ('KRT12', {'updown': 0}),
#  ('DSG2', {'updown': 0}),
#  ('USP2', {'updown': 0.9982091034}),
#  ('DSG4', {'updown': 0}),
#  ('CAPN2', {'updown': 0}),
#  ('HMGCS1', {'updown': 0.0035198}),
#  ('HMGCS2', {'updown': 0}),
#  ('PDHA1', {'updown': 0.2717698371}),
#  ('SRF', {'updown': 0.9958308734}),
#  ('SAP18', {'updown': 0}),
#  ('FBXO43', {'updown': 0}),
#  ('LGALS9', {'updown': 0}),
#  ('RPS6KA3', {'updown': 0.9848461433}),
#  ('LGALS3', {'updown': 0}),
#  ('KCNH1', {'updown': 0}),
#  ('LGALS1', {'updown': 0.9967049043999999}),
#  ('CP', {'updown': 0.9983018179}),
#  ('FSCN3', {'updown': 0}),
#  ('PIR', {'updown': 0}),
#  ('FSCN1', {'updown': 0.9983150157999999}),
#  ('LGALS4', {'updown': 0}),
#  ('SFRP2', {'updown': 0}),
#  ('KCNJ2', {'updown': 0}),
#  ('EPHA1', {'updown': 0}),
#  ('SFRP1', {'updown': 0}),
#  ('MYL12B', {'updown': 0.6822300292}),
#  ('AKIRIN1', {'updown': 0.9983308093000001}),
#  ('NUP54', {'updown': 0.7202087528}),
#  ('EIF2AK1', {'updown': 0.8689653902}),
#  ('EIF2AK3', {'updown': 0.9948534945999999}),
#  ('EIF2AK2', {'updown': 0.9977510828}),
#  ('EIF2AK4', {'updown': 0}),
#  ('ADRB2', {'updown': 0}),
#  ('CD247', {'updown': 0.9966549147}),
#  ('COL1A2', {'updown': 0}),
#  ('EREG', {'updown': 0}),
#  ('COL1A1', {'updown': 0}),
#  ('ELN', {'updown': 0}),
#  ('ASAP1', {'updown': 0.7856786309}),
#  ('ASAP2', {'updown': 0.9981618718}),
#  ('NMI', {'updown': 0.9980442076999999}),
#  ('IDO1', {'updown': 0}),
#  ('CAMK1G', {'updown': 0.2282715455}),
#  ('PLAUR', {'updown': 0}),
#  ('NLRP12', {'updown': 0}),
#  ('FCGR3A', {'updown': 0.995743814}),
#  ('ECM1', {'updown': 0.26806564969999996}),
#  ('FOXO3', {'updown': 0.9948796882}),
#  ('FOXO1', {'updown': 0}),
#  ('CD28', {'updown': 0}),
#  ('TOP1', {'updown': 0}),
#  ('FOXO4', {'updown': 0}),
#  ('ALDH1A1', {'updown': 0.8167799423000001}),
#  ('ALDH1A2', {'updown': 0}),
#  ('HIST4H4', {'updown': 0}),
#  ('PHLPP1', {'updown': 0}),
#  ('DEFB4A', {'updown': 0}),
#  ('TAC1', {'updown': 0.0009746907000000001}),
#  ('TNIK', {'updown': 0.9978993412}),
#  ('TAC3', {'updown': 0.22223278600000002}),
#  ('NCOA6', {'updown': 0.9945007787000001}),
#  ('SLCO4C1', {'updown': 0}),
#  ('RGS4', {'updown': 0.0001708871}),
#  ('RGS5', {'updown': 0.9960187798000001}),
#  ('RGS6', {'updown': 0.6284527713}),
#  ('RGS1', {'updown': 0}),
#  ('ATG5', {'updown': 0.8783319781000001}),
#  ('EEF2K', {'updown': 0}),
#  ('SOX5', {'updown': 0}),
#  ('PLAG1', {'updown': 0}),
#  ('C9orf24', {'updown': 0.9980059077}),
#  ('EYA2', {'updown': 0}),
#  ('SMARCB1', {'updown': 0.9982912134}),
#  ('UTP20', {'updown': 0.9944267553}),
#  ('ITGB6', {'updown': 0}),
#  ('PIGR', {'updown': 0}),
#  ('ILKAP', {'updown': 0}),
#  ('HPN', {'updown': 0}),
#  ('WRAP53', {'updown': 0}),
#  ('EPCAM', {'updown': 0}),
#  ('TAGLN', {'updown': 0.9980514353000001}),
#  ('OSTF1', {'updown': 0.9135393004000001}),
#  ('PPP1CB', {'updown': 0.9928010631}),
#  ('PPP1CC', {'updown': 0}),
#  ('OLR1', {'updown': 0.9982973597}),
#  ('PPP1CA', {'updown': 0.9895956886}),
#  ('SRRM1', {'updown': 0.9969412685}),
#  ('BBIP1', {'updown': 0.9982448576}),
#  ('GABARAPL2', {'updown': 0.9965042801999999}),
#  ('ITGAE', {'updown': 0.9954297934}),
#  ('PDK2', {'updown': 0.9816131320999999}),
#  ('PDK4', {'updown': 0}),
#  ('COL6A1', {'updown': 0}),
#  ('PCLAF', {'updown': 0}),
#  ('WBP1', {'updown': 0.9978116854000001}),
#  ('COL6A2', {'updown': 0}),
#  ('DOK1', {'updown': 0}),
#  ('HAVCR2', {'updown': 0}),
#  ('ALPL', {'updown': 0.9983087826}),
#  ('PTGS2', {'updown': 0}),
#  ('PECR', {'updown': 0.7522820615000001}),
#  ('SH2B3', {'updown': 0.9971935962999999}),
#  ('FXYD1', {'updown': 0}),
#  ('ZFAND5', {'updown': 0.41998358880000003}),
#  ('MAFK', {'updown': 0}),
#  ('SV2B', {'updown': 0.37586622560000005}),
#  ('FABP5', {'updown': 0.9060470456999999}),
#  ('MAFA', {'updown': 0}),
#  ('MAFB', {'updown': 0.9146237426}),
#  ('PFKP', {'updown': 0}),
#  ('PLIN2', {'updown': 0}),
#  ('CDK2AP1', {'updown': 0}),
#  ('ZYX', {'updown': 0.9951735003}),
#  ('PLIN1', {'updown': 0}),
#  ('MED10', {'updown': 0.0425027272}),
#  ('TRERF1', {'updown': 0.9937873446}),
#  ('MED11', {'updown': 0}),
#  ('CCR3', {'updown': 0}),
#  ('HIF1AN', {'updown': 0.9921184534}),
#  ('RBPJ', {'updown': 0}),
#  ('GHRL', {'updown': 0}),
#  ('NTRK1', {'updown': 0}),
#  ('NTRK2', {'updown': 0}),
#  ('NTRK3', {'updown': 0}),
#  ('HSP90AB1', {'updown': 0.0446418917}),
#  ('ARHGAP22', {'updown': 0}),
#  ('COP1', {'updown': 0}),
#  ('PTP4A1', {'updown': 0.0014600876}),
#  ('PTP4A3', {'updown': 0.997588114}),
#  ('MED14', {'updown': 0.006268524}),
#  ('LIN37', {'updown': 0.997142463}),
#  ('BLNK', {'updown': 0}),
#  ('CD8A', {'updown': 0.1497443284}),
#  ('KCNMB1', {'updown': 0}),
#  ('DDIT3', {'updown': 0.985037684}),
#  ('DDIT4', {'updown': 0}),
#  ('MED16', {'updown': 0}),
#  ('CCR4', {'updown': 0}),
#  ('BMP6', {'updown': 0.9971360362}),
#  ('OPRL1', {'updown': 0.9904169975}),
#  ('CCR10', {'updown': 0.9916485971}),
#  ('IFI35', {'updown': 0}),
#  ('CD27', {'updown': 0}),
#  ('IFI30', {'updown': 0}),
#  ('VAPB', {'updown': 0.9983186118999999}),
#  ('RBP1', {'updown': 0.9983120656000001}),
#  ('RBP2', {'updown': 0}),
#  ('BMP4', {'updown': 0.9917536427}),
#  ('VAPA', {'updown': 0.9931029722}),
#  ('MYSM1', {'updown': 0.00445}),
#  ('CEBPZ', {'updown': 0}),
#  ('MBTPS2', {'updown': 9.35968105310016e-05}),
#  ('PA2G4', {'updown': 0.0326631877}),
#  ('KRAS', {'updown': 0.0166612982}),
#  ('BMP7', {'updown': 0}),
#  ('SOCS4', {'updown': 0}),
#  ('BMP5', {'updown': 0}),
#  ('SOCS6', {'updown': 0.9940597318000001}),
#  ('SOCS1', {'updown': 0}),
#  ('BMP2', {'updown': 0}),
#  ('SOCS3', {'updown': 0}),
#  ('SOCS2', {'updown': 0.997661204}),
#  ('PPP2CA', {'updown': 0.0036965121000000004}),
#  ('EIF4G2', {'updown': 0.9945829289}),
#  ('SGO1', {'updown': 0}),
#  ('PPP2CB', {'updown': 0}),
#  ('WDR59', {'updown': 0}),
#  ('ADAM9', {'updown': 0.1992908564}),
#  ('TERF2', {'updown': 0.949711168}),
#  ('NR1I2', {'updown': 0}),
#  ('FAT1', {'updown': 0}),
#  ('TERF1', {'updown': 0.9983116178}),
#  ('ULBP2', {'updown': 0}),
#  ('DOK5', {'updown': 0.9983204979000001}),
#  ('GRB7', {'updown': 0}),
#  ('SGO2', {'updown': 0}),
#  ('DLK1', {'updown': 0}),
#  ('PSG4', {'updown': 0}),
#  ('PSG5', {'updown': 0}),
#  ('CCNH', {'updown': 0.9449668653}),
#  ('EIF4G1', {'updown': 0}),
#  ('CCNK', {'updown': 0.9972153953}),
#  ('HOXC9', {'updown': 0}),
#  ('HTR5A', {'updown': 0.0017398331}),
#  ('CCR6', {'updown': 0}),
#  ('IL20RB', {'updown': 0}),
#  ('RASSF1', {'updown': 0}),
#  ('RPL7', {'updown': 0}),
#  ('HP', {'updown': 0}),
#  ('BCL2L2-PABPN1', {'updown': 0}),
#  ('LRPPRC', {'updown': 0.0007654324000000001}),
#  ('HOXC6', {'updown': 0}),
#  ('GREM1', {'updown': 0.9983032998}),
#  ('FEN1', {'updown': 0.6873528661}),
#  ('E2F8', {'updown': 0}),
#  ('THAP11', {'updown': 0.9946792356999999}),
#  ('RSAD2', {'updown': 0.9871207817000001}),
#  ('NCKAP1', {'updown': 0.8697633765999999}),
#  ('NR1I3', {'updown': 0}),
#  ('CHD3', {'updown': 0.9943307793}),
#  ('SLC40A1', {'updown': 0.9982455290000001}),
#  ('CHD4', {'updown': 0}),
#  ('CHD7', {'updown': 0}),
#  ('PTH', {'updown': 0}),
#  ('WISP2', {'updown': 0}),
#  ('CHD8', {'updown': 0}),
#  ('WISP1', {'updown': 0}),
#  ('MNT', {'updown': 0.9823662104}),
#  ('CCNF', {'updown': 0.9956077078}),
#  ('ESRRG', {'updown': 0.47063172119999996}),
#  ('SUPT16H', {'updown': 0.9597538354999999}),
#  ('GRB2', {'updown': 0.8725740861}),
#  ('TGFB1I1', {'updown': 0}),
#  ('IL22RA1', {'updown': 0}),
#  ('PTS', {'updown': 0.4198486566}),
#  ('TTC5', {'updown': 0.9980461699}),
#  ('OXER1', {'updown': 0}),
#  ('SLC22A5', {'updown': 0.9983265653}),
#  ('RAB3GAP2', {'updown': 0.6859965218}),
#  ('IL4R', {'updown': 0}),
#  ('BHLHA15', {'updown': 0}),
#  ('RAB3GAP1', {'updown': 0.22629240239999998}),
#  ('CDC25C', {'updown': 0}),
#  ('CDC25B', {'updown': 0}),
#  ('CDC25A', {'updown': 0}),
#  ('CCNC', {'updown': 0.00036814949999999997}),
#  ('TTC8', {'updown': 0.8531069243000001}),
#  ('ARPC5', {'updown': 0.9979815287}),
#  ('ARPC4', {'updown': 0.9956843104}),
#  ('POLR2E', {'updown': 0.9425854785}),
#  ('POLR2D', {'updown': 0.5485678113}),
#  ('POLR2G', {'updown': 0.9955361267}),
#  ('POLR2F', {'updown': 0}),
#  ('ANKRD23', {'updown': 0}),
#  ('DAG1', {'updown': 0}),
#  ('POLR2C', {'updown': 0.598786873}),
#  ('POLR2B', {'updown': 0.7877976979000001}),
#  ('ACO1', {'updown': 0.9978624671999999}),
#  ('POLR2L', {'updown': 0.9972273596}),
#  ('PTGES', {'updown': 0.9967052676}),
#  ('ITPR1', {'updown': 0.0110083874}),
#  ('POLR2I', {'updown': 0}),
#  ('POLR2K', {'updown': 0.0552698346}),
#  ('POLR2J', {'updown': 0}),
#  ('INHA', {'updown': 0.9953473979}),
#  ('IL1RN', {'updown': 0}),
#  ('ABCG2', {'updown': 0.9983256424}),
#  ('PRDM15', {'updown': 0.9974280549}),
#  ('DEPTOR', {'updown': 0.9983339889}),
#  ('ABCG5', {'updown': 0}),
#  ('LRIG1', {'updown': 0}),
#  ('PLSCR1', {'updown': 0.9982057797}),
#  ('ABCG8', {'updown': 0}),
#  ('MPO', {'updown': 0}),
#  ('MPL', {'updown': 0}),
#  ('HNF4A', {'updown': 0}),
#  ('CFTR', {'updown': 0}),
#  ('GTF3A', {'updown': 0}),
#  ('MTTP', {'updown': 0}),
#  ('SNCA', {'updown': 0.1784017293}),
#  ('AIFM2', {'updown': 0.9982591976999999}),
#  ('AGO4', {'updown': 0.9982490852}),
#  ('RNF125', {'updown': 0}),
#  ('AIFM1', {'updown': 0.9890526622}),
#  ('AGO1', {'updown': 0}),
#  ('AGO3', {'updown': 0}),
#  ('AGO2', {'updown': 0.9967670029000001}),
#  ('IL20RA', {'updown': 0}),
#  ('SOST', {'updown': 0}),
#  ('SSPN', {'updown': 0}),
#  ('HOXC8', {'updown': 0}),
#  ('ACAN', {'updown': 0}),
#  ('SLK', {'updown': 0.9974484958}),
#  ('HCFC1', {'updown': 0}),
#  ('CKS1B', {'updown': 0}),
#  ('MAPK14', {'updown': 0.9825553481}),
#  ('KRIT1', {'updown': 0.5001999853}),
#  ('FOXH1', {'updown': 0}),
#  ('MAPK10', {'updown': 0.08832136789999999}),
#  ...]

# %% [markdown]
# Our package also has a function to load your entire DEG file into a networkx graph, without filtering by p-value or fold change. This function will return a networkx graph representation of your entire specified csv file, a dictionary mapping genes to their (adj) p-values, and a dictionary mapping genes to their (log) fold change

# %% [markdown]
# ## Data Analysis
# <a id='stat'></a>

# %% [markdown]
# Our stat_analysis package can help identify TF's that are statistically significant to our set of DEG's.

# %% [markdown]
# ### Enrichment
# <a id='pvalue'></a>

# %% [markdown]
# Given you have run the appropriate prerequisite functions, you can now start to anaylize your data! First, we check how enriched our set of TF's are. All of our p-value functions calculate the log of the p-value using [scipy.stats.hypergeom.logsf](https://docs.scipy.org/doc/scipy-0.19.1/reference/generated/scipy.stats.hypergeom.html).

# %%
# Enrichment of TF's themselves
ura.tf_enrichment_calc()   
ura.get('tf_enrichment')
# Out:
# TF_ENRICHMENT    2.780709e-11
# dtype: float64

# %% [markdown]
# Next we can check how enriched each TF's targets are.  These values help us determine which TF's are actually associated with our DEG's.
# - high value = significant connection between this TF and its DEG targets
# - low value = TF is randomly associated with its DEG targets
# - zero = None of this TF's targets were DEG's
# - inf = original p-value was so small that its log is inf. Very high significance.
#
# This function may need a minute or so.

# %%
# Enrichment of every TF with respect to its targets
ura.tf_target_enrichment_calc()
tf_target_pvalues = ura.get('tf_target_enrichment')

# %%
df = tf_target_pvalues.to_frame()
df = df.loc[df['tf-target enrichment'] != 0]
df = df.loc[df['tf-target enrichment'] != float('inf')] # removing zeros and inf's for the sake of visualization
display(df)
# Out:
#          tf-target enrichment
# AAAS             2.318940e+01
# RAE1             2.046113e+01
# NUP50            2.027962e+01
# TPR              1.969837e+01
# ELL              1.868296e+01
# RANBP2           1.787164e+01
# NUP37            1.710537e+01
# NFRKB            1.518768e+01
# NCBP2            1.482566e+01
# NUP133           1.451324e+01
# U2AF1            1.297180e+01
# U2AF2            1.297180e+01
# CPSF4            1.276926e+01
# WASL             1.261213e+01
# UPF3B            1.129443e+01
# RNPS1            1.129443e+01
# ZC3H11A          1.129443e+01
# GEMIN5           1.056718e+01
# CDC40            1.056718e+01
# EIF4A3           1.056718e+01
# THOC3            1.056718e+01
# DHX38            1.056718e+01
# POLDIP3          1.056718e+01
# THOC6            1.056718e+01
# SRSF1            1.045660e+01
# POLR2I           9.875268e+00
# NXF5             9.820550e+00
# NRF1             9.449935e+00
# DDX20            9.446466e+00
# GTF2F1           9.134382e+00
# ...                       ...
# STAT3            4.451035e-03
# EHMT1            4.260867e-03
# WWOX             4.158370e-03
# STAT1            4.109819e-03
# AHR              4.102795e-03
# KLF5             3.903719e-03
# FGF9             3.701865e-03
# RBPJ             3.277529e-03
# NKX2-1           2.764636e-03
# ASCL1            2.601374e-03
# CBX6             2.597696e-03
# PHC3             2.597696e-03
# SOX2             2.020583e-03
# MYD88            1.721799e-03
# NFKB1            1.691173e-03
# CBX8             1.617731e-03
# PPARG            1.357917e-03
# CTF1             1.242158e-03
# SNAI2            1.242158e-03
# JUN              1.202232e-03
# LGALS3           1.139215e-03
# IRF1             9.734038e-04
# FOXP3            8.556866e-04
# POU5F1           3.207386e-04
# TBX21            3.207386e-04
# STAT6            8.847492e-05
# CTGF             4.194707e-05
# TGFB1            4.817496e-06
# GATA3            9.619387e-08
# GPSM1            9.279385e-08
#
# [917 rows x 1 columns]

# %% [markdown]
# ### TF Activation State Prediction
# <a id='zscore'></a>

# %% [markdown]
# The goal of our z-score function is to predict the activation states of the TF's. We observe how a TF relates to each of its targets to make our prediction. We compare each targets' observed gene regulation (either up or down) and each TF-target interation (whether it is activating or inhibiting) to conclude whether a TF is activating or inhibiting. A positive value indicates activating while a negative value indicates inhibiting. A value of zero means that we did not have enough information about the target or TF-target interaction to make the prediction.
#
# Our z-score calculater has to calculation methods. Our method calculates how "biased" the background network is towards either activating or inhibiting interactions, then adjusts its calculations to that non-zero average. Our bias-filter parameter is a number between 0 and 1 that indicates the threshold at which the graph is considered "too biased", and therefore the bias z-score formula must be used.
#
# This function may need a minute or so.

# %%
ura.tf_zscore(bias_filter = 1)
unbiased_zscores = ura.get('z_scores')
display(unbiased_zscores.to_frame())
# Out:
#           unbiased-calculated z-scores
# RANBP2                       12.609520
# NUP133                       12.609520
# NUP37                        12.288206
# XPO1                         10.049876
# PAFAH1B1                      9.433981
# CLIP1                         9.327379
# CENPA                         9.219544
# CLASP1                        9.165151
# NUP50                         9.165151
# CKAP5                         9.165151
# KNTC1                         9.110434
# AHCTF1                        9.110434
# CLASP2                        9.110434
# TPR                           9.055385
# RAE1                          9.055385
# MAD1L1                        8.954430
# AAAS                          8.944272
# ATM                           7.090547
# SHC1                          6.639528
# SOS1                          6.090777
# BRCA1                         6.090777
# ELL                           6.082763
# BUB3                          6.021972
# ABL1                          5.813777
# ESR1                          5.547002
# ATF2                          5.357062
# NCOA1                         5.291503
# MDC1                          5.291503
# CDC20                         5.269652
# CREBBP                        5.250000
# ...                                ...
# CDC6                         -2.683282
# OGT                          -2.713602
# CCNA2                        -2.722179
# PPP1R12A                     -2.828427
# CACNA2D2                     -2.897473
# BRAP                         -3.000000
# RBL2                         -3.050851
# FBXO5                        -3.050851
# CCNE1                        -3.202470
# TIA1                         -3.207135
# POLR2L                       -3.211586
# POLR2E                       -3.211586
# CCNB2                        -3.244428
# PER1                         -3.273268
# PPP2R2B                      -3.362691
# AKT3                         -3.517632
# POLR2G                       -3.655631
# AKT2                         -3.656552
# PER2                         -3.709704
# TIAL1                        -3.741657
# CACNA2D4                     -3.771711
# PPP2R2A                      -3.781177
# POLR2I                       -3.887710
# GTF2F2                       -3.889087
# PTTG1                        -4.146140
# RBL1                         -4.242641
# TBC1D1                       -4.472136
# FZR1                         -5.013774
# CCNE2                        -5.604485
# GPSM1                        -6.782330
#
# [1337 rows x 1 columns]

# %%
ura.tf_zscore(bias_filter = 0)
biased_zscores = ura.get('z_scores')
display(biased_zscores.to_frame())
# Out:
# Graph has bias of 0.362398579239. Adjusting z-score calculation accordingly.
#           biased-calculated z-scores
# RANBP2                    101.378626
# NUP133                    101.378626
# NUP37                      96.277815
# XPO1                       64.397743
# PAFAH1B1                   56.746526
# CLIP1                      55.471324
# CENPA                      54.196121
# CLASP1                     53.558519
# CKAP5                      53.558519
# NUP50                      53.558519
# KNTC1                      52.920918
# AHCTF1                     52.920918
# CLASP2                     52.920918
# RAE1                       52.283317
# TPR                        52.283317
# MAD1L1                     52.108925
# AAAS                       51.008114
# ATM                        32.980882
# SHC1                       28.604868
# SOS1                       24.141658
# BRCA1                      24.141658
# ELL                        23.591253
# BUB3                       23.585751
# ABL1                       22.692064
# ESR1                       21.155274
# ATF2                       19.792875
# CREBBP                     18.806491
# PPARGC1A                   18.228854
# NCOA1                      17.852840
# MDC1                       17.852840
# ...                              ...
# PER1                      -22.610370
# IQGAP1                    -22.871957
# CCNB1                     -22.931922
# RBL1                      -24.523174
# PER2                      -24.610370
# NCBP2                     -24.670335
# GTF2F1                    -25.945537
# PTTG1                     -26.610370
# TBC1D1                    -27.247972
# CCNA2                     -31.133545
# TP53                      -31.318940
# POLR2E                    -31.683950
# POLR2L                    -31.683950
# CACNA2D4                  -32.234356
# POLR2G                    -32.959153
# GTF2F2                    -33.596755
# CCNB2                     -33.771146
# CACNA2D2                  -34.583139
# PPP2R2B                   -35.133545
# POLR2I                    -35.683950
# PTEN                      -36.119929
# PPP2R2A                   -36.408747
# CCNE1                     -36.583139
# FZR1                      -37.509559
# MYC                       -44.359787
# CCNE2                     -49.133545
# GPSM1                     -62.670335
# AKT1                      -63.782150
# AKT3                      -70.877459
# AKT2                      -77.139047
#
# [1337 rows x 1 columns]

# %% [markdown]
# ### Display Results
# <a id='display'></a>

# %% [markdown]
# Our stat_analysis module also inculdes methods to help you find the most statistically relevant TF's to your input DEG data set.
# - top_values: will display the highest activating, inhibiting, or overall values
# - rank_and_score_df: will display where an input set of genes rank among all others in terms of their z-score
# - vis_tf_network: will display an interactive network of a specified regulator and its downstream targets

# %% [markdown]
# **Top Values**
# <a id='top'></a>
#
# NOTE: Your DEG_to_pvalue and DEG_to_updown paramters should come from create_DEG_full_graph

# %%
top_act = ura.top_values(act = True, abs_value = False, top = 5)
top_inh = ura.top_values(act = False, abs_value = False, top = 5)
top_overall = ura.top_values(abs_value = True, top = 5)

print "\nTop five activating: "
display(top_act)
print "\nTop five inhibiting: "
display(top_inh)
print "\nTop five overall: "
display(top_overall)
# Out:
# Top five activating:
#              z-score  (adj) p-value  (log) fold change
# RANBP2    101.378626      -0.090858           0.975454
# NUP133    101.378626      -0.115508           0.600609
# NUP37      96.277815       0.006546           0.998296
# XPO1       64.397743       0.046577           0.997240
# PAFAH1B1   56.746526      -0.241807           0.008217
# Top five inhibiting:
#          z-score  (adj) p-value  (log) fold change
# AKT2  -77.139047       0.056609           0.978390
# AKT3  -70.877459      -0.136716           0.058052
# AKT1  -63.782150       0.099134           0.019114
# GPSM1 -62.670335       0.159024           0.010397
# CCNE2 -49.133545            NaN                NaN
# Top five overall:
#            z-score  (adj) p-value  (log) fold change
# NUP133  101.378626      -0.115508           0.600609
# RANBP2  101.378626      -0.090858           0.975454
# NUP37    96.277815       0.006546           0.998296
# AKT3    -70.877459      -0.136716           0.058052
# AKT2    -77.139047       0.056609           0.978390

# %% [markdown]
# **Rank with z-score**
# <a id='rank'></a>

# %% [markdown]
# Ranks range from 0 (best, aka strongest z-score) to whichever number is associated with a z-score of zero, in this case 47. If the remove_dups flag is set to True, any genes with the same z-score will have the same rank.

# %%
genes_to_rank = ['TAF1', 'RPL8', 'STAT1','TP53', 'ZEN2']
ura.compare_genes(genes_to_rank, anno_vert_dist=0.005)
# Out:
# RPL8 is not a valid transcription factor in our graph.
# ZEN2 is not a valid transcription factor in our graph.

# %% [markdown]
# **Network Visualization using visJS2jupyter**
# <a id='visJS'></a>
#
# If you do not already have the package visJS2jupyter, type "pip install visJS2jupyter" into your command prompt.
#
# **Node Color**:
# - yellow: regulator/TF
# - red: up-regulated tarets
# - blue: down-regulated targets
# - the stronger the gene's fold change (specified in DEG_filename), the stronger the shade of red or blue
# - white: no fold change information for this gene
#
# **Node Border**:
# - DEG's (secified by DEG_list) are outlined in black
#
# **Node Size**:
# - small: insiginificant/large adjusted p-value (taken from DEG_filename)
# - large: significant/small adjusted p-value
#
# **Edge Color**:
# - red: activating
# - blue: inhibiting
#
# **Tips**:
# - nodes look too clustered: increase node spacing to ~3000 or ~4000
# - nodes look to sparse: decrease node spacing to ~2000 or ~1000
# - directed_edges = False will center the TF
# - directed_edges = True will pull the TF off to the side

# %%
ura.vis_tf_network('STAT1',
                   directed_edges = False,
                   node_spacing = 3200,
                   color_non_DEGs = True,
                   color_map = plt.cm.bwr,
                   graph_id = 200,
                   tf_size_amplifier = 8,
                   alpha = 0.9, # opacity
                   color_vals_transform = None,
                   ceil_val = 1,
                   color_max_frac = 0.9, # percentage of color map to use, upper bound
                   color_min_frac = 0.1, # percentage of color map to use, lower bound
                   vmin = 0.3,
                   vmax = 0,
                   tf_shape = 'circle'
                   )
# Out:
# ../../network_bio_toolkit\stat_analysis.py:790: RuntimeWarning: invalid value encountered in log
#   nts = {n: (2 + (-np.log(DEG_to_pvalue[n]))) for n in nodes if n in DEG_to_updown}  # keep only those in graph G
# C:\Users\m1web\Anaconda2\lib\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file200"];    frame.runVis([{"node_shape": "circle", "degree": 3.0, "title": "BCL2L1", "color": "rgba(256, 60, 60, 0.9)", "size_field": 4.24754988216634, "y": 736.3768042296784, "x": 1946.2561827735865, "border_width": 0, "id": "BCL2L1"}, {"node_shape": "circle", "degree": 3.0, "title": "HAMP", "color": "rgba(0, 0, 256, 0.9)", "size_field": NaN, "y": 766.0786079454684, "x": 1034.1260295044074, "border_width": 2, "id": "HAMP"}, {"node_shape": "circle", "degree": 3.0, "title": "TBX21", "color": "rgba(256, 50, 50, 0.9)", "size_field": NaN, "y": 2023.1101176358416, "x": 2562.7080733708126, "border_width": 0, "id": "TBX21"}, {"node_shape": "circle", "degree": 3.0, "title": "IL6ST", "color": "rgba(0, 0, 256, 0.9)", "size_field": 4.277491493492599, "y": 2840.900491843588, "x": 1849.965911781896, "border_width": 0, "id": "IL6ST"}, {"node_shape": "circle", "degree": 3.0, "title": "IFNAR2", "color": "rgba(0, 0, 256, 0.9)", "size_field": 5.214921909404362, "y": 2235.4743620784784, "x": 2038.08915287244, "border_width": 2, "id": "IFNAR2"}, {"node_shape": "circle", "degree": 3.0, "title": "EPO", "color": "rgba(256, 50, 50, 0.9)", "size_field": NaN, "y": 1088.1649653847205, "x": 2040.7127741548966, "border_width": 0, "id": "EPO"}, {"node_shape": "circle", "degree": 3.0, "title": "IL22", "color": "rgba(256, 50, 50, 0.9)", "size_field": NaN, "y": 3015.0474179368316, "x": 1402.829907971657, "border_width": 0, "id": "IL22"}, {"node_shape": "circle", "degree": 3.0, "title": "IL27", "color": "rgba(256, 50, 50, 0.9)", "size_field": NaN, "y": 1497.51558143601, "x": 2704.1108819182277, "border_width": 0, "id": "IL27"}, {"node_shape": "circle", "degree": 3.0, "title": "TYK2", "color": "rgba(256, 74, 74, 0.9)", "size_field": 3.6535665857039037, "y": 1771.6740055901373, "x": 1763.5938289288067, "border_width": 0, "id": "TYK2"}, {"node_shape": "circle", "degree": 3.0, "title": "EGF", "color": "rgba(256, 50, 50, 0.9)", "size_field": NaN, "y": 765.541032743469, "x": 560.940499634821, "border_width": 0, "id": "EGF"}, {"node_shape": "circle", "degree": 3.0, "title": "IL12RB1", "color": "rgba(256, 50, 50, 0.9)", "size_field": NaN, "y": 1467.991745533181, "x": 2230.6817926254867, "border_width": 0, "id": "IL12RB1"}, {"node_shape": "circle", "degree": 3.0, "title": "ZNF148", "color": "rgba(0, 0, 256, 0.9)", "size_field": 3.8101929046713474, "y": 2416.9286523273613, "x": 302.1060835150954, "border_width": 0, "id": "ZNF148"}, {"node_shape": "circle", "degree": 3.0, "title": "IL12RB2", "color": "rgba(256, 50, 50, 0.9)", "size_field": NaN, "y": 1775.2882852108228, "x": 2006.351456453215, "border_width": 0, "id": "IL12RB2"}, {"node_shape": "circle", "degree": 3.0, "title": "FADD", "color": "rgba(0, 0, 256, 0.9)", "size_field": 5.205106180550429, "y": 2749.6196886499874, "x": 536.6713352185085, "border_width": 2, "id": "FADD"}, {"node_shape": "circle", "degree": 3.0, "title": "LYN", "color": "rgba(0, 0, 256, 0.9)", "size_field": 5.373315806539202, "y": 985.216281254676, "x": 446.24892415313076, "border_width": 2, "id": "LYN"}, {"node_shape": "circle", "degree": 3.0, "title": "IFNG", "color": "rgba(256, 50, 50, 0.9)", "size_field": NaN, "y": 1544.1967310714822, "x": 1862.542128883603, "border_width": 0, "id": "IFNG"}, {"node_shape": "circle", "degree": 3.0, "title": "CAMK2G", "color": "rgba(0, 0, 256, 0.9)", "size_field": 4.635894704789523, "y": 1208.881422761683, "x": 1368.1695988885074, "border_width": 0, "id": "CAMK2G"}, {"node_shape": "circle", "degree": 3.0, "title": "CAMK2A", "color": "rgba(0, 0, 256, 0.9)", "size_field": NaN, "y": 1394.738559558605, "x": 1674.8174983530798, "border_width": 2, "id": "CAMK2A"}, {"node_shape": "circle", "degree": 3.0, "title": "IFI30", "color": "rgba(0, 0, 256, 0.9)", "size_field": 4.2162752935524, "y": 2429.9682134030513, "x": 2602.682081775573, "border_width":  ...

# %%
ura.vis_tf_network('STAT5A',
                   directed_edges = True,
                   node_spacing = 3000,
                   color_non_DEGs = False,
                   color_map = plt.cm.bwr,
                   graph_id = 201,
                   tf_size_amplifier = 8,
                   alpha = 1.0, 
                   color_vals_transform = None,
                   ceil_val=10,
                   color_max_frac = 1.0,
                   color_min_frac = 0.0,
                   vmin=None,
                   vmax=None,
                   tf_shape = 'circle'
                   )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file201"];    frame.runVis([{"node_shape": "circle", "degree": 3.0, "title": "BCL2L1", "color": "grey", "size_field": 4.24754988216634, "y": 1851.675157112163, "x": 1089.153282832983, "border_width": 0, "id": "BCL2L1"}, {"node_shape": "circle", "degree": 3.0, "title": "SAC3D1", "color": "rgba(256, 0, 0, 1.0)", "size_field": 5.874660373207809, "y": 2348.9774241115047, "x": 1638.9499999563943, "border_width": 2, "id": "SAC3D1"}, {"node_shape": "circle", "degree": 3.0, "title": "GHR", "color": "grey", "size_field": NaN, "y": 902.7727767634505, "x": 225.8922000440465, "border_width": 0, "id": "GHR"}, {"node_shape": "circle", "degree": 3.0, "title": "DPF3", "color": "grey", "size_field": 3.9610973209394835, "y": 927.499660339893, "x": 880.4552984987837, "border_width": 0, "id": "DPF3"}, {"node_shape": "circle", "degree": 3.0, "title": "ZFPM1", "color": "grey", "size_field": 4.246303085752858, "y": 1565.742921759935, "x": 180.7578637474213, "border_width": 0, "id": "ZFPM1"}, {"node_shape": "circle", "degree": 3.0, "title": "IL6ST", "color": "grey", "size_field": 4.277491493492599, "y": 1641.8241193589624, "x": 329.9704905037585, "border_width": 0, "id": "IL6ST"}, {"node_shape": "circle", "degree": 3.0, "title": "EPO", "color": "grey", "size_field": NaN, "y": 1798.4813264586626, "x": 747.4830152136691, "border_width": 0, "id": "EPO"}, {"node_shape": "circle", "degree": 3.0, "title": "IL22", "color": "grey", "size_field": NaN, "y": 2578.782716982702, "x": 569.1350252866224, "border_width": 0, "id": "IL22"}, {"node_shape": "circle", "degree": 3.0, "title": "IL27", "color": "grey", "size_field": NaN, "y": 2425.368507216333, "x": 1212.5625533187965, "border_width": 0, "id": "IL27"}, {"node_shape": "circle", "degree": 3.0, "title": "TYK2", "color": "grey", "size_field": 3.6535665857039037, "y": 938.8271233010914, "x": 647.620403345418, "border_width": 0, "id": "TYK2"}, {"node_shape": "circle", "degree": 3.0, "title": "SLC30A2", "color": "grey", "size_field": NaN, "y": 526.0858996624285, "x": 1871.3654935919399, "border_width": 0, "id": "SLC30A2"}, {"node_shape": "circle", "degree": 3.0, "title": "IL12RB1", "color": "grey", "size_field": NaN, "y": 1914.2323227377601, "x": 6.235927001911858, "border_width": 0, "id": "IL12RB1"}, {"node_shape": "circle", "degree": 3.0, "title": "PRL", "color": "grey", "size_field": NaN, "y": 2027.2670820237533, "x": 1500.5561353538212, "border_width": 0, "id": "PRL"}, {"node_shape": "circle", "degree": 3.0, "title": "IL12RB2", "color": "grey", "size_field": NaN, "y": 1388.293748331483, "x": 313.8052377428468, "border_width": 0, "id": "IL12RB2"}, {"node_shape": "circle", "degree": 3.0, "title": "CDH1", "color": "grey", "size_field": NaN, "y": 1445.7613952125212, "x": 402.78978731021874, "border_width": 0, "id": "CDH1"}, {"node_shape": "circle", "degree": 3.0, "title": "OSM", "color": "grey", "size_field": NaN, "y": 2132.331817591411, "x": 46.33759198067586, "border_width": 0, "id": "OSM"}, {"node_shape": "circle", "degree": 3.0, "title": "LYN", "color": "rgba(256, 0, 0, 1.0)", "size_field": 5.373315806539202, "y": 2284.0949220450216, "x": 899.925324400498, "border_width": 2, "id": "LYN"}, {"node_shape": "circle", "degree": 3.0, "title": "ERBB4", "color": "rgba(256, 52, 52, 1.0)", "size_field": NaN, "y": 2155.961320180085, "x": 1820.9581627060127, "border_width": 2, "id": "ERBB4"}, {"node_shape": "circle", "degree": 3.0, "title": "IFNG", "color": "grey", "size_field": NaN, "y": 2710.214386818158, "x": 645.3933515284793, "border_width": 0, "id": "IFNG"}, {"node_shape": "circle", "degree": 3.0, "title": "FASLG", "color": "grey", "size_field": NaN, "y": 1741.1058526786558, "x": 524.4032428036327, "border_width": 0, "id": "FASLG"}, {"node_shape": "circle", "degree": 3.0, "title": "CXCL12", "color": "rgba(256, 2, 2, 1.0)", "size_field": NaN, "y": 12 ...

# %% [markdown]
# Last but not least, you have the option to write out all of the TF's, their targets, (adj) p-values, (log) fold change, and enrichment information to a tab-separated csv file.

# %%
#ura.to_csv(out_filename = 'example_basic.txt')
