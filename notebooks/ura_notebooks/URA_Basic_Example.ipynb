# %% [markdown]
# # Basic Example
# ## Upstream Regulator Analysis
#
#
# ----------------------
#
# Author: Mikayla Webster (13webstermj@gmail.com)
#
# Date: 8th November, 2017
#
# ----------------------
#
# <a id='toc'></a>
# ## Table of Contents
# 1. [Background](#background)
# 2. [Import packages](#import)
# 3. [Create Graph](#graph)
#     1. [Transcription Factors](#tf)
#     2. [Background Network](#bn)
#     3. [Differentially Expressed Genes](#deg)
# 3. [Stat Analysis](#stat)
#     1. [P-value](#pvalue)
#     2. [Z-score](#zscore)
#     3. [Display Our Results](#display)
#         1. [Top Values](#top)
#         2. [Rank with z-score](#rank)
#         3. [Network Visualization using visJS2jupyter](#visJS)

# %% [markdown]
# ## Background
# <a id='background'></a>

# %% [markdown]
# The inspiration for these modules comes from Ingenuity System's [Ingenuity Upstream Regulator Analysis in IPA®](http://pages.ingenuity.com/rs/ingenuity/images/0812%20upstream_regulator_analysis_whitepaper.pdf).
#
# This notebook is meant to explain how to use the individual functions from our URA modules, with emphasis on different parameter options. If you need further help on how to use a function or what that function's purpose is, see the comments associated with that function in the source code (Upstream.py, create_graph.py, or stat_analysis.py).

# %% [markdown]
# ## Import packages
# <a id='import'></a>

# %%
# import upstream regulator module
import sys
code_path = '../../network_bio_toolkit'
sys.path.append(code_path)
import Upstream
reload(Upstream)

# import matplotlib for color map
import matplotlib as plt

# %%
# %matplotlib inline

# %%
# User preferences
symbol = 'symbol'
entrez = 'entrez'

ura = Upstream.Upstream(symbol)

# %% [markdown]
# ## Create Graph ##
# <a id='graph'></a>

# %% [markdown]
# ### Transcription Factors
# <a id='tf'></a>
#
# Our create_graph module prepares 3 databases to use in our analysis: a transcription factor interaction network, a background network, and a differentially expressed genes database. Our transcription factor data comes from two sources: [slowkow](https://github.com/slowkow/tftargets) and [jaspar](http://jaspar.genereg.net/). Slowkow is a compilation of 6 smaller databases: TRED, ITFP, ENCODE, Neph2012, TRRUST, Marbach2016. Information about these specific databases, including links to their sources, is available through the slowkow github page. Some basic information on these databases is as follows:
# - Size of Jaspar Database: 2049
# - Size of Slowkow Database: 2705
# - Size of TRED: 133
# - Size of ITFP: 1974
# - Size of ENCODE: 157
# - Size of Neph2012: 536
# - Size of TRRUST: 748
# - Size of Marbach2016: 643
#
# Our trascription factor list contains 3983 unique entries.

# %%
ura.easy_load_TF_list('../../TF_databases/TF_database_URA.csv', jaspar = False, TRED = True, ITFP = True, ENCODE = True, 
                          Neph2012 = True, TRRUST = True, Marbach2016 = True)
len(ura.get('TF_list'))
# Out:
# 2705

# %% [markdown]
# ### Background Network
# <a id='bn'></a>
#
# Our background network comes from the [STRING](https://string-db.org/) database. Our module uses our list of transcription factors (TF_list) to extract only relevant information from the STRING database. Namely, we remove all edges and nodes not conected to our TF's.
#
# This function may need a minute or so to process.

# %%
filename = "../../background_networks/9606.protein.actions.v10.5.txt"
confidence_filter = 400
ura.load_STRING_to_digraph(filename, confidence_filter)
DG_TF = ura.get('DG_TF')
DG_universe = ura.get('DG_universe')

print "\nNumber of interactions: " + str(len(list(DG_TF.edges())))
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-7374...done.
# Finished.
# 56 input query terms found dup hits:
# 	[(u'ENSP00000359550', 3), (u'ENSP00000447879', 2), (u'ENSP00000364076', 2), (u'ENSP00000348986', 2),
# 312 input query terms found no hit:
# 	[u'ENSP00000376684', u'ENSP00000289352', u'ENSP00000202788', u'ENSP00000373637', u'ENSP00000367802',
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
#
# Number of interactions: 28756

# %%
print 'Number of unique nodes without filtering: ' + str(len(list(set(DG_universe.nodes()))))
print 'Number of edges without filtering: ' + str(len(DG_universe.edges()))
print '-----------------------------------------------'
print 'Number of unique nodes with filtering: ' + str(len(list(set(DG_TF.nodes()))))
print 'Number of edges with filtering: ' + str(len(DG_TF.edges()))
# Out:
# Number of unique nodes without filtering: 7047
# Number of edges without filtering: 140378
# -----------------------------------------------
# Number of unique nodes with filtering: 4587
# Number of edges with filtering: 28756

# %% [markdown]
# ### Differentially Expressed Genes
# <a id='deg'></a>
#
# Our last database comes from a list of differentially exressed genes (DEG) found in an experiement. This should come in the form of a tab separated csv file with at least three columns: gene name, (adjusted) p-value, and (log) fold change. Our parser will look for common header names for each of these columns. However, if your file has unusual column headers for any of these three categories, please specify your column headers using the parameters "gene_column_header", "p_value_column_header", and "fold_change_column_header".
#
# **WARNING: Having spaces in your column headers can cause weird bugs.**
#
# Specify a networkx graph G in order to add the fold change (up-down) information from your csv file as a node attribute to this graph. NOTE: 1) the graph will not be modified in place, and 2) if G is not specified, 3 values will be returned rather than 2.

# %%
filename = '../../DEG_databases/differentially_expressed_genes.txt'

ura.create_DEG_list(filename,
                    p_value_filter = 0.05,
                    p_value_or_adj = 'adj',  # filtering by p-value ('p') or adjusted p-value ('adj')
                    fold_change_filter = None,  # specify a number to filter by absolute (log) fold change
                    gene_column_header = 'gene_symbol', # these are common names, but specifying for demonstration
                    p_value_column_header = 'adj_p_value',
                    fold_change_column_header = 'fold_change')

DEG_list = ura.get('DEG_list')
DG_TF = ura.get('DG_TF')
DEG_full_graph = ura.get('DEG_full_graph')
DEG_to_pvalue = ura.get('DEG_to_pvalue')
DEG_to_updown = ura.get('DEG_to_updown')

print "Number of DEG's: " + str(len(DEG_list))
print "Number of genes in our entire input file: " + str(len(DEG_full_graph.nodes()))
# Out:
# Number of DEG's: 8755
# Number of genes in our entire input file: 13297

# %%
DG_TF.nodes(data=True) # updown means fold change
# Out:
# [('HIF3A', {'updown': 0}),
#  ('RNF14', {'updown': 0.3508037846}),
#  ('ELANE', {'updown': 0}),
#  ('KHSRP', {'updown': 0.9599754305}),
#  ('NCBP1', {'updown': 0.9955238004000001}),
#  ('NCBP2', {'updown': 0.99833423890000006}),
#  ('RNF13', {'updown': 0}),
#  ('NELFB', {'updown': 0.99337302000000005}),
#  ('HIST1H4J', {'updown': 0.99796412239999999}),
#  ('HSPA9', {'updown': 0.84444869430000002}),
#  ('HSPA8', {'updown': 0.94796409299999995}),
#  ('NELFE', {'updown': 0}),
#  ('B2M', {'updown': 0.99801843430000003}),
#  ('CD226', {'updown': 0}),
#  ('LIFR', {'updown': 0}),
#  ('PDCD10', {'updown': 0.13305126619999999}),
#  ('PDCD11', {'updown': 0.99801437659999992}),
#  ('AGT', {'updown': 0.99818587799999992}),
#  ('ASS1', {'updown': 0.43299072960000001}),
#  ('SQLE', {'updown': 0.99742004290000008}),
#  ('ADIPOQ', {'updown': 0}),
#  ('LINC02210-CRHR1', {'updown': 0}),
#  ('CYP26B1', {'updown': 0.031157696000000002}),
#  ('SRY', {'updown': 0}),
#  ('HSPA5', {'updown': 0.94674490010000001}),
#  ('NID2', {'updown': 0}),
#  ('CAMK1', {'updown': 0}),
#  ('NR0B2', {'updown': 0}),
#  ('NR0B1', {'updown': 0}),
#  ('HSPA4', {'updown': 0}),
#  ('PIK3CD', {'updown': 0}),
#  ('CAMK4', {'updown': 0.083987409700000001}),
#  ('PIK3CG', {'updown': 0}),
#  ('CRBN', {'updown': 0.1009102585}),
#  ('SPTLC2', {'updown': 0}),
#  ('DRAP1', {'updown': 0.99658972819999991}),
#  ('IRX5', {'updown': 0}),
#  ('IRX4', {'updown': 0}),
#  ('IRX6', {'updown': 0}),
#  ('CCR9', {'updown': 0}),
#  ('IRX3', {'updown': 0}),
#  ('FOXQ1', {'updown': 0}),
#  ('DHX9', {'updown': 0.99832626290000004}),
#  ('NELFA', {'updown': 0}),
#  ('TCOF1', {'updown': 0}),
#  ('NUP98', {'updown': 0.99817139499999996}),
#  ('XPC', {'updown': 0.99822799409999996}),
#  ('SP1', {'updown': 0}),
#  ('SP2', {'updown': 0.99832071919999998}),
#  ('SP3', {'updown': 0.99774025519999998}),
#  ('NUP93', {'updown': 0.99812470499999995}),
#  ('MUC6', {'updown': 0}),
#  ('PPP2R2C', {'updown': 0.066921332}),
#  ('PPP2R2B', {'updown': 0.00019809560000000001}),
#  ('NUP50', {'updown': 0.080430958299999994}),
#  ('NMS', {'updown': 0}),
#  ('PRKCE', {'updown': 0.019267582299999999}),
#  ('MYL12A', {'updown': 0}),
#  ('ORM2', {'updown': 0}),
#  ('HIPK2', {'updown': 0}),
#  ('ELF4', {'updown': 0}),
#  ('MAX', {'updown': 0}),
#  ('PARP14', {'updown': 0.99791827170000003}),
#  ('MAZ', {'updown': 0}),
#  ('BAK1', {'updown': 0}),
#  ('NRTN', {'updown': 0}),
#  ('CSN2', {'updown': 0}),
#  ('MAF', {'updown': 0}),
#  ('TRAF6', {'updown': 0.8370592376999999}),
#  ('CTBP1', {'updown': 0.99200095359999996}),
#  ('CTBP2', {'updown': 0}),
#  ('CLDN7', {'updown': 0}),
#  ('KCNJ9', {'updown': 0.99816979319999988}),
#  ('TSG101', {'updown': 0.9970897058}),
#  ('ITGA9', {'updown': 0.93415424409999992}),
#  ('UGCG', {'updown': 0.29593449799999999}),
#  ('ATP2A1', {'updown': 0}),
#  ('ATP2A2', {'updown': 0.0067718861}),
#  ('ATP2A3', {'updown': 0}),
#  ('ITGA1', {'updown': 0.99637524749999995}),
#  ('ITGA2', {'updown': 0}),
#  ('ITGA3', {'updown': 0.99832579720000003}),
#  ('ITGA4', {'updown': 0}),
#  ('ITGA5', {'updown': 0}),
#  ('ITGA6', {'updown': 0}),
#  ('ITGA7', {'updown': 0}),
#  ('GTF3C5', {'updown': 0}),
#  ('APOA5', {'updown': 0}),
#  ('PREB', {'updown': 0.99747473659999997}),
#  ('PHLDA1', {'updown': 0.9973778297}),
#  ('APOA1', {'updown': 0}),
#  ('APOA2', {'updown': 0}),
#  ('PHLDA2', {'updown': 0.038411258199999999}),
#  ('XPO1', {'updown': 0.99724005680000005}),
#  ('PPME1', {'updown': 0.55352825630000002}),
#  ('XPO5', {'updown': 0.99308579900000005}),
#  ('CSDE1', {'updown': 0.99819801080000004}),
#  ('LILRB1', {'updown': 0}),
#  ('TTR', {'updown': 0}),
#  ('JAM3', {'updown': 0}),
#  ('CSNK2A1', {'updown': 0.12435083500000001}),
#  ('MDK', {'updown': 0.3287100537}),
#  ('MTCP1', {'updown': 0}),
#  ('TTK', {'updown': 0}),
#  ('HRH4', {'updown': 0}),
#  ('GRAP2', {'updown': 0}),
#  ('HRH2', {'updown': 0.9982293176}),
#  ('HRH3', {'updown': 0}),
#  ('RASEF', {'updown': 0}),
#  ('KSR2', {'updown': 0.9982619184}),
#  ('KCNIP4', {'updown': 0.029880542599999997}),
#  ('KCNIP3', {'updown': 0.9981592628}),
#  ('CCNA1', {'updown': 0.86541341199999999}),
#  ('ABCB1', {'updown': 0}),
#  ('PRSS50', {'updown': 0}),
#  ('GRP', {'updown': 0}),
#  ('LIN28B', {'updown': 0}),
#  ('LIN28A', {'updown': 0}),
#  ('TFB2M', {'updown': 0.81349849540000008}),
#  ('COL4A2', {'updown': 0.99749295370000002}),
#  ('EPS15L1', {'updown': 0.81078741249999997}),
#  ('ANAPC1', {'updown': 0.0026609140999999999}),
#  ('ANAPC2', {'updown': 0.99833436279999999}),
#  ('ANAPC5', {'updown': 0.99795836920000003}),
#  ('ANAPC4', {'updown': 0.99498368479999999}),
#  ('ANAPC7', {'updown': 0.63553803009999998}),
#  ('ZEB2', {'updown': 0}),
#  ('ITGAX', {'updown': 0}),
#  ('RPS6KA1', {'updown': 0}),
#  ('RPS6KA2', {'updown': 0}),
#  ('SNRPB2', {'updown': 0}),
#  ('RPS6KA4', {'updown': 0.99805638209999992}),
#  ('RPS6KA6', {'updown': 0}),
#  ('BCL2A1', {'updown': 0}),
#  ('PISD', {'updown': 0.98147127180000004}),
#  ('TP53I13', {'updown': 0}),
#  ('NOG', {'updown': 0.9950236737999999}),
#  ('PSMD10', {'updown': 0.1075874307}),
#  ('ITGAV', {'updown': 0.99832392640000001}),
#  ('ATAD2', {'updown': 0.99598353829999997}),
#  ('FRAT1', {'updown': 0}),
#  ('FRAT2', {'updown': 0}),
#  ('DLAT', {'updown': 0.000106665}),
#  ('GIT1', {'updown': 0}),
#  ('GIT2', {'updown': 0.1360269177}),
#  ('SERBP1', {'updown': 0.99833121099999989}),
#  ('HLF', {'updown': 0.91367289239999994}),
#  ('NOV', {'updown': 0.50101817810000004}),
#  ('MYO10', {'updown': 0}),
#  ('ITGAD', {'updown': 0}),
#  ('PIK3CB', {'updown': 0.77844153099999991}),
#  ('FOXC1', {'updown': 0}),
#  ('ISL1', {'updown': 0}),
#  ('GHRH', {'updown': 0}),
#  ('CD40LG', {'updown': 0}),
#  ('SMAD9', {'updown': 0.99776436989999995}),
#  ('NUP133', {'updown': 0.60060883909999996}),
#  ('SESN3', {'updown': 0}),
#  ('SMAD4', {'updown': 0}),
#  ('SMAD5', {'updown': 0}),
#  ('SMAD6', {'updown': 0}),
#  ('SMAD7', {'updown': 0}),
#  ('SMAD1', {'updown': 0.99493498739999997}),
#  ('SMAD2', {'updown': 0}),
#  ('SMAD3', {'updown': 0.99618182580000003}),
#  ('SC5D', {'updown': 0.1604219194}),
#  ('FOXM1', {'updown': 0}),
#  ('NDUFAF2', {'updown': 0.99832666930000002}),
#  ('IGF2R', {'updown': 0.99833337219999996}),
#  ('CTH', {'updown': 0.97596321799999997}),
#  ('ARF3', {'updown': 0.096750597699999996}),
#  ('ARF1', {'updown': 0.4013190505}),
#  ('ARF6', {'updown': 0.99814068450000004}),
#  ('ARF5', {'updown': 0.070634460999999996}),
#  ('ARF4', {'updown': 0.83059825300000001}),
#  ('CXCR2', {'updown': 0}),
#  ('SERPIND1', {'updown': 0}),
#  ('PRIM1', {'updown': 0.97352684489999997}),
#  ('EIF4B', {'updown': 0.99552715859999996}),
#  ('ARTN', {'updown': 0}),
#  ('TCEA2', {'updown': 0.99815638950000007}),
#  ('TCEA3', {'updown': 0}),
#  ('TCEA1', {'updown': 0}),
#  ('RGPD2', {'updown': 0}),
#  ('KDM2A', {'updown': 0}),
#  ('RGPD1', {'updown': 0}),
#  ('RGPD6', {'updown': 0.44740890799999999}),
#  ('PRKAR1A', {'updown': 0.095661752400000008}),
#  ('RGPD4', {'updown': 0}),
#  ('RGPD5', {'updown': 0.99826695809999999}),
#  ('SAR1A', {'updown': 0.9902988826000001}),
#  ('RGPD8', {'updown': 0}),
#  ('OLIG2', {'updown': 0}),
#  ('OLIG1', {'updown': 0}),
#  ('BDKRB1', {'updown': 0}),
#  ('LOR', {'updown': 0}),
#  ('CD99', {'updown': 0}),
#  ('ADCY3', {'updown': 0.99818109889999995}),
#  ('SENP1', {'updown': 0.99818708909999998}),
#  ('CD86', {'updown': 0}),
#  ('SPP1', {'updown': 0}),
#  ('CXXC5', {'updown': 0.99831087559999998}),
#  ('LGALS8', {'updown': 0.080270586599999999}),
#  ('CDC45', {'updown': 0}),
#  ('CDC40', {'updown': 0.98775924140000004}),
#  ('CDC42', {'updown': 0.018640359199999998}),
#  ('SP8', {'updown': 0}),
#  ('IFIH1', {'updown': 0.99736524659999992}),
#  ('DPT', {'updown': 0}),
#  ('CBLB', {'updown': 0.99759885450000008}),
#  ('CBLC', {'updown': 0}),
#  ('HMGB2', {'updown': 0.9862456584999999}),
#  ('HMGB1', {'updown': 0.99609950480000009}),
#  ('CPEB3', {'updown': 0.99768304200000002}),
#  ('CPEB2', {'updown': 0.99833440449999999}),
#  ('PGLYRP3', {'updown': 0}),
#  ('PGLYRP2', {'updown': 0}),
#  ('CACNG6', {'updown': 0}),
#  ('ACRV1', {'updown': 0.99833168230000002}),
#  ('CHAF1B', {'updown': 0.0020586714999999999}),
#  ('AMHR2', {'updown': 0}),
#  ('BIN1', {'updown': 0}),
#  ('DDAH2', {'updown': 0}),
#  ('FRG2', {'updown': 0}),
#  ('EEA1', {'updown': 0.99743006629999997}),
#  ('ADORA2B', {'updown': 0}),
#  ('UBTF', {'updown': 0}),
#  ('IFT88', {'updown': 0}),
#  ('ACTA2', {'updown': 0.99821485349999994}),
#  ('CLIP3', {'updown': 0.0268555883}),
#  ('CLIP1', {'updown': 0}),
#  ('SLIT3', {'updown': 0.54771593220000003}),
#  ('CDCA7', {'updown': 0}),
#  ('SLIT1', {'updown': 0.77249725430000005}),
#  ('FIP1L1', {'updown': 0.99824646799999994}),
#  ('CDCA8', {'updown': 0}),
#  ('GFAP', {'updown': 0}),
#  ('UTS2', {'updown': 0}),
#  ('CNTF', {'updown': 0}),
#  ('UCN2', {'updown': 0}),
#  ('MND1', {'updown': 0}),
#  ('PPP2R2A', {'updown': 0.99776842980000002}),
#  ('CD46', {'updown': 0.99829313459999991}),
#  ('CD40', {'updown': 0}),
#  ('RSF1', {'updown': 0}),
#  ('SP5', {'updown': 0}),
#  ('ATG4B', {'updown': 0}),
#  ('FXN', {'updown': 0.98909766860000004}),
#  ('FGFR1OP', {'updown': 0.033579132000000005}),
#  ('POLR3GL', {'updown': 0}),
#  ('PHOX2A', {'updown': 0}),
#  ('SP7', {'updown': 0}),
#  ('PFKL', {'updown': 0}),
#  ('SMOX', {'updown': 0}),
#  ('REST', {'updown': 0}),
#  ('TCL1B', {'updown': 0}),
#  ('EIF4E3', {'updown': 0.41062097790000002}),
#  ('SNW1', {'updown': 0.96862550560000005}),
#  ('TBL1X', {'updown': 0}),
#  ('GPT2', {'updown': 0}),
#  ('CALR', {'updown': 0.997550877}),
#  ('CYB5A', {'updown': 0.99636417690000001}),
#  ('RALA', {'updown': 0}),
#  ('EWSR1', {'updown': 0.99830660650000003}),
#  ('WDR77', {'updown': 0.95958399129999994}),
#  ('HLA-DMA', {'updown': 0}),
#  ('TRIM11', {'updown': 0}),
#  ('EFNB2', {'updown': 0.98947426099999991}),
#  ('AAAS', {'updown': 0.99740717739999996}),
#  ('PCK1', {'updown': 0}),
#  ('HAMP', {'updown': 0.99728583879999999}),
#  ('AHCTF1', {'updown': 0.99802778799999992}),
#  ('PPP2R3B', {'updown': 0}),
#  ('PPP2R3C', {'updown': 0.9966372240000001}),
#  ('TAS2R5', {'updown': 0}),
#  ('PPP2R3A', {'updown': 0.99810534760000003}),
#  ('IL12RB1', {'updown': 0}),
#  ('SPRED1', {'updown': 0}),
#  ('SPRED2', {'updown': 0.99754932689999998}),
#  ('PTHLH', {'updown': 0.28165727820000003}),
#  ('BRK1', {'updown': 0.9540772206999999}),
#  ('RNF32', {'updown': 0}),
#  ('EFNB1', {'updown': 0}),
#  ('CHI3L1', {'updown': 0}),
#  ('STIM1', {'updown': 0.9696878189}),
#  ('HDAC5', {'updown': 0.99331010510000006}),
#  ('ALX3', {'updown': 0}),
#  ('PIWIL2', {'updown': 0}),
#  ('MAPKAP1', {'updown': 0}),
#  ('FBXO5', {'updown': 0}),
#  ('SLC4A1', {'updown': 0}),
#  ('SIX4', {'updown': 0}),
#  ('PRL', {'updown': 0}),
#  ('SIX6', {'updown': 0}),
#  ('SIX1', {'updown': 0}),
#  ('SIX2', {'updown': 0}),
#  ('SIX3', {'updown': 0}),
#  ('ESRP2', {'updown': 0}),
#  ('ESRP1', {'updown': 0}),
#  ('RELN', {'updown': 0.73497344459999991}),
#  ('HDAC8', {'updown': 0.99797361370000004}),
#  ('RELB', {'updown': 0.99832947709999997}),
#  ('RELA', {'updown': 0}),
#  ('HDGF', {'updown': 0}),
#  ('PRX', {'updown': 0}),
#  ('HNRNPA2B1', {'updown': 0}),
#  ('TYRP1', {'updown': 0}),
#  ('DYNC1I1', {'updown': 0.011153202799999999}),
#  ('RFFL', {'updown': 0}),
#  ('LEFTY2', {'updown': 0}),
#  ('LEFTY1', {'updown': 0.99751017330000002}),
#  ('SMARCE1', {'updown': 0.99599376159999997}),
#  ('ESX1', {'updown': 0}),
#  ('KLK2', {'updown': 0}),
#  ('KLK3', {'updown': 0}),
#  ('ZFHX3', {'updown': 0}),
#  ('THOC3', {'updown': 0.37717101229999994}),
#  ('THOC2', {'updown': 0}),
#  ('THOC1', {'updown': 0.99832975349999997}),
#  ('AL591806.3', {'updown': 0}),
#  ('THOC7', {'updown': 5.3960181848481801e-05}),
#  ('THOC6', {'updown': 0}),
#  ('THOC5', {'updown': 0.99755872540000001}),
#  ('DBI', {'updown': 0}),
#  ('DBH', {'updown': 0}),
#  ('RFX5', {'updown': 0.99821791489999989}),
#  ('APP', {'updown': 0.11724267720000001}),
#  ('NRXN3', {'updown': 0.0046067671999999995}),
#  ('RFX1', {'updown': 0}),
#  ('RFX2', {'updown': 0}),
#  ('RFX3', {'updown': 0.99321717349999994}),
#  ('TCAP', {'updown': 0}),
#  ('CDON', {'updown': 0.80586549819999997}),
#  ('ELK1', {'updown': 0}),
#  ('ELK4', {'updown': 0.9903678159999999}),
#  ('APC', {'updown': 0.99811213389999998}),
#  ('MAVS', {'updown': 0}),
#  ('PAK1', {'updown': 0.0010622400999999999}),
#  ('STRADB', {'updown': 0}),
#  ('STXBP4', {'updown': 0}),
#  ('NUP88', {'updown': 0}),
#  ('FOXP3', {'updown': 0}),
#  ('COPS8', {'updown': 0.0216362173}),
#  ('FOXP1', {'updown': 0}),
#  ('IL10RA', {'updown': 0.99810577200000006}),
#  ('COPS2', {'updown': 0.71361065599999995}),
#  ('COPS3', {'updown': 0.52790886799999992}),
#  ('SMPD2', {'updown': 0}),
#  ('COPS6', {'updown': 0.99789882769999994}),
#  ('NUP85', {'updown': 0.9551047305}),
#  ('COPS4', {'updown': 0.025125908500000002}),
#  ('COPS5', {'updown': 0.3063448426}),
#  ('KRT19', {'updown': 0}),
#  ('HES7', {'updown': 0}),
#  ('MED1', {'updown': 0}),
#  ('MED6', {'updown': 0.57349320079999999}),
#  ('MED7', {'updown': 0.98772894550000001}),
#  ('MED4', {'updown': 0.22429646410000001}),
#  ('MESP1', {'updown': 0.99749858480000009}),
#  ('PINK1', {'updown': 0.99695303049999995}),
#  ('MED8', {'updown': 0.984022222}),
#  ('MED9', {'updown': 0.99611932959999994}),
#  ('GAST', {'updown': 0}),
#  ('WNT2B', {'updown': 0.99233054440000001}),
#  ('MYCN', {'updown': 0.9942946077}),
#  ('CBX4', {'updown': 0.69916848150000011}),
#  ('CRY2', {'updown': 0.0061869171999999993}),
#  ('AC006486.1', {'updown': 0}),
#  ('MIB1', {'updown': 0}),
#  ('ITIH4', {'updown': 0}),
#  ('DMBT1', {'updown': 0}),
#  ('PRKG1', {'updown': 0}),
#  ('MXD1', {'updown': 0.99833197659999995}),
#  ('PANK1', {'updown': 0.67782950019999999}),
#  ('PRKG2', {'updown': 0}),
#  ('PLTP', {'updown': 0}),
#  ('NLK', {'updown': 0.001267025}),
#  ('AKR1C3', {'updown': 0}),
#  ('FDFT1', {'updown': 0.99787278200000007}),
#  ('TNS4', {'updown': 0}),
#  ('IGF2', {'updown': 0}),
#  ('TCF4', {'updown': 0}),
#  ('TCF7', {'updown': 0}),
#  ('IGF1', {'updown': 0}),
#  ('TCF3', {'updown': 0}),
#  ('DLD', {'updown': 0.10458210130000001}),
#  ('ARID2', {'updown': 0}),
#  ('GCK', {'updown': 0}),
#  ('SPRR3', {'updown': 0}),
#  ('PMEPA1', {'updown': 0}),
#  ('IGFBP2', {'updown': 0.21422022460000001}),
#  ('IGFBP3', {'updown': 0}),
#  ('IGFBP1', {'updown': 0}),
#  ('HBE1', {'updown': 0}),
#  ('IGFBP7', {'updown': 0.99802003739999989}),
#  ('IGFBP4', {'updown': 0.99810592540000009}),
#  ('IGFBP5', {'updown': 0}),
#  ('NLRP1', {'updown': 0.81878412090000008}),
#  ('AFP', {'updown': 0}),
#  ('EIF5A2', {'updown': 0.046461187899999999}),
#  ('GJA1', {'updown': 0}),
#  ('APLNR', {'updown': 0}),
#  ('NLRP3', {'updown': 0.9835519343000001}),
#  ('DEPP1', {'updown': 0}),
#  ('CYP8B1', {'updown': 0}),
#  ('ATP5F1B', {'updown': 0}),
#  ('MEF2C', {'updown': 0.99809943779999999}),
#  ('TRIM8', {'updown': 0}),
#  ('MEF2A', {'updown': 0.94224436329999994}),
#  ('PFN3', {'updown': 0}),
#  ('PFN4', {'updown': 0}),
#  ('CREM', {'updown': 0}),
#  ('BTC', {'updown': 0}),
#  ('MEF2D', {'updown': 0.99833390510000009}),
#  ('GAS1', {'updown': 0}),
#  ('TRIM3', {'updown': 0.99507943599999993}),
#  ('KDM3A', {'updown': 0}),
#  ('PROC', {'updown': 0}),
#  ('DNAJB1', {'updown': 0}),
#  ('BTK', {'updown': 0}),
#  ('SSB', {'updown': 0.99832869980000005}),
#  ('NUTF2', {'updown': 0.99661598790000006}),
#  ('NSL1', {'updown': 0}),
#  ('PDGFRA', {'updown': 0}),
#  ('MFNG', {'updown': 0}),
#  ('HIST1H4C', {'updown': 0}),
#  ('LGR4', {'updown': 0.99828642790000011}),
#  ('TEX15', {'updown': 0}),
#  ('EIF2B4', {'updown': 0}),
#  ('EIF2B5', {'updown': 0.99750477339999999}),
#  ('EIF2B2', {'updown': 0.99830145310000007}),
#  ('EIF2B3', {'updown': 0.020669031399999999}),
#  ('EIF2B1', {'updown': 0.00037454769999999994}),
#  ('PRKAR2A', {'updown': 0}),
#  ('COL24A1', {'updown': 0.9923886476999999}),
#  ('PRKAR2B', {'updown': 0.85675350579999998}),
#  ('PPA1', {'updown': 0.99167117180000008}),
#  ('S1PR4', {'updown': 0}),
#  ('HIST1H4B', {'updown': 0}),
#  ('FANCF', {'updown': 0.85215668379999998}),
#  ('MECOM', {'updown': 0}),
#  ('ITGA2B', {'updown': 0.99831351700000004}),
#  ('TPM3', {'updown': 0.59160818780000002}),
#  ('IFI16', {'updown': 0}),
#  ('TRADD', {'updown': 0}),
#  ('RPS6KB2', {'updown': 0}),
#  ('THYN1', {'updown': 0.34548252659999995}),
#  ('JCHAIN', {'updown': 0}),
#  ('TNFRSF6B', {'updown': 0}),
#  ('FBXW7', {'updown': 0.99755454650000008}),
#  ('TGFBR3', {'updown': 0}),
#  ('TGFBR2', {'updown': 0}),
#  ('TGFBR1', {'updown': 0.99699788919999999}),
#  ('NTF3', {'updown': 0}),
#  ('NUP107', {'updown': 0.99795949930000005}),
#  ('TET1', {'updown': 0}),
#  ('TET2', {'updown': 0}),
#  ('UPP1', {'updown': 0.99550041959999991}),
#  ('ARAP1', {'updown': 0}),
#  ('FOXL2', {'updown': 0}),
#  ('FOXL1', {'updown': 0}),
#  ('RPS4X', {'updown': 0}),
#  ('RHPN1', {'updown': 0.99811233790000009}),
#  ('GALR1', {'updown': 0}),
#  ('FSD1L', {'updown': 0.99611959709999998}),
#  ('CXADR', {'updown': 0.99828620879999996}),
#  ('CYP24A1', {'updown': 0}),
#  ('AGTR2', {'updown': 0}),
#  ('YOD1', {'updown': 0.99824542080000001}),
#  ('RAB14', {'updown': 0.19309164129999998}),
#  ('MFN2', {'updown': 0.99333343590000001}),
#  ('TCP1', {'updown': 0.99361811569999992}),
#  ('PRG4', {'updown': 0}),
#  ('FANCI', {'updown': 0.69118053200000007}),
#  ('BABAM2', {'updown': 0}),
#  ('F2RL1', {'updown': 0}),
#  ('TNFSF4', {'updown': 0}),
#  ('XAB2', {'updown': 0.9972350391}),
#  ('MAD2L2', {'updown': 0}),
#  ('VMP1', {'updown': 0.13467337500000001}),
#  ('MAD2L1', {'updown': 0.00047801010000000005}),
#  ('MYL9', {'updown': 0}),
#  ('PRDX4', {'updown': 0.99810058230000009}),
#  ('PRDX3', {'updown': 0.74455384670000002}),
#  ('PRDX1', {'updown': 0}),
#  ('NFYC', {'updown': 0.98701521519999991}),
#  ('NFYB', {'updown': 0}),
#  ('NFYA', {'updown': 0}),
#  ('BAZ2A', {'updown': 0}),
#  ('MYBL1', {'updown': 0}),
#  ('SMOC2', {'updown': 0}),
#  ('SMARCA2', {'updown': 0.0046147771999999997}),
#  ('MYBL2', {'updown': 0}),
#  ('SMARCA5', {'updown': 0.99735332639999996}),
#  ('PPP1R17', {'updown': 0}),
#  ('AXIN2', {'updown': 0.99770688220000003}),
#  ('AXIN1', {'updown': 0}),
#  ('CTCFL', {'updown': 0}),
#  ('FYN', {'updown': 0}),
#  ('RAB1A', {'updown': 0.19703555780000001}),
#  ('ZAP70', {'updown': 0}),
#  ('IDE', {'updown': 0.99814714000000004}),
#  ('SULT2A1', {'updown': 0}),
#  ('ST3GAL3', {'updown': 0.29251029989999999}),
#  ('ST3GAL2', {'updown': 0.99752269269999994}),
#  ('CSTA', {'updown': 0}),
#  ('RAC2', {'updown': 0.99478865659999993}),
#  ('RAC3', {'updown': 0.9403318369}),
#  ('ST3GAL5', {'updown': 0.2485472011}),
#  ('RAC1', {'updown': 0}),
#  ('NINJ1', {'updown': 0}),
#  ('FCGR2B', {'updown': 0}),
#  ('LNPEP', {'updown': 0.96352817299999993}),
#  ('APOE', {'updown': 0}),
#  ('SKIL', {'updown': 0}),
#  ('MED23', {'updown': 0.38586861310000004}),
#  ('GCGR', {'updown': 0}),
#  ('VASP', {'updown': 0}),
#  ('PBX2', {'updown': 0.99713242760000009}),
#  ('PBX3', {'updown': 0}),
#  ('LILRB2', {'updown': 0}),
#  ('LGMN', {'updown': 0.38076873979999998}),
#  ('CYP7B1', {'updown': 0}),
#  ('AIRE', {'updown': 0}),
#  ('SPAST', {'updown': 0.9982801562000001}),
#  ('CALCR', {'updown': 0}),
#  ('KATNB1', {'updown': 0.77352040609999995}),
#  ('AGR2', {'updown': 0}),
#  ('PRDM4', {'updown': 0.99773203060000004}),
#  ('SLC16A7', {'updown': 0}),
#  ('BACH2', {'updown': 0.99781397589999998}),
#  ('PTCH2', {'updown': 0.99805879480000004}),
#  ('CALCA', {'updown': 0}),
#  ('PTCH1', {'updown': 0}),
#  ('CMKLR1', {'updown': 0}),
#  ('PAGR1', {'updown': 0}),
#  ('LYVE1', {'updown': 0.99557219620000004}),
#  ('CKM', {'updown': 0}),
#  ('RAD9A', {'updown': 0.99635122819999988}),
#  ('KMT5A', {'updown': 0}),
#  ('CD34', {'updown': 0}),
#  ('PTGS1', {'updown': 0}),
#  ('CD36', {'updown': 0}),
#  ('POLR3F', {'updown': 0.34303287469999999}),
#  ('POLR3G', {'updown': 0}),
#  ('POLR3D', {'updown': 0.9959517578}),
#  ('POLR3E', {'updown': 0}),
#  ('POLR3B', {'updown': 0.087125057300000003}),
#  ('POLR3C', {'updown': 0.075784587599999995}),
#  ('POLR3A', {'updown': 0.0249297063}),
#  ('B3GAT3', {'updown': 0.99689128739999999}),
#  ('DAP', {'updown': 0}),
#  ('POLR3K', {'updown': 0.034658463700000003}),
#  ('POLR3H', {'updown': 0}),
#  ('DCN', {'updown': 0}),
#  ('UXT', {'updown': 0}),
#  ('GPAM', {'updown': 0}),
#  ('CALM2', {'updown': 0.2217373305}),
#  ('CALM3', {'updown': 0.022548926899999999}),
#  ('CALM1', {'updown': 0.88076637859999996}),
#  ('CACNA1A', {'updown': 0.99825463180000007}),
#  ('CACNA1B', {'updown': 0.50160294750000001}),
#  ('DNMT1', {'updown': 0}),
#  ('CACNA1D', {'updown': 0.99785891420000006}),
#  ('CACNA1F', {'updown': 0}),
#  ('THRA', {'updown': 0}),
#  ('CDX1', {'updown': 0}),
#  ('TAF4B', {'updown': 0.1060893972}),
#  ('PERP', {'updown': 0}),
#  ('CYP51A1', {'updown': 0.91963386319999996}),
#  ('GLO1', {'updown': 0.31390349350000002}),
#  ('CACNA1S', {'updown': 0}),
#  ('CUL1', {'updown': 0.89077058440000001}),
#  ('CUL3', {'updown': 0.99645262049999994}),
#  ('FCAR', {'updown': 0}),
#  ('PLK2', {'updown': 0.0010715554}),
#  ('HOXD8', {'updown': 0}),
#  ('TRIM29', {'updown': 0}),
#  ('TRIM24', {'updown': 0.99464374069999995}),
#  ('CLCN2', {'updown': 0}),
#  ('CREB5', {'updown': 0}),
#  ('PRMT1', {'updown': 0.99833412749999995}),
#  ('CLCN7', {'updown': 0}),
#  ('PRMT7', {'updown': 0.87282026730000006}),
#  ('CREB1', {'updown': 0.99764539780000006}),
#  ('PRMT5', {'updown': 0.94462042900000009}),
#  ('PER3', {'updown': 0.99696689090000001}),
#  ('BGLAP', {'updown': 0.99778569950000007}),
#  ('PER1', {'updown': 0}),
#  ('BRD4', {'updown': 0}),
#  ('BRD7', {'updown': 0}),
#  ('BRD1', {'updown': 0.99832923370000004}),
#  ('BRD2', {'updown': 0}),
#  ('CARHSP1', {'updown': 0}),
#  ('KAT8', {'updown': 0}),
#  ('DNAJA3', {'updown': 0.24466785829999999}),
#  ('DNAJA1', {'updown': 0.99746474180000011}),
#  ('ORMDL3', {'updown': 0}),
#  ('FCER2', {'updown': 0}),
#  ('PTPN13', {'updown': 0}),
#  ('PTPN12', {'updown': 0}),
#  ('KIF5B', {'updown': 0}),
#  ('NPY1R', {'updown': 0.9974435438}),
#  ('KAT5', {'updown': 0.99748895659999992}),
#  ('MASP2', {'updown': 0}),
#  ('KAT7', {'updown': 0.28386440329999996}),
#  ('GALR3', {'updown': 0}),
#  ('F2R', {'updown': 0}),
#  ('IHH', {'updown': 0}),
#  ('UTRN', {'updown': 0.99831941340000008}),
#  ('LOC101930123', {'updown': 0}),
#  ('RAD51C', {'updown': 0.074276899000000007}),
#  ('CD3D', {'updown': 0}),
#  ('CD3E', {'updown': 0}),
#  ('CH25H', {'updown': 0.95193262849999993}),
#  ('CSF2RB', {'updown': 0}),
#  ('AES', {'updown': 0.99826316519999991}),
#  ('SLBP', {'updown': 0.48781888969999998}),
#  ('DMD', {'updown': 0}),
#  ('SEH1L', {'updown': 0.1788981288}),
#  ('GNAO1', {'updown': 0.99660491559999997}),
#  ('RRAS2', {'updown': 0}),
#  ('GAB2', {'updown': 0}),
#  ('GAPDH', {'updown': 0.92906880670000003}),
#  ('HIF1A', {'updown': 0.99724356719999996}),
#  ('GAB1', {'updown': 0}),
#  ('NKX2-2', {'updown': 0}),
#  ('HAX1', {'updown': 0.94269197780000002}),
#  ('IFNGR1', {'updown': 0}),
#  ('IFNGR2', {'updown': 0.99823976030000006}),
#  ('CD200', {'updown': 0.0011286503999999998}),
#  ('NDRG1', {'updown': 0}),
#  ('NDRG2', {'updown': 0}),
#  ('CMIP', {'updown': 0.51179290079999995}),
#  ('ACADM', {'updown': 0.90773938109999996}),
#  ('SRSF5', {'updown': 0.96931200000000006}),
#  ('SRSF4', {'updown': 0}),
#  ('SRSF7', {'updown': 0.94948696870000004}),
#  ('PPM1D', {'updown': 0.99592437489999996}),
#  ('SRSF1', {'updown': 0.99821611290000012}),
#  ('HMOX1', {'updown': 0}),
#  ('SRSF3', {'updown': 0.99831650029999996}),
#  ('SRSF2', {'updown': 0.39262248100000002}),
#  ('EGR2', {'updown': 0}),
#  ('C4BPA', {'updown': 0}),
#  ('C4BPB', {'updown': 0}),
#  ('EGR1', {'updown': 0.014227599399999999}),
#  ('SRSF9', {'updown': 0.99750545180000005}),
#  ('PPARGC1A', {'updown': 0.77348753810000004}),
#  ('EGR4', {'updown': 0.79555307279999998}),
#  ('USP42', {'updown': 0}),
#  ('RAPH1', {'updown': 0.52676851769999999}),
#  ('PRLH', {'updown': 0}),
#  ('HOXA4', {'updown': 0}),
#  ('RNF135', {'updown': 0}),
#  ('CX3CL1', {'updown': 0.78434621170000007}),
#  ('HOXA3', {'updown': 0}),
#  ('MAFG', {'updown': 0}),
#  ('CHEK2', {'updown': 0}),
#  ('CHEK1', {'updown': 0}),
#  ('PRKAB2', {'updown': 0.99833183889999999}),
#  ('CDK6', {'updown': 0}),
#  ('PRKAB1', {'updown': 0.99823704299999994}),
#  ('TSHZ3', {'updown': 0.98625564010000011}),
#  ('CDK11A', {'updown': 0}),
#  ('PAX5', {'updown': 0}),
#  ('PAX4', {'updown': 0}),
#  ('PAX7', {'updown': 0}),
#  ('PAX6', {'updown': 0}),
#  ('PAX1', {'updown': 0}),
#  ('NCAPD2', {'updown': 0}),
#  ('PAX3', {'updown': 0}),
#  ('PAX2', {'updown': 0}),
#  ('PTPN2', {'updown': 0.99828420819999997}),
#  ('PTPN1', {'updown': 0.99673299910000002}),
#  ('PAXIP1', {'updown': 0}),
#  ('PAX9', {'updown': 0}),
#  ('PTPN6', {'updown': 0}),
#  ('PROK1', {'updown': 0}),
#  ('DDR2', {'updown': 0}),
#  ('ATP5PF', {'updown': 0}),
#  ('DDR1', {'updown': 0}),
#  ('CYP2E1', {'updown': 0.89679966909999997}),
#  ('EDN3', {'updown': 0}),
#  ('STUB1', {'updown': 0}),
#  ('NNMT', {'updown': 0.99829661629999999}),
#  ('EIF4EBP1', {'updown': 0}),
#  ('NPBWR2', {'updown': 0}),
#  ('EIF4EBP3', {'updown': 0}),
#  ('EIF4EBP2', {'updown': 0}),
#  ('BAG3', {'updown': 0}),
#  ('HIST2H3A', {'updown': 0}),
#  ('GRK2', {'updown': 0.98699306610000004}),
#  ('SH2D1A', {'updown': 0}),
#  ('CTDP1', {'updown': 0}),
#  ('CNTFR', {'updown': 0}),
#  ('ADAMTS13', {'updown': 0}),
#  ('AMOTL2', {'updown': 0}),
#  ('RPS3', {'updown': 0}),
#  ('ADAMTS16', {'updown': 0}),
#  ('VDAC1', {'updown': 0.0079682142000000004}),
#  ('CENPM', {'updown': 0}),
#  ('CD79B', {'updown': 0}),
#  ('MEOX1', {'updown': 0}),
#  ('BCR', {'updown': 0}),
#  ('CD79A', {'updown': 0}),
#  ('ADORA1', {'updown': 0}),
#  ('SLC34A1', {'updown': 0}),
#  ('CRTC2', {'updown': 0}),
#  ('DEF6', {'updown': 0}),
#  ('DHX58', {'updown': 0.99816142389999996}),
#  ('ZEB1', {'updown': 0}),
#  ('ZNF385A', {'updown': 0}),
#  ('LCN2', {'updown': 0}),
#  ('HOXA13', {'updown': 0}),
#  ('GPNMB', {'updown': 0}),
#  ('HOXA11', {'updown': 0}),
#  ('HOXA10', {'updown': 0}),
#  ('PPBP', {'updown': 0}),
#  ('RASGRF2', {'updown': 0.65650295209999998}),
#  ('KRT12', {'updown': 0}),
#  ('DSG2', {'updown': 0}),
#  ('USP2', {'updown': 0.99820910340000002}),
#  ('DSG4', {'updown': 0}),
#  ('CAPN2', {'updown': 0}),
#  ('HMGCS1', {'updown': 0.0035198}),
#  ('HMGCS2', {'updown': 0}),
#  ('PDHA1', {'updown': 0.27176983710000002}),
#  ('SRF', {'updown': 0.99583087339999998}),
#  ('SAP18', {'updown': 0}),
#  ('FBXO43', {'updown': 0}),
#  ('LGALS9', {'updown': 0}),
#  ('RPS6KA3', {'updown': 0.98484614329999998}),
#  ('LGALS3', {'updown': 0}),
#  ('KCNH1', {'updown': 0}),
#  ('LGALS1', {'updown': 0.99670490439999992}),
#  ('CP', {'updown': 0.99830181790000005}),
#  ('FSCN3', {'updown': 0}),
#  ('PIR', {'updown': 0}),
#  ('FSCN1', {'updown': 0.99831501579999993}),
#  ('LGALS4', {'updown': 0}),
#  ('SFRP2', {'updown': 0}),
#  ('KCNJ2', {'updown': 0}),
#  ('EPHA1', {'updown': 0}),
#  ('SFRP1', {'updown': 0}),
#  ('MYL12B', {'updown': 0.68223002919999998}),
#  ('AKIRIN1', {'updown': 0.99833080930000007}),
#  ('NUP54', {'updown': 0.72020875279999996}),
#  ('EIF2AK1', {'updown': 0.86896539019999997}),
#  ('EIF2AK3', {'updown': 0.99485349459999994}),
#  ('EIF2AK2', {'updown': 0.99775108280000002}),
#  ('EIF2AK4', {'updown': 0}),
#  ('ADRB2', {'updown': 0}),
#  ('CD247', {'updown': 0.99665491470000001}),
#  ('COL1A2', {'updown': 0}),
#  ('EREG', {'updown': 0}),
#  ('COL1A1', {'updown': 0}),
#  ('ELN', {'updown': 0}),
#  ('ASAP1', {'updown': 0.78567863090000001}),
#  ('ASAP2', {'updown': 0.99816187180000004}),
#  ('NMI', {'updown': 0.99804420769999991}),
#  ('IDO1', {'updown': 0}),
#  ('CAMK1G', {'updown': 0.22827154550000001}),
#  ('PLAUR', {'updown': 0}),
#  ('NLRP12', {'updown': 0}),
#  ('FCGR3A', {'updown': 0.995743814}),
#  ('ECM1', {'updown': 0.26806564969999996}),
#  ('FOXO3', {'updown': 0.99487968819999995}),
#  ('FOXO1', {'updown': 0}),
#  ('CD28', {'updown': 0}),
#  ('TOP1', {'updown': 0}),
#  ('FOXO4', {'updown': 0}),
#  ('ALDH1A1', {'updown': 0.81677994230000006}),
#  ('ALDH1A2', {'updown': 0}),
#  ('HIST4H4', {'updown': 0}),
#  ('PHLPP1', {'updown': 0}),
#  ('DEFB4A', {'updown': 0}),
#  ('TAC1', {'updown': 0.00097469070000000008}),
#  ('TNIK', {'updown': 0.99789934120000001}),
#  ('TAC3', {'updown': 0.22223278600000002}),
#  ('NCOA6', {'updown': 0.99450077870000009}),
#  ('SLCO4C1', {'updown': 0}),
#  ('RGS4', {'updown': 0.0001708871}),
#  ('RGS5', {'updown': 0.99601877980000009}),
#  ('RGS6', {'updown': 0.62845277129999999}),
#  ('RGS1', {'updown': 0}),
#  ('ATG5', {'updown': 0.87833197810000008}),
#  ('SOX5', {'updown': 0}),
#  ('PLAG1', {'updown': 0}),
#  ('C9orf24', {'updown': 0.99800590769999997}),
#  ('EYA2', {'updown': 0}),
#  ('SMARCB1', {'updown': 0.99829121340000004}),
#  ('UTP20', {'updown': 0.99442675530000002}),
#  ('ITGB6', {'updown': 0}),
#  ('PIGR', {'updown': 0}),
#  ('GOLGA2', {'updown': 0}),
#  ('ILKAP', {'updown': 0}),
#  ('HPN', {'updown': 0}),
#  ('WRAP53', {'updown': 0}),
#  ('EPCAM', {'updown': 0}),
#  ('TAGLN', {'updown': 0.99805143530000007}),
#  ('OSTF1', {'updown': 0.91353930040000009}),
#  ('PPP1CB', {'updown': 0.99280106310000005}),
#  ('PPP1CC', {'updown': 0}),
#  ('OLR1', {'updown': 0.9982973597}),
#  ('PPP1CA', {'updown': 0.98959568860000002}),
#  ('SRRM1', {'updown': 0.99694126849999998}),
#  ('BBIP1', {'updown': 0.99824485760000004}),
#  ('GABARAPL2', {'updown': 0.99650428019999993}),
#  ('ITGAE', {'updown': 0.99542979340000004}),
#  ('PDK2', {'updown': 0.9816131320999999}),
#  ('PDK4', {'updown': 0}),
#  ('COL6A1', {'updown': 0}),
#  ('PCLAF', {'updown': 0}),
#  ('WBP1', {'updown': 0.99781168540000009}),
#  ('COL6A2', {'updown': 0}),
#  ('DOK1', {'updown': 0}),
#  ('HAVCR2', {'updown': 0}),
#  ('ALPL', {'updown': 0.9983087826}),
#  ('PTGS2', {'updown': 0}),
#  ('PECR', {'updown': 0.7522820615000001}),
#  ('SH2B3', {'updown': 0.99719359629999993}),
#  ('FXYD1', {'updown': 0}),
#  ('ZFAND5', {'updown': 0.41998358880000003}),
#  ('MAFK', {'updown': 0}),
#  ('SV2B', {'updown': 0.37586622560000005}),
#  ('FABP5', {'updown': 0.90604704569999994}),
#  ('MAFA', {'updown': 0}),
#  ('MAFB', {'updown': 0.91462374260000001}),
#  ('PFKP', {'updown': 0}),
#  ('PLIN2', {'updown': 0}),
#  ('CDK2AP1', {'updown': 0}),
#  ('ZYX', {'updown': 0.99517350029999996}),
#  ('PLIN1', {'updown': 0}),
#  ('MED10', {'updown': 0.0425027272}),
#  ('TRERF1', {'updown': 0.99378734459999996}),
#  ('MED11', {'updown': 0}),
#  ('CCR3', {'updown': 0}),
#  ('HIF1AN', {'updown': 0.99211845340000004}),
#  ('RBPJ', {'updown': 0}),
#  ('GHRL', {'updown': 0}),
#  ('EIF1AX', {'updown': 0.96257285519999991}),
#  ('NTRK1', {'updown': 0}),
#  ('NTRK2', {'updown': 0}),
#  ('NTRK3', {'updown': 0}),
#  ('HSP90AB1', {'updown': 0.044641891699999998}),
#  ('ARHGAP22', {'updown': 0}),
#  ('COP1', {'updown': 0}),
#  ('PTP4A1', {'updown': 0.0014600876000000001}),
#  ('PTP4A3', {'updown': 0.99758811400000003}),
#  ('MED14', {'updown': 0.0062685240000000001}),
#  ('LIN37', {'updown': 0.99714246299999998}),
#  ('BLNK', {'updown': 0}),
#  ('CD8A', {'updown': 0.14974432839999999}),
#  ('KCNMB1', {'updown': 0}),
#  ('DDIT3', {'updown': 0.98503768400000002}),
#  ('DDIT4', {'updown': 0}),
#  ('MED16', {'updown': 0}),
#  ('CCR4', {'updown': 0}),
#  ('BMP6', {'updown': 0.99713603620000002}),
#  ('OPRL1', {'updown': 0.99041699750000001}),
#  ('CCR10', {'updown': 0.99164859709999997}),
#  ('IFI35', {'updown': 0}),
#  ('CD27', {'updown': 0}),
#  ('IFI30', {'updown': 0}),
#  ('VAPB', {'updown': 0.99831861189999993}),
#  ('RBP1', {'updown': 0.99831206560000008}),
#  ('RBP2', {'updown': 0}),
#  ('BMP4', {'updown': 0.99175364269999999}),
#  ('VAPA', {'updown': 0.99310297219999999}),
#  ('MYSM1', {'updown': 0.00445}),
#  ('CEBPZ', {'updown': 0}),
#  ('MBTPS2', {'updown': 9.3596810531001599e-05}),
#  ('PA2G4', {'updown': 0.032663187699999999}),
#  ('KRAS', {'updown': 0.016661298200000001}),
#  ('BMP7', {'updown': 0}),
#  ('SOCS4', {'updown': 0}),
#  ('BMP5', {'updown': 0}),
#  ('SOCS6', {'updown': 0.99405973180000007}),
#  ('SOCS1', {'updown': 0}),
#  ('BMP2', {'updown': 0}),
#  ('SOCS3', {'updown': 0}),
#  ('SOCS2', {'updown': 0.99766120400000002}),
#  ('PPP2CA', {'updown': 0.0036965121000000004}),
#  ('EIF4G2', {'updown': 0.9945829289}),
#  ('SGO1', {'updown': 0}),
#  ('PPP2CB', {'updown': 0}),
#  ('WDR59', {'updown': 0}),
#  ('ADAM9', {'updown': 0.19929085639999999}),
#  ('TERF2', {'updown': 0.94971116799999999}),
#  ('NR1I2', {'updown': 0}),
#  ('FAT1', {'updown': 0}),
#  ('TERF1', {'updown': 0.9983116178}),
#  ('ULBP2', {'updown': 0}),
#  ('DOK5', {'updown': 0.9983204979000001}),
#  ('GRB7', {'updown': 0}),
#  ('SGO2', {'updown': 0}),
#  ('DLK1', {'updown': 0}),
#  ('PSG4', {'updown': 0}),
#  ('PSG5', {'updown': 0}),
#  ('CCNH', {'updown': 0.94496686529999996}),
#  ('EIF4G1', {'updown': 0}),
#  ('CCNK', {'updown': 0.99721539530000003}),
#  ('HOXC9', {'updown': 0}),
#  ('HTR5A', {'updown': 0.0017398330999999999}),
#  ('CCR6', {'updown': 0}),
#  ('IL20RB', {'updown': 0}),
#  ('RASSF1', {'updown': 0}),
#  ('RPL7', {'updown': 0}),
#  ('HP', {'updown': 0}),
#  ('BCL2L2-PABPN1', {'updown': 0}),
#  ('LRPPRC', {'updown': 0.00076543240000000005}),
#  ('HOXC6', {'updown': 0}),
#  ('GREM1', {'updown': 0.99830329979999999}),
#  ('FEN1', {'updown': 0.68735286610000002}),
#  ('E2F8', {'updown': 0}),
#  ('THAP11', {'updown': 0.99467923569999994}),
#  ('RSAD2', {'updown': 0.98712078170000006}),
#  ('NCKAP1', {'updown': 0.86976337659999992}),
#  ('NR1I3', {'updown': 0}),
#  ('CHD3', {'updown': 0.99433077930000002}),
#  ('SLC40A1', {'updown': 0.99824552900000008}),
#  ('CHD4', {'updown': 0}),
#  ('LRRK2', {'updown': 0.6464301737}),
#  ('PTH', {'updown': 0}),
#  ('WISP2', {'updown': 0}),
#  ('CHD8', {'updown': 0}),
#  ('WISP1', {'updown': 0}),
#  ('MNT', {'updown': 0.98236621040000005}),
#  ('CCNF', {'updown': 0.99560770779999996}),
#  ('ESRRG', {'updown': 0.47063172119999996}),
#  ('SUPT16H', {'updown': 0.95975383549999993}),
#  ('GRB2', {'updown': 0.87257408609999998}),
#  ('TGFB1I1', {'updown': 0}),
#  ('IL22RA1', {'updown': 0}),
#  ('PTS', {'updown': 0.41984865659999998}),
#  ('TTC5', {'updown': 0.99804616989999995}),
#  ('OXER1', {'updown': 0}),
#  ('SLC22A5', {'updown': 0.99832656529999997}),
#  ('RAB3GAP2', {'updown': 0.68599652180000004}),
#  ('IL4R', {'updown': 0}),
#  ('BHLHA15', {'updown': 0}),
#  ('RAB3GAP1', {'updown': 0.22629240239999998}),
#  ('CDC25C', {'updown': 0}),
#  ('CDC25B', {'updown': 0}),
#  ('CDC25A', {'updown': 0}),
#  ('CCNC', {'updown': 0.00036814949999999997}),
#  ('TTC8', {'updown': 0.85310692430000012}),
#  ('ARPC5', {'updown': 0.99798152870000001}),
#  ('ARPC4', {'updown': 0.99568431040000005}),
#  ('POLR2E', {'updown': 0.94258547849999996}),
#  ('POLR2D', {'updown': 0.54856781129999999}),
#  ('POLR2G', {'updown': 0.99553612670000002}),
#  ('POLR2F', {'updown': 0}),
#  ('ANKRD23', {'updown': 0}),
#  ('DAG1', {'updown': 0}),
#  ('POLR2C', {'updown': 0.598786873}),
#  ('POLR2B', {'updown': 0.78779769790000009}),
#  ('ACO1', {'updown': 0.99786246719999994}),
#  ('POLR2L', {'updown': 0.99722735959999997}),
#  ('PTGES', {'updown': 0.9967052676}),
#  ('ITPR1', {'updown': 0.0110083874}),
#  ('POLR2I', {'updown': 0}),
#  ('POLR2K', {'updown': 0.055269834599999998}),
#  ('POLR2J', {'updown': 0}),
#  ('INHA', {'updown': 0.99534739790000004}),
#  ('IL1RN', {'updown': 0}),
#  ('ABCG2', {'updown': 0.99832564239999999}),
#  ('PRDM15', {'updown': 0.99742805489999997}),
#  ('DEPTOR', {'updown': 0.99833398890000002}),
#  ('ABCG5', {'updown': 0}),
#  ('LRIG1', {'updown': 0}),
#  ('PLSCR1', {'updown': 0.99820577970000002}),
#  ('ABCG8', {'updown': 0}),
#  ('MPO', {'updown': 0}),
#  ('MPL', {'updown': 0}),
#  ('HNF4A', {'updown': 0}),
#  ('CFTR', {'updown': 0}),
#  ('GTF3A', {'updown': 0}),
#  ('MTTP', {'updown': 0}),
#  ('SNCA', {'updown': 0.17840172930000001}),
#  ('AIFM2', {'updown': 0.99825919769999993}),
#  ('AGO4', {'updown': 0.9982490852}),
#  ('RNF125', {'updown': 0}),
#  ('AIFM1', {'updown': 0.98905266219999999}),
#  ('AGO1', {'updown': 0}),
#  ('AGO3', {'updown': 0}),
#  ('AGO2', {'updown': 0.99676700290000009}),
#  ('IL20RA', {'updown': 0}),
#  ('SOST', {'updown': 0}),
#  ('SSPN', {'updown': 0}),
#  ('HOXC8', {'updown': 0}),
#  ('ACAN', {'updown': 0}),
#  ('SLK', {'updown': 0.99744849579999995}),
#  ('HCFC1', {'updown': 0}),
#  ('CKS1B', {'updown': 0}),
#  ('MAPK14', {'updown': 0.9825553481}),
#  ('KRIT1', {'updown': 0.50019998529999998}),
#  ('FOXH1', {'updown': 0}),
#  ('MAPK10', {'updown': 0.088321367899999989}),
#  ...]

# %% [markdown]
# Our package also has a function to load your entire DEG file into a networkx graph, without filtering by p-value or fold change. This function will return a networkx graph representation of your entire specified csv file, a dictionary mapping genes to their (adj) p-values, and a dictionary mapping genes to their (log) fold change

# %% [markdown]
# ## Stat Analysis
# <a id='stat'></a>

# %% [markdown]
# Our stat_analysis package can help identify TF's that are statistically significant to our set of DEG's.

# %% [markdown]
# ### Enrichment
# <a id='pvalue'></a>

# %% [markdown]
# Given you have run the appropriate prerequisite functions, you can now start to anaylize your data! First, we check how enriched our set of TF's are. All of our p-value functions calculate the log of the p-value using [scipy.stats.hypergeom.logsf](https://docs.scipy.org/doc/scipy-0.19.1/reference/generated/scipy.stats.hypergeom.html).

# %%
# Enrichment of TF's themselves
ura.tf_enrichment_calc()   
ura.get('tf_enrichment')
# Out:
# TF_ENRICHMENT    2.780709e-11
# dtype: float64

# %% [markdown]
# Next we can check how enriched each TF's targets are.  These values help us determine which TF's are actually associated with our DEG's.
# - high value = significant connection between this TF and its DEG targets
# - low value = TF is randomly associated with its DEG targets
# - zero = None of this TF's targets were DEG's
# - inf = original p-value was so small that its log is inf. Very high significance.
#
# This function may need a minute or so.

# %%
# Enrichment of every TF with respect to its targets
ura.tf_target_enrichment_calc()
tf_target_pvalues = ura.get('tf_target_enrichment')

# %%
df = tf_target_pvalues.to_frame()
df = df.loc[df['tf-target enrichment'] != 0]
df = df.loc[df['tf-target enrichment'] != float('inf')] # removing zeros and inf's for the sake of visualization
display(df)
# Out:
#          tf-target enrichment
# AAAS             2.309941e+01
# ELL              2.060388e+01
# RAE1             2.037414e+01
# NUP50            2.019202e+01
# TPR              1.961258e+01
# RANBP2           1.775765e+01
# NUP37            1.699812e+01
# NFRKB            1.515713e+01
# NCBP2            1.477195e+01
# NUP133           1.441079e+01
# U2AF1            1.293261e+01
# U2AF2            1.293261e+01
# CPSF4            1.273250e+01
# WASL             1.258026e+01
# RNPS1            1.126125e+01
# ZC3H11A          1.126125e+01
# UPF3B            1.126125e+01
# GEMIN5           1.053579e+01
# EIF4A3           1.053579e+01
# POLDIP3          1.053579e+01
# DHX38            1.053579e+01
# CDC40            1.053579e+01
# THOC6            1.053579e+01
# THOC3            1.053579e+01
# SRSF1            1.042213e+01
# POLR2I           9.839512e+00
# NXF5             9.800805e+00
# NRF1             9.425223e+00
# DDX20            9.416200e+00
# MDC1             9.094974e+00
# ...                       ...
# EHMT1            4.184188e-03
# STAT3            4.170962e-03
# WWOX             4.092433e-03
# AHR              4.008343e-03
# STAT1            3.923468e-03
# KLF5             3.825287e-03
# FGF9             3.589625e-03
# RBPJ             3.183472e-03
# NKX2-1           2.711586e-03
# PHC3             2.553378e-03
# CBX6             2.553378e-03
# ASCL1            2.546025e-03
# SOX2             1.954638e-03
# MYD88            1.668376e-03
# NFKB1            1.591963e-03
# CBX8             1.588177e-03
# PPARG            1.287617e-03
# SNAI2            1.196759e-03
# CTF1             1.196759e-03
# LGALS3           1.112261e-03
# JUN              1.111591e-03
# IRF1             9.359312e-04
# FOXP3            8.191016e-04
# TBX21            3.097946e-04
# POU5F1           3.097946e-04
# STAT6            8.448119e-05
# CTGF             3.984136e-05
# TGFB1            4.350012e-06
# GATA3            9.101076e-08
# GPSM1            8.321204e-08
#
# [920 rows x 1 columns]

# %% [markdown]
# ### Z-score
# <a id='zscore'></a>

# %% [markdown]
# The goal of our z-score function is to predict the activation states of the TF's. We observe how a TF relates to each of its targets to make our prediction. We compare each targets' observed gene regulation (either up or down) and each TF-target interation (whether it is activating or inhibiting) to conclude whether a TF is activating or inhibiting. A positive value indicates activating while a negative value indicates inhibiting. A value of zero means that we did not have enough information about the target or TF-target interaction to make the prediction.
#
# Our z-score calculater has to calculation methods. Our method calculates how "biased" the background network is towards either activating or inhibiting interactions, then adjusts its calculations to that non-zero average. Our bias-filter parameter is a number between 0 and 1 that indicates the threshold at which the graph is considered "too biased", and therefore the bias z-score formula must be used.
#
# This function may need a minute or so.

# %%
ura.tf_zscore(bias_filter=1)
unbiased_zscores = ura.get('z_scores')
display(unbiased_zscores.to_frame())
# Out:
#           unbiased-calculated z-scores
# RANBP2                       12.609520
# NUP133                       12.609520
# NUP37                        12.288206
# XPO1                         10.049876
# PAFAH1B1                      9.433981
# CLIP1                         9.327379
# CENPA                         9.219544
# NUP50                         9.165151
# CKAP5                         9.165151
# CLASP1                        9.165151
# AHCTF1                        9.110434
# CLASP2                        9.110434
# KNTC1                         9.110434
# TPR                           9.055385
# RAE1                          9.055385
# MAD1L1                        8.954430
# AAAS                          8.944272
# ATM                           7.090547
# SHC1                          6.639528
# ELL                           6.164414
# BRCA1                         6.090777
# SOS1                          6.090777
# BUB3                          6.021972
# ABL1                          5.602794
# ESR1                          5.547002
# NCOA1                         5.385165
# ATF2                          5.357062
# CREBBP                        5.333494
# MDC1                          5.291503
# CDC20                         5.269652
# ...                                ...
# CDC6                         -2.683282
# OGT                          -2.713602
# CCNA2                        -2.722179
# PPP1R12A                     -2.828427
# CACNA2D2                     -2.897473
# BRAP                         -3.000000
# FBXO5                        -3.050851
# RBL2                         -3.050851
# CCNE1                        -3.202470
# TIA1                         -3.207135
# POLR2E                       -3.211586
# POLR2L                       -3.211586
# CCNB2                        -3.244428
# PER1                         -3.273268
# PPP2R2B                      -3.362691
# AKT3                         -3.517632
# POLR2G                       -3.655631
# AKT2                         -3.656552
# PER2                         -3.709704
# TIAL1                        -3.741657
# CACNA2D4                     -3.771711
# PPP2R2A                      -3.781177
# POLR2I                       -3.887710
# GTF2F2                       -3.889087
# PTTG1                        -4.146140
# RBL1                         -4.242641
# TBC1D1                       -4.472136
# FZR1                         -5.013774
# CCNE2                        -5.604485
# GPSM1                        -6.782330
#
# [1339 rows x 1 columns]

# %%
ura.tf_zscore(bias_filter=0)
biased_zscores = ura.get('z_scores')
display(biased_zscores.to_frame())
# Out:
# Graph has bias of 0.363124217555. Adjusting z-score calculation accordingly.
#           biased-calculated z-scores
# RANBP2                    101.263249
# NUP133                    101.263249
# NUP37                      96.168243
# XPO1                       64.324454
# PAFAH1B1                   56.681945
# CLIP1                      55.408193
# CENPA                      54.134442
# NUP50                      53.497566
# CKAP5                      53.497566
# CLASP1                     53.497566
# AHCTF1                     52.860690
# CLASP2                     52.860690
# KNTC1                      52.860690
# TPR                        52.223814
# RAE1                       52.223814
# MAD1L1                     52.045069
# AAAS                       50.950063
# ATM                        32.938795
# SHC1                       28.570038
# ELL                        24.201280
# BRCA1                      24.111907
# SOS1                       24.111907
# BUB3                       23.508833
# ABL1                       21.296286
# ESR1                       21.117541
# ATF2                       19.754416
# CREBBP                     19.396926
# NCOA1                      18.469398
# PPARGC1A                   18.201280
# MDC1                       17.832522
# ...                              ...
# PER1                      -22.625609
# IQGAP1                    -22.893727
# CCNB1                     -22.971832
# RBL1                      -24.536236
# PER2                      -24.625609
# NCBP2                     -24.703714
# GTF2F1                    -25.977466
# PTTG1                     -26.625609
# TBC1D1                    -27.262484
# CCNA2                     -31.161844
# TP53                      -31.451732
# POLR2L                    -31.709348
# POLR2E                    -31.709348
# CACNA2D4                  -32.256851
# POLR2G                    -32.983099
# GTF2F2                    -33.619975
# CCNB2                     -33.798720
# CACNA2D2                  -34.614341
# PPP2R2B                   -35.161844
# POLR2I                    -35.709348
# PTEN                      -36.156211
# PPP2R2A                   -36.435596
# CCNE1                     -36.614341
# FZR1                      -37.530602
# MYC                       -44.468633
# CCNE2                     -49.161844
# GPSM1                     -62.703714
# AKT1                      -63.909862
# AKT3                      -70.949298
# AKT2                      -77.217415
#
# [1339 rows x 1 columns]

# %% [markdown]
# ### Display Results
# <a id='display'></a>

# %% [markdown]
# Our stat_analysis module also inculdes methods to help you find the most statistically relevant TF's to your input DEG data set.
# - top_values: will display the highest activating, inhibiting, or overall values
# - rank_and_score_df: will display where an input set of genes rank among all others in terms of their z-score
# - vis_tf_network: will display an interactive network of a specified regulator and its downstream targets

# %% [markdown]
# **Top Values**
# <a id='top'></a>
#
# NOTE: Your DEG_to_pvalue and DEG_to_updown paramters should come from create_DEG_full_graph

# %%
top_act = ura.top_values(act = True, abs_value = False, top = 5)
top_inh = ura.top_values(act = False, abs_value = False, top = 5)
top_overall = ura.top_values(abs_value = True, top = 5)

print "\nTop five activating: "
display(top_act)
print "\nTop five inhibiting: "
display(top_inh)
print "\nTop five overall: "
display(top_overall)
# Out:
# Top five activating:
#              z-score  (adj) p-value  (log) fold change
# RANBP2    101.263249      -0.090858           0.975454
# NUP133    101.263249      -0.115508           0.600609
# NUP37      96.168243       0.006546           0.998296
# XPO1       64.324454       0.046577           0.997240
# PAFAH1B1   56.681945      -0.241807           0.008217
# Top five inhibiting:
#          z-score  (adj) p-value  (log) fold change
# AKT2  -77.217415       0.056609           0.978390
# AKT3  -70.949298      -0.136716           0.058052
# AKT1  -63.909862       0.099134           0.019114
# GPSM1 -62.703714       0.159024           0.010397
# CCNE2 -49.161844            NaN                NaN
# Top five overall:
#            z-score  (adj) p-value  (log) fold change
# NUP133  101.263249      -0.115508           0.600609
# RANBP2  101.263249      -0.090858           0.975454
# NUP37    96.168243       0.006546           0.998296
# AKT3    -70.949298      -0.136716           0.058052
# AKT2    -77.217415       0.056609           0.978390

# %% [markdown]
# **Rank with z-score**
# <a id='rank'></a>

# %% [markdown]
# Ranks range from 0 (best, aka strongest z-score) to whichever number is associated with a z-score of zero, in this case 47. If the remove_dups flag is set to True, any genes with the same z-score will have the same rank.

# %%
genes_to_rank = ['TAF1', 'RPL8', 'STAT1','TP53', 'ZEN2']
ura.compare_genes(genes_to_rank, anno_vert_dist=0.005)
# Out:
# RPL8 is not a valid transcription factor in our graph.
# ZEN2 is not a valid transcription factor in our graph.

# %% [markdown]
# **Network Visualization using visJS2jupyter**
# <a id='visJS'></a>
#
# If you do not already have the package visJS2jupyter, type "pip install visJS2jupyter" into your command prompt.
#
# **Node Color**:
# - yellow: regulator/TF
# - red: up-regulated tarets
# - blue: down-regulated targets
# - the stronger the gene's fold change (specified in DEG_filename), the stronger the shade of red or blue
# - white: no fold change information for this gene
#
# **Node Border**:
# - DEG's (secified by DEG_list) are outlined in black
#
# **Node Size**:
# - small: insiginificant/large adjusted p-value (taken from DEG_filename)
# - large: significant/small adjusted p-value
#
# **Edge Color**:
# - red: activating
# - blue: inhibiting
#
# **Tips**:
# - nodes look too clustered: increase node spacing to ~3000 or ~4000
# - nodes look to sparse: decrease node spacing to ~2000 or ~1000
# - directed_edges = False will center the TF
# - directed_edges = True will pull the TF off to the side

# %%
ura.vis_tf_network('STAT1',
                   directed_edges = False,
                   node_spacing = 3200,
                   color_non_DEGs = True,
                   color_map = plt.cm.bwr,
                   graph_id = 200,
                   tf_size_amplifier = 8,
                   alpha = 0.9, # opacity
                   color_vals_transform = None,
                   ceil_val = 1,
                   color_max_frac = 0.9, # percentage of color map to use, upper bound
                   color_min_frac = 0.1, # percentage of color map to use, lower bound
                   vmin = 0.3,
                   vmax = 0,
                   tf_shape = 'circle'
                   )
# Out:
# ../../ura\stat_analysis.py:522: RuntimeWarning: invalid value encountered in log
#   nts = {n: (2 + (-np.log(DEG_to_pvalue[n]))) for n in nodes if n in DEG_to_updown}  # keep only those in graph G
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file200"];    frame.runVis([{"node_shape": "circle", "degree": 3.0, "title": "BCL2L1", "color": "rgba(256, 60, 60, 0.9)", "size_field": 4.24754988216634, "y": 2852.9323387708673, "x": 2138.20584204381, "border_width": 0, "id": "BCL2L1"}, {"node_shape": "circle", "degree": 3.0, "title": "HAMP", "color": "rgba(0, 0, 256, 0.9)", "size_field": NaN, "y": 2211.9711664587026, "x": 2254.2409130364354, "border_width": 2, "id": "HAMP"}, {"node_shape": "circle", "degree": 3.0, "title": "TBX21", "color": "rgba(256, 50, 50, 0.9)", "size_field": NaN, "y": 995.1411305816482, "x": 2216.3707598422848, "border_width": 0, "id": "TBX21"}, {"node_shape": "circle", "degree": 3.0, "title": "IL6ST", "color": "rgba(0, 0, 256, 0.9)", "size_field": 4.277491493492599, "y": 1070.0546334574408, "x": 229.64319594442065, "border_width": 0, "id": "IL6ST"}, {"node_shape": "circle", "degree": 3.0, "title": "IFNAR2", "color": "rgba(0, 0, 256, 0.9)", "size_field": 5.214921909404362, "y": 767.1503972740633, "x": 1878.7283913752542, "border_width": 2, "id": "IFNAR2"}, {"node_shape": "circle", "degree": 3.0, "title": "EPO", "color": "rgba(256, 50, 50, 0.9)", "size_field": NaN, "y": 1912.4462364769317, "x": 1703.2823726386862, "border_width": 0, "id": "EPO"}, {"node_shape": "circle", "degree": 3.0, "title": "IL22", "color": "rgba(256, 50, 50, 0.9)", "size_field": NaN, "y": 923.2446838075185, "x": 2538.7511440012704, "border_width": 0, "id": "IL22"}, {"node_shape": "circle", "degree": 3.0, "title": "IL27", "color": "rgba(256, 50, 50, 0.9)", "size_field": NaN, "y": 2807.5215420702802, "x": 1299.6803034230534, "border_width": 0, "id": "IL27"}, {"node_shape": "circle", "degree": 3.0, "title": "TYK2", "color": "rgba(256, 74, 74, 0.9)", "size_field": 3.6535665857039037, "y": 1609.4051936019027, "x": 2094.6249558888626, "border_width": 0, "id": "TYK2"}, {"node_shape": "circle", "degree": 3.0, "title": "EGF", "color": "rgba(256, 50, 50, 0.9)", "size_field": NaN, "y": 2060.7684935092634, "x": 2505.6562842445187, "border_width": 0, "id": "EGF"}, {"node_shape": "circle", "degree": 3.0, "title": "IL12RB1", "color": "rgba(256, 50, 50, 0.9)", "size_field": NaN, "y": 1424.6377135410064, "x": 2338.6416201069565, "border_width": 0, "id": "IL12RB1"}, {"node_shape": "circle", "degree": 3.0, "title": "ZNF148", "color": "rgba(0, 0, 256, 0.9)", "size_field": 3.8101929046713474, "y": 957.0266724173946, "x": 3178.6515360282738, "border_width": 0, "id": "ZNF148"}, {"node_shape": "circle", "degree": 3.0, "title": "IL12RB2", "color": "rgba(256, 50, 50, 0.9)", "size_field": NaN, "y": 1359.974333029489, "x": 2077.176704310329, "border_width": 0, "id": "IL12RB2"}, {"node_shape": "circle", "degree": 3.0, "title": "FADD", "color": "rgba(0, 0, 256, 0.9)", "size_field": 5.205106180550429, "y": 441.6084518718269, "x": 377.30328961144465, "border_width": 2, "id": "FADD"}, {"node_shape": "circle", "degree": 3.0, "title": "LYN", "color": "rgba(0, 0, 256, 0.9)", "size_field": 5.373315806539202, "y": 2280.541919938949, "x": 2479.416895681762, "border_width": 2, "id": "LYN"}, {"node_shape": "circle", "degree": 3.0, "title": "IFNG", "color": "rgba(256, 50, 50, 0.9)", "size_field": NaN, "y": 1709.3788399674104, "x": 1544.549755806056, "border_width": 0, "id": "IFNG"}, {"node_shape": "circle", "degree": 3.0, "title": "CAMK2G", "color": "rgba(0, 0, 256, 0.9)", "size_field": 4.635894704789523, "y": 2016.914351688559, "x": 1563.0821517753816, "border_width": 0, "id": "CAMK2G"}, {"node_shape": "circle", "degree": 3.0, "title": "CAMK2A", "color": "rgba(0, 0, 256, 0.9)", "size_field": NaN, "y": 1732.2147621778754, "x": 793.1840045169938, "border_width": 2, "id": "CAMK2A"}, {"node_shape": "circle", "degree": 3.0, "title": "IFI30", "color": "rgba(0, 0, 256, 0.9)", "size_field": 4.2162752935524, "y": 477.053248549235, "x": 2267.46780804901, "border_wid ...

# %%
ura.vis_tf_network('STAT5A',
                   directed_edges = True,
                   node_spacing = 3000,
                   color_non_DEGs = False,
                   color_map = plt.cm.bwr,
                   graph_id = 201,
                   tf_size_amplifier = 8,
                   alpha = 1.0, 
                   color_vals_transform = None,
                   ceil_val=10,
                   color_max_frac = 1.0,
                   color_min_frac = 0.0,
                   vmin=None,
                   vmax=None,
                   tf_shape = 'circle'
                   )
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file201"];    frame.runVis([{"node_shape": "circle", "degree": 3.0, "title": "BCL2L1", "color": "grey", "size_field": 4.24754988216634, "y": 1000.7623826321037, "x": 2221.2520800282737, "border_width": 0, "id": "BCL2L1"}, {"node_shape": "circle", "degree": 3.0, "title": "SAC3D1", "color": "rgba(256, 0, 0, 1.0)", "size_field": 5.874660373207809, "y": 1379.5115570219193, "x": 736.280258772206, "border_width": 2, "id": "SAC3D1"}, {"node_shape": "circle", "degree": 3.0, "title": "GHR", "color": "grey", "size_field": NaN, "y": 1156.1112393787341, "x": 1974.9780327651176, "border_width": 0, "id": "GHR"}, {"node_shape": "circle", "degree": 3.0, "title": "DPF3", "color": "grey", "size_field": 3.9610973209394835, "y": 1302.0283602258526, "x": 591.6803073460352, "border_width": 0, "id": "DPF3"}, {"node_shape": "circle", "degree": 3.0, "title": "ZFPM1", "color": "grey", "size_field": 4.246303085752858, "y": 1744.5716448237506, "x": 205.4522439479823, "border_width": 0, "id": "ZFPM1"}, {"node_shape": "circle", "degree": 3.0, "title": "IL6ST", "color": "grey", "size_field": 4.277491493492599, "y": 1131.0624533607415, "x": 2593.893078582035, "border_width": 0, "id": "IL6ST"}, {"node_shape": "circle", "degree": 3.0, "title": "EPO", "color": "grey", "size_field": NaN, "y": 1384.97638858239, "x": 1465.935765436763, "border_width": 0, "id": "EPO"}, {"node_shape": "circle", "degree": 3.0, "title": "IL22", "color": "grey", "size_field": NaN, "y": 1360.8686013617264, "x": 2412.983426451795, "border_width": 0, "id": "IL22"}, {"node_shape": "circle", "degree": 3.0, "title": "IL27", "color": "grey", "size_field": NaN, "y": 1102.834326454951, "x": 2129.4670426090047, "border_width": 0, "id": "IL27"}, {"node_shape": "circle", "degree": 3.0, "title": "TYK2", "color": "grey", "size_field": 3.6535665857039037, "y": 609.941556523024, "x": 2578.546895218933, "border_width": 0, "id": "TYK2"}, {"node_shape": "circle", "degree": 3.0, "title": "SLC30A2", "color": "grey", "size_field": NaN, "y": 907.3442956205539, "x": 2391.7526916459533, "border_width": 0, "id": "SLC30A2"}, {"node_shape": "circle", "degree": 3.0, "title": "IL12RB1", "color": "grey", "size_field": NaN, "y": 1911.640089415932, "x": 1690.6298217547164, "border_width": 0, "id": "IL12RB1"}, {"node_shape": "circle", "degree": 3.0, "title": "PRL", "color": "grey", "size_field": NaN, "y": 305.7537134958026, "x": 2597.5932024461144, "border_width": 0, "id": "PRL"}, {"node_shape": "circle", "degree": 3.0, "title": "IL12RB2", "color": "grey", "size_field": NaN, "y": 973.4455308198734, "x": 1185.4501897939904, "border_width": 0, "id": "IL12RB2"}, {"node_shape": "circle", "degree": 3.0, "title": "CDH1", "color": "grey", "size_field": NaN, "y": 1204.817070309049, "x": 2331.000772050307, "border_width": 0, "id": "CDH1"}, {"node_shape": "circle", "degree": 3.0, "title": "OSM", "color": "grey", "size_field": NaN, "y": 2335.6146948932223, "x": 1664.5401759654467, "border_width": 0, "id": "OSM"}, {"node_shape": "circle", "degree": 3.0, "title": "LYN", "color": "rgba(256, 0, 0, 1.0)", "size_field": 5.373315806539202, "y": 1657.224954288343, "x": 1836.9253922664684, "border_width": 2, "id": "LYN"}, {"node_shape": "circle", "degree": 3.0, "title": "ERBB4", "color": "rgba(256, 52, 52, 1.0)", "size_field": NaN, "y": 2304.2948743510333, "x": 1894.40002757993, "border_width": 2, "id": "ERBB4"}, {"node_shape": "circle", "degree": 3.0, "title": "IFNG", "color": "grey", "size_field": NaN, "y": 1365.1741792037658, "x": 1716.5284886515087, "border_width": 0, "id": "IFNG"}, {"node_shape": "circle", "degree": 3.0, "title": "FASLG", "color": "grey", "size_field": NaN, "y": 0.0, "x": 3000.0, "border_width": 0, "id": "FASLG"}, {"node_shape": "circle", "degree": 3.0, "title": "CXCL12", "color": "rgba(256, 2, 2, 1.0)", "size_field": NaN, "y": 1892.592441562491, "x" ...

# %% [markdown]
# Last but not least, you have the option to write out all of the TF's, their targets, (adj) p-values, (log) fold change, and enrichment information to a tab-separated csv file.

# %%
#ura.to_csv(out_filename = 'example_basic.txt')
